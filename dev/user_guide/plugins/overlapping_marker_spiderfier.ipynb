# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b30e56e65d62eb32d76b21b27197ad6c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b30e56e65d62eb32d76b21b27197ad6c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b30e56e65d62eb32d76b21b27197ad6c = L.map(
#                 &quot;map_b30e56e65d62eb32d76b21b27197ad6c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_79bebbfb1a9cb5b1595999cebdd1685b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_79bebbfb1a9cb5b1595999cebdd1685b.addTo(map_b30e56e65d62eb32d76b21b27197ad6c);
#
#
#             var marker_2d91c4b12c5389c85bfc3e094e9178ff = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b30e56e65d62eb32d76b21b27197ad6c);
#
#
#         var popup_eb9b8a23937914c66098256ec570154f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d642ddec865c33067309ec68489528f = $(`&lt;div id=&quot;html_5d642ddec865c33067309ec68489528f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_eb9b8a23937914c66098256ec570154f.setContent(html_5d642ddec865c33067309ec68489528f);
#
#
#
#         marker_2d91c4b12c5389c85bfc3e094e9178ff.bindPopup(popup_eb9b8a23937914c66098256ec570154f)
#         ;
#
#
#
#
#             var marker_2cebaf541acb2fe5389f051a86271a24 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b30e56e65d62eb32d76b21b27197ad6c);
#
#
#         var popup_f0698fdada7ae0ca27a44e4994e91d8f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_56d28e3e8bb1aa87d1f1cf41bee14242 = $(`&lt;div id=&quot;html_56d28e3e8bb1aa87d1f1cf41bee14242&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f0698fdada7ae0ca27a44e4994e91d8f.setContent(html_56d28e3e8bb1aa87d1f1cf41bee14242);
#
#
#
#         marker_2cebaf541acb2fe5389f051a86271a24.bindPopup(popup_f0698fdada7ae0ca27a44e4994e91d8f)
#         ;
#
#
#
#
#             var marker_bf5b01194d9aa1f85874f882d4e3261d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b30e56e65d62eb32d76b21b27197ad6c);
#
#
#         var popup_92014501a4f479e69668ef86a82733d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_217e2e32e0a6a1c6dd04a04017707ee2 = $(`&lt;div id=&quot;html_217e2e32e0a6a1c6dd04a04017707ee2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_92014501a4f479e69668ef86a82733d5.setContent(html_217e2e32e0a6a1c6dd04a04017707ee2);
#
#
#
#         marker_bf5b01194d9aa1f85874f882d4e3261d.bindPopup(popup_92014501a4f479e69668ef86a82733d5)
#         ;
#
#
#
#
#             var marker_bd6f7c64e38a0bd35e9111b6beae213c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b30e56e65d62eb32d76b21b27197ad6c);
#
#
#         var popup_c89bc4801a5b5ee7604adcf57005e86f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cae251c6e6e089006e30b5d980628df9 = $(`&lt;div id=&quot;html_cae251c6e6e089006e30b5d980628df9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c89bc4801a5b5ee7604adcf57005e86f.setContent(html_cae251c6e6e089006e30b5d980628df9);
#
#
#
#         marker_bd6f7c64e38a0bd35e9111b6beae213c.bindPopup(popup_c89bc4801a5b5ee7604adcf57005e86f)
#         ;
#
#
#
#
#             var marker_9a7ef5515f9ad212f234735ff8f38a19 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b30e56e65d62eb32d76b21b27197ad6c);
#
#
#         var popup_a80977f2dd56bf1377fcf4de99ed1c9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86f9f95e6b297a7c3b4d3da5033a55e2 = $(`&lt;div id=&quot;html_86f9f95e6b297a7c3b4d3da5033a55e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a80977f2dd56bf1377fcf4de99ed1c9b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_05af23ac88bf26a0d0c49103dc3a16c8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_05af23ac88bf26a0d0c49103dc3a16c8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_05af23ac88bf26a0d0c49103dc3a16c8 = L.map(
#                 &quot;map_05af23ac88bf26a0d0c49103dc3a16c8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_39e79b447f262e9eb44db247481c37b8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_39e79b447f262e9eb44db247481c37b8.addTo(map_05af23ac88bf26a0d0c49103dc3a16c8);
#
#
#             var feature_group_7f0d149a82457319210a744b924a20c8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8a67f0e48052c9b0628832df6f91040b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7f0d149a82457319210a744b924a20c8);
#
#
#         var popup_b8b41826ec29ebb5574e5c88a8ce491a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2fd82538393996bfb800288cd130f70 = $(`&lt;div id=&quot;html_c2fd82538393996bfb800288cd130f70&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b8b41826ec29ebb5574e5c88a8ce491a.setContent(html_c2fd82538393996bfb800288cd130f70);
#
#
#
#         marker_8a67f0e48052c9b0628832df6f91040b.bindPopup(popup_b8b41826ec29ebb5574e5c88a8ce491a)
#         ;
#
#
#
#
#             var marker_03c7d7358a9790ce43a80a342979270d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7f0d149a82457319210a744b924a20c8);
#
#
#         var popup_c62f73ab507879c49ab233c16b242b6e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5439ff19f046577aa9424b581f80365a = $(`&lt;div id=&quot;html_5439ff19f046577aa9424b581f80365a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c62f73ab507879c49ab233c16b242b6e.setContent(html_5439ff19f046577aa9424b581f80365a);
#
#
#
#         marker_03c7d7358a9790ce43a80a342979270d.bindPopup(popup_c62f73ab507879c49ab233c16b242b6e)
#         ;
#
#
#
#
#             var marker_890c8de35280f8917c68336b51238622 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7f0d149a82457319210a744b924a20c8);
#
#
#         var popup_7cf27b97e8a813f4f69f30e1f7630b52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb284dbbb1780505d162ccff6966a624 = $(`&lt;div id=&quot;html_cb284dbbb1780505d162ccff6966a624&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_7cf27b97e8a813f4f69f30e1f7630b52.setContent(html_cb284dbbb1780505d162ccff6966a624);
#
#
#
#         marker_890c8de35280f8917c68336b51238622.bindPopup(popup_7cf27b97e8a813f4f69f30e1f7630b52)
#         ;
#
#
#
#
#             var marker_31a480142d9df3db5bb67805fd5343eb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7f0d149a82457319210a744b924a20c8);
#
#
#         var popup_46c3ab06b5e0f7d66fce10c11429c2c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3245fa7b19dccbf9dbcae06b6c9e271 = $(`&lt;div id=&quot;html_d3245fa7b19dccbf9dbcae06b6c9e271&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_46c3ab06b5e0f7d66fce10c11429c2c7.setContent(html_d3245fa7b19dccbf9dbcae06b6c9e271);
#
#
#
#         marker_31a480142d9df3db5bb67805fd5343eb.bindPopup(popup_46c3ab06b5e0f7d66fce10c11429c2c7)
#         ;
#
#
#
#
#             var marker_032fb7574748b17512eb217ec18c1b59 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7f0d149a82457319210a744b924a20c8);
#
#
#         var popup_ff046496872321d9d8fde17a3e2ac8b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ddcd9d8f769615621c36d3484a399613 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ddcd9d8f769615621c36d3484a399613&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ddcd9d8f769615621c36d3484a399613 = L.map(
#                 &quot;map_ddcd9d8f769615621c36d3484a399613&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_362b9ffffd56444ded94a7fcfb39ba26 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_362b9ffffd56444ded94a7fcfb39ba26.addTo(map_ddcd9d8f769615621c36d3484a399613);
#
#
#             var feature_group_bb66d193fc07c623ebf55a2a02f853ac = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_bb66d193fc07c623ebf55a2a02f853ac.addTo(map_ddcd9d8f769615621c36d3484a399613);
#
#
#             var feature_group_sub_group_70937503ddbc78a0afb3ef1c2b07b39d = L.featureGroup.subGroup(
#                 feature_group_bb66d193fc07c623ebf55a2a02f853ac
#             );
#
#
#             var marker_532399eaec8eb17ec04e900eebbbb529 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_70937503ddbc78a0afb3ef1c2b07b39d);
#
#
#         var popup_ed09484c0e6ebbe7e30afa66652bbbcb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf98e72aa0631c5da00df4360ee5f89a = $(`&lt;div id=&quot;html_cf98e72aa0631c5da00df4360ee5f89a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ed09484c0e6ebbe7e30afa66652bbbcb.setContent(html_cf98e72aa0631c5da00df4360ee5f89a);
#
#
#
#         marker_532399eaec8eb17ec04e900eebbbb529.bindPopup(popup_ed09484c0e6ebbe7e30afa66652bbbcb)
#         ;
#
#
#
#
#             var marker_7260e46590ae41ee20f35482e6cdff67 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_70937503ddbc78a0afb3ef1c2b07b39d);
#
#
#         var popup_e6e0b9d5e3bee5b42e5d47afe9fd60c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f341e1e7ca2003a55e8cec988761177b = $(`&lt;div id=&quot;html_f341e1e7ca2003a55e8cec988761177b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e6e0b9d5e3bee5b42e5d47afe9fd60c9.setContent(html_f341e1e7ca2003a55e8cec988761177b);
#
#
#
#         marker_7260e46590ae41ee20f35482e6cdff67.bindPopup(popup_e6e0b9d5e3bee5b42e5d47afe9fd60c9)
#         ;
#
#
#
#
#             var marker_140877b7a4a00ea6b1fc5d27da81c16a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_70937503ddbc78a0afb3ef1c2b07b39d);
#
#
#         var popup_c5e0b1c4896e9144874b7f0ad5c09a2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48f63b0db1331662e7f5dc95e92581e8 = $(`&lt;div id=&quot;html_48f63b0db1331662e7f5dc95e92581e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c5e0b1c4896e9144874b7f0ad5c09a2a.setContent(html_48f63b0db1331662e7f5dc95e92581e8);
#
#
#
#         marker_140877b7a4a00ea6b1fc5d27da81c16a.bindPopup(popup_c5e0b1c4896e9144874b7f0ad5c09a2a)
#         ;
#
#
#
#
#             var marker_53282cf8c22f3293ffa1f5b4a7ef074e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_70937503ddbc78a0afb3ef1c2b07b39d);
#
#
#         var popup_fdea8823b28cca69c725d7d0b385da06 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c15ad16fe171828b9ec21827b872d08 = $(`&lt;div id=&quot;html_7c15ad16fe171828b9ec21827b872d08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_fdea8823b28cca69c725d7d0b385da06.setContent(html_7c15ad16fe171828b9ec21827b872d08);
#
#
#
#         marker_
