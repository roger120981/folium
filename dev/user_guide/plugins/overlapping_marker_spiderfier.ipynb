# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_19cd3ade4b2374e95b24eafe8a09d2ba {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_19cd3ade4b2374e95b24eafe8a09d2ba&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_19cd3ade4b2374e95b24eafe8a09d2ba = L.map(
#                 &quot;map_19cd3ade4b2374e95b24eafe8a09d2ba&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_643a1c60749f79016669fcc61ba91d94 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_643a1c60749f79016669fcc61ba91d94.addTo(map_19cd3ade4b2374e95b24eafe8a09d2ba);
#
#
#             var marker_a28b68aa4df0d3ea92ab161cdd8d9729 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_19cd3ade4b2374e95b24eafe8a09d2ba);
#
#
#         var popup_1200b362d4b4286bdc686fc0e67dd44f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d759a75c8b7850ded3b4429939ed9e2 = $(`&lt;div id=&quot;html_1d759a75c8b7850ded3b4429939ed9e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1200b362d4b4286bdc686fc0e67dd44f.setContent(html_1d759a75c8b7850ded3b4429939ed9e2);
#
#
#
#         marker_a28b68aa4df0d3ea92ab161cdd8d9729.bindPopup(popup_1200b362d4b4286bdc686fc0e67dd44f)
#         ;
#
#
#
#
#             var marker_62e789ccad7215f5e9a3ef25415cdefd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_19cd3ade4b2374e95b24eafe8a09d2ba);
#
#
#         var popup_c31a77ebf2e9a22be0ffa6375a8a0d79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1570e933b78fa0840b90bbe92a294407 = $(`&lt;div id=&quot;html_1570e933b78fa0840b90bbe92a294407&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c31a77ebf2e9a22be0ffa6375a8a0d79.setContent(html_1570e933b78fa0840b90bbe92a294407);
#
#
#
#         marker_62e789ccad7215f5e9a3ef25415cdefd.bindPopup(popup_c31a77ebf2e9a22be0ffa6375a8a0d79)
#         ;
#
#
#
#
#             var marker_e3ba71cdb124661f4a6e283f6b175965 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_19cd3ade4b2374e95b24eafe8a09d2ba);
#
#
#         var popup_1ae55de3a5e350653e6453325fd8c4c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_011d29ca58624041c31a197546f84418 = $(`&lt;div id=&quot;html_011d29ca58624041c31a197546f84418&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_1ae55de3a5e350653e6453325fd8c4c4.setContent(html_011d29ca58624041c31a197546f84418);
#
#
#
#         marker_e3ba71cdb124661f4a6e283f6b175965.bindPopup(popup_1ae55de3a5e350653e6453325fd8c4c4)
#         ;
#
#
#
#
#             var marker_37901d05b3e6e05c5f9f0bad753a0d55 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_19cd3ade4b2374e95b24eafe8a09d2ba);
#
#
#         var popup_60ec776a6c45cb334b5d443a9846748f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8d1820e5acc8a9ef5d0a834fc07a248 = $(`&lt;div id=&quot;html_b8d1820e5acc8a9ef5d0a834fc07a248&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_60ec776a6c45cb334b5d443a9846748f.setContent(html_b8d1820e5acc8a9ef5d0a834fc07a248);
#
#
#
#         marker_37901d05b3e6e05c5f9f0bad753a0d55.bindPopup(popup_60ec776a6c45cb334b5d443a9846748f)
#         ;
#
#
#
#
#             var marker_4749959fb8182f2d882f4f4c9d908474 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_19cd3ade4b2374e95b24eafe8a09d2ba);
#
#
#         var popup_00fae5e55fc39835d008692f8f9897bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67b375e7d78aa93235cdc461ba2b5d9c = $(`&lt;div id=&quot;html_67b375e7d78aa93235cdc461ba2b5d9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_00fae5e55fc39835d008692f8f9897bd.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c0ef8a8d62d0b42b7d9502627a3cc1b6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c0ef8a8d62d0b42b7d9502627a3cc1b6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c0ef8a8d62d0b42b7d9502627a3cc1b6 = L.map(
#                 &quot;map_c0ef8a8d62d0b42b7d9502627a3cc1b6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4d0efd5a09cd43365992903ca783fad7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4d0efd5a09cd43365992903ca783fad7.addTo(map_c0ef8a8d62d0b42b7d9502627a3cc1b6);
#
#
#             var feature_group_99dfb6a298dcbfb84d67736c09005ea6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1658381ebd90fc24387e40f8b7dd5481 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_99dfb6a298dcbfb84d67736c09005ea6);
#
#
#         var popup_038c8850e55ae52111142ff5ce32c270 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0518669e23998f98cdf6df39f36a5a38 = $(`&lt;div id=&quot;html_0518669e23998f98cdf6df39f36a5a38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_038c8850e55ae52111142ff5ce32c270.setContent(html_0518669e23998f98cdf6df39f36a5a38);
#
#
#
#         marker_1658381ebd90fc24387e40f8b7dd5481.bindPopup(popup_038c8850e55ae52111142ff5ce32c270)
#         ;
#
#
#
#
#             var marker_15af219a6f92ab01f1a5ef72dc57e719 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_99dfb6a298dcbfb84d67736c09005ea6);
#
#
#         var popup_04012dad7fc73ad78461630a183ab29e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3762d0c49989967b6563e7c44dcd08c = $(`&lt;div id=&quot;html_a3762d0c49989967b6563e7c44dcd08c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_04012dad7fc73ad78461630a183ab29e.setContent(html_a3762d0c49989967b6563e7c44dcd08c);
#
#
#
#         marker_15af219a6f92ab01f1a5ef72dc57e719.bindPopup(popup_04012dad7fc73ad78461630a183ab29e)
#         ;
#
#
#
#
#             var marker_3236f3315b86fdeea8df4386a3308001 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_99dfb6a298dcbfb84d67736c09005ea6);
#
#
#         var popup_96fbeb7f83ae937b0e25159f5116d87e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_993992e0b83a84b6f8e4109f9d5cac61 = $(`&lt;div id=&quot;html_993992e0b83a84b6f8e4109f9d5cac61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_96fbeb7f83ae937b0e25159f5116d87e.setContent(html_993992e0b83a84b6f8e4109f9d5cac61);
#
#
#
#         marker_3236f3315b86fdeea8df4386a3308001.bindPopup(popup_96fbeb7f83ae937b0e25159f5116d87e)
#         ;
#
#
#
#
#             var marker_27f6fa4c5139e40edb00387b175aca88 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_99dfb6a298dcbfb84d67736c09005ea6);
#
#
#         var popup_9d8b1b5cf8c1d049424157aab2292cca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93e17df89f66b5f0571a50f0ec7a7279 = $(`&lt;div id=&quot;html_93e17df89f66b5f0571a50f0ec7a7279&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9d8b1b5cf8c1d049424157aab2292cca.setContent(html_93e17df89f66b5f0571a50f0ec7a7279);
#
#
#
#         marker_27f6fa4c5139e40edb00387b175aca88.bindPopup(popup_9d8b1b5cf8c1d049424157aab2292cca)
#         ;
#
#
#
#
#             var marker_1fee5cb07899f0a1e56efd3e599c66d9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_99dfb6a298dcbfb84d67736c09005ea6);
#
#
#         var popup_5ea4b3a6ae034f40f424135534c242d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f9323e2e6ea666da6512cae62aba9577 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f9323e2e6ea666da6512cae62aba9577&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f9323e2e6ea666da6512cae62aba9577 = L.map(
#                 &quot;map_f9323e2e6ea666da6512cae62aba9577&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_49956364ff97259a701cf75f371831e1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_49956364ff97259a701cf75f371831e1.addTo(map_f9323e2e6ea666da6512cae62aba9577);
#
#
#             var feature_group_e0a19f4db05362a036c3faa553530be4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e0a19f4db05362a036c3faa553530be4.addTo(map_f9323e2e6ea666da6512cae62aba9577);
#
#
#             var feature_group_sub_group_d940ea0ea95a1633e671751b0fd1f31a = L.featureGroup.subGroup(
#                 feature_group_e0a19f4db05362a036c3faa553530be4
#             );
#
#
#             var marker_2c6e270733020b6e0fb895651e223261 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d940ea0ea95a1633e671751b0fd1f31a);
#
#
#         var popup_0b30e22df107c754276fc55ab2cc66ec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad1a86cb665b957d13337b56a80e1e67 = $(`&lt;div id=&quot;html_ad1a86cb665b957d13337b56a80e1e67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0b30e22df107c754276fc55ab2cc66ec.setContent(html_ad1a86cb665b957d13337b56a80e1e67);
#
#
#
#         marker_2c6e270733020b6e0fb895651e223261.bindPopup(popup_0b30e22df107c754276fc55ab2cc66ec)
#         ;
#
#
#
#
#             var marker_a5390ab6afbd3a2c1aa55c745a4d8a5e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d940ea0ea95a1633e671751b0fd1f31a);
#
#
#         var popup_34d320cbfacb3091ea4dfdd9e737c8b6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b1a3b734262f0e6bff15861495881aa3 = $(`&lt;div id=&quot;html_b1a3b734262f0e6bff15861495881aa3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_34d320cbfacb3091ea4dfdd9e737c8b6.setContent(html_b1a3b734262f0e6bff15861495881aa3);
#
#
#
#         marker_a5390ab6afbd3a2c1aa55c745a4d8a5e.bindPopup(popup_34d320cbfacb3091ea4dfdd9e737c8b6)
#         ;
#
#
#
#
#             var marker_090b374720e76390ddcc6eb62311880f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d940ea0ea95a1633e671751b0fd1f31a);
#
#
#         var popup_c19c59114791d0db568d1e4091b789a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f792923d2ea61b819d879a478d285b9 = $(`&lt;div id=&quot;html_9f792923d2ea61b819d879a478d285b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c19c59114791d0db568d1e4091b789a4.setContent(html_9f792923d2ea61b819d879a478d285b9);
#
#
#
#         marker_090b374720e76390ddcc6eb62311880f.bindPopup(popup_c19c59114791d0db568d1e4091b789a4)
#         ;
#
#
#
#
#             var marker_422f7968ed81aab005a6315be8f1233c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d940ea0ea95a1633e671751b0fd1f31a);
#
#
#         var popup_d902a64ab0f255cc72c8ceb54a3bb48a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3338ee092684f9c2536bf640bfab7560 = $(`&lt;div id=&quot;html_3338ee092684f9c2536bf640bfab7560&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d902a64ab0f255cc72c8ceb54a3bb48a.setContent(html_3338ee092684f9c2536bf640bfab7560);
#
#
#
#         marker_
