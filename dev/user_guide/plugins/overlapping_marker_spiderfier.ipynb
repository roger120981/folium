# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e4a072311ce263b550fc88f658ce40b1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e4a072311ce263b550fc88f658ce40b1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e4a072311ce263b550fc88f658ce40b1 = L.map(
#                 &quot;map_e4a072311ce263b550fc88f658ce40b1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3204a17a73bcdb1747792b5c16abe55c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3204a17a73bcdb1747792b5c16abe55c.addTo(map_e4a072311ce263b550fc88f658ce40b1);
#
#
#             var marker_b2b648ee902f2d5732d9eb5d375c6c50 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e4a072311ce263b550fc88f658ce40b1);
#
#
#         var popup_3006c7f33bfb57e47d41725872483fbe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c37ca6e99457ea1003f56da3af9f5cfe = $(`&lt;div id=&quot;html_c37ca6e99457ea1003f56da3af9f5cfe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_3006c7f33bfb57e47d41725872483fbe.setContent(html_c37ca6e99457ea1003f56da3af9f5cfe);
#
#
#
#         marker_b2b648ee902f2d5732d9eb5d375c6c50.bindPopup(popup_3006c7f33bfb57e47d41725872483fbe)
#         ;
#
#
#
#
#             var marker_b588412ee103a5b561f766e4516643ed = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e4a072311ce263b550fc88f658ce40b1);
#
#
#         var popup_85522bf646817c044ef36b39ad31e3ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca6b70085b24b0976eee775a2af50c36 = $(`&lt;div id=&quot;html_ca6b70085b24b0976eee775a2af50c36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_85522bf646817c044ef36b39ad31e3ed.setContent(html_ca6b70085b24b0976eee775a2af50c36);
#
#
#
#         marker_b588412ee103a5b561f766e4516643ed.bindPopup(popup_85522bf646817c044ef36b39ad31e3ed)
#         ;
#
#
#
#
#             var marker_969298b6569e3c54ff2f26e5b8a20293 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e4a072311ce263b550fc88f658ce40b1);
#
#
#         var popup_2c5f74c55903e0dd0f4d40a2d0fed543 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da1de9ad8e2ac181693c6a8a2f88cb69 = $(`&lt;div id=&quot;html_da1de9ad8e2ac181693c6a8a2f88cb69&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_2c5f74c55903e0dd0f4d40a2d0fed543.setContent(html_da1de9ad8e2ac181693c6a8a2f88cb69);
#
#
#
#         marker_969298b6569e3c54ff2f26e5b8a20293.bindPopup(popup_2c5f74c55903e0dd0f4d40a2d0fed543)
#         ;
#
#
#
#
#             var marker_aa78e484d80272e314284daf0962f7ea = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e4a072311ce263b550fc88f658ce40b1);
#
#
#         var popup_6500033d419d7cbfaa5b7d8fb2747df9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c46a4dc12acf7143868c4ecf8d38004 = $(`&lt;div id=&quot;html_4c46a4dc12acf7143868c4ecf8d38004&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6500033d419d7cbfaa5b7d8fb2747df9.setContent(html_4c46a4dc12acf7143868c4ecf8d38004);
#
#
#
#         marker_aa78e484d80272e314284daf0962f7ea.bindPopup(popup_6500033d419d7cbfaa5b7d8fb2747df9)
#         ;
#
#
#
#
#             var marker_865c84666ef0a00d13ec0a8df014c7fa = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e4a072311ce263b550fc88f658ce40b1);
#
#
#         var popup_d20e9f7fe8b7593a2b010b534c7344d3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b7cce249d4e59cba10078fedb7edd0c8 = $(`&lt;div id=&quot;html_b7cce249d4e59cba10078fedb7edd0c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d20e9f7fe8b7593a2b010b534c7344d3.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9fb7406ef155c8310d07c3aa4f64eca1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9fb7406ef155c8310d07c3aa4f64eca1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9fb7406ef155c8310d07c3aa4f64eca1 = L.map(
#                 &quot;map_9fb7406ef155c8310d07c3aa4f64eca1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_808eee57347e3eb355ef74ac9be40059 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_808eee57347e3eb355ef74ac9be40059.addTo(map_9fb7406ef155c8310d07c3aa4f64eca1);
#
#
#             var feature_group_b0d26699e53d00edfbd16dbd317ae779 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5948d1173c2310c5122d3b7b6490a165 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b0d26699e53d00edfbd16dbd317ae779);
#
#
#         var popup_2c0ad2f871a52fac035c3a63f4debf86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02d11353938a75b0e4c2f1b383555330 = $(`&lt;div id=&quot;html_02d11353938a75b0e4c2f1b383555330&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2c0ad2f871a52fac035c3a63f4debf86.setContent(html_02d11353938a75b0e4c2f1b383555330);
#
#
#
#         marker_5948d1173c2310c5122d3b7b6490a165.bindPopup(popup_2c0ad2f871a52fac035c3a63f4debf86)
#         ;
#
#
#
#
#             var marker_d1fe048bd68b109dfc044cc6c56f1f68 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b0d26699e53d00edfbd16dbd317ae779);
#
#
#         var popup_22553740a552642f4cae386b5674931d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3f31227f8ce0a749257aecf33fb33a1b = $(`&lt;div id=&quot;html_3f31227f8ce0a749257aecf33fb33a1b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_22553740a552642f4cae386b5674931d.setContent(html_3f31227f8ce0a749257aecf33fb33a1b);
#
#
#
#         marker_d1fe048bd68b109dfc044cc6c56f1f68.bindPopup(popup_22553740a552642f4cae386b5674931d)
#         ;
#
#
#
#
#             var marker_75fe63351468f49613c2f1fc04df7b39 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b0d26699e53d00edfbd16dbd317ae779);
#
#
#         var popup_98b4c3ad2708a263008ccee57710fdfb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eefd8cdc26f9ee50254b3b8fb9495ca8 = $(`&lt;div id=&quot;html_eefd8cdc26f9ee50254b3b8fb9495ca8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_98b4c3ad2708a263008ccee57710fdfb.setContent(html_eefd8cdc26f9ee50254b3b8fb9495ca8);
#
#
#
#         marker_75fe63351468f49613c2f1fc04df7b39.bindPopup(popup_98b4c3ad2708a263008ccee57710fdfb)
#         ;
#
#
#
#
#             var marker_81f8fecd11bba273195cf4d63886a0ac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b0d26699e53d00edfbd16dbd317ae779);
#
#
#         var popup_9902c48d89b3023f816eeeb0c7a0767d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00e114409065f4b772018eca29ef4360 = $(`&lt;div id=&quot;html_00e114409065f4b772018eca29ef4360&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_9902c48d89b3023f816eeeb0c7a0767d.setContent(html_00e114409065f4b772018eca29ef4360);
#
#
#
#         marker_81f8fecd11bba273195cf4d63886a0ac.bindPopup(popup_9902c48d89b3023f816eeeb0c7a0767d)
#         ;
#
#
#
#
#             var marker_199b47830b5b6faef1272b5c4d7bf3ec = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b0d26699e53d00edfbd16dbd317ae779);
#
#
#         var popup_74fdc6f2811fc8c77922d02f5a632899 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e1d3255ee4d6f9abfa75b512db2fd83b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e1d3255ee4d6f9abfa75b512db2fd83b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e1d3255ee4d6f9abfa75b512db2fd83b = L.map(
#                 &quot;map_e1d3255ee4d6f9abfa75b512db2fd83b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_49d5a7cc0f77f9ccc17899668a21823e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_49d5a7cc0f77f9ccc17899668a21823e.addTo(map_e1d3255ee4d6f9abfa75b512db2fd83b);
#
#
#             var feature_group_1bcbc64641a0d2a809e18da5b01f31f7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_1bcbc64641a0d2a809e18da5b01f31f7.addTo(map_e1d3255ee4d6f9abfa75b512db2fd83b);
#
#
#             var feature_group_sub_group_1b69621f9838409609a29d63fc38ca32 = L.featureGroup.subGroup(
#                 feature_group_1bcbc64641a0d2a809e18da5b01f31f7
#             );
#
#
#             var marker_caa974d49e284163be656a675ea6d7db = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1b69621f9838409609a29d63fc38ca32);
#
#
#         var popup_a598b36329b126e7669358c92e5bcb09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d912c7cf57e7f08aa8d78305ce4882d0 = $(`&lt;div id=&quot;html_d912c7cf57e7f08aa8d78305ce4882d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a598b36329b126e7669358c92e5bcb09.setContent(html_d912c7cf57e7f08aa8d78305ce4882d0);
#
#
#
#         marker_caa974d49e284163be656a675ea6d7db.bindPopup(popup_a598b36329b126e7669358c92e5bcb09)
#         ;
#
#
#
#
#             var marker_69e87556d9a8d10e40e83ae39715320c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1b69621f9838409609a29d63fc38ca32);
#
#
#         var popup_aec93950721f6a1f97f0efc09fb91e28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d12e65fee942728fc6bf7d6354e6ae19 = $(`&lt;div id=&quot;html_d12e65fee942728fc6bf7d6354e6ae19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_aec93950721f6a1f97f0efc09fb91e28.setContent(html_d12e65fee942728fc6bf7d6354e6ae19);
#
#
#
#         marker_69e87556d9a8d10e40e83ae39715320c.bindPopup(popup_aec93950721f6a1f97f0efc09fb91e28)
#         ;
#
#
#
#
#             var marker_958a9b3d7e87ab7c93d62008b5bd45b3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1b69621f9838409609a29d63fc38ca32);
#
#
#         var popup_7c9390c0c81789298810765de444ae71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4fd02b99badc21089a080c406cda9a64 = $(`&lt;div id=&quot;html_4fd02b99badc21089a080c406cda9a64&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_7c9390c0c81789298810765de444ae71.setContent(html_4fd02b99badc21089a080c406cda9a64);
#
#
#
#         marker_958a9b3d7e87ab7c93d62008b5bd45b3.bindPopup(popup_7c9390c0c81789298810765de444ae71)
#         ;
#
#
#
#
#             var marker_1328253589df20ae4cd8fa7edb7cc989 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1b69621f9838409609a29d63fc38ca32);
#
#
#         var popup_c4e84374f9a2fa46baab394e963ef29a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7246bec66fb41a62ffabe5a9a244a0e7 = $(`&lt;div id=&quot;html_7246bec66fb41a62ffabe5a9a244a0e7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c4e84374f9a2fa46baab394e963ef29a.setContent(html_7246bec66fb41a62ffabe5a9a244a0e7);
#
#
#
#         marker_
