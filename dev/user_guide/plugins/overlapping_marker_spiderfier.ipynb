# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a2fd4eff68ed6990caaaa96b0bafefdf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a2fd4eff68ed6990caaaa96b0bafefdf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a2fd4eff68ed6990caaaa96b0bafefdf = L.map(
#                 &quot;map_a2fd4eff68ed6990caaaa96b0bafefdf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e5897071450fa2e3ae5aedee28380796 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e5897071450fa2e3ae5aedee28380796.addTo(map_a2fd4eff68ed6990caaaa96b0bafefdf);
#
#
#             var marker_54cfbfc6cd63cda611d5f71d19b1fc40 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a2fd4eff68ed6990caaaa96b0bafefdf);
#
#
#         var popup_4594dd592e19e93aaf2cb53bd3c65ee3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9802963dc5be9261e8ecf6ce794f0d66 = $(`&lt;div id=&quot;html_9802963dc5be9261e8ecf6ce794f0d66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_4594dd592e19e93aaf2cb53bd3c65ee3.setContent(html_9802963dc5be9261e8ecf6ce794f0d66);
#
#
#
#         marker_54cfbfc6cd63cda611d5f71d19b1fc40.bindPopup(popup_4594dd592e19e93aaf2cb53bd3c65ee3)
#         ;
#
#
#
#
#             var marker_9892d76265da51ce9e8dd70f75ad27ea = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a2fd4eff68ed6990caaaa96b0bafefdf);
#
#
#         var popup_5d049700156d50159ab3dba7a9e1e2de = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33df3573a9dde4ec4b1f51808e2b15cd = $(`&lt;div id=&quot;html_33df3573a9dde4ec4b1f51808e2b15cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5d049700156d50159ab3dba7a9e1e2de.setContent(html_33df3573a9dde4ec4b1f51808e2b15cd);
#
#
#
#         marker_9892d76265da51ce9e8dd70f75ad27ea.bindPopup(popup_5d049700156d50159ab3dba7a9e1e2de)
#         ;
#
#
#
#
#             var marker_a1062d29ec31ec24a42f8da39e5b5527 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a2fd4eff68ed6990caaaa96b0bafefdf);
#
#
#         var popup_7ded9113fddbf25104a9f32db4e46911 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ccf114993483294cb3e102713deca6c8 = $(`&lt;div id=&quot;html_ccf114993483294cb3e102713deca6c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7ded9113fddbf25104a9f32db4e46911.setContent(html_ccf114993483294cb3e102713deca6c8);
#
#
#
#         marker_a1062d29ec31ec24a42f8da39e5b5527.bindPopup(popup_7ded9113fddbf25104a9f32db4e46911)
#         ;
#
#
#
#
#             var marker_fb20bc936591c17cdef7ed3d7beec02e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a2fd4eff68ed6990caaaa96b0bafefdf);
#
#
#         var popup_6975b5919ebd59e45e56820b66099e61 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb0093cb8d0d2e6de84718891128386d = $(`&lt;div id=&quot;html_cb0093cb8d0d2e6de84718891128386d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6975b5919ebd59e45e56820b66099e61.setContent(html_cb0093cb8d0d2e6de84718891128386d);
#
#
#
#         marker_fb20bc936591c17cdef7ed3d7beec02e.bindPopup(popup_6975b5919ebd59e45e56820b66099e61)
#         ;
#
#
#
#
#             var marker_1737cd270cbeb43a7fbe5761ff0c6cde = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a2fd4eff68ed6990caaaa96b0bafefdf);
#
#
#         var popup_f59e8129c10fb77df42ed8cdcce715a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ceb87af8bbe5e0c9da84d8d6fa185c1a = $(`&lt;div id=&quot;html_ceb87af8bbe5e0c9da84d8d6fa185c1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f59e8129c10fb77df42ed8cdcce715a9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_104d74bc87729323780cef2a66656061 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_104d74bc87729323780cef2a66656061&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_104d74bc87729323780cef2a66656061 = L.map(
#                 &quot;map_104d74bc87729323780cef2a66656061&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_45039d63c079a42d68b72d84d0dc804a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_45039d63c079a42d68b72d84d0dc804a.addTo(map_104d74bc87729323780cef2a66656061);
#
#
#             var feature_group_b41d45b5b953ed66780a5d151defaad3 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f633da9d9106caf2ce9843ca5c4851ae = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b41d45b5b953ed66780a5d151defaad3);
#
#
#         var popup_79241ae825c5eb9c6ca2fa903be644f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82361d28d272a8c7042decc0a3f4a558 = $(`&lt;div id=&quot;html_82361d28d272a8c7042decc0a3f4a558&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_79241ae825c5eb9c6ca2fa903be644f4.setContent(html_82361d28d272a8c7042decc0a3f4a558);
#
#
#
#         marker_f633da9d9106caf2ce9843ca5c4851ae.bindPopup(popup_79241ae825c5eb9c6ca2fa903be644f4)
#         ;
#
#
#
#
#             var marker_09e9fcb0d918d963d5ebc40b270a4d10 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b41d45b5b953ed66780a5d151defaad3);
#
#
#         var popup_6517a25f0156600531b93e7cbd17bad3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf6d6dea0891cf97daeafa4e36b1ff11 = $(`&lt;div id=&quot;html_bf6d6dea0891cf97daeafa4e36b1ff11&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6517a25f0156600531b93e7cbd17bad3.setContent(html_bf6d6dea0891cf97daeafa4e36b1ff11);
#
#
#
#         marker_09e9fcb0d918d963d5ebc40b270a4d10.bindPopup(popup_6517a25f0156600531b93e7cbd17bad3)
#         ;
#
#
#
#
#             var marker_9cbfe162840d093d6f24b0dcb15aaf3d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b41d45b5b953ed66780a5d151defaad3);
#
#
#         var popup_e1594ff9155cff0b454c163df9a67bde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb437200fd3b7e3d30a712f5a77e6df0 = $(`&lt;div id=&quot;html_fb437200fd3b7e3d30a712f5a77e6df0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e1594ff9155cff0b454c163df9a67bde.setContent(html_fb437200fd3b7e3d30a712f5a77e6df0);
#
#
#
#         marker_9cbfe162840d093d6f24b0dcb15aaf3d.bindPopup(popup_e1594ff9155cff0b454c163df9a67bde)
#         ;
#
#
#
#
#             var marker_903ef30b6713d87b94d9b81910c35418 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b41d45b5b953ed66780a5d151defaad3);
#
#
#         var popup_62e0b9547572ee50e15c29f9759858fb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc5581ae15cc70c79e029ef8686b0dba = $(`&lt;div id=&quot;html_dc5581ae15cc70c79e029ef8686b0dba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_62e0b9547572ee50e15c29f9759858fb.setContent(html_dc5581ae15cc70c79e029ef8686b0dba);
#
#
#
#         marker_903ef30b6713d87b94d9b81910c35418.bindPopup(popup_62e0b9547572ee50e15c29f9759858fb)
#         ;
#
#
#
#
#             var marker_d9664a3faba41d14cc2ca7ff750c8b4e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b41d45b5b953ed66780a5d151defaad3);
#
#
#         var popup_ea32cdb3d968231febb80ddfc47cccfc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4c08dfa57ed582613202d731f7e97aa5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4c08dfa57ed582613202d731f7e97aa5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4c08dfa57ed582613202d731f7e97aa5 = L.map(
#                 &quot;map_4c08dfa57ed582613202d731f7e97aa5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_279f6922647603b4068533c021ec70ba = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_279f6922647603b4068533c021ec70ba.addTo(map_4c08dfa57ed582613202d731f7e97aa5);
#
#
#             var feature_group_6cb62b6fae75b5e778b7f1871a27bf4c = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6cb62b6fae75b5e778b7f1871a27bf4c.addTo(map_4c08dfa57ed582613202d731f7e97aa5);
#
#
#             var feature_group_sub_group_b5760146cd0df9e43b7c6f8a79e841e9 = L.featureGroup.subGroup(
#                 feature_group_6cb62b6fae75b5e778b7f1871a27bf4c
#             );
#
#
#             var marker_0009020d2250d100bc7e4a2ec7151e49 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_b5760146cd0df9e43b7c6f8a79e841e9);
#
#
#         var popup_f21ea0375f62ff220698ed7e72ff6fc0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77362710f9d7f20943af9f3692897609 = $(`&lt;div id=&quot;html_77362710f9d7f20943af9f3692897609&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f21ea0375f62ff220698ed7e72ff6fc0.setContent(html_77362710f9d7f20943af9f3692897609);
#
#
#
#         marker_0009020d2250d100bc7e4a2ec7151e49.bindPopup(popup_f21ea0375f62ff220698ed7e72ff6fc0)
#         ;
#
#
#
#
#             var marker_a9ddbbc8d5ca162e0d8d14b10cf548b5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_b5760146cd0df9e43b7c6f8a79e841e9);
#
#
#         var popup_a1a5b988801d7fb1b0af8c2aeb99d235 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5ba20bc911e411e8ecc834b42644ab5 = $(`&lt;div id=&quot;html_d5ba20bc911e411e8ecc834b42644ab5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a1a5b988801d7fb1b0af8c2aeb99d235.setContent(html_d5ba20bc911e411e8ecc834b42644ab5);
#
#
#
#         marker_a9ddbbc8d5ca162e0d8d14b10cf548b5.bindPopup(popup_a1a5b988801d7fb1b0af8c2aeb99d235)
#         ;
#
#
#
#
#             var marker_033d57144921240155bbea9be3445f6a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_b5760146cd0df9e43b7c6f8a79e841e9);
#
#
#         var popup_0817dd7de4a6c865fc901fbc8e86a115 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_85dd003628b0cd390046710b5421eeec = $(`&lt;div id=&quot;html_85dd003628b0cd390046710b5421eeec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0817dd7de4a6c865fc901fbc8e86a115.setContent(html_85dd003628b0cd390046710b5421eeec);
#
#
#
#         marker_033d57144921240155bbea9be3445f6a.bindPopup(popup_0817dd7de4a6c865fc901fbc8e86a115)
#         ;
#
#
#
#
#             var marker_3a46c63b459b39370d66ed2a0c709689 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_b5760146cd0df9e43b7c6f8a79e841e9);
#
#
#         var popup_346f648ccbfebf24433cb43d0005768f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93ad120b49793c4d016dc6c7ad1a96b8 = $(`&lt;div id=&quot;html_93ad120b49793c4d016dc6c7ad1a96b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_346f648ccbfebf24433cb43d0005768f.setContent(html_93ad120b49793c4d016dc6c7ad1a96b8);
#
#
#
#         marker_
