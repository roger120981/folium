# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1beecbe03e9dbd64159474d9af28452c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1beecbe03e9dbd64159474d9af28452c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1beecbe03e9dbd64159474d9af28452c = L.map(
#                 &quot;map_1beecbe03e9dbd64159474d9af28452c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6ecae55dea40d2490b38ff6678573a99 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6ecae55dea40d2490b38ff6678573a99.addTo(map_1beecbe03e9dbd64159474d9af28452c);
#
#
#             var marker_80539b84ba6f530e944abad0c63d31a6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1beecbe03e9dbd64159474d9af28452c);
#
#
#         var popup_7f86fac28c18118eb16267bcbfe98167 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0df851bba97a3ab0cf61da7c5b0be4bb = $(`&lt;div id=&quot;html_0df851bba97a3ab0cf61da7c5b0be4bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_7f86fac28c18118eb16267bcbfe98167.setContent(html_0df851bba97a3ab0cf61da7c5b0be4bb);
#
#
#
#         marker_80539b84ba6f530e944abad0c63d31a6.bindPopup(popup_7f86fac28c18118eb16267bcbfe98167)
#         ;
#
#
#
#
#             var marker_7f5cc6a3d46682ef261d868edb9a8691 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1beecbe03e9dbd64159474d9af28452c);
#
#
#         var popup_e1d73f58b1fb674c4f81ff7fc8af22ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a794c97b75e37d3fc1457d061f619c2a = $(`&lt;div id=&quot;html_a794c97b75e37d3fc1457d061f619c2a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e1d73f58b1fb674c4f81ff7fc8af22ef.setContent(html_a794c97b75e37d3fc1457d061f619c2a);
#
#
#
#         marker_7f5cc6a3d46682ef261d868edb9a8691.bindPopup(popup_e1d73f58b1fb674c4f81ff7fc8af22ef)
#         ;
#
#
#
#
#             var marker_3baaac7238dd850678d6cd4ea24943d4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1beecbe03e9dbd64159474d9af28452c);
#
#
#         var popup_a782c47e550d9f90a380eb1738204025 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d1ff93669ad742c8d72e9f9eecea8352 = $(`&lt;div id=&quot;html_d1ff93669ad742c8d72e9f9eecea8352&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a782c47e550d9f90a380eb1738204025.setContent(html_d1ff93669ad742c8d72e9f9eecea8352);
#
#
#
#         marker_3baaac7238dd850678d6cd4ea24943d4.bindPopup(popup_a782c47e550d9f90a380eb1738204025)
#         ;
#
#
#
#
#             var marker_c633e38f3b92ce26f36a296e09f43b32 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1beecbe03e9dbd64159474d9af28452c);
#
#
#         var popup_149c645849043777add14b370c7e2e33 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb8d323c3db127ddb067c64dedac1381 = $(`&lt;div id=&quot;html_cb8d323c3db127ddb067c64dedac1381&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_149c645849043777add14b370c7e2e33.setContent(html_cb8d323c3db127ddb067c64dedac1381);
#
#
#
#         marker_c633e38f3b92ce26f36a296e09f43b32.bindPopup(popup_149c645849043777add14b370c7e2e33)
#         ;
#
#
#
#
#             var marker_2b3b6a5929586041f0f0210dda771573 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1beecbe03e9dbd64159474d9af28452c);
#
#
#         var popup_f21244950566aceb1c614ace9fb49767 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22b13b753bb5f9b3ffedfc6bda43ea01 = $(`&lt;div id=&quot;html_22b13b753bb5f9b3ffedfc6bda43ea01&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f21244950566aceb1c614ace9fb49767.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2cd987c596bd5da17b41fec6246f7ee1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2cd987c596bd5da17b41fec6246f7ee1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2cd987c596bd5da17b41fec6246f7ee1 = L.map(
#                 &quot;map_2cd987c596bd5da17b41fec6246f7ee1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9a090461ee0a9c4e0e1494d7e7530322 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9a090461ee0a9c4e0e1494d7e7530322.addTo(map_2cd987c596bd5da17b41fec6246f7ee1);
#
#
#             var feature_group_fc8ac8424dd55fb2c28fe9a2cf264388 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_0617071f5afea35de5fa1557fd300d28 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fc8ac8424dd55fb2c28fe9a2cf264388);
#
#
#         var popup_f1c47f936d8eb5c67760cb120f6df201 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4873ca5ab05e38d461d697e6445cfd0 = $(`&lt;div id=&quot;html_d4873ca5ab05e38d461d697e6445cfd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f1c47f936d8eb5c67760cb120f6df201.setContent(html_d4873ca5ab05e38d461d697e6445cfd0);
#
#
#
#         marker_0617071f5afea35de5fa1557fd300d28.bindPopup(popup_f1c47f936d8eb5c67760cb120f6df201)
#         ;
#
#
#
#
#             var marker_ce2311ff4a36ea8338cb10ea16834e78 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fc8ac8424dd55fb2c28fe9a2cf264388);
#
#
#         var popup_de7e318a5bb0e52fc3ccba98312bca29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_55e3de17d6c1e56d5327b5c5a7ff3cf4 = $(`&lt;div id=&quot;html_55e3de17d6c1e56d5327b5c5a7ff3cf4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_de7e318a5bb0e52fc3ccba98312bca29.setContent(html_55e3de17d6c1e56d5327b5c5a7ff3cf4);
#
#
#
#         marker_ce2311ff4a36ea8338cb10ea16834e78.bindPopup(popup_de7e318a5bb0e52fc3ccba98312bca29)
#         ;
#
#
#
#
#             var marker_66c90298c480079666815cd589ba5040 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fc8ac8424dd55fb2c28fe9a2cf264388);
#
#
#         var popup_f84190f253ebc7ebc72a3625275c4d75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b8d8fe5ee6d9424275e99b87016f1792 = $(`&lt;div id=&quot;html_b8d8fe5ee6d9424275e99b87016f1792&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f84190f253ebc7ebc72a3625275c4d75.setContent(html_b8d8fe5ee6d9424275e99b87016f1792);
#
#
#
#         marker_66c90298c480079666815cd589ba5040.bindPopup(popup_f84190f253ebc7ebc72a3625275c4d75)
#         ;
#
#
#
#
#             var marker_90969d0781efaaa96d9a605f187c32d6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fc8ac8424dd55fb2c28fe9a2cf264388);
#
#
#         var popup_458d49855549fd29293ca438e4052062 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18e238704c87ec78f0d37895898a7037 = $(`&lt;div id=&quot;html_18e238704c87ec78f0d37895898a7037&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_458d49855549fd29293ca438e4052062.setContent(html_18e238704c87ec78f0d37895898a7037);
#
#
#
#         marker_90969d0781efaaa96d9a605f187c32d6.bindPopup(popup_458d49855549fd29293ca438e4052062)
#         ;
#
#
#
#
#             var marker_ecfaaef8ccfd50986315ab41d22af3f6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fc8ac8424dd55fb2c28fe9a2cf264388);
#
#
#         var popup_ded0133394186904967a7ef9a066dd9e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5f30ac0d4f8fcd15fd11f00e46ebf460 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5f30ac0d4f8fcd15fd11f00e46ebf460&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5f30ac0d4f8fcd15fd11f00e46ebf460 = L.map(
#                 &quot;map_5f30ac0d4f8fcd15fd11f00e46ebf460&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_84e77d57d217d49d288df01916db19d8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_84e77d57d217d49d288df01916db19d8.addTo(map_5f30ac0d4f8fcd15fd11f00e46ebf460);
#
#
#             var feature_group_a76d30a6b06b614ffce802a9a51034fe = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_a76d30a6b06b614ffce802a9a51034fe.addTo(map_5f30ac0d4f8fcd15fd11f00e46ebf460);
#
#
#             var feature_group_sub_group_3b2079b7086fda5ae6ae8dbdcf2a54b3 = L.featureGroup.subGroup(
#                 feature_group_a76d30a6b06b614ffce802a9a51034fe
#             );
#
#
#             var marker_6fc6cce568628838b2bf4c40b5ae1597 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3b2079b7086fda5ae6ae8dbdcf2a54b3);
#
#
#         var popup_4a862e6959ee55560428ba531d551606 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8435a1a98f6b38763224bb6b8faaa8f9 = $(`&lt;div id=&quot;html_8435a1a98f6b38763224bb6b8faaa8f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_4a862e6959ee55560428ba531d551606.setContent(html_8435a1a98f6b38763224bb6b8faaa8f9);
#
#
#
#         marker_6fc6cce568628838b2bf4c40b5ae1597.bindPopup(popup_4a862e6959ee55560428ba531d551606)
#         ;
#
#
#
#
#             var marker_4fdcf18abc003b55d70c9018b5213d0b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3b2079b7086fda5ae6ae8dbdcf2a54b3);
#
#
#         var popup_89dae55ffc5f60adc2c39dd8be7026f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_457cc8464b1dffadc106d6b7d71ed465 = $(`&lt;div id=&quot;html_457cc8464b1dffadc106d6b7d71ed465&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_89dae55ffc5f60adc2c39dd8be7026f7.setContent(html_457cc8464b1dffadc106d6b7d71ed465);
#
#
#
#         marker_4fdcf18abc003b55d70c9018b5213d0b.bindPopup(popup_89dae55ffc5f60adc2c39dd8be7026f7)
#         ;
#
#
#
#
#             var marker_b6af1196b1be88543fc47a20895141a7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3b2079b7086fda5ae6ae8dbdcf2a54b3);
#
#
#         var popup_a9317f29154c59479be3079523b85755 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c8047428e6d5a21205c50e2cdb20f6d1 = $(`&lt;div id=&quot;html_c8047428e6d5a21205c50e2cdb20f6d1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a9317f29154c59479be3079523b85755.setContent(html_c8047428e6d5a21205c50e2cdb20f6d1);
#
#
#
#         marker_b6af1196b1be88543fc47a20895141a7.bindPopup(popup_a9317f29154c59479be3079523b85755)
#         ;
#
#
#
#
#             var marker_f5457bed8423aa0ddeaa91dcb235b84e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3b2079b7086fda5ae6ae8dbdcf2a54b3);
#
#
#         var popup_d50ed2524eba3a6432ffb25f4bf5292f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a98fbd08e3e2e6b155f4df92fef582bc = $(`&lt;div id=&quot;html_a98fbd08e3e2e6b155f4df92fef582bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d50ed2524eba3a6432ffb25f4bf5292f.setContent(html_a98fbd08e3e2e6b155f4df92fef582bc);
#
#
#
#         marker_
