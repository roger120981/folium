# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_67030a4472100531550ab43aaced5069 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_67030a4472100531550ab43aaced5069&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_67030a4472100531550ab43aaced5069 = L.map(
#                 &quot;map_67030a4472100531550ab43aaced5069&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dfa78265e6369b7f73f99152e41c4f34 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dfa78265e6369b7f73f99152e41c4f34.addTo(map_67030a4472100531550ab43aaced5069);
#
#
#             var marker_1bf4a161af50bcbaa48fd4e558e5aecb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_67030a4472100531550ab43aaced5069);
#
#
#         var popup_a99c1a5bf8f626a93249d4809a8bfaf8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62c5db217e3c1292fa7197da5cc61753 = $(`&lt;div id=&quot;html_62c5db217e3c1292fa7197da5cc61753&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a99c1a5bf8f626a93249d4809a8bfaf8.setContent(html_62c5db217e3c1292fa7197da5cc61753);
#
#
#
#         marker_1bf4a161af50bcbaa48fd4e558e5aecb.bindPopup(popup_a99c1a5bf8f626a93249d4809a8bfaf8)
#         ;
#
#
#
#
#             var marker_fc12b2230bb49d6c91add75faf2b4b2f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_67030a4472100531550ab43aaced5069);
#
#
#         var popup_6fb591d5295b16b3a3203f39291eaf95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09ae64b3003b529bbfa76c4e41f3fe1d = $(`&lt;div id=&quot;html_09ae64b3003b529bbfa76c4e41f3fe1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6fb591d5295b16b3a3203f39291eaf95.setContent(html_09ae64b3003b529bbfa76c4e41f3fe1d);
#
#
#
#         marker_fc12b2230bb49d6c91add75faf2b4b2f.bindPopup(popup_6fb591d5295b16b3a3203f39291eaf95)
#         ;
#
#
#
#
#             var marker_4d354f3da1fb1443c0a2b0e74fd29df4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_67030a4472100531550ab43aaced5069);
#
#
#         var popup_60bb6d99138d652026f32a97dfef38ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_186f4d28823e2e575ecec4265a5b8f16 = $(`&lt;div id=&quot;html_186f4d28823e2e575ecec4265a5b8f16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_60bb6d99138d652026f32a97dfef38ae.setContent(html_186f4d28823e2e575ecec4265a5b8f16);
#
#
#
#         marker_4d354f3da1fb1443c0a2b0e74fd29df4.bindPopup(popup_60bb6d99138d652026f32a97dfef38ae)
#         ;
#
#
#
#
#             var marker_65597449262e8db7cc8e30e59ab260c0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_67030a4472100531550ab43aaced5069);
#
#
#         var popup_691f89523c5f3b46992555f866543c17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a78f74c955f50130108ce227e39199d4 = $(`&lt;div id=&quot;html_a78f74c955f50130108ce227e39199d4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_691f89523c5f3b46992555f866543c17.setContent(html_a78f74c955f50130108ce227e39199d4);
#
#
#
#         marker_65597449262e8db7cc8e30e59ab260c0.bindPopup(popup_691f89523c5f3b46992555f866543c17)
#         ;
#
#
#
#
#             var marker_87fdc211bccad58c79ae184acf2321da = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_67030a4472100531550ab43aaced5069);
#
#
#         var popup_4daef8a0b9e51aaa7ccbf08a6a08cffa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e0a91482007ea0f55119960b328f187 = $(`&lt;div id=&quot;html_0e0a91482007ea0f55119960b328f187&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4daef8a0b9e51aaa7ccbf08a6a08cffa.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_800635e88f926169318a8b415ad93a2d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_800635e88f926169318a8b415ad93a2d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_800635e88f926169318a8b415ad93a2d = L.map(
#                 &quot;map_800635e88f926169318a8b415ad93a2d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9dcb5f9fba1e6797e30b96e0de0bdc40 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9dcb5f9fba1e6797e30b96e0de0bdc40.addTo(map_800635e88f926169318a8b415ad93a2d);
#
#
#             var feature_group_291a1ae1d6452e4e289a08a3c45fbbbd = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c0bd73f01ebe811521c2df48b906decd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_291a1ae1d6452e4e289a08a3c45fbbbd);
#
#
#         var popup_0577bbf36fe9f7aacea9bd938423db2f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff07ca489ad2e76b921411257d836842 = $(`&lt;div id=&quot;html_ff07ca489ad2e76b921411257d836842&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_0577bbf36fe9f7aacea9bd938423db2f.setContent(html_ff07ca489ad2e76b921411257d836842);
#
#
#
#         marker_c0bd73f01ebe811521c2df48b906decd.bindPopup(popup_0577bbf36fe9f7aacea9bd938423db2f)
#         ;
#
#
#
#
#             var marker_6d7e304eb80e0cc6497ff0e8e79caf57 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_291a1ae1d6452e4e289a08a3c45fbbbd);
#
#
#         var popup_df261b0b629e7d0241967ca99de4bfee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1be96ada8bc652d8913622874cc15eed = $(`&lt;div id=&quot;html_1be96ada8bc652d8913622874cc15eed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_df261b0b629e7d0241967ca99de4bfee.setContent(html_1be96ada8bc652d8913622874cc15eed);
#
#
#
#         marker_6d7e304eb80e0cc6497ff0e8e79caf57.bindPopup(popup_df261b0b629e7d0241967ca99de4bfee)
#         ;
#
#
#
#
#             var marker_dfb2b5549f0ffdc73c2b5c95e69fcecd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_291a1ae1d6452e4e289a08a3c45fbbbd);
#
#
#         var popup_b2baf92725a4a178d1496f5183b11b18 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b0a379baf6f1652312cd897e81c3262 = $(`&lt;div id=&quot;html_6b0a379baf6f1652312cd897e81c3262&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b2baf92725a4a178d1496f5183b11b18.setContent(html_6b0a379baf6f1652312cd897e81c3262);
#
#
#
#         marker_dfb2b5549f0ffdc73c2b5c95e69fcecd.bindPopup(popup_b2baf92725a4a178d1496f5183b11b18)
#         ;
#
#
#
#
#             var marker_d2dc54420e7432f2ecf88ee8166f3fd7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_291a1ae1d6452e4e289a08a3c45fbbbd);
#
#
#         var popup_ce40edd5e2f3177315545c07205cc86f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_196ee91750a4ce6bd2caff62c42ca5fd = $(`&lt;div id=&quot;html_196ee91750a4ce6bd2caff62c42ca5fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ce40edd5e2f3177315545c07205cc86f.setContent(html_196ee91750a4ce6bd2caff62c42ca5fd);
#
#
#
#         marker_d2dc54420e7432f2ecf88ee8166f3fd7.bindPopup(popup_ce40edd5e2f3177315545c07205cc86f)
#         ;
#
#
#
#
#             var marker_cf653bada05b4ead5d160e8efb6079d7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_291a1ae1d6452e4e289a08a3c45fbbbd);
#
#
#         var popup_dd522215b54ab57e7db87c3c77fa4eea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0df2dc2aa03d8dcea40379ae978582cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0df2dc2aa03d8dcea40379ae978582cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0df2dc2aa03d8dcea40379ae978582cd = L.map(
#                 &quot;map_0df2dc2aa03d8dcea40379ae978582cd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cdbf0b6b07ba553d515121e89f01003e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cdbf0b6b07ba553d515121e89f01003e.addTo(map_0df2dc2aa03d8dcea40379ae978582cd);
#
#
#             var feature_group_c3800e350762e6e67343c7fcdc40840b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c3800e350762e6e67343c7fcdc40840b.addTo(map_0df2dc2aa03d8dcea40379ae978582cd);
#
#
#             var feature_group_sub_group_1e3001bd766c22b44b347c583b6d42bb = L.featureGroup.subGroup(
#                 feature_group_c3800e350762e6e67343c7fcdc40840b
#             );
#
#
#             var marker_c5140b171b104acabcd215b8138b7057 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1e3001bd766c22b44b347c583b6d42bb);
#
#
#         var popup_7294d5b351e2b7c64b5bd5f76a401b75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3d6e300b9eeef3efa51816a3a2fe49ef = $(`&lt;div id=&quot;html_3d6e300b9eeef3efa51816a3a2fe49ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_7294d5b351e2b7c64b5bd5f76a401b75.setContent(html_3d6e300b9eeef3efa51816a3a2fe49ef);
#
#
#
#         marker_c5140b171b104acabcd215b8138b7057.bindPopup(popup_7294d5b351e2b7c64b5bd5f76a401b75)
#         ;
#
#
#
#
#             var marker_9965948d906060d0dc7667ebc6058d84 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1e3001bd766c22b44b347c583b6d42bb);
#
#
#         var popup_23056e58d11408d2d2faa18472bc29a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02bf9bbd08cc19ad7210b1d4f3035bcc = $(`&lt;div id=&quot;html_02bf9bbd08cc19ad7210b1d4f3035bcc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_23056e58d11408d2d2faa18472bc29a3.setContent(html_02bf9bbd08cc19ad7210b1d4f3035bcc);
#
#
#
#         marker_9965948d906060d0dc7667ebc6058d84.bindPopup(popup_23056e58d11408d2d2faa18472bc29a3)
#         ;
#
#
#
#
#             var marker_e0cc5f388d920b226e738626c44a5175 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1e3001bd766c22b44b347c583b6d42bb);
#
#
#         var popup_52d840eb1e3974c450123ef9617f0016 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c580ca5ff8960985156b4a0706169b27 = $(`&lt;div id=&quot;html_c580ca5ff8960985156b4a0706169b27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_52d840eb1e3974c450123ef9617f0016.setContent(html_c580ca5ff8960985156b4a0706169b27);
#
#
#
#         marker_e0cc5f388d920b226e738626c44a5175.bindPopup(popup_52d840eb1e3974c450123ef9617f0016)
#         ;
#
#
#
#
#             var marker_3e968aeccd4bc3b31a57f835b2f2db11 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1e3001bd766c22b44b347c583b6d42bb);
#
#
#         var popup_d417907bb7cfa8eba42603c72aebd13d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1d7b62c614b4a999d5ddada15bb5c70e = $(`&lt;div id=&quot;html_1d7b62c614b4a999d5ddada15bb5c70e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d417907bb7cfa8eba42603c72aebd13d.setContent(html_1d7b62c614b4a999d5ddada15bb5c70e);
#
#
#
#         marker_
