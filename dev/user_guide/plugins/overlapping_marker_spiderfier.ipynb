# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3decfaf8eb1a94daf3a8fc2be5ca1781 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3decfaf8eb1a94daf3a8fc2be5ca1781&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3decfaf8eb1a94daf3a8fc2be5ca1781 = L.map(
#                 &quot;map_3decfaf8eb1a94daf3a8fc2be5ca1781&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_17b7d727bed63e760cae83bd34695150 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_17b7d727bed63e760cae83bd34695150.addTo(map_3decfaf8eb1a94daf3a8fc2be5ca1781);
#
#
#             var marker_5b7f1463c1c2de63c185a79a3b405454 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3decfaf8eb1a94daf3a8fc2be5ca1781);
#
#
#         var popup_f3f4a6718efba03e6f7db573fc89228f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5671e65a7ded1dc1b01f1b5d65ff907b = $(`&lt;div id=&quot;html_5671e65a7ded1dc1b01f1b5d65ff907b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f3f4a6718efba03e6f7db573fc89228f.setContent(html_5671e65a7ded1dc1b01f1b5d65ff907b);
#
#
#
#         marker_5b7f1463c1c2de63c185a79a3b405454.bindPopup(popup_f3f4a6718efba03e6f7db573fc89228f)
#         ;
#
#
#
#
#             var marker_e68c04b18956d9a4e81a56769bda0266 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3decfaf8eb1a94daf3a8fc2be5ca1781);
#
#
#         var popup_46fd98f8a976dbca2f27d871abc3c29f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b8edc159f492ca2e2ea6568a6f9632e = $(`&lt;div id=&quot;html_1b8edc159f492ca2e2ea6568a6f9632e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_46fd98f8a976dbca2f27d871abc3c29f.setContent(html_1b8edc159f492ca2e2ea6568a6f9632e);
#
#
#
#         marker_e68c04b18956d9a4e81a56769bda0266.bindPopup(popup_46fd98f8a976dbca2f27d871abc3c29f)
#         ;
#
#
#
#
#             var marker_dee48f97e34defcd87afca05d7d3a0de = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3decfaf8eb1a94daf3a8fc2be5ca1781);
#
#
#         var popup_a345dff7489b00e303a5bca6aad84ba8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_539d073e4ab53fa79970b2a690027f25 = $(`&lt;div id=&quot;html_539d073e4ab53fa79970b2a690027f25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a345dff7489b00e303a5bca6aad84ba8.setContent(html_539d073e4ab53fa79970b2a690027f25);
#
#
#
#         marker_dee48f97e34defcd87afca05d7d3a0de.bindPopup(popup_a345dff7489b00e303a5bca6aad84ba8)
#         ;
#
#
#
#
#             var marker_b1ed1d69269c338f8da02a0fdb64ea26 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3decfaf8eb1a94daf3a8fc2be5ca1781);
#
#
#         var popup_7e7de2d5546ef806d11a91256f735de0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bede57fc54594cc11deec16c4e24ec5c = $(`&lt;div id=&quot;html_bede57fc54594cc11deec16c4e24ec5c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_7e7de2d5546ef806d11a91256f735de0.setContent(html_bede57fc54594cc11deec16c4e24ec5c);
#
#
#
#         marker_b1ed1d69269c338f8da02a0fdb64ea26.bindPopup(popup_7e7de2d5546ef806d11a91256f735de0)
#         ;
#
#
#
#
#             var marker_1872ef3ae1faf28a7e4562dc9ac1498e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3decfaf8eb1a94daf3a8fc2be5ca1781);
#
#
#         var popup_7cbb5e057c2fcf40723f3eb741e33cfb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22199ca7593b8f73dd3d102121131e08 = $(`&lt;div id=&quot;html_22199ca7593b8f73dd3d102121131e08&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7cbb5e057c2fcf40723f3eb741e33cfb.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ab1397ec81ab55eda7729fc9abf3bb85 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ab1397ec81ab55eda7729fc9abf3bb85&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ab1397ec81ab55eda7729fc9abf3bb85 = L.map(
#                 &quot;map_ab1397ec81ab55eda7729fc9abf3bb85&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3efe89cde0c41e4aaac025e5d26d50af = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3efe89cde0c41e4aaac025e5d26d50af.addTo(map_ab1397ec81ab55eda7729fc9abf3bb85);
#
#
#             var feature_group_d59d7adbe3d3c4f11bd96f9fbba4f681 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_fb921c2ff013400a1f6bd9f06408811c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d59d7adbe3d3c4f11bd96f9fbba4f681);
#
#
#         var popup_f5d643de86ea730a7335765dce196cde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a2cfcf20fcdc7b14bca0d782459cde8 = $(`&lt;div id=&quot;html_0a2cfcf20fcdc7b14bca0d782459cde8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f5d643de86ea730a7335765dce196cde.setContent(html_0a2cfcf20fcdc7b14bca0d782459cde8);
#
#
#
#         marker_fb921c2ff013400a1f6bd9f06408811c.bindPopup(popup_f5d643de86ea730a7335765dce196cde)
#         ;
#
#
#
#
#             var marker_381fe3baab205c317803f485077b0f02 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d59d7adbe3d3c4f11bd96f9fbba4f681);
#
#
#         var popup_d909fd2629bb0a652c3828d15f9a6715 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9aa48a817283c18c55bc815212db792e = $(`&lt;div id=&quot;html_9aa48a817283c18c55bc815212db792e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d909fd2629bb0a652c3828d15f9a6715.setContent(html_9aa48a817283c18c55bc815212db792e);
#
#
#
#         marker_381fe3baab205c317803f485077b0f02.bindPopup(popup_d909fd2629bb0a652c3828d15f9a6715)
#         ;
#
#
#
#
#             var marker_2fe043561ba60faaa2d7bdd46b92d10d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d59d7adbe3d3c4f11bd96f9fbba4f681);
#
#
#         var popup_57f3ada791e94a9fe627eb1263ef44cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54c7b897d2686d8ae65c50a14dcc6b0d = $(`&lt;div id=&quot;html_54c7b897d2686d8ae65c50a14dcc6b0d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_57f3ada791e94a9fe627eb1263ef44cd.setContent(html_54c7b897d2686d8ae65c50a14dcc6b0d);
#
#
#
#         marker_2fe043561ba60faaa2d7bdd46b92d10d.bindPopup(popup_57f3ada791e94a9fe627eb1263ef44cd)
#         ;
#
#
#
#
#             var marker_50732703903b0605bddd75b19bf6faf7 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d59d7adbe3d3c4f11bd96f9fbba4f681);
#
#
#         var popup_f11a73b4e86fab8aaac3cbd665aa45ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b410fa516e7030287b2dbaf93f2e7295 = $(`&lt;div id=&quot;html_b410fa516e7030287b2dbaf93f2e7295&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f11a73b4e86fab8aaac3cbd665aa45ca.setContent(html_b410fa516e7030287b2dbaf93f2e7295);
#
#
#
#         marker_50732703903b0605bddd75b19bf6faf7.bindPopup(popup_f11a73b4e86fab8aaac3cbd665aa45ca)
#         ;
#
#
#
#
#             var marker_eb86d78dd1e26e1bf03bbfc7aad43b8a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d59d7adbe3d3c4f11bd96f9fbba4f681);
#
#
#         var popup_d003372d1f47f2b78e32d6e225a4ce93 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6378973e2279c6e4b35ed7ef2a052588 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6378973e2279c6e4b35ed7ef2a052588&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6378973e2279c6e4b35ed7ef2a052588 = L.map(
#                 &quot;map_6378973e2279c6e4b35ed7ef2a052588&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3644cc3fef6a995bd8f593594cf39722 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3644cc3fef6a995bd8f593594cf39722.addTo(map_6378973e2279c6e4b35ed7ef2a052588);
#
#
#             var feature_group_6e808c75a13ab4128b53635755b2235d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6e808c75a13ab4128b53635755b2235d.addTo(map_6378973e2279c6e4b35ed7ef2a052588);
#
#
#             var feature_group_sub_group_a0edfeabff18560be414249241199e88 = L.featureGroup.subGroup(
#                 feature_group_6e808c75a13ab4128b53635755b2235d
#             );
#
#
#             var marker_150992474e7d29722b912151bfd1d6b7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a0edfeabff18560be414249241199e88);
#
#
#         var popup_3d11056bad999941e03e822c42029cef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dca256e5b0c6ad4865a2ec04bcc65ce9 = $(`&lt;div id=&quot;html_dca256e5b0c6ad4865a2ec04bcc65ce9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3d11056bad999941e03e822c42029cef.setContent(html_dca256e5b0c6ad4865a2ec04bcc65ce9);
#
#
#
#         marker_150992474e7d29722b912151bfd1d6b7.bindPopup(popup_3d11056bad999941e03e822c42029cef)
#         ;
#
#
#
#
#             var marker_68d9f5d7b39299170d23068eba18059d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a0edfeabff18560be414249241199e88);
#
#
#         var popup_aa266478fa94a463d8917902306a53e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_05bf22f9c80d509b02881551304389f9 = $(`&lt;div id=&quot;html_05bf22f9c80d509b02881551304389f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_aa266478fa94a463d8917902306a53e1.setContent(html_05bf22f9c80d509b02881551304389f9);
#
#
#
#         marker_68d9f5d7b39299170d23068eba18059d.bindPopup(popup_aa266478fa94a463d8917902306a53e1)
#         ;
#
#
#
#
#             var marker_66771baab7c0df3d3af07b5c298bb943 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a0edfeabff18560be414249241199e88);
#
#
#         var popup_fb3f1d287714e7e3c9e8740df5b080c5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_563e3ab776eb17819d1af9f2ec5e753c = $(`&lt;div id=&quot;html_563e3ab776eb17819d1af9f2ec5e753c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fb3f1d287714e7e3c9e8740df5b080c5.setContent(html_563e3ab776eb17819d1af9f2ec5e753c);
#
#
#
#         marker_66771baab7c0df3d3af07b5c298bb943.bindPopup(popup_fb3f1d287714e7e3c9e8740df5b080c5)
#         ;
#
#
#
#
#             var marker_260a5bec929e0becbe3504261920d062 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a0edfeabff18560be414249241199e88);
#
#
#         var popup_0f4312a343b1e787d84a5498dd826ae1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d938ba329ba1138a70953e2c70965c4 = $(`&lt;div id=&quot;html_2d938ba329ba1138a70953e2c70965c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0f4312a343b1e787d84a5498dd826ae1.setContent(html_2d938ba329ba1138a70953e2c70965c4);
#
#
#
#         marker_
