# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d22b29f9fca86b8ab285162020ef46ca {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d22b29f9fca86b8ab285162020ef46ca&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d22b29f9fca86b8ab285162020ef46ca = L.map(
#                 &quot;map_d22b29f9fca86b8ab285162020ef46ca&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab09f190168d43c99f69851b5de96342 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ab09f190168d43c99f69851b5de96342.addTo(map_d22b29f9fca86b8ab285162020ef46ca);
#
#
#             var marker_98b1a4759fe16e39dcf9ec73c7667186 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d22b29f9fca86b8ab285162020ef46ca);
#
#
#         var popup_1fa4667e86dd3742e89570143e0f1143 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b83d60b9feb7c8676ca8f8057110d502 = $(`&lt;div id=&quot;html_b83d60b9feb7c8676ca8f8057110d502&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_1fa4667e86dd3742e89570143e0f1143.setContent(html_b83d60b9feb7c8676ca8f8057110d502);
#
#
#
#         marker_98b1a4759fe16e39dcf9ec73c7667186.bindPopup(popup_1fa4667e86dd3742e89570143e0f1143)
#         ;
#
#
#
#
#             var marker_38861bf34a99bfb4f621e79ec037c09a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d22b29f9fca86b8ab285162020ef46ca);
#
#
#         var popup_028a8b71f32477035ef4ef1399381270 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f7cdccce201c2fb2d5062fa4ebd12a6e = $(`&lt;div id=&quot;html_f7cdccce201c2fb2d5062fa4ebd12a6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_028a8b71f32477035ef4ef1399381270.setContent(html_f7cdccce201c2fb2d5062fa4ebd12a6e);
#
#
#
#         marker_38861bf34a99bfb4f621e79ec037c09a.bindPopup(popup_028a8b71f32477035ef4ef1399381270)
#         ;
#
#
#
#
#             var marker_6b06f732dbb57219c1e3dbfd6a1bf7f2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d22b29f9fca86b8ab285162020ef46ca);
#
#
#         var popup_e75b72ab523efbf6ba8f80609cec0f0b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6584c8ce49f6acc9fa351bc1d6b6341a = $(`&lt;div id=&quot;html_6584c8ce49f6acc9fa351bc1d6b6341a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e75b72ab523efbf6ba8f80609cec0f0b.setContent(html_6584c8ce49f6acc9fa351bc1d6b6341a);
#
#
#
#         marker_6b06f732dbb57219c1e3dbfd6a1bf7f2.bindPopup(popup_e75b72ab523efbf6ba8f80609cec0f0b)
#         ;
#
#
#
#
#             var marker_6d2ff74bba823ff8a2b3934edab595d1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d22b29f9fca86b8ab285162020ef46ca);
#
#
#         var popup_f4e5a2ffef4dd7d9a772c9e2bc5a1e0b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bcff61d95237f294f9a9ccda54032f6f = $(`&lt;div id=&quot;html_bcff61d95237f294f9a9ccda54032f6f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_f4e5a2ffef4dd7d9a772c9e2bc5a1e0b.setContent(html_bcff61d95237f294f9a9ccda54032f6f);
#
#
#
#         marker_6d2ff74bba823ff8a2b3934edab595d1.bindPopup(popup_f4e5a2ffef4dd7d9a772c9e2bc5a1e0b)
#         ;
#
#
#
#
#             var marker_e3102ecefb5903f896e0f70723423712 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d22b29f9fca86b8ab285162020ef46ca);
#
#
#         var popup_096709ab7883cd627e536bc72b4c6df7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8681b653b60c7da1af8af62cfa51785b = $(`&lt;div id=&quot;html_8681b653b60c7da1af8af62cfa51785b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_096709ab7883cd627e536bc72b4c6df7.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_36b8ca4c5cc032c34db797d31e17696d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_36b8ca4c5cc032c34db797d31e17696d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_36b8ca4c5cc032c34db797d31e17696d = L.map(
#                 &quot;map_36b8ca4c5cc032c34db797d31e17696d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b26eb1c5e4f5ae1e37abf210380f3cf9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b26eb1c5e4f5ae1e37abf210380f3cf9.addTo(map_36b8ca4c5cc032c34db797d31e17696d);
#
#
#             var feature_group_6a3b72c1dbae05165c006fc2dd2a9a4c = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2dd227a88ab697a9a1fa8ac8430c8d55 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6a3b72c1dbae05165c006fc2dd2a9a4c);
#
#
#         var popup_fcaa5c020860b388ccdf9a7cf97ac4b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1a7ef9d432b495afd171a0126e3382b = $(`&lt;div id=&quot;html_f1a7ef9d432b495afd171a0126e3382b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_fcaa5c020860b388ccdf9a7cf97ac4b2.setContent(html_f1a7ef9d432b495afd171a0126e3382b);
#
#
#
#         marker_2dd227a88ab697a9a1fa8ac8430c8d55.bindPopup(popup_fcaa5c020860b388ccdf9a7cf97ac4b2)
#         ;
#
#
#
#
#             var marker_21c4502aab7932abe92c937a138a7aa8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6a3b72c1dbae05165c006fc2dd2a9a4c);
#
#
#         var popup_f1f105cf0ce86f98a370a4b343feb57b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ce0365886f24557c9ee5faa7bd1ac77 = $(`&lt;div id=&quot;html_3ce0365886f24557c9ee5faa7bd1ac77&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f1f105cf0ce86f98a370a4b343feb57b.setContent(html_3ce0365886f24557c9ee5faa7bd1ac77);
#
#
#
#         marker_21c4502aab7932abe92c937a138a7aa8.bindPopup(popup_f1f105cf0ce86f98a370a4b343feb57b)
#         ;
#
#
#
#
#             var marker_006d51ebdca396d5734453cbe76122f2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6a3b72c1dbae05165c006fc2dd2a9a4c);
#
#
#         var popup_90f574dcdfd53a64f34dd4104face33a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e654e177f1d7b83e4dce9813388baa0 = $(`&lt;div id=&quot;html_5e654e177f1d7b83e4dce9813388baa0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_90f574dcdfd53a64f34dd4104face33a.setContent(html_5e654e177f1d7b83e4dce9813388baa0);
#
#
#
#         marker_006d51ebdca396d5734453cbe76122f2.bindPopup(popup_90f574dcdfd53a64f34dd4104face33a)
#         ;
#
#
#
#
#             var marker_5c522818841c4b3b97831e941ae88f1d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6a3b72c1dbae05165c006fc2dd2a9a4c);
#
#
#         var popup_3b427476a4fc406943361026dab44a17 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ee40558300204263d1c650e4b94065e = $(`&lt;div id=&quot;html_4ee40558300204263d1c650e4b94065e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_3b427476a4fc406943361026dab44a17.setContent(html_4ee40558300204263d1c650e4b94065e);
#
#
#
#         marker_5c522818841c4b3b97831e941ae88f1d.bindPopup(popup_3b427476a4fc406943361026dab44a17)
#         ;
#
#
#
#
#             var marker_804ce2d9e3c213ba446fd5113b505acd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6a3b72c1dbae05165c006fc2dd2a9a4c);
#
#
#         var popup_f003dacb85c407497e39b71ee66ee9ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b6daf3d99ebfecb0c4542703ec7fdd47 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b6daf3d99ebfecb0c4542703ec7fdd47&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b6daf3d99ebfecb0c4542703ec7fdd47 = L.map(
#                 &quot;map_b6daf3d99ebfecb0c4542703ec7fdd47&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_838d8e9bd2076d6fbe40dfb7818b0419 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_838d8e9bd2076d6fbe40dfb7818b0419.addTo(map_b6daf3d99ebfecb0c4542703ec7fdd47);
#
#
#             var feature_group_4f4e3a3226c23bacb9d1e8eb85ce63d1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4f4e3a3226c23bacb9d1e8eb85ce63d1.addTo(map_b6daf3d99ebfecb0c4542703ec7fdd47);
#
#
#             var feature_group_sub_group_daa420ce1c2f5b62d94c5e32c45eef5a = L.featureGroup.subGroup(
#                 feature_group_4f4e3a3226c23bacb9d1e8eb85ce63d1
#             );
#
#
#             var marker_e9de0960faad63562135a79340cde098 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_daa420ce1c2f5b62d94c5e32c45eef5a);
#
#
#         var popup_516cc605ea9d396a14f286b7c0630f71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c20879200de10f1c9babef86518aa934 = $(`&lt;div id=&quot;html_c20879200de10f1c9babef86518aa934&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_516cc605ea9d396a14f286b7c0630f71.setContent(html_c20879200de10f1c9babef86518aa934);
#
#
#
#         marker_e9de0960faad63562135a79340cde098.bindPopup(popup_516cc605ea9d396a14f286b7c0630f71)
#         ;
#
#
#
#
#             var marker_879953b9ffb9d99b7a2ec469163b4abc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_daa420ce1c2f5b62d94c5e32c45eef5a);
#
#
#         var popup_c3a8fc8ae6815631c1e451e7d2132fc9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3c60a3b6fd72d3e372ff98d9b39dd1c = $(`&lt;div id=&quot;html_e3c60a3b6fd72d3e372ff98d9b39dd1c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c3a8fc8ae6815631c1e451e7d2132fc9.setContent(html_e3c60a3b6fd72d3e372ff98d9b39dd1c);
#
#
#
#         marker_879953b9ffb9d99b7a2ec469163b4abc.bindPopup(popup_c3a8fc8ae6815631c1e451e7d2132fc9)
#         ;
#
#
#
#
#             var marker_caab2e1e2034790c7ee0e04eded7eeaa = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_daa420ce1c2f5b62d94c5e32c45eef5a);
#
#
#         var popup_0115115defce4a990aaeee3cde4838d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f991ecc85ed0bbba247306fc83fef0fd = $(`&lt;div id=&quot;html_f991ecc85ed0bbba247306fc83fef0fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0115115defce4a990aaeee3cde4838d8.setContent(html_f991ecc85ed0bbba247306fc83fef0fd);
#
#
#
#         marker_caab2e1e2034790c7ee0e04eded7eeaa.bindPopup(popup_0115115defce4a990aaeee3cde4838d8)
#         ;
#
#
#
#
#             var marker_005c823dd2ffe33a605d8ae57b846901 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_daa420ce1c2f5b62d94c5e32c45eef5a);
#
#
#         var popup_f331aeaae707cb50e7d3dfac97ccf997 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_033e88ec99df1e5055376cedf87c7021 = $(`&lt;div id=&quot;html_033e88ec99df1e5055376cedf87c7021&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_f331aeaae707cb50e7d3dfac97ccf997.setContent(html_033e88ec99df1e5055376cedf87c7021);
#
#
#
#         marker_
