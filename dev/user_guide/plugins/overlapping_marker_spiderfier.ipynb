# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1bcb77dc10bea15b58c6992ae34ee40a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1bcb77dc10bea15b58c6992ae34ee40a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1bcb77dc10bea15b58c6992ae34ee40a = L.map(
#                 &quot;map_1bcb77dc10bea15b58c6992ae34ee40a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_af3a167c5d6dcb2d26370365d476c886 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_af3a167c5d6dcb2d26370365d476c886.addTo(map_1bcb77dc10bea15b58c6992ae34ee40a);
#
#
#             var marker_68be676e83f3f70b9bf523a1ff527d6b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1bcb77dc10bea15b58c6992ae34ee40a);
#
#
#         var popup_310de0da6dac7d4956a53c64a7a25924 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_807747216b82307c29122b60087273cd = $(`&lt;div id=&quot;html_807747216b82307c29122b60087273cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_310de0da6dac7d4956a53c64a7a25924.setContent(html_807747216b82307c29122b60087273cd);
#
#
#
#         marker_68be676e83f3f70b9bf523a1ff527d6b.bindPopup(popup_310de0da6dac7d4956a53c64a7a25924)
#         ;
#
#
#
#
#             var marker_b5c39a038693a843065fcc26922c78bf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1bcb77dc10bea15b58c6992ae34ee40a);
#
#
#         var popup_d37f091390c26ed5b7d60a24a146092b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18901bc4896600c6d3fb41119a22b6c4 = $(`&lt;div id=&quot;html_18901bc4896600c6d3fb41119a22b6c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d37f091390c26ed5b7d60a24a146092b.setContent(html_18901bc4896600c6d3fb41119a22b6c4);
#
#
#
#         marker_b5c39a038693a843065fcc26922c78bf.bindPopup(popup_d37f091390c26ed5b7d60a24a146092b)
#         ;
#
#
#
#
#             var marker_0b337d88ac4f84f9dcf6350ffd138035 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1bcb77dc10bea15b58c6992ae34ee40a);
#
#
#         var popup_8b880f9f0ba0915570386c14b4b39c1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34586b1b3087451b4623b6e02c454e61 = $(`&lt;div id=&quot;html_34586b1b3087451b4623b6e02c454e61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_8b880f9f0ba0915570386c14b4b39c1f.setContent(html_34586b1b3087451b4623b6e02c454e61);
#
#
#
#         marker_0b337d88ac4f84f9dcf6350ffd138035.bindPopup(popup_8b880f9f0ba0915570386c14b4b39c1f)
#         ;
#
#
#
#
#             var marker_85b075fbc6dddd273e01c19a285d797b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1bcb77dc10bea15b58c6992ae34ee40a);
#
#
#         var popup_b3c9b323aa407af6a9a48a92d3239802 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c8c4d4d1d347d086a9caecc4d6d4ab0 = $(`&lt;div id=&quot;html_0c8c4d4d1d347d086a9caecc4d6d4ab0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b3c9b323aa407af6a9a48a92d3239802.setContent(html_0c8c4d4d1d347d086a9caecc4d6d4ab0);
#
#
#
#         marker_85b075fbc6dddd273e01c19a285d797b.bindPopup(popup_b3c9b323aa407af6a9a48a92d3239802)
#         ;
#
#
#
#
#             var marker_46d654264cf5dca9d2d5b90f24f7fdf9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1bcb77dc10bea15b58c6992ae34ee40a);
#
#
#         var popup_ce2e84804bc3bd8c40cf7b74f8b18961 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86e4b044710f010d56cdab1bc01bc073 = $(`&lt;div id=&quot;html_86e4b044710f010d56cdab1bc01bc073&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ce2e84804bc3bd8c40cf7b74f8b18961.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5ff0253a4a48cdcad03fe56c8dd4044 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5ff0253a4a48cdcad03fe56c8dd4044&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5ff0253a4a48cdcad03fe56c8dd4044 = L.map(
#                 &quot;map_d5ff0253a4a48cdcad03fe56c8dd4044&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec95d8e8f836b867b544b59627762552 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec95d8e8f836b867b544b59627762552.addTo(map_d5ff0253a4a48cdcad03fe56c8dd4044);
#
#
#             var feature_group_0c592ec945fdf5fede897732ed5bb32e = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f5fe23bbd278ee287a69b67e2ffbc3b6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0c592ec945fdf5fede897732ed5bb32e);
#
#
#         var popup_3d7391a60a9c8bd11feccb6d63d4ccf8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2832ac94bcf5aa0e0d8b87f8d1c913ae = $(`&lt;div id=&quot;html_2832ac94bcf5aa0e0d8b87f8d1c913ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3d7391a60a9c8bd11feccb6d63d4ccf8.setContent(html_2832ac94bcf5aa0e0d8b87f8d1c913ae);
#
#
#
#         marker_f5fe23bbd278ee287a69b67e2ffbc3b6.bindPopup(popup_3d7391a60a9c8bd11feccb6d63d4ccf8)
#         ;
#
#
#
#
#             var marker_fce9f7b36fafc3f0e0ea11381b4ade6d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0c592ec945fdf5fede897732ed5bb32e);
#
#
#         var popup_073bf4d76b687a04329486a349604e60 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3e7d145b7a0e68a4e1c6d6ed6c8d0cb = $(`&lt;div id=&quot;html_b3e7d145b7a0e68a4e1c6d6ed6c8d0cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_073bf4d76b687a04329486a349604e60.setContent(html_b3e7d145b7a0e68a4e1c6d6ed6c8d0cb);
#
#
#
#         marker_fce9f7b36fafc3f0e0ea11381b4ade6d.bindPopup(popup_073bf4d76b687a04329486a349604e60)
#         ;
#
#
#
#
#             var marker_ae0b08edbc3ee803ebef3f0d8f8bfb7e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0c592ec945fdf5fede897732ed5bb32e);
#
#
#         var popup_8342ea9d32230d10941529adfded4d94 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b566b7fb39245d3e99c8db3f98fddbf2 = $(`&lt;div id=&quot;html_b566b7fb39245d3e99c8db3f98fddbf2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_8342ea9d32230d10941529adfded4d94.setContent(html_b566b7fb39245d3e99c8db3f98fddbf2);
#
#
#
#         marker_ae0b08edbc3ee803ebef3f0d8f8bfb7e.bindPopup(popup_8342ea9d32230d10941529adfded4d94)
#         ;
#
#
#
#
#             var marker_71a250de866fe6988e00164174e156ed = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0c592ec945fdf5fede897732ed5bb32e);
#
#
#         var popup_325a788a640ca7aa77b557cb922fa820 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89f4a0bdef5b28b4000efc2024f522c0 = $(`&lt;div id=&quot;html_89f4a0bdef5b28b4000efc2024f522c0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_325a788a640ca7aa77b557cb922fa820.setContent(html_89f4a0bdef5b28b4000efc2024f522c0);
#
#
#
#         marker_71a250de866fe6988e00164174e156ed.bindPopup(popup_325a788a640ca7aa77b557cb922fa820)
#         ;
#
#
#
#
#             var marker_42d89b0bb661fcc245402215eb7916bf = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0c592ec945fdf5fede897732ed5bb32e);
#
#
#         var popup_86594626321dde330a287afbd285fc0c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_76a3030756496bcc1ad7a098ecfd0688 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_76a3030756496bcc1ad7a098ecfd0688&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_76a3030756496bcc1ad7a098ecfd0688 = L.map(
#                 &quot;map_76a3030756496bcc1ad7a098ecfd0688&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_cc80e2fb1661c21fe3892bd0c42fd89a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_cc80e2fb1661c21fe3892bd0c42fd89a.addTo(map_76a3030756496bcc1ad7a098ecfd0688);
#
#
#             var feature_group_11212f5d0cb3e910896f3dbc81a32a29 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_11212f5d0cb3e910896f3dbc81a32a29.addTo(map_76a3030756496bcc1ad7a098ecfd0688);
#
#
#             var feature_group_sub_group_58cc2d9de19eb9e25dd581f2d41e527e = L.featureGroup.subGroup(
#                 feature_group_11212f5d0cb3e910896f3dbc81a32a29
#             );
#
#
#             var marker_6d086a4773bc60959fc9f21b8dd98428 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_58cc2d9de19eb9e25dd581f2d41e527e);
#
#
#         var popup_1085286a4898067d3cd64728d6e4ca95 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b01bdec84915a124b2fee008a8a143b = $(`&lt;div id=&quot;html_4b01bdec84915a124b2fee008a8a143b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1085286a4898067d3cd64728d6e4ca95.setContent(html_4b01bdec84915a124b2fee008a8a143b);
#
#
#
#         marker_6d086a4773bc60959fc9f21b8dd98428.bindPopup(popup_1085286a4898067d3cd64728d6e4ca95)
#         ;
#
#
#
#
#             var marker_1c84bb89c554fe14bc731745102bb6ed = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_58cc2d9de19eb9e25dd581f2d41e527e);
#
#
#         var popup_dcd4b6f5c1a43a91acf83b34a5ce0e5b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2f890678c24d7e9ce5f4c62b16df66f = $(`&lt;div id=&quot;html_e2f890678c24d7e9ce5f4c62b16df66f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_dcd4b6f5c1a43a91acf83b34a5ce0e5b.setContent(html_e2f890678c24d7e9ce5f4c62b16df66f);
#
#
#
#         marker_1c84bb89c554fe14bc731745102bb6ed.bindPopup(popup_dcd4b6f5c1a43a91acf83b34a5ce0e5b)
#         ;
#
#
#
#
#             var marker_eb5636fe3c3b2c9fc205eb71203e23dc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_58cc2d9de19eb9e25dd581f2d41e527e);
#
#
#         var popup_efd913e2d3fd74c0afda6e62e8ed297c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d35b5f1f698d20670b8fe1c3e95dbfd0 = $(`&lt;div id=&quot;html_d35b5f1f698d20670b8fe1c3e95dbfd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_efd913e2d3fd74c0afda6e62e8ed297c.setContent(html_d35b5f1f698d20670b8fe1c3e95dbfd0);
#
#
#
#         marker_eb5636fe3c3b2c9fc205eb71203e23dc.bindPopup(popup_efd913e2d3fd74c0afda6e62e8ed297c)
#         ;
#
#
#
#
#             var marker_496164633d7bbcc9db3c8d3832c3f3e9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_58cc2d9de19eb9e25dd581f2d41e527e);
#
#
#         var popup_83931d8552eee907ab4eb5610e7c0877 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac5bb3c1662c314ba2871c3ff5ca3a38 = $(`&lt;div id=&quot;html_ac5bb3c1662c314ba2871c3ff5ca3a38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_83931d8552eee907ab4eb5610e7c0877.setContent(html_ac5bb3c1662c314ba2871c3ff5ca3a38);
#
#
#
#         marker_
