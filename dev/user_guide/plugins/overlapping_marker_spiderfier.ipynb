# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3d38bfb93383f10bc6984825b3622b1d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3d38bfb93383f10bc6984825b3622b1d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3d38bfb93383f10bc6984825b3622b1d = L.map(
#                 &quot;map_3d38bfb93383f10bc6984825b3622b1d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_afd6d865dc989db8f2206fc2889de871 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_afd6d865dc989db8f2206fc2889de871.addTo(map_3d38bfb93383f10bc6984825b3622b1d);
#
#
#             var marker_6dabf4c48e7f612225b6d196645f5c05 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_3d38bfb93383f10bc6984825b3622b1d);
#
#
#         var popup_ca09e94628b3bf6fe235a7d0508a9fe9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcd9c496d12e49529ba1dccc5b3d06da = $(`&lt;div id=&quot;html_dcd9c496d12e49529ba1dccc5b3d06da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ca09e94628b3bf6fe235a7d0508a9fe9.setContent(html_dcd9c496d12e49529ba1dccc5b3d06da);
#
#
#
#         marker_6dabf4c48e7f612225b6d196645f5c05.bindPopup(popup_ca09e94628b3bf6fe235a7d0508a9fe9)
#         ;
#
#
#
#
#             var marker_a21ca016e19ac16c6ffd4e2f2143d6f4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_3d38bfb93383f10bc6984825b3622b1d);
#
#
#         var popup_b31ef1d7d051efad12a97577c8a3efdf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54bad7452cdf17fc68fa91a04231eecc = $(`&lt;div id=&quot;html_54bad7452cdf17fc68fa91a04231eecc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_b31ef1d7d051efad12a97577c8a3efdf.setContent(html_54bad7452cdf17fc68fa91a04231eecc);
#
#
#
#         marker_a21ca016e19ac16c6ffd4e2f2143d6f4.bindPopup(popup_b31ef1d7d051efad12a97577c8a3efdf)
#         ;
#
#
#
#
#             var marker_f079b80fe7a70c728e7e339a47f8a97a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_3d38bfb93383f10bc6984825b3622b1d);
#
#
#         var popup_9b271fef1df0976a111f9ba8d7561c1f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_83a1fa28b8ffd6637d15c7ff63d3e394 = $(`&lt;div id=&quot;html_83a1fa28b8ffd6637d15c7ff63d3e394&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9b271fef1df0976a111f9ba8d7561c1f.setContent(html_83a1fa28b8ffd6637d15c7ff63d3e394);
#
#
#
#         marker_f079b80fe7a70c728e7e339a47f8a97a.bindPopup(popup_9b271fef1df0976a111f9ba8d7561c1f)
#         ;
#
#
#
#
#             var marker_c5086d6e494a03b19dcb71bd5ce69e1f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_3d38bfb93383f10bc6984825b3622b1d);
#
#
#         var popup_afb23e34c5e50bb09428c5b29ee01b55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e0a982943a88dacafb80396667ec6e2 = $(`&lt;div id=&quot;html_5e0a982943a88dacafb80396667ec6e2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_afb23e34c5e50bb09428c5b29ee01b55.setContent(html_5e0a982943a88dacafb80396667ec6e2);
#
#
#
#         marker_c5086d6e494a03b19dcb71bd5ce69e1f.bindPopup(popup_afb23e34c5e50bb09428c5b29ee01b55)
#         ;
#
#
#
#
#             var marker_e5dda3f0957890dfcbe8cac40f3c3b64 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_3d38bfb93383f10bc6984825b3622b1d);
#
#
#         var popup_d2ce4ca681e11e15aad83c5419c20777 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b0778723139cfe14c938bf446eb5fb5 = $(`&lt;div id=&quot;html_1b0778723139cfe14c938bf446eb5fb5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d2ce4ca681e11e15aad83c5419c20777.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf197973e2398ce53650db5353bfdad1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf197973e2398ce53650db5353bfdad1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf197973e2398ce53650db5353bfdad1 = L.map(
#                 &quot;map_cf197973e2398ce53650db5353bfdad1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f93eec9cec9e9848e02223df65292c07 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f93eec9cec9e9848e02223df65292c07.addTo(map_cf197973e2398ce53650db5353bfdad1);
#
#
#             var feature_group_0b292f3596029b16864b1bc2800eaf97 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_982781fce67f63c3316c58d06e0409fa = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0b292f3596029b16864b1bc2800eaf97);
#
#
#         var popup_dbd4aa6cc2acba046244c310434283cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4c1832056c991641cd712d2f4ea4e2c = $(`&lt;div id=&quot;html_a4c1832056c991641cd712d2f4ea4e2c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_dbd4aa6cc2acba046244c310434283cf.setContent(html_a4c1832056c991641cd712d2f4ea4e2c);
#
#
#
#         marker_982781fce67f63c3316c58d06e0409fa.bindPopup(popup_dbd4aa6cc2acba046244c310434283cf)
#         ;
#
#
#
#
#             var marker_da62c6913bae41ca9e85982e4afcc2c3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0b292f3596029b16864b1bc2800eaf97);
#
#
#         var popup_d0d2aa50a94a804a146085544710334c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8162628c92ef0b24a0a008589d1d02c3 = $(`&lt;div id=&quot;html_8162628c92ef0b24a0a008589d1d02c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d0d2aa50a94a804a146085544710334c.setContent(html_8162628c92ef0b24a0a008589d1d02c3);
#
#
#
#         marker_da62c6913bae41ca9e85982e4afcc2c3.bindPopup(popup_d0d2aa50a94a804a146085544710334c)
#         ;
#
#
#
#
#             var marker_56f565b0bf2465f08e9e07a92630be10 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0b292f3596029b16864b1bc2800eaf97);
#
#
#         var popup_0514b9f57941728374f8f229456cdb3f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c1eedafbc84a8c67aaf0df2e1ea5015 = $(`&lt;div id=&quot;html_8c1eedafbc84a8c67aaf0df2e1ea5015&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_0514b9f57941728374f8f229456cdb3f.setContent(html_8c1eedafbc84a8c67aaf0df2e1ea5015);
#
#
#
#         marker_56f565b0bf2465f08e9e07a92630be10.bindPopup(popup_0514b9f57941728374f8f229456cdb3f)
#         ;
#
#
#
#
#             var marker_a08ccfd33f39c94c7ab3ea16ca11db12 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0b292f3596029b16864b1bc2800eaf97);
#
#
#         var popup_f0622daf8ab848a046d9f61555ee4b30 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23bcb42f7d4e39fcf79b99c83a243615 = $(`&lt;div id=&quot;html_23bcb42f7d4e39fcf79b99c83a243615&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f0622daf8ab848a046d9f61555ee4b30.setContent(html_23bcb42f7d4e39fcf79b99c83a243615);
#
#
#
#         marker_a08ccfd33f39c94c7ab3ea16ca11db12.bindPopup(popup_f0622daf8ab848a046d9f61555ee4b30)
#         ;
#
#
#
#
#             var marker_dc544ee90cadebdc8944d16b16d15392 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0b292f3596029b16864b1bc2800eaf97);
#
#
#         var popup_b3b11043b9549b6072be59a2e1083dfe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f18df74e1104c52229a2948ab3fea33a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f18df74e1104c52229a2948ab3fea33a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f18df74e1104c52229a2948ab3fea33a = L.map(
#                 &quot;map_f18df74e1104c52229a2948ab3fea33a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d429cfb823bf3f9088a8395b921000d9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d429cfb823bf3f9088a8395b921000d9.addTo(map_f18df74e1104c52229a2948ab3fea33a);
#
#
#             var feature_group_78e3006048012b657228288e0dfb3644 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_78e3006048012b657228288e0dfb3644.addTo(map_f18df74e1104c52229a2948ab3fea33a);
#
#
#             var feature_group_sub_group_a3dc9e5bff0f24dfab463a7cb177cf7f = L.featureGroup.subGroup(
#                 feature_group_78e3006048012b657228288e0dfb3644
#             );
#
#
#             var marker_11c7e65bd52ddf32174e56add2ad1e47 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a3dc9e5bff0f24dfab463a7cb177cf7f);
#
#
#         var popup_3dc77796d0e443a190c852e1968129c7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23ffeb03a92cb9e5cc76f77139c72048 = $(`&lt;div id=&quot;html_23ffeb03a92cb9e5cc76f77139c72048&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3dc77796d0e443a190c852e1968129c7.setContent(html_23ffeb03a92cb9e5cc76f77139c72048);
#
#
#
#         marker_11c7e65bd52ddf32174e56add2ad1e47.bindPopup(popup_3dc77796d0e443a190c852e1968129c7)
#         ;
#
#
#
#
#             var marker_8ee38129ccf1b34feece421f0c4440d3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a3dc9e5bff0f24dfab463a7cb177cf7f);
#
#
#         var popup_8600add9640762fbd521b5f40188b823 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_71c98b9afb8ac53eed74fb256ebfcc2f = $(`&lt;div id=&quot;html_71c98b9afb8ac53eed74fb256ebfcc2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8600add9640762fbd521b5f40188b823.setContent(html_71c98b9afb8ac53eed74fb256ebfcc2f);
#
#
#
#         marker_8ee38129ccf1b34feece421f0c4440d3.bindPopup(popup_8600add9640762fbd521b5f40188b823)
#         ;
#
#
#
#
#             var marker_10b6c30a546cd474f594a01223dafc64 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a3dc9e5bff0f24dfab463a7cb177cf7f);
#
#
#         var popup_d5fbb6732098bfafe7a3d9970c4f5e3d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c3b67fa3553867c0d8009210cf47d901 = $(`&lt;div id=&quot;html_c3b67fa3553867c0d8009210cf47d901&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d5fbb6732098bfafe7a3d9970c4f5e3d.setContent(html_c3b67fa3553867c0d8009210cf47d901);
#
#
#
#         marker_10b6c30a546cd474f594a01223dafc64.bindPopup(popup_d5fbb6732098bfafe7a3d9970c4f5e3d)
#         ;
#
#
#
#
#             var marker_4ede5f401a2d799faaa9366b91e9c7e4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a3dc9e5bff0f24dfab463a7cb177cf7f);
#
#
#         var popup_b9a4ff5d0bd9f09985b512ce1b1dd8d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c620f151d8d8bbb1b70748674c2006dd = $(`&lt;div id=&quot;html_c620f151d8d8bbb1b70748674c2006dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b9a4ff5d0bd9f09985b512ce1b1dd8d5.setContent(html_c620f151d8d8bbb1b70748674c2006dd);
#
#
#
#         marker_
