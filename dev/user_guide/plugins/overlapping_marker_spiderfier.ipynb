# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b99b5b63432bd47d0661665b9a2e610c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b99b5b63432bd47d0661665b9a2e610c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b99b5b63432bd47d0661665b9a2e610c = L.map(
#                 &quot;map_b99b5b63432bd47d0661665b9a2e610c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_61fa7e98e90519321bf29c6d193a7561 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_61fa7e98e90519321bf29c6d193a7561.addTo(map_b99b5b63432bd47d0661665b9a2e610c);
#
#
#             var marker_d35dd75fb903ce9b9400695a44c952a0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_b99b5b63432bd47d0661665b9a2e610c);
#
#
#         var popup_765b65389636b41ac27674b3d9f5585a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b89b0572ba4bf4506ff3815b5f62cbbe = $(`&lt;div id=&quot;html_b89b0572ba4bf4506ff3815b5f62cbbe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_765b65389636b41ac27674b3d9f5585a.setContent(html_b89b0572ba4bf4506ff3815b5f62cbbe);
#
#
#
#         marker_d35dd75fb903ce9b9400695a44c952a0.bindPopup(popup_765b65389636b41ac27674b3d9f5585a)
#         ;
#
#
#
#
#             var marker_68c25c5b4cec5c305d97f087e5b9de83 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_b99b5b63432bd47d0661665b9a2e610c);
#
#
#         var popup_ce02cb424bacd5b676930bd0ca3d2d62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4afcd655c1345978cb22d19159de99b = $(`&lt;div id=&quot;html_f4afcd655c1345978cb22d19159de99b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_ce02cb424bacd5b676930bd0ca3d2d62.setContent(html_f4afcd655c1345978cb22d19159de99b);
#
#
#
#         marker_68c25c5b4cec5c305d97f087e5b9de83.bindPopup(popup_ce02cb424bacd5b676930bd0ca3d2d62)
#         ;
#
#
#
#
#             var marker_e12eda433435a12a4ba98ce4b2e80c09 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_b99b5b63432bd47d0661665b9a2e610c);
#
#
#         var popup_df80ea87b3ca468f12acbd131af139ed = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d27d8dfd930319a54fc7a6b0e6dc9cf5 = $(`&lt;div id=&quot;html_d27d8dfd930319a54fc7a6b0e6dc9cf5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_df80ea87b3ca468f12acbd131af139ed.setContent(html_d27d8dfd930319a54fc7a6b0e6dc9cf5);
#
#
#
#         marker_e12eda433435a12a4ba98ce4b2e80c09.bindPopup(popup_df80ea87b3ca468f12acbd131af139ed)
#         ;
#
#
#
#
#             var marker_69da9718df3e626755d134fa1b1437cf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_b99b5b63432bd47d0661665b9a2e610c);
#
#
#         var popup_4fccd117392c93237e9383035f37018d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b5edfd672663dcdcdadd5f749108e51 = $(`&lt;div id=&quot;html_8b5edfd672663dcdcdadd5f749108e51&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4fccd117392c93237e9383035f37018d.setContent(html_8b5edfd672663dcdcdadd5f749108e51);
#
#
#
#         marker_69da9718df3e626755d134fa1b1437cf.bindPopup(popup_4fccd117392c93237e9383035f37018d)
#         ;
#
#
#
#
#             var marker_d81dad37c4d672892759cd4e1fc7b09d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_b99b5b63432bd47d0661665b9a2e610c);
#
#
#         var popup_0c4b7c49f7b8da2021cc62f2091666cd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_969c418c1efabbc8222df97b8be710e3 = $(`&lt;div id=&quot;html_969c418c1efabbc8222df97b8be710e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_0c4b7c49f7b8da2021cc62f2091666cd.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0cdc20450bc33494076e3f3b1b5b174a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0cdc20450bc33494076e3f3b1b5b174a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0cdc20450bc33494076e3f3b1b5b174a = L.map(
#                 &quot;map_0cdc20450bc33494076e3f3b1b5b174a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_71dcdc041c5894d36ff8491d8554141e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_71dcdc041c5894d36ff8491d8554141e.addTo(map_0cdc20450bc33494076e3f3b1b5b174a);
#
#
#             var feature_group_910671fe375565c00c687ab02a951a02 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c79f6db1eee17488e277c84105c4e09c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_910671fe375565c00c687ab02a951a02);
#
#
#         var popup_2f10b15e2b8c8997076afc76c47ac86c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e7e9f2cf6384bbd029e06bf29476ad0c = $(`&lt;div id=&quot;html_e7e9f2cf6384bbd029e06bf29476ad0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2f10b15e2b8c8997076afc76c47ac86c.setContent(html_e7e9f2cf6384bbd029e06bf29476ad0c);
#
#
#
#         marker_c79f6db1eee17488e277c84105c4e09c.bindPopup(popup_2f10b15e2b8c8997076afc76c47ac86c)
#         ;
#
#
#
#
#             var marker_6cac44cc788021b828fcfed1c92bd275 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_910671fe375565c00c687ab02a951a02);
#
#
#         var popup_f07d9903476b9ae4f0062c0f36001861 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_292624a770b8ab688156b6401555b154 = $(`&lt;div id=&quot;html_292624a770b8ab688156b6401555b154&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f07d9903476b9ae4f0062c0f36001861.setContent(html_292624a770b8ab688156b6401555b154);
#
#
#
#         marker_6cac44cc788021b828fcfed1c92bd275.bindPopup(popup_f07d9903476b9ae4f0062c0f36001861)
#         ;
#
#
#
#
#             var marker_85492720f1e265e799a34d43a163f549 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_910671fe375565c00c687ab02a951a02);
#
#
#         var popup_f39f899aa9091fc9c21da0c9902bcf45 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8709cbc2773cb359aaa1952d1c32126e = $(`&lt;div id=&quot;html_8709cbc2773cb359aaa1952d1c32126e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f39f899aa9091fc9c21da0c9902bcf45.setContent(html_8709cbc2773cb359aaa1952d1c32126e);
#
#
#
#         marker_85492720f1e265e799a34d43a163f549.bindPopup(popup_f39f899aa9091fc9c21da0c9902bcf45)
#         ;
#
#
#
#
#             var marker_2c0348dcef2adbaa2d062e9f2e61b373 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_910671fe375565c00c687ab02a951a02);
#
#
#         var popup_ea6f0354a1cd830c32c020ba02cc6ee1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62a5ee97af1988e6607378546de4bbf0 = $(`&lt;div id=&quot;html_62a5ee97af1988e6607378546de4bbf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ea6f0354a1cd830c32c020ba02cc6ee1.setContent(html_62a5ee97af1988e6607378546de4bbf0);
#
#
#
#         marker_2c0348dcef2adbaa2d062e9f2e61b373.bindPopup(popup_ea6f0354a1cd830c32c020ba02cc6ee1)
#         ;
#
#
#
#
#             var marker_770b8f688c873405f9a5605db56ac02a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_910671fe375565c00c687ab02a951a02);
#
#
#         var popup_dd97d810984f062921bab2be20337fc5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2630b983c5ccec4ce2d19b9524a8be46 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2630b983c5ccec4ce2d19b9524a8be46&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2630b983c5ccec4ce2d19b9524a8be46 = L.map(
#                 &quot;map_2630b983c5ccec4ce2d19b9524a8be46&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c85aa6622947ab98549e6d32320ba94d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c85aa6622947ab98549e6d32320ba94d.addTo(map_2630b983c5ccec4ce2d19b9524a8be46);
#
#
#             var feature_group_761815b89b65f2680bf2c10843eb1667 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_761815b89b65f2680bf2c10843eb1667.addTo(map_2630b983c5ccec4ce2d19b9524a8be46);
#
#
#             var feature_group_sub_group_f8d2d3d0b869ef1c41f7e2a4ee6d9695 = L.featureGroup.subGroup(
#                 feature_group_761815b89b65f2680bf2c10843eb1667
#             );
#
#
#             var marker_c87db679f58e0ae4bfbb7cd1ad3494cb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f8d2d3d0b869ef1c41f7e2a4ee6d9695);
#
#
#         var popup_443dcdbb635d570ed6672f8d83258515 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ec2c3e0e6180f4f3efb4130ec246e25 = $(`&lt;div id=&quot;html_0ec2c3e0e6180f4f3efb4130ec246e25&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_443dcdbb635d570ed6672f8d83258515.setContent(html_0ec2c3e0e6180f4f3efb4130ec246e25);
#
#
#
#         marker_c87db679f58e0ae4bfbb7cd1ad3494cb.bindPopup(popup_443dcdbb635d570ed6672f8d83258515)
#         ;
#
#
#
#
#             var marker_6d9d1310ee428bf92a99f4fe1abb4a48 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f8d2d3d0b869ef1c41f7e2a4ee6d9695);
#
#
#         var popup_e7c441a25bc9d4c19ddc8bc53e0506fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_282de7cd3b3eb104024beb1cd82c49ae = $(`&lt;div id=&quot;html_282de7cd3b3eb104024beb1cd82c49ae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e7c441a25bc9d4c19ddc8bc53e0506fa.setContent(html_282de7cd3b3eb104024beb1cd82c49ae);
#
#
#
#         marker_6d9d1310ee428bf92a99f4fe1abb4a48.bindPopup(popup_e7c441a25bc9d4c19ddc8bc53e0506fa)
#         ;
#
#
#
#
#             var marker_ec0c889fc3962ab071210b4d0c98f83c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f8d2d3d0b869ef1c41f7e2a4ee6d9695);
#
#
#         var popup_391942415093ddb496289c2be82f9017 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2954bba99fd361bd1914bc175c651c91 = $(`&lt;div id=&quot;html_2954bba99fd361bd1914bc175c651c91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_391942415093ddb496289c2be82f9017.setContent(html_2954bba99fd361bd1914bc175c651c91);
#
#
#
#         marker_ec0c889fc3962ab071210b4d0c98f83c.bindPopup(popup_391942415093ddb496289c2be82f9017)
#         ;
#
#
#
#
#             var marker_38a45c324aa39b5953d6958262f3e83e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f8d2d3d0b869ef1c41f7e2a4ee6d9695);
#
#
#         var popup_51bfd5cf601f8e8e79bcae0b7a74dafb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_53516b8bccb6cc905e3a933f92323a48 = $(`&lt;div id=&quot;html_53516b8bccb6cc905e3a933f92323a48&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_51bfd5cf601f8e8e79bcae0b7a74dafb.setContent(html_53516b8bccb6cc905e3a933f92323a48);
#
#
#
#         marker_
