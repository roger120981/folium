# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3615d5cb5e6d5cded2c02afc3c1ab16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3615d5cb5e6d5cded2c02afc3c1ab16&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3615d5cb5e6d5cded2c02afc3c1ab16 = L.map(
#                 &quot;map_d3615d5cb5e6d5cded2c02afc3c1ab16&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bc92ef00a916d4f6184134cf17fa5491 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bc92ef00a916d4f6184134cf17fa5491.addTo(map_d3615d5cb5e6d5cded2c02afc3c1ab16);
#
#
#             var marker_8808109d881da555bb79c42e0fbc938d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d3615d5cb5e6d5cded2c02afc3c1ab16);
#
#
#         var popup_c80dc8d5e78c86e1b633c9247a725398 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_44c1a0406007111d842b9b0b92f6b56d = $(`&lt;div id=&quot;html_44c1a0406007111d842b9b0b92f6b56d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c80dc8d5e78c86e1b633c9247a725398.setContent(html_44c1a0406007111d842b9b0b92f6b56d);
#
#
#
#         marker_8808109d881da555bb79c42e0fbc938d.bindPopup(popup_c80dc8d5e78c86e1b633c9247a725398)
#         ;
#
#
#
#
#             var marker_f8f06a181cf9ef7e22ab1d48597ae1f5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d3615d5cb5e6d5cded2c02afc3c1ab16);
#
#
#         var popup_8c2c204596ed37c674f1569c1c5aaec6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ede88e872d5c4def54becce548d8c642 = $(`&lt;div id=&quot;html_ede88e872d5c4def54becce548d8c642&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8c2c204596ed37c674f1569c1c5aaec6.setContent(html_ede88e872d5c4def54becce548d8c642);
#
#
#
#         marker_f8f06a181cf9ef7e22ab1d48597ae1f5.bindPopup(popup_8c2c204596ed37c674f1569c1c5aaec6)
#         ;
#
#
#
#
#             var marker_e4dd2ff30c911d9e0d51f9479f9e19d5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d3615d5cb5e6d5cded2c02afc3c1ab16);
#
#
#         var popup_c043bc7aa46940bd8dddb94a577122ac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32518f0919f2ad82eb107d81dba38f8c = $(`&lt;div id=&quot;html_32518f0919f2ad82eb107d81dba38f8c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c043bc7aa46940bd8dddb94a577122ac.setContent(html_32518f0919f2ad82eb107d81dba38f8c);
#
#
#
#         marker_e4dd2ff30c911d9e0d51f9479f9e19d5.bindPopup(popup_c043bc7aa46940bd8dddb94a577122ac)
#         ;
#
#
#
#
#             var marker_edd59da53658e532a8094b843f35516d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d3615d5cb5e6d5cded2c02afc3c1ab16);
#
#
#         var popup_e0d28454f0a921728f0c024cfcc5cea2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_526d8d2dc5e09bf8e4b1c6c16cdd85d2 = $(`&lt;div id=&quot;html_526d8d2dc5e09bf8e4b1c6c16cdd85d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e0d28454f0a921728f0c024cfcc5cea2.setContent(html_526d8d2dc5e09bf8e4b1c6c16cdd85d2);
#
#
#
#         marker_edd59da53658e532a8094b843f35516d.bindPopup(popup_e0d28454f0a921728f0c024cfcc5cea2)
#         ;
#
#
#
#
#             var marker_6e52cf1a511b38e4d8ba1625c84c9175 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d3615d5cb5e6d5cded2c02afc3c1ab16);
#
#
#         var popup_09ee15b580d1719bd5645c4960df2d02 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_895a6c6d1d19f9c51787c748c73ec832 = $(`&lt;div id=&quot;html_895a6c6d1d19f9c51787c748c73ec832&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_09ee15b580d1719bd5645c4960df2d02.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_627de8cf030b91189209d84e28847c3d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_627de8cf030b91189209d84e28847c3d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_627de8cf030b91189209d84e28847c3d = L.map(
#                 &quot;map_627de8cf030b91189209d84e28847c3d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6ff29d41c04d88ca0d0b282f90c487f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6ff29d41c04d88ca0d0b282f90c487f1.addTo(map_627de8cf030b91189209d84e28847c3d);
#
#
#             var feature_group_d660fa7ce1ab776f8ac06f72f1bc216b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c050a937534ae44214a355276d440ce5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d660fa7ce1ab776f8ac06f72f1bc216b);
#
#
#         var popup_b0db91320765a969c48279e75f72c980 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8e6f68e81a310149cfad16086ca38a2 = $(`&lt;div id=&quot;html_a8e6f68e81a310149cfad16086ca38a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b0db91320765a969c48279e75f72c980.setContent(html_a8e6f68e81a310149cfad16086ca38a2);
#
#
#
#         marker_c050a937534ae44214a355276d440ce5.bindPopup(popup_b0db91320765a969c48279e75f72c980)
#         ;
#
#
#
#
#             var marker_0814414cb5a2ae197ca24f8fbf8872f1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d660fa7ce1ab776f8ac06f72f1bc216b);
#
#
#         var popup_c290b66f0564f9bff3cc64ddd8716f11 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7f3d30ad958e21094ac02e92bf6653f1 = $(`&lt;div id=&quot;html_7f3d30ad958e21094ac02e92bf6653f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c290b66f0564f9bff3cc64ddd8716f11.setContent(html_7f3d30ad958e21094ac02e92bf6653f1);
#
#
#
#         marker_0814414cb5a2ae197ca24f8fbf8872f1.bindPopup(popup_c290b66f0564f9bff3cc64ddd8716f11)
#         ;
#
#
#
#
#             var marker_4de0b6f19d185a886144f053df6f2b87 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d660fa7ce1ab776f8ac06f72f1bc216b);
#
#
#         var popup_141b3c230da720412f75c68d92496a4a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c561aed1fd1aa4edccd0e6168d1de517 = $(`&lt;div id=&quot;html_c561aed1fd1aa4edccd0e6168d1de517&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_141b3c230da720412f75c68d92496a4a.setContent(html_c561aed1fd1aa4edccd0e6168d1de517);
#
#
#
#         marker_4de0b6f19d185a886144f053df6f2b87.bindPopup(popup_141b3c230da720412f75c68d92496a4a)
#         ;
#
#
#
#
#             var marker_c88f59b9190f012d6c8a2888afc80e68 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d660fa7ce1ab776f8ac06f72f1bc216b);
#
#
#         var popup_20fbf7500e283bca41aa705a3cdd0f0d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1bb233d075eace08fa64e9fbafb14aac = $(`&lt;div id=&quot;html_1bb233d075eace08fa64e9fbafb14aac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_20fbf7500e283bca41aa705a3cdd0f0d.setContent(html_1bb233d075eace08fa64e9fbafb14aac);
#
#
#
#         marker_c88f59b9190f012d6c8a2888afc80e68.bindPopup(popup_20fbf7500e283bca41aa705a3cdd0f0d)
#         ;
#
#
#
#
#             var marker_4d8066e0d492a845a9e8b0a8473d2d29 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d660fa7ce1ab776f8ac06f72f1bc216b);
#
#
#         var popup_beb81de5b5d4f3b154a11587b2af9620 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f17c346be36885d288dc5356f5b2e499 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f17c346be36885d288dc5356f5b2e499&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f17c346be36885d288dc5356f5b2e499 = L.map(
#                 &quot;map_f17c346be36885d288dc5356f5b2e499&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13eb46c292406c3024e1bab0f0660b98 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_13eb46c292406c3024e1bab0f0660b98.addTo(map_f17c346be36885d288dc5356f5b2e499);
#
#
#             var feature_group_6c99f15f3071fdc3792a9733a9aacc60 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6c99f15f3071fdc3792a9733a9aacc60.addTo(map_f17c346be36885d288dc5356f5b2e499);
#
#
#             var feature_group_sub_group_29f66a3b2b9640e1a279f2841a1ee7fd = L.featureGroup.subGroup(
#                 feature_group_6c99f15f3071fdc3792a9733a9aacc60
#             );
#
#
#             var marker_607430168cd722f5eded130711c349ac = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_29f66a3b2b9640e1a279f2841a1ee7fd);
#
#
#         var popup_5f7cd940484028ee9916d4dde11a007c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_80afbf9ae726c710573ed689e15597a4 = $(`&lt;div id=&quot;html_80afbf9ae726c710573ed689e15597a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_5f7cd940484028ee9916d4dde11a007c.setContent(html_80afbf9ae726c710573ed689e15597a4);
#
#
#
#         marker_607430168cd722f5eded130711c349ac.bindPopup(popup_5f7cd940484028ee9916d4dde11a007c)
#         ;
#
#
#
#
#             var marker_73359b3a8623610fea26efbf1418a657 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_29f66a3b2b9640e1a279f2841a1ee7fd);
#
#
#         var popup_8ad29a8a2edc192e741c5a58497fb65a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b08a83d1280bbbe34523836a23db907 = $(`&lt;div id=&quot;html_6b08a83d1280bbbe34523836a23db907&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_8ad29a8a2edc192e741c5a58497fb65a.setContent(html_6b08a83d1280bbbe34523836a23db907);
#
#
#
#         marker_73359b3a8623610fea26efbf1418a657.bindPopup(popup_8ad29a8a2edc192e741c5a58497fb65a)
#         ;
#
#
#
#
#             var marker_75478d73e76ac50047c6c670bf3e3b8d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_29f66a3b2b9640e1a279f2841a1ee7fd);
#
#
#         var popup_bb4693735dbe09f57e87aded790fa184 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_241b182f1b80b46a0a836241c73de174 = $(`&lt;div id=&quot;html_241b182f1b80b46a0a836241c73de174&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bb4693735dbe09f57e87aded790fa184.setContent(html_241b182f1b80b46a0a836241c73de174);
#
#
#
#         marker_75478d73e76ac50047c6c670bf3e3b8d.bindPopup(popup_bb4693735dbe09f57e87aded790fa184)
#         ;
#
#
#
#
#             var marker_4d7cc4dde0497c266173b979d98ea5a8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_29f66a3b2b9640e1a279f2841a1ee7fd);
#
#
#         var popup_fc88f2f6fe02c39a2d563b0396d4b1a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2c2b6180100304ebc7b20401fbcca20 = $(`&lt;div id=&quot;html_d2c2b6180100304ebc7b20401fbcca20&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_fc88f2f6fe02c39a2d563b0396d4b1a7.setContent(html_d2c2b6180100304ebc7b20401fbcca20);
#
#
#
#         marker_
