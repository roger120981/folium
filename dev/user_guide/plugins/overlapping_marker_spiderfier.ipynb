# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4046f81a2cb74722e418eb621805a17a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4046f81a2cb74722e418eb621805a17a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4046f81a2cb74722e418eb621805a17a = L.map(
#                 &quot;map_4046f81a2cb74722e418eb621805a17a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_00c245627129ea33e72f074238c2996f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_00c245627129ea33e72f074238c2996f.addTo(map_4046f81a2cb74722e418eb621805a17a);
#
#
#             var marker_87af1a3a8d9c07116ae74195dce472d9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4046f81a2cb74722e418eb621805a17a);
#
#
#         var popup_64191f7b6696ca205109a2cd08bb825e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_06df0a93e01011d95a2e618acf32c80c = $(`&lt;div id=&quot;html_06df0a93e01011d95a2e618acf32c80c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_64191f7b6696ca205109a2cd08bb825e.setContent(html_06df0a93e01011d95a2e618acf32c80c);
#
#
#
#         marker_87af1a3a8d9c07116ae74195dce472d9.bindPopup(popup_64191f7b6696ca205109a2cd08bb825e)
#         ;
#
#
#
#
#             var marker_eb2905413249ff36359c1abaab7a0c67 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4046f81a2cb74722e418eb621805a17a);
#
#
#         var popup_4c3a312c8d5eba373f4b20c44a7d964f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c9cadb0eb2cbbc17f2ba88080c0e0d7f = $(`&lt;div id=&quot;html_c9cadb0eb2cbbc17f2ba88080c0e0d7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_4c3a312c8d5eba373f4b20c44a7d964f.setContent(html_c9cadb0eb2cbbc17f2ba88080c0e0d7f);
#
#
#
#         marker_eb2905413249ff36359c1abaab7a0c67.bindPopup(popup_4c3a312c8d5eba373f4b20c44a7d964f)
#         ;
#
#
#
#
#             var marker_bd7d25ff67294002c604907b9f00712c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4046f81a2cb74722e418eb621805a17a);
#
#
#         var popup_c3e05b8dd91e3fa33aeca255ca1de6f4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eacc75a90b398500bdfd6c5901432749 = $(`&lt;div id=&quot;html_eacc75a90b398500bdfd6c5901432749&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c3e05b8dd91e3fa33aeca255ca1de6f4.setContent(html_eacc75a90b398500bdfd6c5901432749);
#
#
#
#         marker_bd7d25ff67294002c604907b9f00712c.bindPopup(popup_c3e05b8dd91e3fa33aeca255ca1de6f4)
#         ;
#
#
#
#
#             var marker_c358a0d3e21487aee3abbf33869064fa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4046f81a2cb74722e418eb621805a17a);
#
#
#         var popup_60e9f6fbfeea92fb3815db9a2b2f4507 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_930c2c84326cfcdf8ad784afd323d5fb = $(`&lt;div id=&quot;html_930c2c84326cfcdf8ad784afd323d5fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_60e9f6fbfeea92fb3815db9a2b2f4507.setContent(html_930c2c84326cfcdf8ad784afd323d5fb);
#
#
#
#         marker_c358a0d3e21487aee3abbf33869064fa.bindPopup(popup_60e9f6fbfeea92fb3815db9a2b2f4507)
#         ;
#
#
#
#
#             var marker_a8cf3d60035d051b147753793fa82899 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4046f81a2cb74722e418eb621805a17a);
#
#
#         var popup_a346c3bb88002371d1e7c18f3b2f2f78 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f460a8fa2fef8eb547456a18356d80d2 = $(`&lt;div id=&quot;html_f460a8fa2fef8eb547456a18356d80d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_a346c3bb88002371d1e7c18f3b2f2f78.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_98a79a1760c283d2f7d3297dcaba889c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_98a79a1760c283d2f7d3297dcaba889c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_98a79a1760c283d2f7d3297dcaba889c = L.map(
#                 &quot;map_98a79a1760c283d2f7d3297dcaba889c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3c7ec70bce2dd3ff339e572e72ba0a59 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3c7ec70bce2dd3ff339e572e72ba0a59.addTo(map_98a79a1760c283d2f7d3297dcaba889c);
#
#
#             var feature_group_59cecae0e6b9008222cb9738a20c86c9 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_09307632649826422cff4b4eb298d2c4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_59cecae0e6b9008222cb9738a20c86c9);
#
#
#         var popup_96a7ef728b7db502f3b4011d74a81bfd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c26fdfdfe635d7155bb40ecdb2ff02ad = $(`&lt;div id=&quot;html_c26fdfdfe635d7155bb40ecdb2ff02ad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_96a7ef728b7db502f3b4011d74a81bfd.setContent(html_c26fdfdfe635d7155bb40ecdb2ff02ad);
#
#
#
#         marker_09307632649826422cff4b4eb298d2c4.bindPopup(popup_96a7ef728b7db502f3b4011d74a81bfd)
#         ;
#
#
#
#
#             var marker_25ec0255b952e4a19aecb25d88db68cd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_59cecae0e6b9008222cb9738a20c86c9);
#
#
#         var popup_f605f612e0fa7ccd0d7b4ef54f68da59 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3b791bb1b5f38af109691ac3c49bf0cf = $(`&lt;div id=&quot;html_3b791bb1b5f38af109691ac3c49bf0cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f605f612e0fa7ccd0d7b4ef54f68da59.setContent(html_3b791bb1b5f38af109691ac3c49bf0cf);
#
#
#
#         marker_25ec0255b952e4a19aecb25d88db68cd.bindPopup(popup_f605f612e0fa7ccd0d7b4ef54f68da59)
#         ;
#
#
#
#
#             var marker_fd19361799914900af6939ce03346b76 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_59cecae0e6b9008222cb9738a20c86c9);
#
#
#         var popup_ce33f8fd5df9ec8f138d933c57e84fa3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34bc60212f297d2146821fffb37c3b6c = $(`&lt;div id=&quot;html_34bc60212f297d2146821fffb37c3b6c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_ce33f8fd5df9ec8f138d933c57e84fa3.setContent(html_34bc60212f297d2146821fffb37c3b6c);
#
#
#
#         marker_fd19361799914900af6939ce03346b76.bindPopup(popup_ce33f8fd5df9ec8f138d933c57e84fa3)
#         ;
#
#
#
#
#             var marker_42081bac0ff9b8e82dc7ad67122ddeba = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_59cecae0e6b9008222cb9738a20c86c9);
#
#
#         var popup_078aee23253fc19497b14dbf314a5b33 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4838a66af13f5ef70fdfb7e125b5589f = $(`&lt;div id=&quot;html_4838a66af13f5ef70fdfb7e125b5589f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_078aee23253fc19497b14dbf314a5b33.setContent(html_4838a66af13f5ef70fdfb7e125b5589f);
#
#
#
#         marker_42081bac0ff9b8e82dc7ad67122ddeba.bindPopup(popup_078aee23253fc19497b14dbf314a5b33)
#         ;
#
#
#
#
#             var marker_f7adece51b54ca47ed3e573d04fee908 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_59cecae0e6b9008222cb9738a20c86c9);
#
#
#         var popup_b1e01bb295f878dde4a3881dd658c4ef = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e0845c08a2b4bef9e00e4a1257b6f5a9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e0845c08a2b4bef9e00e4a1257b6f5a9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e0845c08a2b4bef9e00e4a1257b6f5a9 = L.map(
#                 &quot;map_e0845c08a2b4bef9e00e4a1257b6f5a9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2c92bafefc30193db24bbe83f360c03b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2c92bafefc30193db24bbe83f360c03b.addTo(map_e0845c08a2b4bef9e00e4a1257b6f5a9);
#
#
#             var feature_group_b620a40420aaf709f8c9af7a6d609d92 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_b620a40420aaf709f8c9af7a6d609d92.addTo(map_e0845c08a2b4bef9e00e4a1257b6f5a9);
#
#
#             var feature_group_sub_group_ec7a0bb74d969f0e83393f0691ff296d = L.featureGroup.subGroup(
#                 feature_group_b620a40420aaf709f8c9af7a6d609d92
#             );
#
#
#             var marker_aad1e504815f043d5189f047b41ece5a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ec7a0bb74d969f0e83393f0691ff296d);
#
#
#         var popup_3ee4b125b077bb0afe2365757cef0040 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48e333a3e85ba062c1d329529b1fe2c3 = $(`&lt;div id=&quot;html_48e333a3e85ba062c1d329529b1fe2c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_3ee4b125b077bb0afe2365757cef0040.setContent(html_48e333a3e85ba062c1d329529b1fe2c3);
#
#
#
#         marker_aad1e504815f043d5189f047b41ece5a.bindPopup(popup_3ee4b125b077bb0afe2365757cef0040)
#         ;
#
#
#
#
#             var marker_3f88cbcb80e190d5d4a3eb66aa23eda6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ec7a0bb74d969f0e83393f0691ff296d);
#
#
#         var popup_bf74e8def728f89f0ab2a36e10fcf00d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_36e9ee49e3228b2a005caf8d586a38f0 = $(`&lt;div id=&quot;html_36e9ee49e3228b2a005caf8d586a38f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bf74e8def728f89f0ab2a36e10fcf00d.setContent(html_36e9ee49e3228b2a005caf8d586a38f0);
#
#
#
#         marker_3f88cbcb80e190d5d4a3eb66aa23eda6.bindPopup(popup_bf74e8def728f89f0ab2a36e10fcf00d)
#         ;
#
#
#
#
#             var marker_66e087839741b4c2cb7a42278fe6cb69 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ec7a0bb74d969f0e83393f0691ff296d);
#
#
#         var popup_4a7d88bd83499ba820a62d013a0a5cec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b3b9de5e44e1e7f3651c0f358b36e638 = $(`&lt;div id=&quot;html_b3b9de5e44e1e7f3651c0f358b36e638&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4a7d88bd83499ba820a62d013a0a5cec.setContent(html_b3b9de5e44e1e7f3651c0f358b36e638);
#
#
#
#         marker_66e087839741b4c2cb7a42278fe6cb69.bindPopup(popup_4a7d88bd83499ba820a62d013a0a5cec)
#         ;
#
#
#
#
#             var marker_b3de9c373355c4ff5dd55fcd114cb286 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ec7a0bb74d969f0e83393f0691ff296d);
#
#
#         var popup_d1e0b18108245dbf367443a1f12f57f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2699c65268acf246d5c752302613f2fe = $(`&lt;div id=&quot;html_2699c65268acf246d5c752302613f2fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d1e0b18108245dbf367443a1f12f57f1.setContent(html_2699c65268acf246d5c752302613f2fe);
#
#
#
#         marker_
