# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c195db054583482fcf93809642a6d047 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c195db054583482fcf93809642a6d047&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c195db054583482fcf93809642a6d047 = L.map(
#                 &quot;map_c195db054583482fcf93809642a6d047&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_044472855b8bf8a5f4c939f760312032 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_044472855b8bf8a5f4c939f760312032.addTo(map_c195db054583482fcf93809642a6d047);
#
#
#             var marker_8fcca52cd6557184c7748397a3c05898 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c195db054583482fcf93809642a6d047);
#
#
#         var popup_2f4f0cf33e9d59cbfb533ee480aafe2a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_26f44f27ff5704395c72ee77428d9376 = $(`&lt;div id=&quot;html_26f44f27ff5704395c72ee77428d9376&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2f4f0cf33e9d59cbfb533ee480aafe2a.setContent(html_26f44f27ff5704395c72ee77428d9376);
#
#
#
#         marker_8fcca52cd6557184c7748397a3c05898.bindPopup(popup_2f4f0cf33e9d59cbfb533ee480aafe2a)
#         ;
#
#
#
#
#             var marker_64f3edec17273b7c7e3fb98a26f669fa = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c195db054583482fcf93809642a6d047);
#
#
#         var popup_a8ce41e9709a6f17369a6980555f8dfd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a8db3b9b4a0ae7e47416a7fafe55fee9 = $(`&lt;div id=&quot;html_a8db3b9b4a0ae7e47416a7fafe55fee9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a8ce41e9709a6f17369a6980555f8dfd.setContent(html_a8db3b9b4a0ae7e47416a7fafe55fee9);
#
#
#
#         marker_64f3edec17273b7c7e3fb98a26f669fa.bindPopup(popup_a8ce41e9709a6f17369a6980555f8dfd)
#         ;
#
#
#
#
#             var marker_954385a419209337c020f4344e210248 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c195db054583482fcf93809642a6d047);
#
#
#         var popup_e4ecf25a24cbec8460df40ae40d3228a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d662783e44ac8f923d0771757ad7938e = $(`&lt;div id=&quot;html_d662783e44ac8f923d0771757ad7938e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_e4ecf25a24cbec8460df40ae40d3228a.setContent(html_d662783e44ac8f923d0771757ad7938e);
#
#
#
#         marker_954385a419209337c020f4344e210248.bindPopup(popup_e4ecf25a24cbec8460df40ae40d3228a)
#         ;
#
#
#
#
#             var marker_5c85a37c3bf010c2495c0d81723eeaec = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c195db054583482fcf93809642a6d047);
#
#
#         var popup_d50c308c4d82f2eeb91c048ad625df6c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c0efb2b3f8ed3732b387c5764b16d9c = $(`&lt;div id=&quot;html_9c0efb2b3f8ed3732b387c5764b16d9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_d50c308c4d82f2eeb91c048ad625df6c.setContent(html_9c0efb2b3f8ed3732b387c5764b16d9c);
#
#
#
#         marker_5c85a37c3bf010c2495c0d81723eeaec.bindPopup(popup_d50c308c4d82f2eeb91c048ad625df6c)
#         ;
#
#
#
#
#             var marker_0a36a87d0c907fad4501c359f357c5ed = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c195db054583482fcf93809642a6d047);
#
#
#         var popup_4e333eedd34dd6340f72b00e5b39c024 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77919c958c163a3b14c1ad1195beac0f = $(`&lt;div id=&quot;html_77919c958c163a3b14c1ad1195beac0f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4e333eedd34dd6340f72b00e5b39c024.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ef6deae36bac50f9335742cef7cf1f5a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ef6deae36bac50f9335742cef7cf1f5a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ef6deae36bac50f9335742cef7cf1f5a = L.map(
#                 &quot;map_ef6deae36bac50f9335742cef7cf1f5a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_147caba6bce89c80a07ad2577aec8e93 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_147caba6bce89c80a07ad2577aec8e93.addTo(map_ef6deae36bac50f9335742cef7cf1f5a);
#
#
#             var feature_group_cc9e970a1698b36876cfdf2ea4d0a210 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_e8b1d4ff0287927fc6524c0eb16090d1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_cc9e970a1698b36876cfdf2ea4d0a210);
#
#
#         var popup_b63c3aa33c59eed205420fb06663023c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82a0203ad16e75ad349e6d96569231dc = $(`&lt;div id=&quot;html_82a0203ad16e75ad349e6d96569231dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b63c3aa33c59eed205420fb06663023c.setContent(html_82a0203ad16e75ad349e6d96569231dc);
#
#
#
#         marker_e8b1d4ff0287927fc6524c0eb16090d1.bindPopup(popup_b63c3aa33c59eed205420fb06663023c)
#         ;
#
#
#
#
#             var marker_ed2e19495cf77879cbc3f12d045a1517 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_cc9e970a1698b36876cfdf2ea4d0a210);
#
#
#         var popup_ebff747fe922bc2b476d4d1ce39823fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4438a16cc1bf1325237208273e7134a2 = $(`&lt;div id=&quot;html_4438a16cc1bf1325237208273e7134a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ebff747fe922bc2b476d4d1ce39823fc.setContent(html_4438a16cc1bf1325237208273e7134a2);
#
#
#
#         marker_ed2e19495cf77879cbc3f12d045a1517.bindPopup(popup_ebff747fe922bc2b476d4d1ce39823fc)
#         ;
#
#
#
#
#             var marker_a04f2cff70c0db69ba4d2d7b6db99791 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_cc9e970a1698b36876cfdf2ea4d0a210);
#
#
#         var popup_2f6c6072fad46555d85338b733473aa5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67cf31d93761154982b94ab54ff10445 = $(`&lt;div id=&quot;html_67cf31d93761154982b94ab54ff10445&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2f6c6072fad46555d85338b733473aa5.setContent(html_67cf31d93761154982b94ab54ff10445);
#
#
#
#         marker_a04f2cff70c0db69ba4d2d7b6db99791.bindPopup(popup_2f6c6072fad46555d85338b733473aa5)
#         ;
#
#
#
#
#             var marker_79e3dc8e14bb98715beb2681681a61af = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_cc9e970a1698b36876cfdf2ea4d0a210);
#
#
#         var popup_40859269fa393aab693800ad10d87b1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_848323986c6ffdd918ab46d81d66c7b5 = $(`&lt;div id=&quot;html_848323986c6ffdd918ab46d81d66c7b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_40859269fa393aab693800ad10d87b1d.setContent(html_848323986c6ffdd918ab46d81d66c7b5);
#
#
#
#         marker_79e3dc8e14bb98715beb2681681a61af.bindPopup(popup_40859269fa393aab693800ad10d87b1d)
#         ;
#
#
#
#
#             var marker_b72d209a1aa49ad3d407aff1ea8b7de7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_cc9e970a1698b36876cfdf2ea4d0a210);
#
#
#         var popup_ea2d82100ae3d22250337787c795241a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b7a3e9833d76089826ff917e0901d917 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b7a3e9833d76089826ff917e0901d917&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b7a3e9833d76089826ff917e0901d917 = L.map(
#                 &quot;map_b7a3e9833d76089826ff917e0901d917&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_df8ed06d87e1793abe7d61b3ff55841a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_df8ed06d87e1793abe7d61b3ff55841a.addTo(map_b7a3e9833d76089826ff917e0901d917);
#
#
#             var feature_group_e4cb624e35c11bd05a138b7e7008126b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_e4cb624e35c11bd05a138b7e7008126b.addTo(map_b7a3e9833d76089826ff917e0901d917);
#
#
#             var feature_group_sub_group_199d19b8800307751ad0b07b9dc0038a = L.featureGroup.subGroup(
#                 feature_group_e4cb624e35c11bd05a138b7e7008126b
#             );
#
#
#             var marker_c3fe89f2fbb595bbd388cd3098f910d5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_199d19b8800307751ad0b07b9dc0038a);
#
#
#         var popup_c765a18fb9da77176fab5c54eba898b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_91abad117587cecd2be2cff05cf462cd = $(`&lt;div id=&quot;html_91abad117587cecd2be2cff05cf462cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c765a18fb9da77176fab5c54eba898b2.setContent(html_91abad117587cecd2be2cff05cf462cd);
#
#
#
#         marker_c3fe89f2fbb595bbd388cd3098f910d5.bindPopup(popup_c765a18fb9da77176fab5c54eba898b2)
#         ;
#
#
#
#
#             var marker_d6297bfe2f769c9f7e983b15996aac52 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_199d19b8800307751ad0b07b9dc0038a);
#
#
#         var popup_0d738820ac2c3a298319cac450100e75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8f95dc6a32ed525c2174e03148706ea = $(`&lt;div id=&quot;html_f8f95dc6a32ed525c2174e03148706ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_0d738820ac2c3a298319cac450100e75.setContent(html_f8f95dc6a32ed525c2174e03148706ea);
#
#
#
#         marker_d6297bfe2f769c9f7e983b15996aac52.bindPopup(popup_0d738820ac2c3a298319cac450100e75)
#         ;
#
#
#
#
#             var marker_2421edf97575dfeab186783f8cbd9fb8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_199d19b8800307751ad0b07b9dc0038a);
#
#
#         var popup_a9fafa480300865c06dba73ce8c4ba8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_860f7b9e5f1a2be15c7f9fe6ce0a1cce = $(`&lt;div id=&quot;html_860f7b9e5f1a2be15c7f9fe6ce0a1cce&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a9fafa480300865c06dba73ce8c4ba8b.setContent(html_860f7b9e5f1a2be15c7f9fe6ce0a1cce);
#
#
#
#         marker_2421edf97575dfeab186783f8cbd9fb8.bindPopup(popup_a9fafa480300865c06dba73ce8c4ba8b)
#         ;
#
#
#
#
#             var marker_d0bb0041e85285bd28ffb2abcd125c68 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_199d19b8800307751ad0b07b9dc0038a);
#
#
#         var popup_65aeb9b0341406fe5a7a753a6e6f2db0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7cc9decf84ab64b02e6abcfee47eb10a = $(`&lt;div id=&quot;html_7cc9decf84ab64b02e6abcfee47eb10a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_65aeb9b0341406fe5a7a753a6e6f2db0.setContent(html_7cc9decf84ab64b02e6abcfee47eb10a);
#
#
#
#         marker_
