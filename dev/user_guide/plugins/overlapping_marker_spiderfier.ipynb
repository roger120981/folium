# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_85dd6fae60a0fca789f9ada31e4fbb43 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_85dd6fae60a0fca789f9ada31e4fbb43&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_85dd6fae60a0fca789f9ada31e4fbb43 = L.map(
#                 &quot;map_85dd6fae60a0fca789f9ada31e4fbb43&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f3a0d609cc2e7aad3854eb819ea30e8b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f3a0d609cc2e7aad3854eb819ea30e8b.addTo(map_85dd6fae60a0fca789f9ada31e4fbb43);
#
#
#             var marker_68333edb2e8059d35221230165b97c25 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_85dd6fae60a0fca789f9ada31e4fbb43);
#
#
#         var popup_baf4b4680668c3b73cdeace3750ac6ad = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6691b1dbbdc1d643c98368b67460df4 = $(`&lt;div id=&quot;html_f6691b1dbbdc1d643c98368b67460df4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_baf4b4680668c3b73cdeace3750ac6ad.setContent(html_f6691b1dbbdc1d643c98368b67460df4);
#
#
#
#         marker_68333edb2e8059d35221230165b97c25.bindPopup(popup_baf4b4680668c3b73cdeace3750ac6ad)
#         ;
#
#
#
#
#             var marker_08e70e6a7d18fc4b4fa1b62f581a92cd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_85dd6fae60a0fca789f9ada31e4fbb43);
#
#
#         var popup_60f22cf3a8f2f2658bcd8c61028e4277 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e401fa5468b56928ba423de7a3f926c = $(`&lt;div id=&quot;html_1e401fa5468b56928ba423de7a3f926c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_60f22cf3a8f2f2658bcd8c61028e4277.setContent(html_1e401fa5468b56928ba423de7a3f926c);
#
#
#
#         marker_08e70e6a7d18fc4b4fa1b62f581a92cd.bindPopup(popup_60f22cf3a8f2f2658bcd8c61028e4277)
#         ;
#
#
#
#
#             var marker_bf92d9cfd30d6890c356c295f50a9c13 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_85dd6fae60a0fca789f9ada31e4fbb43);
#
#
#         var popup_ae8eecdf055d65b283a3383652bb797d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aff2bc883c28ac8d20a41446122cde39 = $(`&lt;div id=&quot;html_aff2bc883c28ac8d20a41446122cde39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ae8eecdf055d65b283a3383652bb797d.setContent(html_aff2bc883c28ac8d20a41446122cde39);
#
#
#
#         marker_bf92d9cfd30d6890c356c295f50a9c13.bindPopup(popup_ae8eecdf055d65b283a3383652bb797d)
#         ;
#
#
#
#
#             var marker_659963f54385ad2453defafda79ef3bb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_85dd6fae60a0fca789f9ada31e4fbb43);
#
#
#         var popup_984c83b237b5497297d58d7e4826fc74 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1fbc2c919950e35fa819cc9a96f02180 = $(`&lt;div id=&quot;html_1fbc2c919950e35fa819cc9a96f02180&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_984c83b237b5497297d58d7e4826fc74.setContent(html_1fbc2c919950e35fa819cc9a96f02180);
#
#
#
#         marker_659963f54385ad2453defafda79ef3bb.bindPopup(popup_984c83b237b5497297d58d7e4826fc74)
#         ;
#
#
#
#
#             var marker_1424326b3460d706945970cc2b353347 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_85dd6fae60a0fca789f9ada31e4fbb43);
#
#
#         var popup_d9f2f66f7b9d1a11a0fa6878e6c11435 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fea19ff48bb9c8f17a2c8e15d05865bd = $(`&lt;div id=&quot;html_fea19ff48bb9c8f17a2c8e15d05865bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_d9f2f66f7b9d1a11a0fa6878e6c11435.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_49b0e1aefed9c97cbe563aa260d43463 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_49b0e1aefed9c97cbe563aa260d43463&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_49b0e1aefed9c97cbe563aa260d43463 = L.map(
#                 &quot;map_49b0e1aefed9c97cbe563aa260d43463&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e74fd2f441bd603952f1254318e10e85 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e74fd2f441bd603952f1254318e10e85.addTo(map_49b0e1aefed9c97cbe563aa260d43463);
#
#
#             var feature_group_9410db4b03c81cfa834bbb47779ada56 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_486c97f86253401ad68ec31b6728fb7a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9410db4b03c81cfa834bbb47779ada56);
#
#
#         var popup_2790acf0433c9cca598b19699d2ff83c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7323b8ca122934afd7ba99eeb22f06f4 = $(`&lt;div id=&quot;html_7323b8ca122934afd7ba99eeb22f06f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_2790acf0433c9cca598b19699d2ff83c.setContent(html_7323b8ca122934afd7ba99eeb22f06f4);
#
#
#
#         marker_486c97f86253401ad68ec31b6728fb7a.bindPopup(popup_2790acf0433c9cca598b19699d2ff83c)
#         ;
#
#
#
#
#             var marker_77480e4ca504712dc59e580209897fd7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9410db4b03c81cfa834bbb47779ada56);
#
#
#         var popup_1baa1a483692a2c9113283d7eade91f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8c96785c51dd63e6ef0c1940f920d06f = $(`&lt;div id=&quot;html_8c96785c51dd63e6ef0c1940f920d06f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1baa1a483692a2c9113283d7eade91f7.setContent(html_8c96785c51dd63e6ef0c1940f920d06f);
#
#
#
#         marker_77480e4ca504712dc59e580209897fd7.bindPopup(popup_1baa1a483692a2c9113283d7eade91f7)
#         ;
#
#
#
#
#             var marker_8b36dbdaec51060a791ded0240512cea = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9410db4b03c81cfa834bbb47779ada56);
#
#
#         var popup_86de173820f67e335480ca71c00e9f4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_babf5de041aedabcc457c20f7915b1a7 = $(`&lt;div id=&quot;html_babf5de041aedabcc457c20f7915b1a7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_86de173820f67e335480ca71c00e9f4b.setContent(html_babf5de041aedabcc457c20f7915b1a7);
#
#
#
#         marker_8b36dbdaec51060a791ded0240512cea.bindPopup(popup_86de173820f67e335480ca71c00e9f4b)
#         ;
#
#
#
#
#             var marker_e60b45151e4f52b2f6d491607d612c8f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9410db4b03c81cfa834bbb47779ada56);
#
#
#         var popup_5e19e9361b975b38c97e37fffa10d1c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5ac5a799c4ebe543f065c509805bbbe3 = $(`&lt;div id=&quot;html_5ac5a799c4ebe543f065c509805bbbe3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5e19e9361b975b38c97e37fffa10d1c3.setContent(html_5ac5a799c4ebe543f065c509805bbbe3);
#
#
#
#         marker_e60b45151e4f52b2f6d491607d612c8f.bindPopup(popup_5e19e9361b975b38c97e37fffa10d1c3)
#         ;
#
#
#
#
#             var marker_651466e8e7e30a0bcd9269143d4d701d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9410db4b03c81cfa834bbb47779ada56);
#
#
#         var popup_75558f1ef8411e4d1a900b6f530110cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ddfddc5037f0da7f9187114efe3e6af0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ddfddc5037f0da7f9187114efe3e6af0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ddfddc5037f0da7f9187114efe3e6af0 = L.map(
#                 &quot;map_ddfddc5037f0da7f9187114efe3e6af0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a787d99982b044b45718d296c53c94d5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a787d99982b044b45718d296c53c94d5.addTo(map_ddfddc5037f0da7f9187114efe3e6af0);
#
#
#             var feature_group_555788d83e3217d579d16bc33a2e36e2 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_555788d83e3217d579d16bc33a2e36e2.addTo(map_ddfddc5037f0da7f9187114efe3e6af0);
#
#
#             var feature_group_sub_group_e8201ebfaf78c79cbdcfc4fd05e5ca8c = L.featureGroup.subGroup(
#                 feature_group_555788d83e3217d579d16bc33a2e36e2
#             );
#
#
#             var marker_ec0368ade7f638560b135c69e523682b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_e8201ebfaf78c79cbdcfc4fd05e5ca8c);
#
#
#         var popup_d588c41d7d4e11b07d542d43db597453 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a11cf28d50fe40b4809a7dc1cb52fcd = $(`&lt;div id=&quot;html_9a11cf28d50fe40b4809a7dc1cb52fcd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d588c41d7d4e11b07d542d43db597453.setContent(html_9a11cf28d50fe40b4809a7dc1cb52fcd);
#
#
#
#         marker_ec0368ade7f638560b135c69e523682b.bindPopup(popup_d588c41d7d4e11b07d542d43db597453)
#         ;
#
#
#
#
#             var marker_fdc88805147bebf8c06a4dc5c08132ff = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_e8201ebfaf78c79cbdcfc4fd05e5ca8c);
#
#
#         var popup_a3fdfd7d756b6753b474f4c3b2d81117 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b32a505278d4045df0833b830efbe6b1 = $(`&lt;div id=&quot;html_b32a505278d4045df0833b830efbe6b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_a3fdfd7d756b6753b474f4c3b2d81117.setContent(html_b32a505278d4045df0833b830efbe6b1);
#
#
#
#         marker_fdc88805147bebf8c06a4dc5c08132ff.bindPopup(popup_a3fdfd7d756b6753b474f4c3b2d81117)
#         ;
#
#
#
#
#             var marker_834b86a68b63f32aa17d876d56f69d0f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_e8201ebfaf78c79cbdcfc4fd05e5ca8c);
#
#
#         var popup_54bcae5cd215c3babefbe03544640b10 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_724022a46668da4ad59e6794b2a776b9 = $(`&lt;div id=&quot;html_724022a46668da4ad59e6794b2a776b9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_54bcae5cd215c3babefbe03544640b10.setContent(html_724022a46668da4ad59e6794b2a776b9);
#
#
#
#         marker_834b86a68b63f32aa17d876d56f69d0f.bindPopup(popup_54bcae5cd215c3babefbe03544640b10)
#         ;
#
#
#
#
#             var marker_72068ec4d6193fdc2265f0ea66cccf61 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_e8201ebfaf78c79cbdcfc4fd05e5ca8c);
#
#
#         var popup_d834b445958098c22c15aff592ef1a71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f19e5de23fad3d81c806112b964a23f9 = $(`&lt;div id=&quot;html_f19e5de23fad3d81c806112b964a23f9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_d834b445958098c22c15aff592ef1a71.setContent(html_f19e5de23fad3d81c806112b964a23f9);
#
#
#
#         marker_
