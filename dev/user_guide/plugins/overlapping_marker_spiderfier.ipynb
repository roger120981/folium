# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77662b89570b859d901f10781732eaf0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77662b89570b859d901f10781732eaf0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_77662b89570b859d901f10781732eaf0 = L.map(
#                 &quot;map_77662b89570b859d901f10781732eaf0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5011ce06b985d54dcdc2085bb861e18e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5011ce06b985d54dcdc2085bb861e18e.addTo(map_77662b89570b859d901f10781732eaf0);
#
#
#             var marker_503446a232bed991ae93aa31fa7394ba = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_77662b89570b859d901f10781732eaf0);
#
#
#         var popup_ef9888af33f27ba500d82e354f858a36 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_816049a9df1b298a7c0e5ee7fcc9f95d = $(`&lt;div id=&quot;html_816049a9df1b298a7c0e5ee7fcc9f95d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ef9888af33f27ba500d82e354f858a36.setContent(html_816049a9df1b298a7c0e5ee7fcc9f95d);
#
#
#
#         marker_503446a232bed991ae93aa31fa7394ba.bindPopup(popup_ef9888af33f27ba500d82e354f858a36)
#         ;
#
#
#
#
#             var marker_1914490c12f289241c3297fd5f32ac5c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_77662b89570b859d901f10781732eaf0);
#
#
#         var popup_35ec0d05a1cb06915ce65adb230b5c56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4617c193d102ee37a190536d4a4e258d = $(`&lt;div id=&quot;html_4617c193d102ee37a190536d4a4e258d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_35ec0d05a1cb06915ce65adb230b5c56.setContent(html_4617c193d102ee37a190536d4a4e258d);
#
#
#
#         marker_1914490c12f289241c3297fd5f32ac5c.bindPopup(popup_35ec0d05a1cb06915ce65adb230b5c56)
#         ;
#
#
#
#
#             var marker_dd41b20053c845920d492bd371b349dc = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_77662b89570b859d901f10781732eaf0);
#
#
#         var popup_ee60a7ea222e703a6f8f84cdc40dd648 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcb29d8c9716d588e22fe05a7bc7ce83 = $(`&lt;div id=&quot;html_dcb29d8c9716d588e22fe05a7bc7ce83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ee60a7ea222e703a6f8f84cdc40dd648.setContent(html_dcb29d8c9716d588e22fe05a7bc7ce83);
#
#
#
#         marker_dd41b20053c845920d492bd371b349dc.bindPopup(popup_ee60a7ea222e703a6f8f84cdc40dd648)
#         ;
#
#
#
#
#             var marker_2093e39da8a23478ffa10f9273940bbd = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_77662b89570b859d901f10781732eaf0);
#
#
#         var popup_ccfa4608e6c1c8130fe9d9f8c5a0bdab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bf03970d73053a9e5d2f3bdcdf3d44fe = $(`&lt;div id=&quot;html_bf03970d73053a9e5d2f3bdcdf3d44fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_ccfa4608e6c1c8130fe9d9f8c5a0bdab.setContent(html_bf03970d73053a9e5d2f3bdcdf3d44fe);
#
#
#
#         marker_2093e39da8a23478ffa10f9273940bbd.bindPopup(popup_ccfa4608e6c1c8130fe9d9f8c5a0bdab)
#         ;
#
#
#
#
#             var marker_f1ad1683b846626a24aa64ac25cc444a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_77662b89570b859d901f10781732eaf0);
#
#
#         var popup_77c2b6ec9725fe740a472ee88f415ad5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ade9dd521df946a03d00c7d5b54afe7 = $(`&lt;div id=&quot;html_4ade9dd521df946a03d00c7d5b54afe7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_77c2b6ec9725fe740a472ee88f415ad5.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_200a18ff3d3dc3148c4bf3691252acd0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_200a18ff3d3dc3148c4bf3691252acd0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_200a18ff3d3dc3148c4bf3691252acd0 = L.map(
#                 &quot;map_200a18ff3d3dc3148c4bf3691252acd0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b2e78bd8c22bc45f4c4679ad3796ec6 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5b2e78bd8c22bc45f4c4679ad3796ec6.addTo(map_200a18ff3d3dc3148c4bf3691252acd0);
#
#
#             var feature_group_fc9bc0f457ae8a463282b838ec2c819f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_24690632947f7c05bd213ec233367ae0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_fc9bc0f457ae8a463282b838ec2c819f);
#
#
#         var popup_89e2c49003bc137f8033c095fb0bc4e6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a0e7ed02bf52445a836f5e4fc0a5ce67 = $(`&lt;div id=&quot;html_a0e7ed02bf52445a836f5e4fc0a5ce67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_89e2c49003bc137f8033c095fb0bc4e6.setContent(html_a0e7ed02bf52445a836f5e4fc0a5ce67);
#
#
#
#         marker_24690632947f7c05bd213ec233367ae0.bindPopup(popup_89e2c49003bc137f8033c095fb0bc4e6)
#         ;
#
#
#
#
#             var marker_35455958fa72d6318da6eb8e16e093bc = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_fc9bc0f457ae8a463282b838ec2c819f);
#
#
#         var popup_46b40271e85b4b26b5e1c975f5ff6616 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce2daedad0afa50aa728c9c8a092f2b8 = $(`&lt;div id=&quot;html_ce2daedad0afa50aa728c9c8a092f2b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_46b40271e85b4b26b5e1c975f5ff6616.setContent(html_ce2daedad0afa50aa728c9c8a092f2b8);
#
#
#
#         marker_35455958fa72d6318da6eb8e16e093bc.bindPopup(popup_46b40271e85b4b26b5e1c975f5ff6616)
#         ;
#
#
#
#
#             var marker_c1e524e98e2e92788be6213b87ca3da7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_fc9bc0f457ae8a463282b838ec2c819f);
#
#
#         var popup_edcb2def9edc108d4b494dce6c423ac3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7abfa7288873c620543eb99642e3c726 = $(`&lt;div id=&quot;html_7abfa7288873c620543eb99642e3c726&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_edcb2def9edc108d4b494dce6c423ac3.setContent(html_7abfa7288873c620543eb99642e3c726);
#
#
#
#         marker_c1e524e98e2e92788be6213b87ca3da7.bindPopup(popup_edcb2def9edc108d4b494dce6c423ac3)
#         ;
#
#
#
#
#             var marker_95ef4fc55541fb4d7e7444ab0b6ca8e8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_fc9bc0f457ae8a463282b838ec2c819f);
#
#
#         var popup_19e762bbba989d02f575cc6c70904ed2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90b54314bd52c0487f72f8f3253122fd = $(`&lt;div id=&quot;html_90b54314bd52c0487f72f8f3253122fd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_19e762bbba989d02f575cc6c70904ed2.setContent(html_90b54314bd52c0487f72f8f3253122fd);
#
#
#
#         marker_95ef4fc55541fb4d7e7444ab0b6ca8e8.bindPopup(popup_19e762bbba989d02f575cc6c70904ed2)
#         ;
#
#
#
#
#             var marker_bbd7523560a2264ad920bc468dbbaf82 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_fc9bc0f457ae8a463282b838ec2c819f);
#
#
#         var popup_1995d1dcd58afdf0493e58683cc9ea3a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ca38b614352dd8d9019e4f8bda64cd1a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ca38b614352dd8d9019e4f8bda64cd1a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ca38b614352dd8d9019e4f8bda64cd1a = L.map(
#                 &quot;map_ca38b614352dd8d9019e4f8bda64cd1a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_03894eab71a9a4f9385e1a7380995a69 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_03894eab71a9a4f9385e1a7380995a69.addTo(map_ca38b614352dd8d9019e4f8bda64cd1a);
#
#
#             var feature_group_27957ed5ea000282009ab5d81569ef15 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_27957ed5ea000282009ab5d81569ef15.addTo(map_ca38b614352dd8d9019e4f8bda64cd1a);
#
#
#             var feature_group_sub_group_519b861a5b831324a04f19275c2b10a0 = L.featureGroup.subGroup(
#                 feature_group_27957ed5ea000282009ab5d81569ef15
#             );
#
#
#             var marker_169c1fe476f7ec7e82ea01aa1c2b1505 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_519b861a5b831324a04f19275c2b10a0);
#
#
#         var popup_e9c5e9a972054f91046fdc74ecf5fffa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bca83023387ba77b8baa0e9756db9c53 = $(`&lt;div id=&quot;html_bca83023387ba77b8baa0e9756db9c53&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e9c5e9a972054f91046fdc74ecf5fffa.setContent(html_bca83023387ba77b8baa0e9756db9c53);
#
#
#
#         marker_169c1fe476f7ec7e82ea01aa1c2b1505.bindPopup(popup_e9c5e9a972054f91046fdc74ecf5fffa)
#         ;
#
#
#
#
#             var marker_a5e30bd7341ed5bf2d5323a4ce96cad4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_519b861a5b831324a04f19275c2b10a0);
#
#
#         var popup_1fcd9423b1db336085f0517a70eef9cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_862c00bd0b39c701f67d551a4d55fb47 = $(`&lt;div id=&quot;html_862c00bd0b39c701f67d551a4d55fb47&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1fcd9423b1db336085f0517a70eef9cb.setContent(html_862c00bd0b39c701f67d551a4d55fb47);
#
#
#
#         marker_a5e30bd7341ed5bf2d5323a4ce96cad4.bindPopup(popup_1fcd9423b1db336085f0517a70eef9cb)
#         ;
#
#
#
#
#             var marker_aad60244af5df41a5d54e2361837639f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_519b861a5b831324a04f19275c2b10a0);
#
#
#         var popup_bc73fc128d5dc7eafa8f42d7386141a7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50b71c71ba4ad6f145ba636096fcd2f2 = $(`&lt;div id=&quot;html_50b71c71ba4ad6f145ba636096fcd2f2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bc73fc128d5dc7eafa8f42d7386141a7.setContent(html_50b71c71ba4ad6f145ba636096fcd2f2);
#
#
#
#         marker_aad60244af5df41a5d54e2361837639f.bindPopup(popup_bc73fc128d5dc7eafa8f42d7386141a7)
#         ;
#
#
#
#
#             var marker_4fdfb212a67d913b93be454e76b71fe6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_519b861a5b831324a04f19275c2b10a0);
#
#
#         var popup_1a1ac4348612d1f5011fe5fd5790533a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fb86d4cd435e10d1e0ee23f9ba6af090 = $(`&lt;div id=&quot;html_fb86d4cd435e10d1e0ee23f9ba6af090&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1a1ac4348612d1f5011fe5fd5790533a.setContent(html_fb86d4cd435e10d1e0ee23f9ba6af090);
#
#
#
#         marker_
