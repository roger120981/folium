# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42e120a600bc7ca310709f1d964c85a5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42e120a600bc7ca310709f1d964c85a5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42e120a600bc7ca310709f1d964c85a5 = L.map(
#                 &quot;map_42e120a600bc7ca310709f1d964c85a5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0f76f850a3d6da661c4c0ec13dd0ecf3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0f76f850a3d6da661c4c0ec13dd0ecf3.addTo(map_42e120a600bc7ca310709f1d964c85a5);
#
#
#             var marker_3afb817c40cd81ebbfc9095c5015fce3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_42e120a600bc7ca310709f1d964c85a5);
#
#
#         var popup_077e518abc845bad5021f63add85220b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5a26e1460705838de5cabcea999adc2 = $(`&lt;div id=&quot;html_e5a26e1460705838de5cabcea999adc2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_077e518abc845bad5021f63add85220b.setContent(html_e5a26e1460705838de5cabcea999adc2);
#
#
#
#         marker_3afb817c40cd81ebbfc9095c5015fce3.bindPopup(popup_077e518abc845bad5021f63add85220b)
#         ;
#
#
#
#
#             var marker_7f8fc10bac695deb3580895cf482031e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_42e120a600bc7ca310709f1d964c85a5);
#
#
#         var popup_87a3aabd6418a2e291019eb4c49c3390 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_906b252c6de6688181e8a93ae5062aa2 = $(`&lt;div id=&quot;html_906b252c6de6688181e8a93ae5062aa2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_87a3aabd6418a2e291019eb4c49c3390.setContent(html_906b252c6de6688181e8a93ae5062aa2);
#
#
#
#         marker_7f8fc10bac695deb3580895cf482031e.bindPopup(popup_87a3aabd6418a2e291019eb4c49c3390)
#         ;
#
#
#
#
#             var marker_c7a4fed947ee248ae8211e966e95e33d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_42e120a600bc7ca310709f1d964c85a5);
#
#
#         var popup_f7641933b3375d918aa35eff56ec8aa7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a201833864b170dcb8c52c439523e5a = $(`&lt;div id=&quot;html_5a201833864b170dcb8c52c439523e5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f7641933b3375d918aa35eff56ec8aa7.setContent(html_5a201833864b170dcb8c52c439523e5a);
#
#
#
#         marker_c7a4fed947ee248ae8211e966e95e33d.bindPopup(popup_f7641933b3375d918aa35eff56ec8aa7)
#         ;
#
#
#
#
#             var marker_51e51c6afc8f993918b34df6b31ef84e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_42e120a600bc7ca310709f1d964c85a5);
#
#
#         var popup_0d3226217e588c41483333ed4a7f6ecd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e11bb3f0e416bb95b8dcc80002bcd38 = $(`&lt;div id=&quot;html_9e11bb3f0e416bb95b8dcc80002bcd38&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_0d3226217e588c41483333ed4a7f6ecd.setContent(html_9e11bb3f0e416bb95b8dcc80002bcd38);
#
#
#
#         marker_51e51c6afc8f993918b34df6b31ef84e.bindPopup(popup_0d3226217e588c41483333ed4a7f6ecd)
#         ;
#
#
#
#
#             var marker_ce008ec557089b61763f7834ec4656ee = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_42e120a600bc7ca310709f1d964c85a5);
#
#
#         var popup_8105d5d6d7cf99c0394986829cc1253f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_417330a24e68b367f844d543cc747e98 = $(`&lt;div id=&quot;html_417330a24e68b367f844d543cc747e98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8105d5d6d7cf99c0394986829cc1253f.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9cf4809f985f8fdbc2dbaa56d524d671 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9cf4809f985f8fdbc2dbaa56d524d671&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9cf4809f985f8fdbc2dbaa56d524d671 = L.map(
#                 &quot;map_9cf4809f985f8fdbc2dbaa56d524d671&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_38ffdfe64022483496c7b82d29e6246f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_38ffdfe64022483496c7b82d29e6246f.addTo(map_9cf4809f985f8fdbc2dbaa56d524d671);
#
#
#             var feature_group_7bc8bff9558d7143a3ee10c508d47ba6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_727f4923e84aba62a4b7dbc7d40a65dc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7bc8bff9558d7143a3ee10c508d47ba6);
#
#
#         var popup_b52916db129f5640e666f4e41a505042 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ddc4b6b0dfd8b64d65733373da57a4f4 = $(`&lt;div id=&quot;html_ddc4b6b0dfd8b64d65733373da57a4f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b52916db129f5640e666f4e41a505042.setContent(html_ddc4b6b0dfd8b64d65733373da57a4f4);
#
#
#
#         marker_727f4923e84aba62a4b7dbc7d40a65dc.bindPopup(popup_b52916db129f5640e666f4e41a505042)
#         ;
#
#
#
#
#             var marker_7f1bc7fa3464dab788d52f913112e1a3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7bc8bff9558d7143a3ee10c508d47ba6);
#
#
#         var popup_69cdc7c1875b301dd06f6ef1b9159254 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5acf9229d9b01340fbc364481a23d05 = $(`&lt;div id=&quot;html_b5acf9229d9b01340fbc364481a23d05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_69cdc7c1875b301dd06f6ef1b9159254.setContent(html_b5acf9229d9b01340fbc364481a23d05);
#
#
#
#         marker_7f1bc7fa3464dab788d52f913112e1a3.bindPopup(popup_69cdc7c1875b301dd06f6ef1b9159254)
#         ;
#
#
#
#
#             var marker_bca777c82bd3db2cb5957b22a5b08094 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7bc8bff9558d7143a3ee10c508d47ba6);
#
#
#         var popup_854335d01f4768bcac19e3d8cb57bf69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a56fd0faeb9fec9d9028e0256f163dc1 = $(`&lt;div id=&quot;html_a56fd0faeb9fec9d9028e0256f163dc1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_854335d01f4768bcac19e3d8cb57bf69.setContent(html_a56fd0faeb9fec9d9028e0256f163dc1);
#
#
#
#         marker_bca777c82bd3db2cb5957b22a5b08094.bindPopup(popup_854335d01f4768bcac19e3d8cb57bf69)
#         ;
#
#
#
#
#             var marker_cc2972e582975fc14a4799928565bc36 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7bc8bff9558d7143a3ee10c508d47ba6);
#
#
#         var popup_660a9a964d98d03146a28ea452e1d858 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e66a6e1f7bc87a7dcc5e750f89e9ea49 = $(`&lt;div id=&quot;html_e66a6e1f7bc87a7dcc5e750f89e9ea49&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_660a9a964d98d03146a28ea452e1d858.setContent(html_e66a6e1f7bc87a7dcc5e750f89e9ea49);
#
#
#
#         marker_cc2972e582975fc14a4799928565bc36.bindPopup(popup_660a9a964d98d03146a28ea452e1d858)
#         ;
#
#
#
#
#             var marker_391484fd39cde9dc8a967395a9653871 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7bc8bff9558d7143a3ee10c508d47ba6);
#
#
#         var popup_46d99de57ee0ab0be4522eb93d0b15e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_88f80575aa661d22fd81ce6125e734c6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_88f80575aa661d22fd81ce6125e734c6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_88f80575aa661d22fd81ce6125e734c6 = L.map(
#                 &quot;map_88f80575aa661d22fd81ce6125e734c6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1a71b7732f0adba4f106adc1a58b1cbd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1a71b7732f0adba4f106adc1a58b1cbd.addTo(map_88f80575aa661d22fd81ce6125e734c6);
#
#
#             var feature_group_23d98ddabf474f4cb30e5c7d20e4f444 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_23d98ddabf474f4cb30e5c7d20e4f444.addTo(map_88f80575aa661d22fd81ce6125e734c6);
#
#
#             var feature_group_sub_group_81333c2c98cb65bcb94998a25bde5411 = L.featureGroup.subGroup(
#                 feature_group_23d98ddabf474f4cb30e5c7d20e4f444
#             );
#
#
#             var marker_74607a70aac81f528a4094d96204a7b0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_81333c2c98cb65bcb94998a25bde5411);
#
#
#         var popup_148acb1245196d0d80147bb1e1eb178d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ed089ec308d10fd207255e775df23d2 = $(`&lt;div id=&quot;html_4ed089ec308d10fd207255e775df23d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_148acb1245196d0d80147bb1e1eb178d.setContent(html_4ed089ec308d10fd207255e775df23d2);
#
#
#
#         marker_74607a70aac81f528a4094d96204a7b0.bindPopup(popup_148acb1245196d0d80147bb1e1eb178d)
#         ;
#
#
#
#
#             var marker_31843de31c1c447dac10686dd9c73804 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_81333c2c98cb65bcb94998a25bde5411);
#
#
#         var popup_00457e2a07837ceb3a3ab951a8a202f2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_47309bde46080ffd866398190c19a581 = $(`&lt;div id=&quot;html_47309bde46080ffd866398190c19a581&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_00457e2a07837ceb3a3ab951a8a202f2.setContent(html_47309bde46080ffd866398190c19a581);
#
#
#
#         marker_31843de31c1c447dac10686dd9c73804.bindPopup(popup_00457e2a07837ceb3a3ab951a8a202f2)
#         ;
#
#
#
#
#             var marker_28e556a88f5886a8de6767f506b0e229 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_81333c2c98cb65bcb94998a25bde5411);
#
#
#         var popup_89476b89574302a462bab6b6c52b26b9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_60efcc99338ad1204e0d2e2c8d1ebc29 = $(`&lt;div id=&quot;html_60efcc99338ad1204e0d2e2c8d1ebc29&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_89476b89574302a462bab6b6c52b26b9.setContent(html_60efcc99338ad1204e0d2e2c8d1ebc29);
#
#
#
#         marker_28e556a88f5886a8de6767f506b0e229.bindPopup(popup_89476b89574302a462bab6b6c52b26b9)
#         ;
#
#
#
#
#             var marker_a0d0a983894193858029e8b66ac28052 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_81333c2c98cb65bcb94998a25bde5411);
#
#
#         var popup_e0eee3f24d229bb4b951ff1ff2d14c75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7cd163b1797da91f3671463fedbff0e3 = $(`&lt;div id=&quot;html_7cd163b1797da91f3671463fedbff0e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e0eee3f24d229bb4b951ff1ff2d14c75.setContent(html_7cd163b1797da91f3671463fedbff0e3);
#
#
#
#         marker_
