# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2f6ce33623adff6efb3a453b90191497 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2f6ce33623adff6efb3a453b90191497&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2f6ce33623adff6efb3a453b90191497 = L.map(
#                 &quot;map_2f6ce33623adff6efb3a453b90191497&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bb6c18caabfb650d0671dcc6983dc722 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bb6c18caabfb650d0671dcc6983dc722.addTo(map_2f6ce33623adff6efb3a453b90191497);
#
#
#             var marker_d4d0a6acdd498124cb588000dbb970bf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2f6ce33623adff6efb3a453b90191497);
#
#
#         var popup_a46f2be362f8113c017b39127c13b392 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_310a2c6cc9089432469ea836393325e8 = $(`&lt;div id=&quot;html_310a2c6cc9089432469ea836393325e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_a46f2be362f8113c017b39127c13b392.setContent(html_310a2c6cc9089432469ea836393325e8);
#
#
#
#         marker_d4d0a6acdd498124cb588000dbb970bf.bindPopup(popup_a46f2be362f8113c017b39127c13b392)
#         ;
#
#
#
#
#             var marker_7b2487d140edb54c92271152ab13d58e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2f6ce33623adff6efb3a453b90191497);
#
#
#         var popup_7c3a4a0bdb2dede84b0b46a997cfc0f6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c7a1bf4a31f34344f481b041dd27697f = $(`&lt;div id=&quot;html_c7a1bf4a31f34344f481b041dd27697f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7c3a4a0bdb2dede84b0b46a997cfc0f6.setContent(html_c7a1bf4a31f34344f481b041dd27697f);
#
#
#
#         marker_7b2487d140edb54c92271152ab13d58e.bindPopup(popup_7c3a4a0bdb2dede84b0b46a997cfc0f6)
#         ;
#
#
#
#
#             var marker_a56c048a2faaa2f79f67d2259feb342b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2f6ce33623adff6efb3a453b90191497);
#
#
#         var popup_77c2b0c43c2b05a88c7e56e0e4cd61ee = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5f887dc0e95afdbc55d5db61d5984e1a = $(`&lt;div id=&quot;html_5f887dc0e95afdbc55d5db61d5984e1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_77c2b0c43c2b05a88c7e56e0e4cd61ee.setContent(html_5f887dc0e95afdbc55d5db61d5984e1a);
#
#
#
#         marker_a56c048a2faaa2f79f67d2259feb342b.bindPopup(popup_77c2b0c43c2b05a88c7e56e0e4cd61ee)
#         ;
#
#
#
#
#             var marker_1f51e8043d98c6328cdc7bc4d2352080 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2f6ce33623adff6efb3a453b90191497);
#
#
#         var popup_b3928b198e6966a5388735ec2460d25d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e4464e72cd4ce6f89e2c0c21d2d311a = $(`&lt;div id=&quot;html_4e4464e72cd4ce6f89e2c0c21d2d311a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b3928b198e6966a5388735ec2460d25d.setContent(html_4e4464e72cd4ce6f89e2c0c21d2d311a);
#
#
#
#         marker_1f51e8043d98c6328cdc7bc4d2352080.bindPopup(popup_b3928b198e6966a5388735ec2460d25d)
#         ;
#
#
#
#
#             var marker_337c754f08b507fcd82876828990b1e7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2f6ce33623adff6efb3a453b90191497);
#
#
#         var popup_358fa3ff1b361f522c37b7e32afa9cc1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d8bf5fc94f531b92b3f8d206893da2d8 = $(`&lt;div id=&quot;html_d8bf5fc94f531b92b3f8d206893da2d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_358fa3ff1b361f522c37b7e32afa9cc1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9b3b29c0ec8afe39ac5e8814886e74b8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9b3b29c0ec8afe39ac5e8814886e74b8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9b3b29c0ec8afe39ac5e8814886e74b8 = L.map(
#                 &quot;map_9b3b29c0ec8afe39ac5e8814886e74b8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d229926f07a47dc9aab1e3ff4064966c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d229926f07a47dc9aab1e3ff4064966c.addTo(map_9b3b29c0ec8afe39ac5e8814886e74b8);
#
#
#             var feature_group_9c8d0350a94c5715c74e6593f9d15bc8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f96b939852b5a357d4c0fffa1a782fbc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9c8d0350a94c5715c74e6593f9d15bc8);
#
#
#         var popup_a695e014aabc3895782fe1cdd77bd7fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fcb1bc07267f6fd895c1a905ce32a40 = $(`&lt;div id=&quot;html_2fcb1bc07267f6fd895c1a905ce32a40&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a695e014aabc3895782fe1cdd77bd7fa.setContent(html_2fcb1bc07267f6fd895c1a905ce32a40);
#
#
#
#         marker_f96b939852b5a357d4c0fffa1a782fbc.bindPopup(popup_a695e014aabc3895782fe1cdd77bd7fa)
#         ;
#
#
#
#
#             var marker_a71673a611f0603232d513cdea6c5663 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9c8d0350a94c5715c74e6593f9d15bc8);
#
#
#         var popup_d243d2d0c87f51f03e7d9f6dd5be8d1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_635cba52cf586aca78f303e02c59a37e = $(`&lt;div id=&quot;html_635cba52cf586aca78f303e02c59a37e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d243d2d0c87f51f03e7d9f6dd5be8d1b.setContent(html_635cba52cf586aca78f303e02c59a37e);
#
#
#
#         marker_a71673a611f0603232d513cdea6c5663.bindPopup(popup_d243d2d0c87f51f03e7d9f6dd5be8d1b)
#         ;
#
#
#
#
#             var marker_1fe89d8d988c8f9b999729c9871bb89d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9c8d0350a94c5715c74e6593f9d15bc8);
#
#
#         var popup_d872082d7c57fd01a5c0c1b7752f42bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6306bcbf4aae3d6b84557e28d839989b = $(`&lt;div id=&quot;html_6306bcbf4aae3d6b84557e28d839989b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d872082d7c57fd01a5c0c1b7752f42bf.setContent(html_6306bcbf4aae3d6b84557e28d839989b);
#
#
#
#         marker_1fe89d8d988c8f9b999729c9871bb89d.bindPopup(popup_d872082d7c57fd01a5c0c1b7752f42bf)
#         ;
#
#
#
#
#             var marker_5a5bdbac4e539e3be8ecff9fff93c9f5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9c8d0350a94c5715c74e6593f9d15bc8);
#
#
#         var popup_2ca7c1b1207ef58b816326161dd2a804 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76a238632d4470efaab3d3a1f9b8438b = $(`&lt;div id=&quot;html_76a238632d4470efaab3d3a1f9b8438b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2ca7c1b1207ef58b816326161dd2a804.setContent(html_76a238632d4470efaab3d3a1f9b8438b);
#
#
#
#         marker_5a5bdbac4e539e3be8ecff9fff93c9f5.bindPopup(popup_2ca7c1b1207ef58b816326161dd2a804)
#         ;
#
#
#
#
#             var marker_1f652f94b53b4a6053c7072b4f496688 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9c8d0350a94c5715c74e6593f9d15bc8);
#
#
#         var popup_72e4caabf8116bde3eb5cda146665640 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b4004339ccb43cc8db399129d0446b71 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b4004339ccb43cc8db399129d0446b71&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b4004339ccb43cc8db399129d0446b71 = L.map(
#                 &quot;map_b4004339ccb43cc8db399129d0446b71&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_10935419f9015fdd9ab2d45b0666412c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_10935419f9015fdd9ab2d45b0666412c.addTo(map_b4004339ccb43cc8db399129d0446b71);
#
#
#             var feature_group_c5ed7bf32841ea1437487ec857ffd680 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_c5ed7bf32841ea1437487ec857ffd680.addTo(map_b4004339ccb43cc8db399129d0446b71);
#
#
#             var feature_group_sub_group_38d2b69c461015b3954f7f2614a21857 = L.featureGroup.subGroup(
#                 feature_group_c5ed7bf32841ea1437487ec857ffd680
#             );
#
#
#             var marker_8be4e2a90c346f5c86a9410d22ffd23f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_38d2b69c461015b3954f7f2614a21857);
#
#
#         var popup_a8537155979b0187592afc276c8fb516 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b44a29bd7333eb92c216cce53414665c = $(`&lt;div id=&quot;html_b44a29bd7333eb92c216cce53414665c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a8537155979b0187592afc276c8fb516.setContent(html_b44a29bd7333eb92c216cce53414665c);
#
#
#
#         marker_8be4e2a90c346f5c86a9410d22ffd23f.bindPopup(popup_a8537155979b0187592afc276c8fb516)
#         ;
#
#
#
#
#             var marker_3162e603f45c10dc14e784ce34bf26de = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_38d2b69c461015b3954f7f2614a21857);
#
#
#         var popup_08f8a15847fe2507d23ac426d3024a84 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_34d3d9cdb0ff857ac51a028165dc46d3 = $(`&lt;div id=&quot;html_34d3d9cdb0ff857ac51a028165dc46d3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_08f8a15847fe2507d23ac426d3024a84.setContent(html_34d3d9cdb0ff857ac51a028165dc46d3);
#
#
#
#         marker_3162e603f45c10dc14e784ce34bf26de.bindPopup(popup_08f8a15847fe2507d23ac426d3024a84)
#         ;
#
#
#
#
#             var marker_3f493f64926db015abb1306293a1ede7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_38d2b69c461015b3954f7f2614a21857);
#
#
#         var popup_67c49b77eff2c815f95a45d170ed1a2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_50bf42bd44fbac8bca5e4ac4cb6fe21b = $(`&lt;div id=&quot;html_50bf42bd44fbac8bca5e4ac4cb6fe21b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_67c49b77eff2c815f95a45d170ed1a2c.setContent(html_50bf42bd44fbac8bca5e4ac4cb6fe21b);
#
#
#
#         marker_3f493f64926db015abb1306293a1ede7.bindPopup(popup_67c49b77eff2c815f95a45d170ed1a2c)
#         ;
#
#
#
#
#             var marker_0daeab0e6cbc00794f009dec46081da9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_38d2b69c461015b3954f7f2614a21857);
#
#
#         var popup_621665f6eafa0ea790ec88dc149355a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f692c6c8ee54e54615551b6f265cb289 = $(`&lt;div id=&quot;html_f692c6c8ee54e54615551b6f265cb289&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_621665f6eafa0ea790ec88dc149355a4.setContent(html_f692c6c8ee54e54615551b6f265cb289);
#
#
#
#         marker_
