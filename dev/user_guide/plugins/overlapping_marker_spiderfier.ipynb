# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c0c2e2c8337873779d7e9e7f3d2a9875 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c0c2e2c8337873779d7e9e7f3d2a9875&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c0c2e2c8337873779d7e9e7f3d2a9875 = L.map(
#                 &quot;map_c0c2e2c8337873779d7e9e7f3d2a9875&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_723cf2dd033373ddd7ea97a7600038b1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_723cf2dd033373ddd7ea97a7600038b1.addTo(map_c0c2e2c8337873779d7e9e7f3d2a9875);
#
#
#             var marker_baff38666608c0e251b9babe68a148d2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c0c2e2c8337873779d7e9e7f3d2a9875);
#
#
#         var popup_ede1c6f5d794c65b03d913fb831fa79f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_04e2be69d19ed022052e381aa99c42dd = $(`&lt;div id=&quot;html_04e2be69d19ed022052e381aa99c42dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ede1c6f5d794c65b03d913fb831fa79f.setContent(html_04e2be69d19ed022052e381aa99c42dd);
#
#
#
#         marker_baff38666608c0e251b9babe68a148d2.bindPopup(popup_ede1c6f5d794c65b03d913fb831fa79f)
#         ;
#
#
#
#
#             var marker_dfaef18a44b2f7fd1da74333ab7ca3a5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c0c2e2c8337873779d7e9e7f3d2a9875);
#
#
#         var popup_8a1c83d6441550b26424e0f263250e66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_def8ab2f2049f6a5055c5e9e25bbb917 = $(`&lt;div id=&quot;html_def8ab2f2049f6a5055c5e9e25bbb917&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_8a1c83d6441550b26424e0f263250e66.setContent(html_def8ab2f2049f6a5055c5e9e25bbb917);
#
#
#
#         marker_dfaef18a44b2f7fd1da74333ab7ca3a5.bindPopup(popup_8a1c83d6441550b26424e0f263250e66)
#         ;
#
#
#
#
#             var marker_50d4551f2c813285675634ae3bd0316b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c0c2e2c8337873779d7e9e7f3d2a9875);
#
#
#         var popup_49843981d7aca0160adaa7bc70ca0640 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_87eb9b24fc86c48a90343f7e60813ead = $(`&lt;div id=&quot;html_87eb9b24fc86c48a90343f7e60813ead&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_49843981d7aca0160adaa7bc70ca0640.setContent(html_87eb9b24fc86c48a90343f7e60813ead);
#
#
#
#         marker_50d4551f2c813285675634ae3bd0316b.bindPopup(popup_49843981d7aca0160adaa7bc70ca0640)
#         ;
#
#
#
#
#             var marker_b4c5b366804ecff6bcc23e44752fcfe1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c0c2e2c8337873779d7e9e7f3d2a9875);
#
#
#         var popup_4a36cfd1f0ec6af58ac63f28b526f7c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6561df73c7cc01080fcf67099ec2fc58 = $(`&lt;div id=&quot;html_6561df73c7cc01080fcf67099ec2fc58&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4a36cfd1f0ec6af58ac63f28b526f7c9.setContent(html_6561df73c7cc01080fcf67099ec2fc58);
#
#
#
#         marker_b4c5b366804ecff6bcc23e44752fcfe1.bindPopup(popup_4a36cfd1f0ec6af58ac63f28b526f7c9)
#         ;
#
#
#
#
#             var marker_56adc41011d4f30673c59f17e29309ab = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c0c2e2c8337873779d7e9e7f3d2a9875);
#
#
#         var popup_c2aa65a6b11a3a08166b8b7a6bc04980 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4ab537553005c3ad05db291bff425c2 = $(`&lt;div id=&quot;html_f4ab537553005c3ad05db291bff425c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c2aa65a6b11a3a08166b8b7a6bc04980.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c4c914d78728f903ef05f2184d23889f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c4c914d78728f903ef05f2184d23889f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c4c914d78728f903ef05f2184d23889f = L.map(
#                 &quot;map_c4c914d78728f903ef05f2184d23889f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_396264b56e280964e871e6e00994c703 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_396264b56e280964e871e6e00994c703.addTo(map_c4c914d78728f903ef05f2184d23889f);
#
#
#             var feature_group_505eda17d995a596512ac284526ed247 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_9efcb3230a80dee6b466d3fd1ec6c2a1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_505eda17d995a596512ac284526ed247);
#
#
#         var popup_b8e8292d721641518a5c69425273069e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_943601cf31abf7b63c96ef6b33c21a90 = $(`&lt;div id=&quot;html_943601cf31abf7b63c96ef6b33c21a90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_b8e8292d721641518a5c69425273069e.setContent(html_943601cf31abf7b63c96ef6b33c21a90);
#
#
#
#         marker_9efcb3230a80dee6b466d3fd1ec6c2a1.bindPopup(popup_b8e8292d721641518a5c69425273069e)
#         ;
#
#
#
#
#             var marker_2d3727fd217ae86c7fe5da072279f558 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_505eda17d995a596512ac284526ed247);
#
#
#         var popup_2d84b6f38f004dad54618b36d2ee19be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2ec9eb2f8aaaa884ffcfd78a28532c6 = $(`&lt;div id=&quot;html_c2ec9eb2f8aaaa884ffcfd78a28532c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2d84b6f38f004dad54618b36d2ee19be.setContent(html_c2ec9eb2f8aaaa884ffcfd78a28532c6);
#
#
#
#         marker_2d3727fd217ae86c7fe5da072279f558.bindPopup(popup_2d84b6f38f004dad54618b36d2ee19be)
#         ;
#
#
#
#
#             var marker_441ecbaa896c2ad4a1fcd1e78f15f93e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_505eda17d995a596512ac284526ed247);
#
#
#         var popup_5e06ff9982ecf114f3d5971be84b12db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d44b1662e2555465b8c2ecb200735998 = $(`&lt;div id=&quot;html_d44b1662e2555465b8c2ecb200735998&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5e06ff9982ecf114f3d5971be84b12db.setContent(html_d44b1662e2555465b8c2ecb200735998);
#
#
#
#         marker_441ecbaa896c2ad4a1fcd1e78f15f93e.bindPopup(popup_5e06ff9982ecf114f3d5971be84b12db)
#         ;
#
#
#
#
#             var marker_2a720b231c91ba8f7acdab6659adaaca = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_505eda17d995a596512ac284526ed247);
#
#
#         var popup_5f856629a46ed1d8a1271eecade4f48e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20d5a32fb18b0ed984f7c7e8f0f5715e = $(`&lt;div id=&quot;html_20d5a32fb18b0ed984f7c7e8f0f5715e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_5f856629a46ed1d8a1271eecade4f48e.setContent(html_20d5a32fb18b0ed984f7c7e8f0f5715e);
#
#
#
#         marker_2a720b231c91ba8f7acdab6659adaaca.bindPopup(popup_5f856629a46ed1d8a1271eecade4f48e)
#         ;
#
#
#
#
#             var marker_f5bd1d9d97ad46f6a002f0d60d71b11e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_505eda17d995a596512ac284526ed247);
#
#
#         var popup_70e5ecf5108353d515650615dba004f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9713f6b986246cfc8c98700822e8d3bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9713f6b986246cfc8c98700822e8d3bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9713f6b986246cfc8c98700822e8d3bb = L.map(
#                 &quot;map_9713f6b986246cfc8c98700822e8d3bb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f1e12fc536b51bc0c6073112391442ef = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f1e12fc536b51bc0c6073112391442ef.addTo(map_9713f6b986246cfc8c98700822e8d3bb);
#
#
#             var feature_group_5db40c59712914474090b299aedfa71e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5db40c59712914474090b299aedfa71e.addTo(map_9713f6b986246cfc8c98700822e8d3bb);
#
#
#             var feature_group_sub_group_09a2be13effc6ed91b7a24152c435544 = L.featureGroup.subGroup(
#                 feature_group_5db40c59712914474090b299aedfa71e
#             );
#
#
#             var marker_bb59c5ad05094e64fd22a065fac150f9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_09a2be13effc6ed91b7a24152c435544);
#
#
#         var popup_97dbb451787ef8ad440ff1e9cd20eba4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23c84e0d36391ed909df1e436d4942e6 = $(`&lt;div id=&quot;html_23c84e0d36391ed909df1e436d4942e6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_97dbb451787ef8ad440ff1e9cd20eba4.setContent(html_23c84e0d36391ed909df1e436d4942e6);
#
#
#
#         marker_bb59c5ad05094e64fd22a065fac150f9.bindPopup(popup_97dbb451787ef8ad440ff1e9cd20eba4)
#         ;
#
#
#
#
#             var marker_e7bc209fb7a7100c604587e97f518d97 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_09a2be13effc6ed91b7a24152c435544);
#
#
#         var popup_40450fa4455baa203afedd16c5f9a9f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b84fcac1a32be861712943ff626243c = $(`&lt;div id=&quot;html_7b84fcac1a32be861712943ff626243c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_40450fa4455baa203afedd16c5f9a9f7.setContent(html_7b84fcac1a32be861712943ff626243c);
#
#
#
#         marker_e7bc209fb7a7100c604587e97f518d97.bindPopup(popup_40450fa4455baa203afedd16c5f9a9f7)
#         ;
#
#
#
#
#             var marker_972f433087d07a5a046b0cca2974064f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_09a2be13effc6ed91b7a24152c435544);
#
#
#         var popup_36552b611a2c5faa0e63feba6fc5640e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dda16c447e8d5f55ec57f8baf9241266 = $(`&lt;div id=&quot;html_dda16c447e8d5f55ec57f8baf9241266&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_36552b611a2c5faa0e63feba6fc5640e.setContent(html_dda16c447e8d5f55ec57f8baf9241266);
#
#
#
#         marker_972f433087d07a5a046b0cca2974064f.bindPopup(popup_36552b611a2c5faa0e63feba6fc5640e)
#         ;
#
#
#
#
#             var marker_270d9f05b90fb56fd20eac39fc918ed3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_09a2be13effc6ed91b7a24152c435544);
#
#
#         var popup_083fc91e056a02d3a3e98e995e2ebb8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f3c58a4eddb2236c0b8a902d65cb01f = $(`&lt;div id=&quot;html_1f3c58a4eddb2236c0b8a902d65cb01f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_083fc91e056a02d3a3e98e995e2ebb8d.setContent(html_1f3c58a4eddb2236c0b8a902d65cb01f);
#
#
#
#         marker_
