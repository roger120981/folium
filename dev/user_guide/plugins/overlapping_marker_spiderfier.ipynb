# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5d7ea22a183c2fcc1c916161bf685c3f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5d7ea22a183c2fcc1c916161bf685c3f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5d7ea22a183c2fcc1c916161bf685c3f = L.map(
#                 &quot;map_5d7ea22a183c2fcc1c916161bf685c3f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c3edbc4e3a62e17abffb1a8ddff6cd12 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c3edbc4e3a62e17abffb1a8ddff6cd12.addTo(map_5d7ea22a183c2fcc1c916161bf685c3f);
#
#
#             var marker_aa25a797c798187b45c25a2ade5a4811 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5d7ea22a183c2fcc1c916161bf685c3f);
#
#
#         var popup_b199ab0375c9c4899a759232752d617c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9500193a04eee76c476e0229e495a218 = $(`&lt;div id=&quot;html_9500193a04eee76c476e0229e495a218&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b199ab0375c9c4899a759232752d617c.setContent(html_9500193a04eee76c476e0229e495a218);
#
#
#
#         marker_aa25a797c798187b45c25a2ade5a4811.bindPopup(popup_b199ab0375c9c4899a759232752d617c)
#         ;
#
#
#
#
#             var marker_c6041ded2a652af45960f23736651a6d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5d7ea22a183c2fcc1c916161bf685c3f);
#
#
#         var popup_03c444d932f89457d71049f4a272030a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7c9b1735601ffe70a71d0e58d520bd39 = $(`&lt;div id=&quot;html_7c9b1735601ffe70a71d0e58d520bd39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_03c444d932f89457d71049f4a272030a.setContent(html_7c9b1735601ffe70a71d0e58d520bd39);
#
#
#
#         marker_c6041ded2a652af45960f23736651a6d.bindPopup(popup_03c444d932f89457d71049f4a272030a)
#         ;
#
#
#
#
#             var marker_72d40615c60eb4ca0f8e0c2dd017c545 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5d7ea22a183c2fcc1c916161bf685c3f);
#
#
#         var popup_be08fdba0c17054cd5ef7531dbe6e490 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a4f67e962eded6f0cdb7ea6e0023473d = $(`&lt;div id=&quot;html_a4f67e962eded6f0cdb7ea6e0023473d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_be08fdba0c17054cd5ef7531dbe6e490.setContent(html_a4f67e962eded6f0cdb7ea6e0023473d);
#
#
#
#         marker_72d40615c60eb4ca0f8e0c2dd017c545.bindPopup(popup_be08fdba0c17054cd5ef7531dbe6e490)
#         ;
#
#
#
#
#             var marker_cbedbc780395782c773160adbbacac73 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5d7ea22a183c2fcc1c916161bf685c3f);
#
#
#         var popup_b4cf6a40cc1dbcd5fea8d83f91c7d864 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8f9894478255b0ed3064beaff8210625 = $(`&lt;div id=&quot;html_8f9894478255b0ed3064beaff8210625&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b4cf6a40cc1dbcd5fea8d83f91c7d864.setContent(html_8f9894478255b0ed3064beaff8210625);
#
#
#
#         marker_cbedbc780395782c773160adbbacac73.bindPopup(popup_b4cf6a40cc1dbcd5fea8d83f91c7d864)
#         ;
#
#
#
#
#             var marker_3e52d5aa96df068bd1bd4d1bf6c1f2ef = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5d7ea22a183c2fcc1c916161bf685c3f);
#
#
#         var popup_8455c5168daa755ef6e2a6428cb1e8ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a879e8607a2ca207ca8d450193b5a11c = $(`&lt;div id=&quot;html_a879e8607a2ca207ca8d450193b5a11c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_8455c5168daa755ef6e2a6428cb1e8ce.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_22e917d6c3cc13eec657ea753b6bbf2c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_22e917d6c3cc13eec657ea753b6bbf2c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_22e917d6c3cc13eec657ea753b6bbf2c = L.map(
#                 &quot;map_22e917d6c3cc13eec657ea753b6bbf2c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_38e494905ce2e419b0ff15c36a37af39 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_38e494905ce2e419b0ff15c36a37af39.addTo(map_22e917d6c3cc13eec657ea753b6bbf2c);
#
#
#             var feature_group_8a5b7b6f46a77f4893680178d76c7dbe = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6ee2435366731efe01918ff172eedb13 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_8a5b7b6f46a77f4893680178d76c7dbe);
#
#
#         var popup_846d1afe0d03e349ae80608c34055dcb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7af11b988d986e97d86e4fbb59210f71 = $(`&lt;div id=&quot;html_7af11b988d986e97d86e4fbb59210f71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_846d1afe0d03e349ae80608c34055dcb.setContent(html_7af11b988d986e97d86e4fbb59210f71);
#
#
#
#         marker_6ee2435366731efe01918ff172eedb13.bindPopup(popup_846d1afe0d03e349ae80608c34055dcb)
#         ;
#
#
#
#
#             var marker_3fcab08fdba24c956b2cf1409fa9d0f9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_8a5b7b6f46a77f4893680178d76c7dbe);
#
#
#         var popup_6fc9ad29667f84ed6b4f5e5489c72851 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5eee4dd4e6e5b15ebf68aad953698345 = $(`&lt;div id=&quot;html_5eee4dd4e6e5b15ebf68aad953698345&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_6fc9ad29667f84ed6b4f5e5489c72851.setContent(html_5eee4dd4e6e5b15ebf68aad953698345);
#
#
#
#         marker_3fcab08fdba24c956b2cf1409fa9d0f9.bindPopup(popup_6fc9ad29667f84ed6b4f5e5489c72851)
#         ;
#
#
#
#
#             var marker_89e2e9004f01ea7b9a3266c7bef6ae3f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_8a5b7b6f46a77f4893680178d76c7dbe);
#
#
#         var popup_1930f1a94e3c0e15629ae3e868cef55d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca094fda7e8ec0fdeeff0c5f33e36893 = $(`&lt;div id=&quot;html_ca094fda7e8ec0fdeeff0c5f33e36893&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_1930f1a94e3c0e15629ae3e868cef55d.setContent(html_ca094fda7e8ec0fdeeff0c5f33e36893);
#
#
#
#         marker_89e2e9004f01ea7b9a3266c7bef6ae3f.bindPopup(popup_1930f1a94e3c0e15629ae3e868cef55d)
#         ;
#
#
#
#
#             var marker_4a9fa6c2929a12454c1197063e4ee609 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_8a5b7b6f46a77f4893680178d76c7dbe);
#
#
#         var popup_a0a144c8f20764ebc0c3841fdb16fcf0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc1d80a75288b253e6795b8da84cf54b = $(`&lt;div id=&quot;html_dc1d80a75288b253e6795b8da84cf54b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a0a144c8f20764ebc0c3841fdb16fcf0.setContent(html_dc1d80a75288b253e6795b8da84cf54b);
#
#
#
#         marker_4a9fa6c2929a12454c1197063e4ee609.bindPopup(popup_a0a144c8f20764ebc0c3841fdb16fcf0)
#         ;
#
#
#
#
#             var marker_e0eb6d2b16a9be523518e2d7bbc97062 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_8a5b7b6f46a77f4893680178d76c7dbe);
#
#
#         var popup_1a8b4074ff1c0e003c599ec4ba5a168b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4dc8f140de042ccabde920aa05a7785b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4dc8f140de042ccabde920aa05a7785b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4dc8f140de042ccabde920aa05a7785b = L.map(
#                 &quot;map_4dc8f140de042ccabde920aa05a7785b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec4d92943507f73c26dd064af4d9c270 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec4d92943507f73c26dd064af4d9c270.addTo(map_4dc8f140de042ccabde920aa05a7785b);
#
#
#             var feature_group_eada82939d39ad340bf883bba7be6501 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_eada82939d39ad340bf883bba7be6501.addTo(map_4dc8f140de042ccabde920aa05a7785b);
#
#
#             var feature_group_sub_group_0fd00161a0b4dd3a9b4ba80edd89c111 = L.featureGroup.subGroup(
#                 feature_group_eada82939d39ad340bf883bba7be6501
#             );
#
#
#             var marker_3146435b27b7b050d724863e84125828 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_0fd00161a0b4dd3a9b4ba80edd89c111);
#
#
#         var popup_149f87c7524782463ada887576a96c2b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1850dc272273814bf5c38389e72d14a = $(`&lt;div id=&quot;html_c1850dc272273814bf5c38389e72d14a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_149f87c7524782463ada887576a96c2b.setContent(html_c1850dc272273814bf5c38389e72d14a);
#
#
#
#         marker_3146435b27b7b050d724863e84125828.bindPopup(popup_149f87c7524782463ada887576a96c2b)
#         ;
#
#
#
#
#             var marker_de50c5b971d885b94cc6698af68ae0f9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_0fd00161a0b4dd3a9b4ba80edd89c111);
#
#
#         var popup_98c9543138c7540605507ded2b966df4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5bdbb20f66adc317642c2d0d35800c4d = $(`&lt;div id=&quot;html_5bdbb20f66adc317642c2d0d35800c4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_98c9543138c7540605507ded2b966df4.setContent(html_5bdbb20f66adc317642c2d0d35800c4d);
#
#
#
#         marker_de50c5b971d885b94cc6698af68ae0f9.bindPopup(popup_98c9543138c7540605507ded2b966df4)
#         ;
#
#
#
#
#             var marker_3a6fbb12425d6ab839c2f4ed8c554c3f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_0fd00161a0b4dd3a9b4ba80edd89c111);
#
#
#         var popup_c15560defcc6f274c11f89dd59cfa4fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f5165d8779fc622f3c99e4e966870f1 = $(`&lt;div id=&quot;html_1f5165d8779fc622f3c99e4e966870f1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c15560defcc6f274c11f89dd59cfa4fa.setContent(html_1f5165d8779fc622f3c99e4e966870f1);
#
#
#
#         marker_3a6fbb12425d6ab839c2f4ed8c554c3f.bindPopup(popup_c15560defcc6f274c11f89dd59cfa4fa)
#         ;
#
#
#
#
#             var marker_74245118134f851484661246227c01a4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_0fd00161a0b4dd3a9b4ba80edd89c111);
#
#
#         var popup_febc55172d260460eece89325e02f8e0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a14eda6a883a777b4b808f7815f87cd5 = $(`&lt;div id=&quot;html_a14eda6a883a777b4b808f7815f87cd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_febc55172d260460eece89325e02f8e0.setContent(html_a14eda6a883a777b4b808f7815f87cd5);
#
#
#
#         marker_
