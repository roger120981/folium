# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_34bd8bd31a1d9c353d41ff7de0a609cd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_34bd8bd31a1d9c353d41ff7de0a609cd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_34bd8bd31a1d9c353d41ff7de0a609cd = L.map(
#                 &quot;map_34bd8bd31a1d9c353d41ff7de0a609cd&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_9da093c142cddf0f113a4da4ea9f8c23 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_9da093c142cddf0f113a4da4ea9f8c23.addTo(map_34bd8bd31a1d9c353d41ff7de0a609cd);
#
#
#             var marker_b8fccca93356e5f8f08f7d66f20432c4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_34bd8bd31a1d9c353d41ff7de0a609cd);
#
#
#         var popup_e4c56fad49c7a3c6c3b10f4533a7012e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c41d5c91571219034ee18e7184c72302 = $(`&lt;div id=&quot;html_c41d5c91571219034ee18e7184c72302&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e4c56fad49c7a3c6c3b10f4533a7012e.setContent(html_c41d5c91571219034ee18e7184c72302);
#
#
#
#         marker_b8fccca93356e5f8f08f7d66f20432c4.bindPopup(popup_e4c56fad49c7a3c6c3b10f4533a7012e)
#         ;
#
#
#
#
#             var marker_47088b8dfca6da00e4f1e1644ca04dc4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_34bd8bd31a1d9c353d41ff7de0a609cd);
#
#
#         var popup_78a20cca7c412af3cc4beb0dfbadea59 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d77c172dbaf890ebc221580a82424064 = $(`&lt;div id=&quot;html_d77c172dbaf890ebc221580a82424064&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_78a20cca7c412af3cc4beb0dfbadea59.setContent(html_d77c172dbaf890ebc221580a82424064);
#
#
#
#         marker_47088b8dfca6da00e4f1e1644ca04dc4.bindPopup(popup_78a20cca7c412af3cc4beb0dfbadea59)
#         ;
#
#
#
#
#             var marker_8d9f3d1c4b6f37822c4566e1a58373d3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_34bd8bd31a1d9c353d41ff7de0a609cd);
#
#
#         var popup_40ec5d4e726112736b5a32de887e7b9b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_32a6f68ea4f9d65a4bb768fe9a6647bb = $(`&lt;div id=&quot;html_32a6f68ea4f9d65a4bb768fe9a6647bb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_40ec5d4e726112736b5a32de887e7b9b.setContent(html_32a6f68ea4f9d65a4bb768fe9a6647bb);
#
#
#
#         marker_8d9f3d1c4b6f37822c4566e1a58373d3.bindPopup(popup_40ec5d4e726112736b5a32de887e7b9b)
#         ;
#
#
#
#
#             var marker_4dc096bf60435a3a8fe3f868ada613ed = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_34bd8bd31a1d9c353d41ff7de0a609cd);
#
#
#         var popup_eb184d35f0ec381eac32eb2e59482533 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d17967e04f1677e0320bf8815a71590d = $(`&lt;div id=&quot;html_d17967e04f1677e0320bf8815a71590d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_eb184d35f0ec381eac32eb2e59482533.setContent(html_d17967e04f1677e0320bf8815a71590d);
#
#
#
#         marker_4dc096bf60435a3a8fe3f868ada613ed.bindPopup(popup_eb184d35f0ec381eac32eb2e59482533)
#         ;
#
#
#
#
#             var marker_99f07c7487b09b40542f688838c2e0ea = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_34bd8bd31a1d9c353d41ff7de0a609cd);
#
#
#         var popup_ce8ccc717023ee6748441b9b4b8618b1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4479f59a9276bdd1968b364a810e34cf = $(`&lt;div id=&quot;html_4479f59a9276bdd1968b364a810e34cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ce8ccc717023ee6748441b9b4b8618b1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ef125cab7302114b882cdc8efa96f96 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ef125cab7302114b882cdc8efa96f96&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ef125cab7302114b882cdc8efa96f96 = L.map(
#                 &quot;map_1ef125cab7302114b882cdc8efa96f96&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3230083174be0b2b6b8ce9f0e5dd2944 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3230083174be0b2b6b8ce9f0e5dd2944.addTo(map_1ef125cab7302114b882cdc8efa96f96);
#
#
#             var feature_group_dc52f539a4b69f15161cafc50124c1ca = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3ea5958395d332c95fce9bba64ccf25c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_dc52f539a4b69f15161cafc50124c1ca);
#
#
#         var popup_cc6be0eba57ccabc95c02db5751ba95b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_701a816edf643fe3844206a8f5550808 = $(`&lt;div id=&quot;html_701a816edf643fe3844206a8f5550808&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_cc6be0eba57ccabc95c02db5751ba95b.setContent(html_701a816edf643fe3844206a8f5550808);
#
#
#
#         marker_3ea5958395d332c95fce9bba64ccf25c.bindPopup(popup_cc6be0eba57ccabc95c02db5751ba95b)
#         ;
#
#
#
#
#             var marker_93e870384eac3f40cfe0188c7e86222c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_dc52f539a4b69f15161cafc50124c1ca);
#
#
#         var popup_a2069bfd1e47d579762dcdf95f41ad16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5c2089c926925252808f0f95f8f5807 = $(`&lt;div id=&quot;html_b5c2089c926925252808f0f95f8f5807&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_a2069bfd1e47d579762dcdf95f41ad16.setContent(html_b5c2089c926925252808f0f95f8f5807);
#
#
#
#         marker_93e870384eac3f40cfe0188c7e86222c.bindPopup(popup_a2069bfd1e47d579762dcdf95f41ad16)
#         ;
#
#
#
#
#             var marker_ac467265c47e4ae922983bc4be4e2413 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_dc52f539a4b69f15161cafc50124c1ca);
#
#
#         var popup_fb232d01a871868b27ffd50d65650cb3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40ae66c351487b16dccb2e62ca491c5b = $(`&lt;div id=&quot;html_40ae66c351487b16dccb2e62ca491c5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_fb232d01a871868b27ffd50d65650cb3.setContent(html_40ae66c351487b16dccb2e62ca491c5b);
#
#
#
#         marker_ac467265c47e4ae922983bc4be4e2413.bindPopup(popup_fb232d01a871868b27ffd50d65650cb3)
#         ;
#
#
#
#
#             var marker_4f8f1e1289a5bdcbe97a1ef014c044b8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_dc52f539a4b69f15161cafc50124c1ca);
#
#
#         var popup_f7d17b712b0f30a9591954f44ca8e4bd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dc7a1e0fda25f0653c65324dfe95d8f7 = $(`&lt;div id=&quot;html_dc7a1e0fda25f0653c65324dfe95d8f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f7d17b712b0f30a9591954f44ca8e4bd.setContent(html_dc7a1e0fda25f0653c65324dfe95d8f7);
#
#
#
#         marker_4f8f1e1289a5bdcbe97a1ef014c044b8.bindPopup(popup_f7d17b712b0f30a9591954f44ca8e4bd)
#         ;
#
#
#
#
#             var marker_89c69910d6821a2135b3ed70c5884f9e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_dc52f539a4b69f15161cafc50124c1ca);
#
#
#         var popup_526884bb7443a13ffa483b26c534d5a3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a527db1f7bd7b7627d54975cbd5fb55 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a527db1f7bd7b7627d54975cbd5fb55&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a527db1f7bd7b7627d54975cbd5fb55 = L.map(
#                 &quot;map_9a527db1f7bd7b7627d54975cbd5fb55&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_375dc092f8944a78eb12c933ec18bc59 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_375dc092f8944a78eb12c933ec18bc59.addTo(map_9a527db1f7bd7b7627d54975cbd5fb55);
#
#
#             var feature_group_cf0bd01e49f50def4cace8c430c299a6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_cf0bd01e49f50def4cace8c430c299a6.addTo(map_9a527db1f7bd7b7627d54975cbd5fb55);
#
#
#             var feature_group_sub_group_6739632b0a23e6f6f30d05bbe2ca8a1f = L.featureGroup.subGroup(
#                 feature_group_cf0bd01e49f50def4cace8c430c299a6
#             );
#
#
#             var marker_a6b36a0e31bcdf29e94eb28c80de7a0f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6739632b0a23e6f6f30d05bbe2ca8a1f);
#
#
#         var popup_c391c715c540fa065c2522579ac68bf2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b70929419cca0598270a82f5c13fcec3 = $(`&lt;div id=&quot;html_b70929419cca0598270a82f5c13fcec3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c391c715c540fa065c2522579ac68bf2.setContent(html_b70929419cca0598270a82f5c13fcec3);
#
#
#
#         marker_a6b36a0e31bcdf29e94eb28c80de7a0f.bindPopup(popup_c391c715c540fa065c2522579ac68bf2)
#         ;
#
#
#
#
#             var marker_d584d0e9c4ccafeea2c40d9a342ba0df = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6739632b0a23e6f6f30d05bbe2ca8a1f);
#
#
#         var popup_d220a1f752ddc7e3675aa1e080836309 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_496d47a7ad6e2561072d171ef839535e = $(`&lt;div id=&quot;html_496d47a7ad6e2561072d171ef839535e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d220a1f752ddc7e3675aa1e080836309.setContent(html_496d47a7ad6e2561072d171ef839535e);
#
#
#
#         marker_d584d0e9c4ccafeea2c40d9a342ba0df.bindPopup(popup_d220a1f752ddc7e3675aa1e080836309)
#         ;
#
#
#
#
#             var marker_581522f0ee6a51f12d39ca815b195a85 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6739632b0a23e6f6f30d05bbe2ca8a1f);
#
#
#         var popup_def88dd803bb110f1016e1c6a5a6ec79 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ad91e4440b1d87f936a671a6326870d2 = $(`&lt;div id=&quot;html_ad91e4440b1d87f936a671a6326870d2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_def88dd803bb110f1016e1c6a5a6ec79.setContent(html_ad91e4440b1d87f936a671a6326870d2);
#
#
#
#         marker_581522f0ee6a51f12d39ca815b195a85.bindPopup(popup_def88dd803bb110f1016e1c6a5a6ec79)
#         ;
#
#
#
#
#             var marker_6ee86a8a0d216eaeb15c8032c290edcb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6739632b0a23e6f6f30d05bbe2ca8a1f);
#
#
#         var popup_09fa1430fa3f7a1972d090922f742d0e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_322f70d737c55ab20199a0c14a9d3aed = $(`&lt;div id=&quot;html_322f70d737c55ab20199a0c14a9d3aed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_09fa1430fa3f7a1972d090922f742d0e.setContent(html_322f70d737c55ab20199a0c14a9d3aed);
#
#
#
#         marker_
