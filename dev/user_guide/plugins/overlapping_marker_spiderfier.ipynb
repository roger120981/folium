# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a303b47c23ee876a61db7628742be531 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a303b47c23ee876a61db7628742be531&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a303b47c23ee876a61db7628742be531 = L.map(
#                 &quot;map_a303b47c23ee876a61db7628742be531&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_87ceba9c48d9e64b81012e0a6255534c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_87ceba9c48d9e64b81012e0a6255534c.addTo(map_a303b47c23ee876a61db7628742be531);
#
#
#             var marker_34f333cf1ff302170232b30283fd3645 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a303b47c23ee876a61db7628742be531);
#
#
#         var popup_ec58cc7e721e8c1e587bde07a3f4c275 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d3cc9fdfb832ffacf598548b7ccf237 = $(`&lt;div id=&quot;html_6d3cc9fdfb832ffacf598548b7ccf237&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_ec58cc7e721e8c1e587bde07a3f4c275.setContent(html_6d3cc9fdfb832ffacf598548b7ccf237);
#
#
#
#         marker_34f333cf1ff302170232b30283fd3645.bindPopup(popup_ec58cc7e721e8c1e587bde07a3f4c275)
#         ;
#
#
#
#
#             var marker_ddad7ceb5714114b2d10b44a083bb31b = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a303b47c23ee876a61db7628742be531);
#
#
#         var popup_7da47bc68ff38a1ade9f0ec2a6ce96be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e908d90b35517d5c063a9490827fd162 = $(`&lt;div id=&quot;html_e908d90b35517d5c063a9490827fd162&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_7da47bc68ff38a1ade9f0ec2a6ce96be.setContent(html_e908d90b35517d5c063a9490827fd162);
#
#
#
#         marker_ddad7ceb5714114b2d10b44a083bb31b.bindPopup(popup_7da47bc68ff38a1ade9f0ec2a6ce96be)
#         ;
#
#
#
#
#             var marker_b3f3500e20f441f225ef4ae1ab1ef873 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a303b47c23ee876a61db7628742be531);
#
#
#         var popup_7f558e04a8cf9f30dced62bbc35c0d8e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e994feb2ce8c996516aaffb7f2f53d98 = $(`&lt;div id=&quot;html_e994feb2ce8c996516aaffb7f2f53d98&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_7f558e04a8cf9f30dced62bbc35c0d8e.setContent(html_e994feb2ce8c996516aaffb7f2f53d98);
#
#
#
#         marker_b3f3500e20f441f225ef4ae1ab1ef873.bindPopup(popup_7f558e04a8cf9f30dced62bbc35c0d8e)
#         ;
#
#
#
#
#             var marker_bb999da737ccef617b11f01ba973f929 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a303b47c23ee876a61db7628742be531);
#
#
#         var popup_db33b7c8fa6404f37fbd2ce61bcde687 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7737b5e5931ce8a905a73919dae6b800 = $(`&lt;div id=&quot;html_7737b5e5931ce8a905a73919dae6b800&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_db33b7c8fa6404f37fbd2ce61bcde687.setContent(html_7737b5e5931ce8a905a73919dae6b800);
#
#
#
#         marker_bb999da737ccef617b11f01ba973f929.bindPopup(popup_db33b7c8fa6404f37fbd2ce61bcde687)
#         ;
#
#
#
#
#             var marker_01295c25967df627a87f024bfa78f368 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a303b47c23ee876a61db7628742be531);
#
#
#         var popup_67c862ee6a8f6d75d75799384c6e382d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e91c65a13818ff5fba51b9adab16ae9c = $(`&lt;div id=&quot;html_e91c65a13818ff5fba51b9adab16ae9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_67c862ee6a8f6d75d75799384c6e382d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9892222d37503194a7fae442978f5f32 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9892222d37503194a7fae442978f5f32&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9892222d37503194a7fae442978f5f32 = L.map(
#                 &quot;map_9892222d37503194a7fae442978f5f32&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab3db32b059002c240a7673ed8290527 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ab3db32b059002c240a7673ed8290527.addTo(map_9892222d37503194a7fae442978f5f32);
#
#
#             var feature_group_ae26f52b8dc1f5dff8f32ca05b0c2234 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1167bb268e02153297291ef7cf678e19 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ae26f52b8dc1f5dff8f32ca05b0c2234);
#
#
#         var popup_36884d1539d723f5d24319c21ed5f57f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c02f2ca8d1669e5c24912a12379723a6 = $(`&lt;div id=&quot;html_c02f2ca8d1669e5c24912a12379723a6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_36884d1539d723f5d24319c21ed5f57f.setContent(html_c02f2ca8d1669e5c24912a12379723a6);
#
#
#
#         marker_1167bb268e02153297291ef7cf678e19.bindPopup(popup_36884d1539d723f5d24319c21ed5f57f)
#         ;
#
#
#
#
#             var marker_910d2453aba37a3da552bfe115ca6fea = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ae26f52b8dc1f5dff8f32ca05b0c2234);
#
#
#         var popup_2eedf6359fda584c4a0cf364d8dc447b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_099eaf5ea1a23c67cb6efce9574597c2 = $(`&lt;div id=&quot;html_099eaf5ea1a23c67cb6efce9574597c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_2eedf6359fda584c4a0cf364d8dc447b.setContent(html_099eaf5ea1a23c67cb6efce9574597c2);
#
#
#
#         marker_910d2453aba37a3da552bfe115ca6fea.bindPopup(popup_2eedf6359fda584c4a0cf364d8dc447b)
#         ;
#
#
#
#
#             var marker_f37955325f9cd3c114ce995e0d470b07 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ae26f52b8dc1f5dff8f32ca05b0c2234);
#
#
#         var popup_5a0f70979d0fa85640f04b126f376ec2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9c85cf369591cf471a8e71a802b568f = $(`&lt;div id=&quot;html_e9c85cf369591cf471a8e71a802b568f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5a0f70979d0fa85640f04b126f376ec2.setContent(html_e9c85cf369591cf471a8e71a802b568f);
#
#
#
#         marker_f37955325f9cd3c114ce995e0d470b07.bindPopup(popup_5a0f70979d0fa85640f04b126f376ec2)
#         ;
#
#
#
#
#             var marker_2cecd35b27464888693efd102027a2aa = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ae26f52b8dc1f5dff8f32ca05b0c2234);
#
#
#         var popup_80d515ee4db9ec32fbf47f2b902c91fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6501ae98d898216d36fb49e73020cd9b = $(`&lt;div id=&quot;html_6501ae98d898216d36fb49e73020cd9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_80d515ee4db9ec32fbf47f2b902c91fd.setContent(html_6501ae98d898216d36fb49e73020cd9b);
#
#
#
#         marker_2cecd35b27464888693efd102027a2aa.bindPopup(popup_80d515ee4db9ec32fbf47f2b902c91fd)
#         ;
#
#
#
#
#             var marker_a02f744f87c2f2b71ed8547648e19bf4 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ae26f52b8dc1f5dff8f32ca05b0c2234);
#
#
#         var popup_ebe07e5b17dcf818995342eeeb57ef35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_37c2411c6bbc36b8479cf09b62b3a186 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_37c2411c6bbc36b8479cf09b62b3a186&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_37c2411c6bbc36b8479cf09b62b3a186 = L.map(
#                 &quot;map_37c2411c6bbc36b8479cf09b62b3a186&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_52a0f5ff76eda93e58253b27c46b2228 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_52a0f5ff76eda93e58253b27c46b2228.addTo(map_37c2411c6bbc36b8479cf09b62b3a186);
#
#
#             var feature_group_734445ae0507b34d087356fc59d0bf2a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_734445ae0507b34d087356fc59d0bf2a.addTo(map_37c2411c6bbc36b8479cf09b62b3a186);
#
#
#             var feature_group_sub_group_c57773dca661bf7ead2853225c5ed415 = L.featureGroup.subGroup(
#                 feature_group_734445ae0507b34d087356fc59d0bf2a
#             );
#
#
#             var marker_a37ace02acb2e32d4455ea4f211e12fe = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c57773dca661bf7ead2853225c5ed415);
#
#
#         var popup_46c45723a2bc37bded843e1172255a76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14a84253658d21d90fbe15f8993d4cba = $(`&lt;div id=&quot;html_14a84253658d21d90fbe15f8993d4cba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_46c45723a2bc37bded843e1172255a76.setContent(html_14a84253658d21d90fbe15f8993d4cba);
#
#
#
#         marker_a37ace02acb2e32d4455ea4f211e12fe.bindPopup(popup_46c45723a2bc37bded843e1172255a76)
#         ;
#
#
#
#
#             var marker_38b5b370d2feb6d4c987701cfaaac5f9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c57773dca661bf7ead2853225c5ed415);
#
#
#         var popup_7960ac8bce12a02832921fd06613a37b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9445d24740fa425e0d5c126c1ad2650 = $(`&lt;div id=&quot;html_f9445d24740fa425e0d5c126c1ad2650&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_7960ac8bce12a02832921fd06613a37b.setContent(html_f9445d24740fa425e0d5c126c1ad2650);
#
#
#
#         marker_38b5b370d2feb6d4c987701cfaaac5f9.bindPopup(popup_7960ac8bce12a02832921fd06613a37b)
#         ;
#
#
#
#
#             var marker_a477261758a5b6045ea60dff07dcc75e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c57773dca661bf7ead2853225c5ed415);
#
#
#         var popup_a51764f0897deefe960f1e87f3ed4384 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f1b07e6a8c3ccc065ce7ae30c247bea1 = $(`&lt;div id=&quot;html_f1b07e6a8c3ccc065ce7ae30c247bea1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a51764f0897deefe960f1e87f3ed4384.setContent(html_f1b07e6a8c3ccc065ce7ae30c247bea1);
#
#
#
#         marker_a477261758a5b6045ea60dff07dcc75e.bindPopup(popup_a51764f0897deefe960f1e87f3ed4384)
#         ;
#
#
#
#
#             var marker_9b77579c07e1e5c1c2806985261983d2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c57773dca661bf7ead2853225c5ed415);
#
#
#         var popup_0f0b799aec726bb156cd54df125f5f74 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b10fae54612b834b188bf7eea8422a63 = $(`&lt;div id=&quot;html_b10fae54612b834b188bf7eea8422a63&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0f0b799aec726bb156cd54df125f5f74.setContent(html_b10fae54612b834b188bf7eea8422a63);
#
#
#
#         marker_
