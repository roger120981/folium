# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_42768b0b9e9bae0c6864d86edb2dcd5b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_42768b0b9e9bae0c6864d86edb2dcd5b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_42768b0b9e9bae0c6864d86edb2dcd5b = L.map(
#                 &quot;map_42768b0b9e9bae0c6864d86edb2dcd5b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e9ab8be447899438f4f894a1ec7255c2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e9ab8be447899438f4f894a1ec7255c2.addTo(map_42768b0b9e9bae0c6864d86edb2dcd5b);
#
#
#             var marker_5cd61b23058455c9e6e25da371dc8621 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_42768b0b9e9bae0c6864d86edb2dcd5b);
#
#
#         var popup_405dea5993241068e82d2a9ea0c8d174 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_15d2cdc431c1c8f1584376182eeee33a = $(`&lt;div id=&quot;html_15d2cdc431c1c8f1584376182eeee33a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_405dea5993241068e82d2a9ea0c8d174.setContent(html_15d2cdc431c1c8f1584376182eeee33a);
#
#
#
#         marker_5cd61b23058455c9e6e25da371dc8621.bindPopup(popup_405dea5993241068e82d2a9ea0c8d174)
#         ;
#
#
#
#
#             var marker_63479d41b6f96b44ac5d80808683d87d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_42768b0b9e9bae0c6864d86edb2dcd5b);
#
#
#         var popup_10e25e57317e8c25de689640d57aa935 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6f263f2b51560f1a26ece67c53bd61b = $(`&lt;div id=&quot;html_c6f263f2b51560f1a26ece67c53bd61b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_10e25e57317e8c25de689640d57aa935.setContent(html_c6f263f2b51560f1a26ece67c53bd61b);
#
#
#
#         marker_63479d41b6f96b44ac5d80808683d87d.bindPopup(popup_10e25e57317e8c25de689640d57aa935)
#         ;
#
#
#
#
#             var marker_f9da195f59e5b7ae3443dd9252b4cf09 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_42768b0b9e9bae0c6864d86edb2dcd5b);
#
#
#         var popup_4d3862f4478085b22dbf98d6f8f3f586 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_622509965adfb13568679a9cd25f82cf = $(`&lt;div id=&quot;html_622509965adfb13568679a9cd25f82cf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4d3862f4478085b22dbf98d6f8f3f586.setContent(html_622509965adfb13568679a9cd25f82cf);
#
#
#
#         marker_f9da195f59e5b7ae3443dd9252b4cf09.bindPopup(popup_4d3862f4478085b22dbf98d6f8f3f586)
#         ;
#
#
#
#
#             var marker_07fc1e12811ba1d0c632f7d560ac09fc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_42768b0b9e9bae0c6864d86edb2dcd5b);
#
#
#         var popup_068e4cab372858ba6539d3a76c57f6b2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_77f0584ce3da9d86e358c4498f0d5769 = $(`&lt;div id=&quot;html_77f0584ce3da9d86e358c4498f0d5769&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_068e4cab372858ba6539d3a76c57f6b2.setContent(html_77f0584ce3da9d86e358c4498f0d5769);
#
#
#
#         marker_07fc1e12811ba1d0c632f7d560ac09fc.bindPopup(popup_068e4cab372858ba6539d3a76c57f6b2)
#         ;
#
#
#
#
#             var marker_48479d5c1f4ab525aa99a7d0ff7749ce = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_42768b0b9e9bae0c6864d86edb2dcd5b);
#
#
#         var popup_50d8823fb2b00bcc45b26f53470a03c9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd731ccb273459fe67efdca1c86fb8ef = $(`&lt;div id=&quot;html_dd731ccb273459fe67efdca1c86fb8ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_50d8823fb2b00bcc45b26f53470a03c9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d449c0f9442ca89e73276c1657153b19 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d449c0f9442ca89e73276c1657153b19&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d449c0f9442ca89e73276c1657153b19 = L.map(
#                 &quot;map_d449c0f9442ca89e73276c1657153b19&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c83c24822aed05acd0f91b577b83547f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c83c24822aed05acd0f91b577b83547f.addTo(map_d449c0f9442ca89e73276c1657153b19);
#
#
#             var feature_group_7e1c2a9f580e156c1e9896c2dec601ca = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_bae4807d54b1f805e01d2fc22b45a2f4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7e1c2a9f580e156c1e9896c2dec601ca);
#
#
#         var popup_a88d03ca10c872b0fadd11b1d3b419e4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a7ea6afc998b0e114440b809a0dfdcf3 = $(`&lt;div id=&quot;html_a7ea6afc998b0e114440b809a0dfdcf3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a88d03ca10c872b0fadd11b1d3b419e4.setContent(html_a7ea6afc998b0e114440b809a0dfdcf3);
#
#
#
#         marker_bae4807d54b1f805e01d2fc22b45a2f4.bindPopup(popup_a88d03ca10c872b0fadd11b1d3b419e4)
#         ;
#
#
#
#
#             var marker_df547e54bb234f516e5c3f39f09b83fd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7e1c2a9f580e156c1e9896c2dec601ca);
#
#
#         var popup_aa639f54e6c47753f9a2526c008ea6bc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac1af6b02dbf0fc4ebfee5ee72f5bbe3 = $(`&lt;div id=&quot;html_ac1af6b02dbf0fc4ebfee5ee72f5bbe3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_aa639f54e6c47753f9a2526c008ea6bc.setContent(html_ac1af6b02dbf0fc4ebfee5ee72f5bbe3);
#
#
#
#         marker_df547e54bb234f516e5c3f39f09b83fd.bindPopup(popup_aa639f54e6c47753f9a2526c008ea6bc)
#         ;
#
#
#
#
#             var marker_14984dece3996ecdf6684a71fc7067d9 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7e1c2a9f580e156c1e9896c2dec601ca);
#
#
#         var popup_6600544cd59c9e90082ad3b0c61e2472 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_65d16e2607238bd6e3d0adc35a071f55 = $(`&lt;div id=&quot;html_65d16e2607238bd6e3d0adc35a071f55&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6600544cd59c9e90082ad3b0c61e2472.setContent(html_65d16e2607238bd6e3d0adc35a071f55);
#
#
#
#         marker_14984dece3996ecdf6684a71fc7067d9.bindPopup(popup_6600544cd59c9e90082ad3b0c61e2472)
#         ;
#
#
#
#
#             var marker_acfc5d2a00f9f8e5e4b9a292fdb9a66d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7e1c2a9f580e156c1e9896c2dec601ca);
#
#
#         var popup_d359f660bf32289dcd00a9912124274c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79756c8d293580ea16b39268068db9e1 = $(`&lt;div id=&quot;html_79756c8d293580ea16b39268068db9e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d359f660bf32289dcd00a9912124274c.setContent(html_79756c8d293580ea16b39268068db9e1);
#
#
#
#         marker_acfc5d2a00f9f8e5e4b9a292fdb9a66d.bindPopup(popup_d359f660bf32289dcd00a9912124274c)
#         ;
#
#
#
#
#             var marker_9df8e97caddbbd10c3df2315f1d79062 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7e1c2a9f580e156c1e9896c2dec601ca);
#
#
#         var popup_7279eda2e8e08eaf3c8bf5bcb7b646ca = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_04d2a4ae26a74979940ccf790daf0a63 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_04d2a4ae26a74979940ccf790daf0a63&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_04d2a4ae26a74979940ccf790daf0a63 = L.map(
#                 &quot;map_04d2a4ae26a74979940ccf790daf0a63&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c85d7fb5bdf724152701e678d415ce26 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c85d7fb5bdf724152701e678d415ce26.addTo(map_04d2a4ae26a74979940ccf790daf0a63);
#
#
#             var feature_group_4b153bbaa4df4c17f1f1db242e3146cf = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4b153bbaa4df4c17f1f1db242e3146cf.addTo(map_04d2a4ae26a74979940ccf790daf0a63);
#
#
#             var feature_group_sub_group_1848287c33aaff77d606fcaa33b9614a = L.featureGroup.subGroup(
#                 feature_group_4b153bbaa4df4c17f1f1db242e3146cf
#             );
#
#
#             var marker_678e8b7cb35c92d2dc6537fa09884427 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_1848287c33aaff77d606fcaa33b9614a);
#
#
#         var popup_e2bf19b277422b430f31c84ca9058d14 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd99bc26d5f8a89273786a9a727c3827 = $(`&lt;div id=&quot;html_dd99bc26d5f8a89273786a9a727c3827&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e2bf19b277422b430f31c84ca9058d14.setContent(html_dd99bc26d5f8a89273786a9a727c3827);
#
#
#
#         marker_678e8b7cb35c92d2dc6537fa09884427.bindPopup(popup_e2bf19b277422b430f31c84ca9058d14)
#         ;
#
#
#
#
#             var marker_f1a9534f4d14c5eeddd7ce5e07d00652 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_1848287c33aaff77d606fcaa33b9614a);
#
#
#         var popup_2e4bdaaeb4698e83017975f5aee7d2a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0326af22ade7d6bf19b29aeca9ea97d7 = $(`&lt;div id=&quot;html_0326af22ade7d6bf19b29aeca9ea97d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2e4bdaaeb4698e83017975f5aee7d2a0.setContent(html_0326af22ade7d6bf19b29aeca9ea97d7);
#
#
#
#         marker_f1a9534f4d14c5eeddd7ce5e07d00652.bindPopup(popup_2e4bdaaeb4698e83017975f5aee7d2a0)
#         ;
#
#
#
#
#             var marker_4cedaf58e5dbcc8561bfb71d4d6062df = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_1848287c33aaff77d606fcaa33b9614a);
#
#
#         var popup_d94f5c040f59e409dd9bb496efe8d6cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4be68e03a71a345434f8fe4a2faee676 = $(`&lt;div id=&quot;html_4be68e03a71a345434f8fe4a2faee676&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_d94f5c040f59e409dd9bb496efe8d6cc.setContent(html_4be68e03a71a345434f8fe4a2faee676);
#
#
#
#         marker_4cedaf58e5dbcc8561bfb71d4d6062df.bindPopup(popup_d94f5c040f59e409dd9bb496efe8d6cc)
#         ;
#
#
#
#
#             var marker_ec9e5f1b652785f62b4465ba5220f4c0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_1848287c33aaff77d606fcaa33b9614a);
#
#
#         var popup_19f8d1b89a214fe53fb385c6a50cd457 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbeb4e78bd9c0f5c2d33aa4a57ad2830 = $(`&lt;div id=&quot;html_fbeb4e78bd9c0f5c2d33aa4a57ad2830&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_19f8d1b89a214fe53fb385c6a50cd457.setContent(html_fbeb4e78bd9c0f5c2d33aa4a57ad2830);
#
#
#
#         marker_
