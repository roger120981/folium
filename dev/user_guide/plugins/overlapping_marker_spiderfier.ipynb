# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_63fee51a3585c19ddfa171c0b942b288 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_63fee51a3585c19ddfa171c0b942b288&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_63fee51a3585c19ddfa171c0b942b288 = L.map(
#                 &quot;map_63fee51a3585c19ddfa171c0b942b288&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_563fc72092c503f2b099882282723172 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_563fc72092c503f2b099882282723172.addTo(map_63fee51a3585c19ddfa171c0b942b288);
#
#
#             var marker_8a2bd3d85c2de2deca05f50c37c361ec = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_63fee51a3585c19ddfa171c0b942b288);
#
#
#         var popup_fbcf8ca64810ce3db3d6f59445f1ff21 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e47639a3c20be877219fb94e7aaf1bc3 = $(`&lt;div id=&quot;html_e47639a3c20be877219fb94e7aaf1bc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_fbcf8ca64810ce3db3d6f59445f1ff21.setContent(html_e47639a3c20be877219fb94e7aaf1bc3);
#
#
#
#         marker_8a2bd3d85c2de2deca05f50c37c361ec.bindPopup(popup_fbcf8ca64810ce3db3d6f59445f1ff21)
#         ;
#
#
#
#
#             var marker_400b46052a821aad6086bb2cdbf62a83 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_63fee51a3585c19ddfa171c0b942b288);
#
#
#         var popup_9364a4f49c064ca2352cbb303d04b65c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2aed65d2a74682162b76e58a033583d = $(`&lt;div id=&quot;html_d2aed65d2a74682162b76e58a033583d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_9364a4f49c064ca2352cbb303d04b65c.setContent(html_d2aed65d2a74682162b76e58a033583d);
#
#
#
#         marker_400b46052a821aad6086bb2cdbf62a83.bindPopup(popup_9364a4f49c064ca2352cbb303d04b65c)
#         ;
#
#
#
#
#             var marker_98a5e0d34c01508700bfb7807346900c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_63fee51a3585c19ddfa171c0b942b288);
#
#
#         var popup_a32a4acab31d00950170f4d223a84992 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_626fc20dca5915697373486b85a95876 = $(`&lt;div id=&quot;html_626fc20dca5915697373486b85a95876&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_a32a4acab31d00950170f4d223a84992.setContent(html_626fc20dca5915697373486b85a95876);
#
#
#
#         marker_98a5e0d34c01508700bfb7807346900c.bindPopup(popup_a32a4acab31d00950170f4d223a84992)
#         ;
#
#
#
#
#             var marker_bb71e47b96c76b2ccea178d142f0fae1 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_63fee51a3585c19ddfa171c0b942b288);
#
#
#         var popup_b17aefae1e0947b0cd71def6a2878df7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9e5ddd06cbd77543a77a780be583b17 = $(`&lt;div id=&quot;html_e9e5ddd06cbd77543a77a780be583b17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_b17aefae1e0947b0cd71def6a2878df7.setContent(html_e9e5ddd06cbd77543a77a780be583b17);
#
#
#
#         marker_bb71e47b96c76b2ccea178d142f0fae1.bindPopup(popup_b17aefae1e0947b0cd71def6a2878df7)
#         ;
#
#
#
#
#             var marker_5088ad7ce5f00b640d8380eb4f13c7f5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_63fee51a3585c19ddfa171c0b942b288);
#
#
#         var popup_01d27f5a01f5d8e10f7e6207b5905c68 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_026fab4df54e29a27ca363079be9b53c = $(`&lt;div id=&quot;html_026fab4df54e29a27ca363079be9b53c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_01d27f5a01f5d8e10f7e6207b5905c68.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_718fa5c5b022f96c13f77708a8a19c63 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_718fa5c5b022f96c13f77708a8a19c63&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_718fa5c5b022f96c13f77708a8a19c63 = L.map(
#                 &quot;map_718fa5c5b022f96c13f77708a8a19c63&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ba6fba64bb02a47fba8b5a553415e71 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8ba6fba64bb02a47fba8b5a553415e71.addTo(map_718fa5c5b022f96c13f77708a8a19c63);
#
#
#             var feature_group_9c6926e4b3e366663064f07107c0db27 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3f4bc0e6d2bf71a3aa0aade780f48dbf = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_9c6926e4b3e366663064f07107c0db27);
#
#
#         var popup_96509a08463eb842d7755dc4e247db7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2ae522e8de916ed6992254c933acb1d = $(`&lt;div id=&quot;html_d2ae522e8de916ed6992254c933acb1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_96509a08463eb842d7755dc4e247db7e.setContent(html_d2ae522e8de916ed6992254c933acb1d);
#
#
#
#         marker_3f4bc0e6d2bf71a3aa0aade780f48dbf.bindPopup(popup_96509a08463eb842d7755dc4e247db7e)
#         ;
#
#
#
#
#             var marker_b2384e6007d9d8d190a398b5565a4ee4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_9c6926e4b3e366663064f07107c0db27);
#
#
#         var popup_baade678899c6ac7e248bdc30d0ee8c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07fc80c46157861121817b51976f3818 = $(`&lt;div id=&quot;html_07fc80c46157861121817b51976f3818&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_baade678899c6ac7e248bdc30d0ee8c0.setContent(html_07fc80c46157861121817b51976f3818);
#
#
#
#         marker_b2384e6007d9d8d190a398b5565a4ee4.bindPopup(popup_baade678899c6ac7e248bdc30d0ee8c0)
#         ;
#
#
#
#
#             var marker_eddc74523148b13022db087d08b476d3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_9c6926e4b3e366663064f07107c0db27);
#
#
#         var popup_f294d3b304aaab3b510edc2c001d407d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24af11e82dde89a584d18614b48e457f = $(`&lt;div id=&quot;html_24af11e82dde89a584d18614b48e457f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_f294d3b304aaab3b510edc2c001d407d.setContent(html_24af11e82dde89a584d18614b48e457f);
#
#
#
#         marker_eddc74523148b13022db087d08b476d3.bindPopup(popup_f294d3b304aaab3b510edc2c001d407d)
#         ;
#
#
#
#
#             var marker_0860225ab82d5be055cb3c06bd5edd18 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_9c6926e4b3e366663064f07107c0db27);
#
#
#         var popup_d193f779b3951b167014cd9aa163b2b0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eba963b3bdb5cc0ef5db49aee3cf375c = $(`&lt;div id=&quot;html_eba963b3bdb5cc0ef5db49aee3cf375c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_d193f779b3951b167014cd9aa163b2b0.setContent(html_eba963b3bdb5cc0ef5db49aee3cf375c);
#
#
#
#         marker_0860225ab82d5be055cb3c06bd5edd18.bindPopup(popup_d193f779b3951b167014cd9aa163b2b0)
#         ;
#
#
#
#
#             var marker_5121b06f2f4957ae68afe5763355d73b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_9c6926e4b3e366663064f07107c0db27);
#
#
#         var popup_1eff467d7594baea393c310da87a601c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b1444937d665c6ddf2c2ed66e0c96429 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b1444937d665c6ddf2c2ed66e0c96429&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b1444937d665c6ddf2c2ed66e0c96429 = L.map(
#                 &quot;map_b1444937d665c6ddf2c2ed66e0c96429&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ec014ff3c087525ff31e6193f221336f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ec014ff3c087525ff31e6193f221336f.addTo(map_b1444937d665c6ddf2c2ed66e0c96429);
#
#
#             var feature_group_7b1d778b1a41a6badc97a80680328450 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7b1d778b1a41a6badc97a80680328450.addTo(map_b1444937d665c6ddf2c2ed66e0c96429);
#
#
#             var feature_group_sub_group_27573fbf5802d540c3967a0117fa0653 = L.featureGroup.subGroup(
#                 feature_group_7b1d778b1a41a6badc97a80680328450
#             );
#
#
#             var marker_5b5d6be3d92c5d7f1b81c4853ff44322 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_27573fbf5802d540c3967a0117fa0653);
#
#
#         var popup_ce05db7a499e0be8a8c3c4abaec64d09 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_38ad4e0b582d5ba5b217308ab8be7fb1 = $(`&lt;div id=&quot;html_38ad4e0b582d5ba5b217308ab8be7fb1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_ce05db7a499e0be8a8c3c4abaec64d09.setContent(html_38ad4e0b582d5ba5b217308ab8be7fb1);
#
#
#
#         marker_5b5d6be3d92c5d7f1b81c4853ff44322.bindPopup(popup_ce05db7a499e0be8a8c3c4abaec64d09)
#         ;
#
#
#
#
#             var marker_06412e50414fd86e64bc2c22f4ebced6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_27573fbf5802d540c3967a0117fa0653);
#
#
#         var popup_1277d2b064619297287065233dba70ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b434f2fef72a5cadda5bb97ec437b050 = $(`&lt;div id=&quot;html_b434f2fef72a5cadda5bb97ec437b050&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1277d2b064619297287065233dba70ce.setContent(html_b434f2fef72a5cadda5bb97ec437b050);
#
#
#
#         marker_06412e50414fd86e64bc2c22f4ebced6.bindPopup(popup_1277d2b064619297287065233dba70ce)
#         ;
#
#
#
#
#             var marker_17b82248a2ce26b651ac91b263e90d16 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_27573fbf5802d540c3967a0117fa0653);
#
#
#         var popup_08aeeb3774a177518947b9643a298d57 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f168eaf89de51c6f30a3b17834b2b5cd = $(`&lt;div id=&quot;html_f168eaf89de51c6f30a3b17834b2b5cd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_08aeeb3774a177518947b9643a298d57.setContent(html_f168eaf89de51c6f30a3b17834b2b5cd);
#
#
#
#         marker_17b82248a2ce26b651ac91b263e90d16.bindPopup(popup_08aeeb3774a177518947b9643a298d57)
#         ;
#
#
#
#
#             var marker_03ac833cb2c93d2a0c99b04b9b273713 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_27573fbf5802d540c3967a0117fa0653);
#
#
#         var popup_164e753bf25b2bae74d331f5fb51bd75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f6c22deb4810304ba51eb2301694808 = $(`&lt;div id=&quot;html_9f6c22deb4810304ba51eb2301694808&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_164e753bf25b2bae74d331f5fb51bd75.setContent(html_9f6c22deb4810304ba51eb2301694808);
#
#
#
#         marker_
