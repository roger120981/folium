# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1ac5e956a5c589a047d65811067fa6b7 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1ac5e956a5c589a047d65811067fa6b7&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1ac5e956a5c589a047d65811067fa6b7 = L.map(
#                 &quot;map_1ac5e956a5c589a047d65811067fa6b7&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b8e484cb13bc33668745bac1def7ce62 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b8e484cb13bc33668745bac1def7ce62.addTo(map_1ac5e956a5c589a047d65811067fa6b7);
#
#
#             var marker_ba4774926a93e8aa312ef5d5740a3607 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1ac5e956a5c589a047d65811067fa6b7);
#
#
#         var popup_488f103d7ccfe9f3fe889e4f11f8f39c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4ecbb4a1a3e161b7bc6e7055f540f9fa = $(`&lt;div id=&quot;html_4ecbb4a1a3e161b7bc6e7055f540f9fa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_488f103d7ccfe9f3fe889e4f11f8f39c.setContent(html_4ecbb4a1a3e161b7bc6e7055f540f9fa);
#
#
#
#         marker_ba4774926a93e8aa312ef5d5740a3607.bindPopup(popup_488f103d7ccfe9f3fe889e4f11f8f39c)
#         ;
#
#
#
#
#             var marker_566b2de07b86a47575d9893c27f50552 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1ac5e956a5c589a047d65811067fa6b7);
#
#
#         var popup_e5e1433af417c5cb12183f24340bfd9d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ecb2bbb86369f0301206fd710f123e07 = $(`&lt;div id=&quot;html_ecb2bbb86369f0301206fd710f123e07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_e5e1433af417c5cb12183f24340bfd9d.setContent(html_ecb2bbb86369f0301206fd710f123e07);
#
#
#
#         marker_566b2de07b86a47575d9893c27f50552.bindPopup(popup_e5e1433af417c5cb12183f24340bfd9d)
#         ;
#
#
#
#
#             var marker_7f4be6ffee5dfc13efefce18fcbb843d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1ac5e956a5c589a047d65811067fa6b7);
#
#
#         var popup_9d44244b73ae0169186f6110745fe102 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c676d85c67bcce4b03243b4bff583715 = $(`&lt;div id=&quot;html_c676d85c67bcce4b03243b4bff583715&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9d44244b73ae0169186f6110745fe102.setContent(html_c676d85c67bcce4b03243b4bff583715);
#
#
#
#         marker_7f4be6ffee5dfc13efefce18fcbb843d.bindPopup(popup_9d44244b73ae0169186f6110745fe102)
#         ;
#
#
#
#
#             var marker_315156100b44fa0329e52ac33f595752 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1ac5e956a5c589a047d65811067fa6b7);
#
#
#         var popup_6b161ba56114c8361a77eb6832784888 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6da7b3fe24e9cd82fe1a458272b827f6 = $(`&lt;div id=&quot;html_6da7b3fe24e9cd82fe1a458272b827f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_6b161ba56114c8361a77eb6832784888.setContent(html_6da7b3fe24e9cd82fe1a458272b827f6);
#
#
#
#         marker_315156100b44fa0329e52ac33f595752.bindPopup(popup_6b161ba56114c8361a77eb6832784888)
#         ;
#
#
#
#
#             var marker_1804d5e1feabc28a44a2cb14795928a7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1ac5e956a5c589a047d65811067fa6b7);
#
#
#         var popup_7c7fba7804e11ae24bc27bf14ec091bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_140833f23783781ff3af515eef7e87c8 = $(`&lt;div id=&quot;html_140833f23783781ff3af515eef7e87c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7c7fba7804e11ae24bc27bf14ec091bf.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_708c99406e919a560feba6586e94ae9e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_708c99406e919a560feba6586e94ae9e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_708c99406e919a560feba6586e94ae9e = L.map(
#                 &quot;map_708c99406e919a560feba6586e94ae9e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dbf1a37a30af6138ae37f2e561d7640c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dbf1a37a30af6138ae37f2e561d7640c.addTo(map_708c99406e919a560feba6586e94ae9e);
#
#
#             var feature_group_f5f1c894a7aa452aca2597c9d01e86b4 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_6350d30c49b5df1f927fcaf82094655f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f5f1c894a7aa452aca2597c9d01e86b4);
#
#
#         var popup_7a100ecec70d8958a43b16154769af2d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d82d46413004474798dfa31c23eadb4 = $(`&lt;div id=&quot;html_5d82d46413004474798dfa31c23eadb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7a100ecec70d8958a43b16154769af2d.setContent(html_5d82d46413004474798dfa31c23eadb4);
#
#
#
#         marker_6350d30c49b5df1f927fcaf82094655f.bindPopup(popup_7a100ecec70d8958a43b16154769af2d)
#         ;
#
#
#
#
#             var marker_aa6ed73cc6f45d5674b5dad85f927f88 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f5f1c894a7aa452aca2597c9d01e86b4);
#
#
#         var popup_22278115ddad702c72809e2a415a984f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6794663396b564e9c3ad0aee05c8ec22 = $(`&lt;div id=&quot;html_6794663396b564e9c3ad0aee05c8ec22&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_22278115ddad702c72809e2a415a984f.setContent(html_6794663396b564e9c3ad0aee05c8ec22);
#
#
#
#         marker_aa6ed73cc6f45d5674b5dad85f927f88.bindPopup(popup_22278115ddad702c72809e2a415a984f)
#         ;
#
#
#
#
#             var marker_aecc2b75d64dc0a3ebb8eb61d41c084c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f5f1c894a7aa452aca2597c9d01e86b4);
#
#
#         var popup_73fa0e0089ab34dab1982b288923c06d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3ed4a5cb09b46226622a2f9b0fc161a1 = $(`&lt;div id=&quot;html_3ed4a5cb09b46226622a2f9b0fc161a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_73fa0e0089ab34dab1982b288923c06d.setContent(html_3ed4a5cb09b46226622a2f9b0fc161a1);
#
#
#
#         marker_aecc2b75d64dc0a3ebb8eb61d41c084c.bindPopup(popup_73fa0e0089ab34dab1982b288923c06d)
#         ;
#
#
#
#
#             var marker_8d24a4d1ee25b2ccb74a00137a4a0837 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f5f1c894a7aa452aca2597c9d01e86b4);
#
#
#         var popup_592f30a5b7592c4386a682734589fbeb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b394f192ad397926dda2b45fecf4e4b = $(`&lt;div id=&quot;html_0b394f192ad397926dda2b45fecf4e4b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_592f30a5b7592c4386a682734589fbeb.setContent(html_0b394f192ad397926dda2b45fecf4e4b);
#
#
#
#         marker_8d24a4d1ee25b2ccb74a00137a4a0837.bindPopup(popup_592f30a5b7592c4386a682734589fbeb)
#         ;
#
#
#
#
#             var marker_43c535a133604502a4905dd86c1d2c0c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f5f1c894a7aa452aca2597c9d01e86b4);
#
#
#         var popup_20f23b0ebfef8300348726b6210dda29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b131d60a3bef6fe094c3f94b0758a6f1 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b131d60a3bef6fe094c3f94b0758a6f1&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b131d60a3bef6fe094c3f94b0758a6f1 = L.map(
#                 &quot;map_b131d60a3bef6fe094c3f94b0758a6f1&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f01db0b9e904672141d601202fd58910 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f01db0b9e904672141d601202fd58910.addTo(map_b131d60a3bef6fe094c3f94b0758a6f1);
#
#
#             var feature_group_2499dfbe5d310ebfc611964c3b129e2d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_2499dfbe5d310ebfc611964c3b129e2d.addTo(map_b131d60a3bef6fe094c3f94b0758a6f1);
#
#
#             var feature_group_sub_group_9fe44d03195e148b8d9eb2fbe076d6d7 = L.featureGroup.subGroup(
#                 feature_group_2499dfbe5d310ebfc611964c3b129e2d
#             );
#
#
#             var marker_3990997988ef43d1e15983151883a27c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_9fe44d03195e148b8d9eb2fbe076d6d7);
#
#
#         var popup_fa7b7af326386c95a727aaedcf89300d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_275c4f15b23a2edca23b7fdd64534e18 = $(`&lt;div id=&quot;html_275c4f15b23a2edca23b7fdd64534e18&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fa7b7af326386c95a727aaedcf89300d.setContent(html_275c4f15b23a2edca23b7fdd64534e18);
#
#
#
#         marker_3990997988ef43d1e15983151883a27c.bindPopup(popup_fa7b7af326386c95a727aaedcf89300d)
#         ;
#
#
#
#
#             var marker_4f284eb13e0f9dd64172da3b67241acf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_9fe44d03195e148b8d9eb2fbe076d6d7);
#
#
#         var popup_f3f456c1ae99654f8492708fa32baab3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_446460c225782744acffdfec5feb284c = $(`&lt;div id=&quot;html_446460c225782744acffdfec5feb284c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f3f456c1ae99654f8492708fa32baab3.setContent(html_446460c225782744acffdfec5feb284c);
#
#
#
#         marker_4f284eb13e0f9dd64172da3b67241acf.bindPopup(popup_f3f456c1ae99654f8492708fa32baab3)
#         ;
#
#
#
#
#             var marker_8333ee66bb6b1e7aa57c408d97cd5b14 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_9fe44d03195e148b8d9eb2fbe076d6d7);
#
#
#         var popup_426b8ff8b35276532c43d0f37786b039 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f4c7aaa2be3a0d635fa96fd4c5387d4a = $(`&lt;div id=&quot;html_f4c7aaa2be3a0d635fa96fd4c5387d4a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_426b8ff8b35276532c43d0f37786b039.setContent(html_f4c7aaa2be3a0d635fa96fd4c5387d4a);
#
#
#
#         marker_8333ee66bb6b1e7aa57c408d97cd5b14.bindPopup(popup_426b8ff8b35276532c43d0f37786b039)
#         ;
#
#
#
#
#             var marker_b2c4b3037bbbeaf1554975a3ebc42e37 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_9fe44d03195e148b8d9eb2fbe076d6d7);
#
#
#         var popup_705c57fdef092771c10feab272018919 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d2722295c20d37f0abd5f3a16f7905c2 = $(`&lt;div id=&quot;html_d2722295c20d37f0abd5f3a16f7905c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_705c57fdef092771c10feab272018919.setContent(html_d2722295c20d37f0abd5f3a16f7905c2);
#
#
#
#         marker_
