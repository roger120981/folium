# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_091619962893712472bf6ad3e5b7958d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_091619962893712472bf6ad3e5b7958d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_091619962893712472bf6ad3e5b7958d = L.map(
#                 &quot;map_091619962893712472bf6ad3e5b7958d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5e89a33cc9644c83a0404f3bc228c45f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5e89a33cc9644c83a0404f3bc228c45f.addTo(map_091619962893712472bf6ad3e5b7958d);
#
#
#             var marker_35c90afa57888547de56da8112d3638a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_091619962893712472bf6ad3e5b7958d);
#
#
#         var popup_5861f0497fcc3aec89c6a03ee7805800 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc920c9cb475854c54495fb8f9b36b5d = $(`&lt;div id=&quot;html_bc920c9cb475854c54495fb8f9b36b5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_5861f0497fcc3aec89c6a03ee7805800.setContent(html_bc920c9cb475854c54495fb8f9b36b5d);
#
#
#
#         marker_35c90afa57888547de56da8112d3638a.bindPopup(popup_5861f0497fcc3aec89c6a03ee7805800)
#         ;
#
#
#
#
#             var marker_afae4cb184af67ce6028208ecd9c12e8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_091619962893712472bf6ad3e5b7958d);
#
#
#         var popup_522bb30d60913897dc3a1656aefee203 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f703884888a1776c91240e5f920fa36b = $(`&lt;div id=&quot;html_f703884888a1776c91240e5f920fa36b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_522bb30d60913897dc3a1656aefee203.setContent(html_f703884888a1776c91240e5f920fa36b);
#
#
#
#         marker_afae4cb184af67ce6028208ecd9c12e8.bindPopup(popup_522bb30d60913897dc3a1656aefee203)
#         ;
#
#
#
#
#             var marker_18ce31480b8e9c9e5bd6d29147350b43 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_091619962893712472bf6ad3e5b7958d);
#
#
#         var popup_9c85780916912a69a01df4c7f8f3381a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fed0e63ef44c6708e6741089e3ae55f5 = $(`&lt;div id=&quot;html_fed0e63ef44c6708e6741089e3ae55f5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_9c85780916912a69a01df4c7f8f3381a.setContent(html_fed0e63ef44c6708e6741089e3ae55f5);
#
#
#
#         marker_18ce31480b8e9c9e5bd6d29147350b43.bindPopup(popup_9c85780916912a69a01df4c7f8f3381a)
#         ;
#
#
#
#
#             var marker_7db54534ee9eec9b7433b89a7d28d6d5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_091619962893712472bf6ad3e5b7958d);
#
#
#         var popup_bf4ea4ed7df1dc23ea4dc0e9edbe533e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01be73e9125fc6390d0d901c63636e5d = $(`&lt;div id=&quot;html_01be73e9125fc6390d0d901c63636e5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_bf4ea4ed7df1dc23ea4dc0e9edbe533e.setContent(html_01be73e9125fc6390d0d901c63636e5d);
#
#
#
#         marker_7db54534ee9eec9b7433b89a7d28d6d5.bindPopup(popup_bf4ea4ed7df1dc23ea4dc0e9edbe533e)
#         ;
#
#
#
#
#             var marker_69652965ee43651efc67be1913e7e0ae = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_091619962893712472bf6ad3e5b7958d);
#
#
#         var popup_12aac2e7c55cfbd399bd117e24f2c7fd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1353822403814eeeabef96f74e671d3f = $(`&lt;div id=&quot;html_1353822403814eeeabef96f74e671d3f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_12aac2e7c55cfbd399bd117e24f2c7fd.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_49b46a9b9cf0ec3284f21e17ad6895af {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_49b46a9b9cf0ec3284f21e17ad6895af&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_49b46a9b9cf0ec3284f21e17ad6895af = L.map(
#                 &quot;map_49b46a9b9cf0ec3284f21e17ad6895af&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_efc4eab0523df814604dae26beb9cb8a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_efc4eab0523df814604dae26beb9cb8a.addTo(map_49b46a9b9cf0ec3284f21e17ad6895af);
#
#
#             var feature_group_14126181ec7f25dc5dcc4d5cdd5be012 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_066380d531b89cc6b2ea1bb196b6bfe6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_14126181ec7f25dc5dcc4d5cdd5be012);
#
#
#         var popup_644ebf7b729fefbc92e2d6cf36e76608 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_93d4fc271ac5cd5f80561c7bb4ab8742 = $(`&lt;div id=&quot;html_93d4fc271ac5cd5f80561c7bb4ab8742&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_644ebf7b729fefbc92e2d6cf36e76608.setContent(html_93d4fc271ac5cd5f80561c7bb4ab8742);
#
#
#
#         marker_066380d531b89cc6b2ea1bb196b6bfe6.bindPopup(popup_644ebf7b729fefbc92e2d6cf36e76608)
#         ;
#
#
#
#
#             var marker_96fd9950dee411e4580dfcbf5204c816 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_14126181ec7f25dc5dcc4d5cdd5be012);
#
#
#         var popup_bdf6323142d22256ddd0ef1c8739585c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3387d0d6a25b75874591a0d1483ec0ab = $(`&lt;div id=&quot;html_3387d0d6a25b75874591a0d1483ec0ab&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_bdf6323142d22256ddd0ef1c8739585c.setContent(html_3387d0d6a25b75874591a0d1483ec0ab);
#
#
#
#         marker_96fd9950dee411e4580dfcbf5204c816.bindPopup(popup_bdf6323142d22256ddd0ef1c8739585c)
#         ;
#
#
#
#
#             var marker_2f327a471feef319e3bf3c7d464dd512 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_14126181ec7f25dc5dcc4d5cdd5be012);
#
#
#         var popup_d8e9855be8b47a1fea25ab15343c9831 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_128e3d867ff5b14c5593af1d1a791732 = $(`&lt;div id=&quot;html_128e3d867ff5b14c5593af1d1a791732&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_d8e9855be8b47a1fea25ab15343c9831.setContent(html_128e3d867ff5b14c5593af1d1a791732);
#
#
#
#         marker_2f327a471feef319e3bf3c7d464dd512.bindPopup(popup_d8e9855be8b47a1fea25ab15343c9831)
#         ;
#
#
#
#
#             var marker_427f5a6c3f1a330eb9f3165909da4eed = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_14126181ec7f25dc5dcc4d5cdd5be012);
#
#
#         var popup_93acce1885cb5cfc20b64de1ce2b3752 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b4dd7c2d86803cb2930fb399ce2bab61 = $(`&lt;div id=&quot;html_b4dd7c2d86803cb2930fb399ce2bab61&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_93acce1885cb5cfc20b64de1ce2b3752.setContent(html_b4dd7c2d86803cb2930fb399ce2bab61);
#
#
#
#         marker_427f5a6c3f1a330eb9f3165909da4eed.bindPopup(popup_93acce1885cb5cfc20b64de1ce2b3752)
#         ;
#
#
#
#
#             var marker_4bf8006e5c5b88a64515a14835334c8c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_14126181ec7f25dc5dcc4d5cdd5be012);
#
#
#         var popup_e58bb6e564418bd2252a1fdefc06c0a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_0a1fc9a211cc5e3a718b75010f1da78b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_0a1fc9a211cc5e3a718b75010f1da78b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_0a1fc9a211cc5e3a718b75010f1da78b = L.map(
#                 &quot;map_0a1fc9a211cc5e3a718b75010f1da78b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_36f873706dd7c615ce6f0b15a8791076 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_36f873706dd7c615ce6f0b15a8791076.addTo(map_0a1fc9a211cc5e3a718b75010f1da78b);
#
#
#             var feature_group_60b63ed3ea0a5b6b19f04a85f298c0a6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_60b63ed3ea0a5b6b19f04a85f298c0a6.addTo(map_0a1fc9a211cc5e3a718b75010f1da78b);
#
#
#             var feature_group_sub_group_384ba9281df7a5fdbd7e431cec8b36d8 = L.featureGroup.subGroup(
#                 feature_group_60b63ed3ea0a5b6b19f04a85f298c0a6
#             );
#
#
#             var marker_94e9411eb31fcad413b7d5f4c8dec202 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_384ba9281df7a5fdbd7e431cec8b36d8);
#
#
#         var popup_11cc081a52d879cebb2672adc1fb97aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_58a1dbff68037dd893b02285eb5ba77f = $(`&lt;div id=&quot;html_58a1dbff68037dd893b02285eb5ba77f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_11cc081a52d879cebb2672adc1fb97aa.setContent(html_58a1dbff68037dd893b02285eb5ba77f);
#
#
#
#         marker_94e9411eb31fcad413b7d5f4c8dec202.bindPopup(popup_11cc081a52d879cebb2672adc1fb97aa)
#         ;
#
#
#
#
#             var marker_5600056ee96024bd05a71fd2e2baeeea = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_384ba9281df7a5fdbd7e431cec8b36d8);
#
#
#         var popup_3da6f2d185efca9f299a0a3e3b4bdf73 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_99c5d3c3a54d1e02f19e383b9ee6b6f8 = $(`&lt;div id=&quot;html_99c5d3c3a54d1e02f19e383b9ee6b6f8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3da6f2d185efca9f299a0a3e3b4bdf73.setContent(html_99c5d3c3a54d1e02f19e383b9ee6b6f8);
#
#
#
#         marker_5600056ee96024bd05a71fd2e2baeeea.bindPopup(popup_3da6f2d185efca9f299a0a3e3b4bdf73)
#         ;
#
#
#
#
#             var marker_0d075b78ed9064e7c2988c7d4e877623 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_384ba9281df7a5fdbd7e431cec8b36d8);
#
#
#         var popup_80bfdafa4780941c7aa879ebfe5b6c41 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1eed546368f8aa6beea5d198756e2c3a = $(`&lt;div id=&quot;html_1eed546368f8aa6beea5d198756e2c3a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_80bfdafa4780941c7aa879ebfe5b6c41.setContent(html_1eed546368f8aa6beea5d198756e2c3a);
#
#
#
#         marker_0d075b78ed9064e7c2988c7d4e877623.bindPopup(popup_80bfdafa4780941c7aa879ebfe5b6c41)
#         ;
#
#
#
#
#             var marker_aebd88285d2812da3b7fe1acefbd92e0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_384ba9281df7a5fdbd7e431cec8b36d8);
#
#
#         var popup_5e5e0317c75403102a90a360142f56f8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2bc10c236ffe3aa610580a56e5b1dc44 = $(`&lt;div id=&quot;html_2bc10c236ffe3aa610580a56e5b1dc44&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5e5e0317c75403102a90a360142f56f8.setContent(html_2bc10c236ffe3aa610580a56e5b1dc44);
#
#
#
#         marker_
