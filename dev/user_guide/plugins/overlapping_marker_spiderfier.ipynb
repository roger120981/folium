# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f3b21ef7846b9ad5a8ff8d77c335795c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f3b21ef7846b9ad5a8ff8d77c335795c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f3b21ef7846b9ad5a8ff8d77c335795c = L.map(
#                 &quot;map_f3b21ef7846b9ad5a8ff8d77c335795c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d1e7b9f36cc5c45edcef45dd9d64debc = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d1e7b9f36cc5c45edcef45dd9d64debc.addTo(map_f3b21ef7846b9ad5a8ff8d77c335795c);
#
#
#             var marker_ba7f475b7d9791a8426d28b049d1a20d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_f3b21ef7846b9ad5a8ff8d77c335795c);
#
#
#         var popup_698fe87ef562a638e17024cbf6a8b71a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_674b6cdd0d3c34235204fbffba614770 = $(`&lt;div id=&quot;html_674b6cdd0d3c34235204fbffba614770&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_698fe87ef562a638e17024cbf6a8b71a.setContent(html_674b6cdd0d3c34235204fbffba614770);
#
#
#
#         marker_ba7f475b7d9791a8426d28b049d1a20d.bindPopup(popup_698fe87ef562a638e17024cbf6a8b71a)
#         ;
#
#
#
#
#             var marker_2c7ebd2bc23f1ec16304ea0b9c725652 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_f3b21ef7846b9ad5a8ff8d77c335795c);
#
#
#         var popup_c1f949edf098fad7c232b206945e098b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7757fde663ee28ad84e3c630bcb4d81b = $(`&lt;div id=&quot;html_7757fde663ee28ad84e3c630bcb4d81b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c1f949edf098fad7c232b206945e098b.setContent(html_7757fde663ee28ad84e3c630bcb4d81b);
#
#
#
#         marker_2c7ebd2bc23f1ec16304ea0b9c725652.bindPopup(popup_c1f949edf098fad7c232b206945e098b)
#         ;
#
#
#
#
#             var marker_4ab17a22f3902804febe2aefc8a4fced = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_f3b21ef7846b9ad5a8ff8d77c335795c);
#
#
#         var popup_f71d648194a37d8b0e0226df56b43560 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dba33c0eeb70b850280fbd704ac2b24e = $(`&lt;div id=&quot;html_dba33c0eeb70b850280fbd704ac2b24e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f71d648194a37d8b0e0226df56b43560.setContent(html_dba33c0eeb70b850280fbd704ac2b24e);
#
#
#
#         marker_4ab17a22f3902804febe2aefc8a4fced.bindPopup(popup_f71d648194a37d8b0e0226df56b43560)
#         ;
#
#
#
#
#             var marker_21c941a8fe3e2e0287d9674bdcfadf3e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_f3b21ef7846b9ad5a8ff8d77c335795c);
#
#
#         var popup_a88ec912cb0c23e155086c1c9ca14cdc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f719088dd0f262d7eb1a93088b90b1e5 = $(`&lt;div id=&quot;html_f719088dd0f262d7eb1a93088b90b1e5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a88ec912cb0c23e155086c1c9ca14cdc.setContent(html_f719088dd0f262d7eb1a93088b90b1e5);
#
#
#
#         marker_21c941a8fe3e2e0287d9674bdcfadf3e.bindPopup(popup_a88ec912cb0c23e155086c1c9ca14cdc)
#         ;
#
#
#
#
#             var marker_1afe18ca3490455fb6191b2439eb0ff0 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_f3b21ef7846b9ad5a8ff8d77c335795c);
#
#
#         var popup_33285594cfc983604c83bdc4d730385b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ee7912dcf0538f04ba0ae0884cfc675 = $(`&lt;div id=&quot;html_2ee7912dcf0538f04ba0ae0884cfc675&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_33285594cfc983604c83bdc4d730385b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9d6a845af5358d7bdbd6a6dfa1b3593 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9d6a845af5358d7bdbd6a6dfa1b3593&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9d6a845af5358d7bdbd6a6dfa1b3593 = L.map(
#                 &quot;map_c9d6a845af5358d7bdbd6a6dfa1b3593&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7def3528ff4b049cdad55781bf9102f9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7def3528ff4b049cdad55781bf9102f9.addTo(map_c9d6a845af5358d7bdbd6a6dfa1b3593);
#
#
#             var feature_group_a6a7f613aa1e88d1269189129abbb926 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_201841762d12a6abd1f2e7811a573810 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_a6a7f613aa1e88d1269189129abbb926);
#
#
#         var popup_e87652a0b110a08358d6bca6ebc69c07 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b5368df7d60eb3b1d664636c1a53108 = $(`&lt;div id=&quot;html_0b5368df7d60eb3b1d664636c1a53108&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e87652a0b110a08358d6bca6ebc69c07.setContent(html_0b5368df7d60eb3b1d664636c1a53108);
#
#
#
#         marker_201841762d12a6abd1f2e7811a573810.bindPopup(popup_e87652a0b110a08358d6bca6ebc69c07)
#         ;
#
#
#
#
#             var marker_a1e7cb60fc4962e6d23ab1c88ba6f4a4 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_a6a7f613aa1e88d1269189129abbb926);
#
#
#         var popup_d5ca2bbd1094ada28f03c1687356b402 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_312c01bae03849afe8fc009259cc33da = $(`&lt;div id=&quot;html_312c01bae03849afe8fc009259cc33da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d5ca2bbd1094ada28f03c1687356b402.setContent(html_312c01bae03849afe8fc009259cc33da);
#
#
#
#         marker_a1e7cb60fc4962e6d23ab1c88ba6f4a4.bindPopup(popup_d5ca2bbd1094ada28f03c1687356b402)
#         ;
#
#
#
#
#             var marker_ff1aaf1bcc692ff8cd7374c0986e30e8 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_a6a7f613aa1e88d1269189129abbb926);
#
#
#         var popup_19a3ca867fc9a98d36e4b633cdc9dd71 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e85364d1c5132f27de3c7a14e283494 = $(`&lt;div id=&quot;html_4e85364d1c5132f27de3c7a14e283494&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_19a3ca867fc9a98d36e4b633cdc9dd71.setContent(html_4e85364d1c5132f27de3c7a14e283494);
#
#
#
#         marker_ff1aaf1bcc692ff8cd7374c0986e30e8.bindPopup(popup_19a3ca867fc9a98d36e4b633cdc9dd71)
#         ;
#
#
#
#
#             var marker_33530cbdd00e69a9d29d637d311a4df2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_a6a7f613aa1e88d1269189129abbb926);
#
#
#         var popup_52728b9c68277e28e1151fe67d02700a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2ea5613c6022c6b999c752ddf17438a4 = $(`&lt;div id=&quot;html_2ea5613c6022c6b999c752ddf17438a4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_52728b9c68277e28e1151fe67d02700a.setContent(html_2ea5613c6022c6b999c752ddf17438a4);
#
#
#
#         marker_33530cbdd00e69a9d29d637d311a4df2.bindPopup(popup_52728b9c68277e28e1151fe67d02700a)
#         ;
#
#
#
#
#             var marker_732698928c3841b787dfbab372066b4a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_a6a7f613aa1e88d1269189129abbb926);
#
#
#         var popup_88d4d37f57a9c536c07b3e42ec7bd83e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_264ad4c383c03b98534c56189218dd14 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_264ad4c383c03b98534c56189218dd14&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_264ad4c383c03b98534c56189218dd14 = L.map(
#                 &quot;map_264ad4c383c03b98534c56189218dd14&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_923e62f6c1be8d043475360bd6ee8f63 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_923e62f6c1be8d043475360bd6ee8f63.addTo(map_264ad4c383c03b98534c56189218dd14);
#
#
#             var feature_group_dedc3aaa56f59f6d930a68e3964e75cf = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_dedc3aaa56f59f6d930a68e3964e75cf.addTo(map_264ad4c383c03b98534c56189218dd14);
#
#
#             var feature_group_sub_group_f573ce1298446536144dbb55c40e809f = L.featureGroup.subGroup(
#                 feature_group_dedc3aaa56f59f6d930a68e3964e75cf
#             );
#
#
#             var marker_b5dbc8b62d2c852862c9938fe30af1fc = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_f573ce1298446536144dbb55c40e809f);
#
#
#         var popup_03cbaf4c31d5c1c5721e699b45b0427d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8838255afad0643dfd530620039fa3ff = $(`&lt;div id=&quot;html_8838255afad0643dfd530620039fa3ff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_03cbaf4c31d5c1c5721e699b45b0427d.setContent(html_8838255afad0643dfd530620039fa3ff);
#
#
#
#         marker_b5dbc8b62d2c852862c9938fe30af1fc.bindPopup(popup_03cbaf4c31d5c1c5721e699b45b0427d)
#         ;
#
#
#
#
#             var marker_4870ef7e9fdf498a2b7eef0daa97faa1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_f573ce1298446536144dbb55c40e809f);
#
#
#         var popup_60e6eaed353e06bc55e25742f5e69689 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_aa3a880d535e6f68264017e52777ce81 = $(`&lt;div id=&quot;html_aa3a880d535e6f68264017e52777ce81&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_60e6eaed353e06bc55e25742f5e69689.setContent(html_aa3a880d535e6f68264017e52777ce81);
#
#
#
#         marker_4870ef7e9fdf498a2b7eef0daa97faa1.bindPopup(popup_60e6eaed353e06bc55e25742f5e69689)
#         ;
#
#
#
#
#             var marker_fc13166483421b71613dc9c24a86d00b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_f573ce1298446536144dbb55c40e809f);
#
#
#         var popup_4e928730f10f14c582a1c41b3da17379 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_980e33117711382dc0b74596f2b9085e = $(`&lt;div id=&quot;html_980e33117711382dc0b74596f2b9085e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_4e928730f10f14c582a1c41b3da17379.setContent(html_980e33117711382dc0b74596f2b9085e);
#
#
#
#         marker_fc13166483421b71613dc9c24a86d00b.bindPopup(popup_4e928730f10f14c582a1c41b3da17379)
#         ;
#
#
#
#
#             var marker_d6530ad96799058bb5c853eddd9cbc2d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_f573ce1298446536144dbb55c40e809f);
#
#
#         var popup_b8692a207372d539ea606720223ea781 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21e8ff9ecf49825105eb4dcebedbbba5 = $(`&lt;div id=&quot;html_21e8ff9ecf49825105eb4dcebedbbba5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b8692a207372d539ea606720223ea781.setContent(html_21e8ff9ecf49825105eb4dcebedbbba5);
#
#
#
#         marker_
