# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1e85a5f64be72be9dad6026f59ddd578 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1e85a5f64be72be9dad6026f59ddd578&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1e85a5f64be72be9dad6026f59ddd578 = L.map(
#                 &quot;map_1e85a5f64be72be9dad6026f59ddd578&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0d294d92af3c462937a0c567189a1ce2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0d294d92af3c462937a0c567189a1ce2.addTo(map_1e85a5f64be72be9dad6026f59ddd578);
#
#
#             var marker_cfa3e79e4d75eba30aa23b790849c8a3 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1e85a5f64be72be9dad6026f59ddd578);
#
#
#         var popup_b2903cab4ddb795de1f7cd8ef5c77f70 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e5a081081312ff3584da70a7acf74d5a = $(`&lt;div id=&quot;html_e5a081081312ff3584da70a7acf74d5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b2903cab4ddb795de1f7cd8ef5c77f70.setContent(html_e5a081081312ff3584da70a7acf74d5a);
#
#
#
#         marker_cfa3e79e4d75eba30aa23b790849c8a3.bindPopup(popup_b2903cab4ddb795de1f7cd8ef5c77f70)
#         ;
#
#
#
#
#             var marker_05f45deb20c2d75abc114c3aed6c93d6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1e85a5f64be72be9dad6026f59ddd578);
#
#
#         var popup_dfe3d25cff0bb906168eeca749dc3f32 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2fb2cfd8f96ae8cdf2698cd8c2e1edcc = $(`&lt;div id=&quot;html_2fb2cfd8f96ae8cdf2698cd8c2e1edcc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_dfe3d25cff0bb906168eeca749dc3f32.setContent(html_2fb2cfd8f96ae8cdf2698cd8c2e1edcc);
#
#
#
#         marker_05f45deb20c2d75abc114c3aed6c93d6.bindPopup(popup_dfe3d25cff0bb906168eeca749dc3f32)
#         ;
#
#
#
#
#             var marker_111e4c7af67638d022505eafa3c43f83 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1e85a5f64be72be9dad6026f59ddd578);
#
#
#         var popup_fc1c09be3e73308cc551dca5289a6203 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_634b399d9ec4e2ffb98bcd1423be938a = $(`&lt;div id=&quot;html_634b399d9ec4e2ffb98bcd1423be938a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_fc1c09be3e73308cc551dca5289a6203.setContent(html_634b399d9ec4e2ffb98bcd1423be938a);
#
#
#
#         marker_111e4c7af67638d022505eafa3c43f83.bindPopup(popup_fc1c09be3e73308cc551dca5289a6203)
#         ;
#
#
#
#
#             var marker_1202a726c288ee66e57e91611e54d39f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1e85a5f64be72be9dad6026f59ddd578);
#
#
#         var popup_06fceff8bdad5ab4d504e014b5d9dd75 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_75abea3b00fb977882f711f0d3a170d7 = $(`&lt;div id=&quot;html_75abea3b00fb977882f711f0d3a170d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_06fceff8bdad5ab4d504e014b5d9dd75.setContent(html_75abea3b00fb977882f711f0d3a170d7);
#
#
#
#         marker_1202a726c288ee66e57e91611e54d39f.bindPopup(popup_06fceff8bdad5ab4d504e014b5d9dd75)
#         ;
#
#
#
#
#             var marker_d3e420532e6dde2ef02b118e36aae0e1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1e85a5f64be72be9dad6026f59ddd578);
#
#
#         var popup_ccf8e2f93108c9344abfd555d8c7169b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a75a4fae47eb07c7182ab3e1b242c7f = $(`&lt;div id=&quot;html_5a75a4fae47eb07c7182ab3e1b242c7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ccf8e2f93108c9344abfd555d8c7169b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_058357a8ae2563b47ae5cdf48063c8fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_058357a8ae2563b47ae5cdf48063c8fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_058357a8ae2563b47ae5cdf48063c8fb = L.map(
#                 &quot;map_058357a8ae2563b47ae5cdf48063c8fb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2552fc93f0bcef9c9c23f83ae9d8288b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2552fc93f0bcef9c9c23f83ae9d8288b.addTo(map_058357a8ae2563b47ae5cdf48063c8fb);
#
#
#             var feature_group_d6ec32ddaad257aa3e385ea73562738d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ca3e86cd586c60630caf2fad57fd059c = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_d6ec32ddaad257aa3e385ea73562738d);
#
#
#         var popup_854f6535021eeaecc1a42e6b7cb78bf8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_125b6ad2c5fcd24dc861a7ff5ba39f39 = $(`&lt;div id=&quot;html_125b6ad2c5fcd24dc861a7ff5ba39f39&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_854f6535021eeaecc1a42e6b7cb78bf8.setContent(html_125b6ad2c5fcd24dc861a7ff5ba39f39);
#
#
#
#         marker_ca3e86cd586c60630caf2fad57fd059c.bindPopup(popup_854f6535021eeaecc1a42e6b7cb78bf8)
#         ;
#
#
#
#
#             var marker_75d10335e49138d06c897dcdee17c85c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_d6ec32ddaad257aa3e385ea73562738d);
#
#
#         var popup_904ef09dcb0ed3de0a3561e32f4414e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe73d5e799028c9efe2a0c24eb69982e = $(`&lt;div id=&quot;html_fe73d5e799028c9efe2a0c24eb69982e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_904ef09dcb0ed3de0a3561e32f4414e5.setContent(html_fe73d5e799028c9efe2a0c24eb69982e);
#
#
#
#         marker_75d10335e49138d06c897dcdee17c85c.bindPopup(popup_904ef09dcb0ed3de0a3561e32f4414e5)
#         ;
#
#
#
#
#             var marker_822615754b0e1d4629ca07cfba581141 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_d6ec32ddaad257aa3e385ea73562738d);
#
#
#         var popup_b3076cdd9e9b7ccf70176ac680868991 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e1553d13dbfe68fad77f0343891cfca = $(`&lt;div id=&quot;html_5e1553d13dbfe68fad77f0343891cfca&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b3076cdd9e9b7ccf70176ac680868991.setContent(html_5e1553d13dbfe68fad77f0343891cfca);
#
#
#
#         marker_822615754b0e1d4629ca07cfba581141.bindPopup(popup_b3076cdd9e9b7ccf70176ac680868991)
#         ;
#
#
#
#
#             var marker_d5b90e343ccf196ff23c1508c3391ee0 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_d6ec32ddaad257aa3e385ea73562738d);
#
#
#         var popup_603be124d2ae494724c97355ed58301b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3455e337a004fa9dbb6fdb8dc0ce827f = $(`&lt;div id=&quot;html_3455e337a004fa9dbb6fdb8dc0ce827f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_603be124d2ae494724c97355ed58301b.setContent(html_3455e337a004fa9dbb6fdb8dc0ce827f);
#
#
#
#         marker_d5b90e343ccf196ff23c1508c3391ee0.bindPopup(popup_603be124d2ae494724c97355ed58301b)
#         ;
#
#
#
#
#             var marker_1c393ef6e73144fdca33f87cb1ff728d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_d6ec32ddaad257aa3e385ea73562738d);
#
#
#         var popup_f7c9f331f3a536f4b9de3dfe05bcbe1b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5b326a0eee2bda03ce41d8ff7970d56c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5b326a0eee2bda03ce41d8ff7970d56c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5b326a0eee2bda03ce41d8ff7970d56c = L.map(
#                 &quot;map_5b326a0eee2bda03ce41d8ff7970d56c&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_04cac49de0b7e7e53ac1352dfce3e6d2 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_04cac49de0b7e7e53ac1352dfce3e6d2.addTo(map_5b326a0eee2bda03ce41d8ff7970d56c);
#
#
#             var feature_group_7deddfacf793b00724dce3ee24363baa = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7deddfacf793b00724dce3ee24363baa.addTo(map_5b326a0eee2bda03ce41d8ff7970d56c);
#
#
#             var feature_group_sub_group_57869e76e5718b4b3a8d6174bf614dfe = L.featureGroup.subGroup(
#                 feature_group_7deddfacf793b00724dce3ee24363baa
#             );
#
#
#             var marker_e93aec1f68e6123ac873428c673e5954 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_57869e76e5718b4b3a8d6174bf614dfe);
#
#
#         var popup_1f285b522dd79e8c4326ba498d386ba9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4324d503dfcd52e5d85260c9433ff6a5 = $(`&lt;div id=&quot;html_4324d503dfcd52e5d85260c9433ff6a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_1f285b522dd79e8c4326ba498d386ba9.setContent(html_4324d503dfcd52e5d85260c9433ff6a5);
#
#
#
#         marker_e93aec1f68e6123ac873428c673e5954.bindPopup(popup_1f285b522dd79e8c4326ba498d386ba9)
#         ;
#
#
#
#
#             var marker_ebe8dd6ae89e41cb67d3f2b6c32489b6 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_57869e76e5718b4b3a8d6174bf614dfe);
#
#
#         var popup_cabb38aa470fb6c3ef5ff99bc397e8ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4184f0f198e524740b49e1ccefca9856 = $(`&lt;div id=&quot;html_4184f0f198e524740b49e1ccefca9856&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_cabb38aa470fb6c3ef5ff99bc397e8ab.setContent(html_4184f0f198e524740b49e1ccefca9856);
#
#
#
#         marker_ebe8dd6ae89e41cb67d3f2b6c32489b6.bindPopup(popup_cabb38aa470fb6c3ef5ff99bc397e8ab)
#         ;
#
#
#
#
#             var marker_5613556b8023c0439addad08b44d4e81 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_57869e76e5718b4b3a8d6174bf614dfe);
#
#
#         var popup_bdb8e6b23e229ba0feec5f48a5625af4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c458256539bb3bb309292647c86d1ed2 = $(`&lt;div id=&quot;html_c458256539bb3bb309292647c86d1ed2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_bdb8e6b23e229ba0feec5f48a5625af4.setContent(html_c458256539bb3bb309292647c86d1ed2);
#
#
#
#         marker_5613556b8023c0439addad08b44d4e81.bindPopup(popup_bdb8e6b23e229ba0feec5f48a5625af4)
#         ;
#
#
#
#
#             var marker_a394435fd9b425f33dcbcd228a2f70a3 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_57869e76e5718b4b3a8d6174bf614dfe);
#
#
#         var popup_75bda92d16d041d3e65836a2c2146380 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4261643f5a1320492da32ee2bde5f19f = $(`&lt;div id=&quot;html_4261643f5a1320492da32ee2bde5f19f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_75bda92d16d041d3e65836a2c2146380.setContent(html_4261643f5a1320492da32ee2bde5f19f);
#
#
#
#         marker_
