# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_489bb500b58683fbb18f6af8a4ae4109 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_489bb500b58683fbb18f6af8a4ae4109&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_489bb500b58683fbb18f6af8a4ae4109 = L.map(
#                 &quot;map_489bb500b58683fbb18f6af8a4ae4109&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2f4c1bde94033463307a56c75df1365c = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2f4c1bde94033463307a56c75df1365c.addTo(map_489bb500b58683fbb18f6af8a4ae4109);
#
#
#             var marker_3c47cff7f2ffe9f91d8c5df569e931c6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_489bb500b58683fbb18f6af8a4ae4109);
#
#
#         var popup_b24175cc2c74866c26cb6d51b540532f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4c61453629706d576809e3f21a628a5d = $(`&lt;div id=&quot;html_4c61453629706d576809e3f21a628a5d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_b24175cc2c74866c26cb6d51b540532f.setContent(html_4c61453629706d576809e3f21a628a5d);
#
#
#
#         marker_3c47cff7f2ffe9f91d8c5df569e931c6.bindPopup(popup_b24175cc2c74866c26cb6d51b540532f)
#         ;
#
#
#
#
#             var marker_372c1d86118a75609d93d364c562709f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_489bb500b58683fbb18f6af8a4ae4109);
#
#
#         var popup_c12508f515d4a0727db13cff5a2e5ce8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_085ae698b92e5b930a1725919c5533fb = $(`&lt;div id=&quot;html_085ae698b92e5b930a1725919c5533fb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_c12508f515d4a0727db13cff5a2e5ce8.setContent(html_085ae698b92e5b930a1725919c5533fb);
#
#
#
#         marker_372c1d86118a75609d93d364c562709f.bindPopup(popup_c12508f515d4a0727db13cff5a2e5ce8)
#         ;
#
#
#
#
#             var marker_5bbeca8aa99043baa1c123763642ae6d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_489bb500b58683fbb18f6af8a4ae4109);
#
#
#         var popup_91afe691003b985001fd66d3ed760910 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1e08f08fadeb095233127e4a1055aebe = $(`&lt;div id=&quot;html_1e08f08fadeb095233127e4a1055aebe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_91afe691003b985001fd66d3ed760910.setContent(html_1e08f08fadeb095233127e4a1055aebe);
#
#
#
#         marker_5bbeca8aa99043baa1c123763642ae6d.bindPopup(popup_91afe691003b985001fd66d3ed760910)
#         ;
#
#
#
#
#             var marker_b7508663a23c55be86a74c4a34c39863 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_489bb500b58683fbb18f6af8a4ae4109);
#
#
#         var popup_4d4d918144933bd11c77e96400a7aa6d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76b0c491bd2e8ebbb73c0118cfac7485 = $(`&lt;div id=&quot;html_76b0c491bd2e8ebbb73c0118cfac7485&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_4d4d918144933bd11c77e96400a7aa6d.setContent(html_76b0c491bd2e8ebbb73c0118cfac7485);
#
#
#
#         marker_b7508663a23c55be86a74c4a34c39863.bindPopup(popup_4d4d918144933bd11c77e96400a7aa6d)
#         ;
#
#
#
#
#             var marker_35044672266e0a67284920bfac6226d2 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_489bb500b58683fbb18f6af8a4ae4109);
#
#
#         var popup_72179f236796d96b9616ccd9dbc6a360 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ad23e17d3ad3ddc6477bfbbf225ad17 = $(`&lt;div id=&quot;html_0ad23e17d3ad3ddc6477bfbbf225ad17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_72179f236796d96b9616ccd9dbc6a360.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d2d2f10ab76b2fc6ad63808ba021384e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d2d2f10ab76b2fc6ad63808ba021384e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d2d2f10ab76b2fc6ad63808ba021384e = L.map(
#                 &quot;map_d2d2f10ab76b2fc6ad63808ba021384e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4150b5a1bb42a0543ce21454a6794ff1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4150b5a1bb42a0543ce21454a6794ff1.addTo(map_d2d2f10ab76b2fc6ad63808ba021384e);
#
#
#             var feature_group_0e30d9e0622238a2471ccff526a69ac7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c3e75f2e9e6c1023c9793f279e9a480b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_0e30d9e0622238a2471ccff526a69ac7);
#
#
#         var popup_4a93c7b7635be5b7e76e49503304d419 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0f058c276483e820291cbc3b6f7ecb6 = $(`&lt;div id=&quot;html_b0f058c276483e820291cbc3b6f7ecb6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4a93c7b7635be5b7e76e49503304d419.setContent(html_b0f058c276483e820291cbc3b6f7ecb6);
#
#
#
#         marker_c3e75f2e9e6c1023c9793f279e9a480b.bindPopup(popup_4a93c7b7635be5b7e76e49503304d419)
#         ;
#
#
#
#
#             var marker_45ac58c47a2ed17bb848ea5309224e69 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_0e30d9e0622238a2471ccff526a69ac7);
#
#
#         var popup_3dfcf88020a7fef1194346d27b0a8dd7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_029cf39f0ee7e27ba92b29aa1c141fd0 = $(`&lt;div id=&quot;html_029cf39f0ee7e27ba92b29aa1c141fd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_3dfcf88020a7fef1194346d27b0a8dd7.setContent(html_029cf39f0ee7e27ba92b29aa1c141fd0);
#
#
#
#         marker_45ac58c47a2ed17bb848ea5309224e69.bindPopup(popup_3dfcf88020a7fef1194346d27b0a8dd7)
#         ;
#
#
#
#
#             var marker_88fe4f8b0a7bf3208804b71b7af33627 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_0e30d9e0622238a2471ccff526a69ac7);
#
#
#         var popup_555f466e675497b3596baa1a697e54ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2e9607c0654dee7bbcd3fa0ff8705d83 = $(`&lt;div id=&quot;html_2e9607c0654dee7bbcd3fa0ff8705d83&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_555f466e675497b3596baa1a697e54ae.setContent(html_2e9607c0654dee7bbcd3fa0ff8705d83);
#
#
#
#         marker_88fe4f8b0a7bf3208804b71b7af33627.bindPopup(popup_555f466e675497b3596baa1a697e54ae)
#         ;
#
#
#
#
#             var marker_61c42ddb2d3bcf4757889a444021d74d = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_0e30d9e0622238a2471ccff526a69ac7);
#
#
#         var popup_573e986e860707836d56f5394c5225b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96ec4412aae6deb2654fd7c8d36e0f1e = $(`&lt;div id=&quot;html_96ec4412aae6deb2654fd7c8d36e0f1e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_573e986e860707836d56f5394c5225b8.setContent(html_96ec4412aae6deb2654fd7c8d36e0f1e);
#
#
#
#         marker_61c42ddb2d3bcf4757889a444021d74d.bindPopup(popup_573e986e860707836d56f5394c5225b8)
#         ;
#
#
#
#
#             var marker_0dafbc1234b992f981a9202bf88b2ade = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_0e30d9e0622238a2471ccff526a69ac7);
#
#
#         var popup_b5f18c40a00edc6ebe8b806580f383a4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cd26e7d77fea3cee413594139603d424 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cd26e7d77fea3cee413594139603d424&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cd26e7d77fea3cee413594139603d424 = L.map(
#                 &quot;map_cd26e7d77fea3cee413594139603d424&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fa7187e31353556112d75f144756ab9b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fa7187e31353556112d75f144756ab9b.addTo(map_cd26e7d77fea3cee413594139603d424);
#
#
#             var feature_group_115b49d629e52a23333684495712ff20 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_115b49d629e52a23333684495712ff20.addTo(map_cd26e7d77fea3cee413594139603d424);
#
#
#             var feature_group_sub_group_c86544e383352fc5b92b3e6e21c9f7b5 = L.featureGroup.subGroup(
#                 feature_group_115b49d629e52a23333684495712ff20
#             );
#
#
#             var marker_f321194760dbf4c34e0c1f210e32142a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_c86544e383352fc5b92b3e6e21c9f7b5);
#
#
#         var popup_0365637e723b7ff46555d364feb3124d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d4e42677ef8a9d098b6307ab5db97842 = $(`&lt;div id=&quot;html_d4e42677ef8a9d098b6307ab5db97842&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0365637e723b7ff46555d364feb3124d.setContent(html_d4e42677ef8a9d098b6307ab5db97842);
#
#
#
#         marker_f321194760dbf4c34e0c1f210e32142a.bindPopup(popup_0365637e723b7ff46555d364feb3124d)
#         ;
#
#
#
#
#             var marker_f5cf8f9ef4a46abf545a4cf78380fcfd = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_c86544e383352fc5b92b3e6e21c9f7b5);
#
#
#         var popup_c5c2683cdaf364ba3de95412553d262f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_92bc53fcc3cf5f5dc995e3430e1e39b1 = $(`&lt;div id=&quot;html_92bc53fcc3cf5f5dc995e3430e1e39b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c5c2683cdaf364ba3de95412553d262f.setContent(html_92bc53fcc3cf5f5dc995e3430e1e39b1);
#
#
#
#         marker_f5cf8f9ef4a46abf545a4cf78380fcfd.bindPopup(popup_c5c2683cdaf364ba3de95412553d262f)
#         ;
#
#
#
#
#             var marker_06a970978520ddbeab6d5e505914c57d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_c86544e383352fc5b92b3e6e21c9f7b5);
#
#
#         var popup_8edfc57b1cf9edb5ed4db124cfab0b74 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fdafa0b0511232ecdf9429a6bd6b60d = $(`&lt;div id=&quot;html_6fdafa0b0511232ecdf9429a6bd6b60d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8edfc57b1cf9edb5ed4db124cfab0b74.setContent(html_6fdafa0b0511232ecdf9429a6bd6b60d);
#
#
#
#         marker_06a970978520ddbeab6d5e505914c57d.bindPopup(popup_8edfc57b1cf9edb5ed4db124cfab0b74)
#         ;
#
#
#
#
#             var marker_21311d3b6fb3e58236a7d7568ad2452e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_c86544e383352fc5b92b3e6e21c9f7b5);
#
#
#         var popup_c628d13d262d6d68ed273d145141b68c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_48f298ef53d90f366f0c73e72a4939e8 = $(`&lt;div id=&quot;html_48f298ef53d90f366f0c73e72a4939e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_c628d13d262d6d68ed273d145141b68c.setContent(html_48f298ef53d90f366f0c73e72a4939e8);
#
#
#
#         marker_
