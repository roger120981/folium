# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c012de897721c322e13e3850a1edc6e2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c012de897721c322e13e3850a1edc6e2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c012de897721c322e13e3850a1edc6e2 = L.map(
#                 &quot;map_c012de897721c322e13e3850a1edc6e2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2e4ad658bcbc66d4a868a29f7fdc51c7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2e4ad658bcbc66d4a868a29f7fdc51c7.addTo(map_c012de897721c322e13e3850a1edc6e2);
#
#
#             var marker_b0d0c15293febe295cac1d89e4f8035f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_c012de897721c322e13e3850a1edc6e2);
#
#
#         var popup_fc4ad9e6f4e31ec9ed99c33e6dfb3d7f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f53abf8ed1d68ec438ca51ca9d6cc849 = $(`&lt;div id=&quot;html_f53abf8ed1d68ec438ca51ca9d6cc849&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_fc4ad9e6f4e31ec9ed99c33e6dfb3d7f.setContent(html_f53abf8ed1d68ec438ca51ca9d6cc849);
#
#
#
#         marker_b0d0c15293febe295cac1d89e4f8035f.bindPopup(popup_fc4ad9e6f4e31ec9ed99c33e6dfb3d7f)
#         ;
#
#
#
#
#             var marker_7077fe889c0a82c68f45cfd56fc41731 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_c012de897721c322e13e3850a1edc6e2);
#
#
#         var popup_bae11a7c658e62a6cb7033db2416a25e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9b11ff2b29d4f5d4b619cd78e788484 = $(`&lt;div id=&quot;html_f9b11ff2b29d4f5d4b619cd78e788484&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_bae11a7c658e62a6cb7033db2416a25e.setContent(html_f9b11ff2b29d4f5d4b619cd78e788484);
#
#
#
#         marker_7077fe889c0a82c68f45cfd56fc41731.bindPopup(popup_bae11a7c658e62a6cb7033db2416a25e)
#         ;
#
#
#
#
#             var marker_77307e58da4b4b798460f2100cc15560 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_c012de897721c322e13e3850a1edc6e2);
#
#
#         var popup_25716404f8de594e73b8efa3d6b438f0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a162f1e90bdc5a9ab73dc712607e34b = $(`&lt;div id=&quot;html_5a162f1e90bdc5a9ab73dc712607e34b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_25716404f8de594e73b8efa3d6b438f0.setContent(html_5a162f1e90bdc5a9ab73dc712607e34b);
#
#
#
#         marker_77307e58da4b4b798460f2100cc15560.bindPopup(popup_25716404f8de594e73b8efa3d6b438f0)
#         ;
#
#
#
#
#             var marker_cc2f9cd30efcb63b6871bffee95de1e9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_c012de897721c322e13e3850a1edc6e2);
#
#
#         var popup_db45e2b826f5ccd1676e5d9e2f634b8c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_515d8856f5ab74fa367e590de7c86ec1 = $(`&lt;div id=&quot;html_515d8856f5ab74fa367e590de7c86ec1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_db45e2b826f5ccd1676e5d9e2f634b8c.setContent(html_515d8856f5ab74fa367e590de7c86ec1);
#
#
#
#         marker_cc2f9cd30efcb63b6871bffee95de1e9.bindPopup(popup_db45e2b826f5ccd1676e5d9e2f634b8c)
#         ;
#
#
#
#
#             var marker_d663d3750e7881ab37ecfa84e389f1cb = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_c012de897721c322e13e3850a1edc6e2);
#
#
#         var popup_84304b84c81ad39f61b5a76ed9c38c66 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e24a6797b0d0a5e58ee877ee899e277 = $(`&lt;div id=&quot;html_0e24a6797b0d0a5e58ee877ee899e277&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_84304b84c81ad39f61b5a76ed9c38c66.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b91ce309db5cc0afbe49687834bf10fb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b91ce309db5cc0afbe49687834bf10fb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b91ce309db5cc0afbe49687834bf10fb = L.map(
#                 &quot;map_b91ce309db5cc0afbe49687834bf10fb&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a9ac486d57276efbeba0cd1b87a2a72d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a9ac486d57276efbeba0cd1b87a2a72d.addTo(map_b91ce309db5cc0afbe49687834bf10fb);
#
#
#             var feature_group_7d7acf716b80fefe8b6403fd0fa4f008 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_efecf2353476f17d41c6197044136b91 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_7d7acf716b80fefe8b6403fd0fa4f008);
#
#
#         var popup_5bc8836d53f2fc3c567360fd39f7fbac = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6140da876b1c0a0559ef522ef5ad48e4 = $(`&lt;div id=&quot;html_6140da876b1c0a0559ef522ef5ad48e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5bc8836d53f2fc3c567360fd39f7fbac.setContent(html_6140da876b1c0a0559ef522ef5ad48e4);
#
#
#
#         marker_efecf2353476f17d41c6197044136b91.bindPopup(popup_5bc8836d53f2fc3c567360fd39f7fbac)
#         ;
#
#
#
#
#             var marker_fbd0fb71fffdbeb1a490d053f76d6af5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_7d7acf716b80fefe8b6403fd0fa4f008);
#
#
#         var popup_35f45dcd7dc62ae24e594a06ac85d6a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23a20c766d04f0201929eb7f072c4836 = $(`&lt;div id=&quot;html_23a20c766d04f0201929eb7f072c4836&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_35f45dcd7dc62ae24e594a06ac85d6a6.setContent(html_23a20c766d04f0201929eb7f072c4836);
#
#
#
#         marker_fbd0fb71fffdbeb1a490d053f76d6af5.bindPopup(popup_35f45dcd7dc62ae24e594a06ac85d6a6)
#         ;
#
#
#
#
#             var marker_a4220730c0640300ee2d9ae36eda9514 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_7d7acf716b80fefe8b6403fd0fa4f008);
#
#
#         var popup_6fee875e69e0b34d5e0c75f51df5a895 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0c6dce70a6c12b98bc182058cfbc010f = $(`&lt;div id=&quot;html_0c6dce70a6c12b98bc182058cfbc010f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_6fee875e69e0b34d5e0c75f51df5a895.setContent(html_0c6dce70a6c12b98bc182058cfbc010f);
#
#
#
#         marker_a4220730c0640300ee2d9ae36eda9514.bindPopup(popup_6fee875e69e0b34d5e0c75f51df5a895)
#         ;
#
#
#
#
#             var marker_890d177eb1e90ebaff130c5931e447c4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_7d7acf716b80fefe8b6403fd0fa4f008);
#
#
#         var popup_7242204a1c41a1026468cd6ffced13d0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a50ddd1568a068fa28ac9712375b87f0 = $(`&lt;div id=&quot;html_a50ddd1568a068fa28ac9712375b87f0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7242204a1c41a1026468cd6ffced13d0.setContent(html_a50ddd1568a068fa28ac9712375b87f0);
#
#
#
#         marker_890d177eb1e90ebaff130c5931e447c4.bindPopup(popup_7242204a1c41a1026468cd6ffced13d0)
#         ;
#
#
#
#
#             var marker_86fdd5d1eb5106a05ad984b9cacaf134 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_7d7acf716b80fefe8b6403fd0fa4f008);
#
#
#         var popup_2be89af43bd7d80f2eb5f4e734bcd57f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9ab6d569d347610900e606330ad2fe6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9ab6d569d347610900e606330ad2fe6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e9ab6d569d347610900e606330ad2fe6 = L.map(
#                 &quot;map_e9ab6d569d347610900e606330ad2fe6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dbd50250e2be6f0dadfabde113955450 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dbd50250e2be6f0dadfabde113955450.addTo(map_e9ab6d569d347610900e606330ad2fe6);
#
#
#             var feature_group_595456e079b1c00522f285d73e47d84b = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_595456e079b1c00522f285d73e47d84b.addTo(map_e9ab6d569d347610900e606330ad2fe6);
#
#
#             var feature_group_sub_group_d0ffa9757a731cc0b461901bd1d0ac10 = L.featureGroup.subGroup(
#                 feature_group_595456e079b1c00522f285d73e47d84b
#             );
#
#
#             var marker_2d776726edabd83c40d35ccd89e1f82a = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d0ffa9757a731cc0b461901bd1d0ac10);
#
#
#         var popup_b94c83b6507fc684ac47663a16ad9ef9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8d90897291101b4b74aa7b783b31b0da = $(`&lt;div id=&quot;html_8d90897291101b4b74aa7b783b31b0da&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b94c83b6507fc684ac47663a16ad9ef9.setContent(html_8d90897291101b4b74aa7b783b31b0da);
#
#
#
#         marker_2d776726edabd83c40d35ccd89e1f82a.bindPopup(popup_b94c83b6507fc684ac47663a16ad9ef9)
#         ;
#
#
#
#
#             var marker_c3d9272faa15e236556006be385865eb = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d0ffa9757a731cc0b461901bd1d0ac10);
#
#
#         var popup_1a5aa96bc032b3188622cc2422c2163c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bbfe9ecd8ff3485f4018ccd97ebaaf7e = $(`&lt;div id=&quot;html_bbfe9ecd8ff3485f4018ccd97ebaaf7e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1a5aa96bc032b3188622cc2422c2163c.setContent(html_bbfe9ecd8ff3485f4018ccd97ebaaf7e);
#
#
#
#         marker_c3d9272faa15e236556006be385865eb.bindPopup(popup_1a5aa96bc032b3188622cc2422c2163c)
#         ;
#
#
#
#
#             var marker_878feb0aabc91a724fd384a171f45ad7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d0ffa9757a731cc0b461901bd1d0ac10);
#
#
#         var popup_1e4b5a3a0474af5e92244843fea2a7c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ca59df42ca1d9c558f7d6068ac7c5ab1 = $(`&lt;div id=&quot;html_ca59df42ca1d9c558f7d6068ac7c5ab1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1e4b5a3a0474af5e92244843fea2a7c3.setContent(html_ca59df42ca1d9c558f7d6068ac7c5ab1);
#
#
#
#         marker_878feb0aabc91a724fd384a171f45ad7.bindPopup(popup_1e4b5a3a0474af5e92244843fea2a7c3)
#         ;
#
#
#
#
#             var marker_3d3b4d706d9a07694b3269f55667badb = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d0ffa9757a731cc0b461901bd1d0ac10);
#
#
#         var popup_ea0d0e4d1885aa5c14f87094e78e0804 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f71a2c951e2f29d87c127486ec025cdf = $(`&lt;div id=&quot;html_f71a2c951e2f29d87c127486ec025cdf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ea0d0e4d1885aa5c14f87094e78e0804.setContent(html_f71a2c951e2f29d87c127486ec025cdf);
#
#
#
#         marker_
