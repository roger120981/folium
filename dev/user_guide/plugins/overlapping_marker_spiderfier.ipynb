# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_12e217538594f1690e2293bc45ae3171 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_12e217538594f1690e2293bc45ae3171&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_12e217538594f1690e2293bc45ae3171 = L.map(
#                 &quot;map_12e217538594f1690e2293bc45ae3171&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c36b2b8d6a0a5ae28f3b4165d13c2f36 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c36b2b8d6a0a5ae28f3b4165d13c2f36.addTo(map_12e217538594f1690e2293bc45ae3171);
#
#
#             var marker_36cb0b6dbf739a1aea5bd5efad0dfa46 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_12e217538594f1690e2293bc45ae3171);
#
#
#         var popup_d053cad08c6c3f11d230097c05985046 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a6ed5d18c05d59a0e9bb8cc6ecb701e = $(`&lt;div id=&quot;html_4a6ed5d18c05d59a0e9bb8cc6ecb701e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_d053cad08c6c3f11d230097c05985046.setContent(html_4a6ed5d18c05d59a0e9bb8cc6ecb701e);
#
#
#
#         marker_36cb0b6dbf739a1aea5bd5efad0dfa46.bindPopup(popup_d053cad08c6c3f11d230097c05985046)
#         ;
#
#
#
#
#             var marker_814ebe92c75b24e956ee36f653e2a909 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_12e217538594f1690e2293bc45ae3171);
#
#
#         var popup_d97174faa5bf09cbe1eccce15705f215 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29cc636ac247d97d7a77594e34e3619c = $(`&lt;div id=&quot;html_29cc636ac247d97d7a77594e34e3619c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d97174faa5bf09cbe1eccce15705f215.setContent(html_29cc636ac247d97d7a77594e34e3619c);
#
#
#
#         marker_814ebe92c75b24e956ee36f653e2a909.bindPopup(popup_d97174faa5bf09cbe1eccce15705f215)
#         ;
#
#
#
#
#             var marker_d4efed57a4db766ff21fbd7e3bed92c6 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_12e217538594f1690e2293bc45ae3171);
#
#
#         var popup_f1e33f0e9a6766bf54561a07901c4b7e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2371303f54cabfe2570b26b8e73188dc = $(`&lt;div id=&quot;html_2371303f54cabfe2570b26b8e73188dc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_f1e33f0e9a6766bf54561a07901c4b7e.setContent(html_2371303f54cabfe2570b26b8e73188dc);
#
#
#
#         marker_d4efed57a4db766ff21fbd7e3bed92c6.bindPopup(popup_f1e33f0e9a6766bf54561a07901c4b7e)
#         ;
#
#
#
#
#             var marker_c5ee69ddbdea2e47efb2dbefcc0d6b3c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_12e217538594f1690e2293bc45ae3171);
#
#
#         var popup_60a8c9d527af60995dd46ae7e4ee7978 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_527e4ccba6a188bd94a55deef0078af0 = $(`&lt;div id=&quot;html_527e4ccba6a188bd94a55deef0078af0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_60a8c9d527af60995dd46ae7e4ee7978.setContent(html_527e4ccba6a188bd94a55deef0078af0);
#
#
#
#         marker_c5ee69ddbdea2e47efb2dbefcc0d6b3c.bindPopup(popup_60a8c9d527af60995dd46ae7e4ee7978)
#         ;
#
#
#
#
#             var marker_6fcdf79724143680d1512478e19be42d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_12e217538594f1690e2293bc45ae3171);
#
#
#         var popup_ea13097386e01c6f8b81388ee33c602e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0e43a87caf1605018093f3f9f516514e = $(`&lt;div id=&quot;html_0e43a87caf1605018093f3f9f516514e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_ea13097386e01c6f8b81388ee33c602e.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e93aa95a5602090acfa5367983c32b13 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e93aa95a5602090acfa5367983c32b13&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e93aa95a5602090acfa5367983c32b13 = L.map(
#                 &quot;map_e93aa95a5602090acfa5367983c32b13&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5b8f70583d94e89178ce79cd8d0dc443 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5b8f70583d94e89178ce79cd8d0dc443.addTo(map_e93aa95a5602090acfa5367983c32b13);
#
#
#             var feature_group_ee8ab98dd1f1a87dfd89f1f544be586d = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_77c189727c8ef5fae359b5f58f27bdde = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ee8ab98dd1f1a87dfd89f1f544be586d);
#
#
#         var popup_3c72b245588a04bc85bcddcc785fd0c4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12b09256c158f41bfc63ad686fb15b5e = $(`&lt;div id=&quot;html_12b09256c158f41bfc63ad686fb15b5e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_3c72b245588a04bc85bcddcc785fd0c4.setContent(html_12b09256c158f41bfc63ad686fb15b5e);
#
#
#
#         marker_77c189727c8ef5fae359b5f58f27bdde.bindPopup(popup_3c72b245588a04bc85bcddcc785fd0c4)
#         ;
#
#
#
#
#             var marker_2937485aade10ef6314f1c2eff7705d3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ee8ab98dd1f1a87dfd89f1f544be586d);
#
#
#         var popup_d5b07ff80bebc1dbddc7610531d58f69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d802ffbc8fa7830668a2313ac3c66082 = $(`&lt;div id=&quot;html_d802ffbc8fa7830668a2313ac3c66082&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_d5b07ff80bebc1dbddc7610531d58f69.setContent(html_d802ffbc8fa7830668a2313ac3c66082);
#
#
#
#         marker_2937485aade10ef6314f1c2eff7705d3.bindPopup(popup_d5b07ff80bebc1dbddc7610531d58f69)
#         ;
#
#
#
#
#             var marker_a33072745eff24da5daa0132db189f1e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ee8ab98dd1f1a87dfd89f1f544be586d);
#
#
#         var popup_fa6b6e1137fe337e830ce377c4d277e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3e87e80bec6a62de3781ca0f1d9eb247 = $(`&lt;div id=&quot;html_3e87e80bec6a62de3781ca0f1d9eb247&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_fa6b6e1137fe337e830ce377c4d277e9.setContent(html_3e87e80bec6a62de3781ca0f1d9eb247);
#
#
#
#         marker_a33072745eff24da5daa0132db189f1e.bindPopup(popup_fa6b6e1137fe337e830ce377c4d277e9)
#         ;
#
#
#
#
#             var marker_32719932c52b3b72f785daff61672edf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ee8ab98dd1f1a87dfd89f1f544be586d);
#
#
#         var popup_cd0859401a0625deb3e3c9f097b09e2d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a50c2203069f193a438a29debc0d589c = $(`&lt;div id=&quot;html_a50c2203069f193a438a29debc0d589c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cd0859401a0625deb3e3c9f097b09e2d.setContent(html_a50c2203069f193a438a29debc0d589c);
#
#
#
#         marker_32719932c52b3b72f785daff61672edf.bindPopup(popup_cd0859401a0625deb3e3c9f097b09e2d)
#         ;
#
#
#
#
#             var marker_fc63d28d493ce8f4c58f53f6aeff2212 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ee8ab98dd1f1a87dfd89f1f544be586d);
#
#
#         var popup_8937270d4092e7fbf6588e5d2044f779 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f942a622517e27e25a77167bffdffdc4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f942a622517e27e25a77167bffdffdc4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f942a622517e27e25a77167bffdffdc4 = L.map(
#                 &quot;map_f942a622517e27e25a77167bffdffdc4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_62a32bba65daf975bfc0f54e7b456350 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_62a32bba65daf975bfc0f54e7b456350.addTo(map_f942a622517e27e25a77167bffdffdc4);
#
#
#             var feature_group_6ba07eec5880c7b8c096007a9400cd2d = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_6ba07eec5880c7b8c096007a9400cd2d.addTo(map_f942a622517e27e25a77167bffdffdc4);
#
#
#             var feature_group_sub_group_6db8577a39ecdc061c33d7a4845feca9 = L.featureGroup.subGroup(
#                 feature_group_6ba07eec5880c7b8c096007a9400cd2d
#             );
#
#
#             var marker_ffe0b10a3c4273592c34b07f65bc3683 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_6db8577a39ecdc061c33d7a4845feca9);
#
#
#         var popup_a996c14ea94b1e669452c3685c870e16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6ba42d7d27fa4ba033dcdbf7b088debb = $(`&lt;div id=&quot;html_6ba42d7d27fa4ba033dcdbf7b088debb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a996c14ea94b1e669452c3685c870e16.setContent(html_6ba42d7d27fa4ba033dcdbf7b088debb);
#
#
#
#         marker_ffe0b10a3c4273592c34b07f65bc3683.bindPopup(popup_a996c14ea94b1e669452c3685c870e16)
#         ;
#
#
#
#
#             var marker_ed93ed22778c97a08f8d6ecb07088280 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_6db8577a39ecdc061c33d7a4845feca9);
#
#
#         var popup_9c51b21ffbc8024b20a8084fb545e654 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_226a082e8c2c4699ff72accb1a6ba004 = $(`&lt;div id=&quot;html_226a082e8c2c4699ff72accb1a6ba004&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_9c51b21ffbc8024b20a8084fb545e654.setContent(html_226a082e8c2c4699ff72accb1a6ba004);
#
#
#
#         marker_ed93ed22778c97a08f8d6ecb07088280.bindPopup(popup_9c51b21ffbc8024b20a8084fb545e654)
#         ;
#
#
#
#
#             var marker_aa2f2c8e92b4539ed2ec540061c972ff = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_6db8577a39ecdc061c33d7a4845feca9);
#
#
#         var popup_b14ebe685da7c521e0bca3076ea4eb46 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e603d1780938ddc42ceec6719f10ea67 = $(`&lt;div id=&quot;html_e603d1780938ddc42ceec6719f10ea67&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_b14ebe685da7c521e0bca3076ea4eb46.setContent(html_e603d1780938ddc42ceec6719f10ea67);
#
#
#
#         marker_aa2f2c8e92b4539ed2ec540061c972ff.bindPopup(popup_b14ebe685da7c521e0bca3076ea4eb46)
#         ;
#
#
#
#
#             var marker_bd53e43b5ed510e7aead89de22a2e2bf = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_6db8577a39ecdc061c33d7a4845feca9);
#
#
#         var popup_ecfa6e36985e93ce7e89e360abf8973d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cfa68b2bc79712cd1c02efbfe50dbbfc = $(`&lt;div id=&quot;html_cfa68b2bc79712cd1c02efbfe50dbbfc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ecfa6e36985e93ce7e89e360abf8973d.setContent(html_cfa68b2bc79712cd1c02efbfe50dbbfc);
#
#
#
#         marker_
