# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4bf9ebfce38b3fa3d1c2d8cff96f7fed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4bf9ebfce38b3fa3d1c2d8cff96f7fed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4bf9ebfce38b3fa3d1c2d8cff96f7fed = L.map(
#                 &quot;map_4bf9ebfce38b3fa3d1c2d8cff96f7fed&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f7a9659ff5931adc29dd91bf4aaa0f03 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f7a9659ff5931adc29dd91bf4aaa0f03.addTo(map_4bf9ebfce38b3fa3d1c2d8cff96f7fed);
#
#
#             var marker_649329ceb1db22a31f562a058ffa8b94 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_4bf9ebfce38b3fa3d1c2d8cff96f7fed);
#
#
#         var popup_c5bcb7b960535d373a6be3b8d957b387 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_676e4302f44c3fb5754c0362fa383a57 = $(`&lt;div id=&quot;html_676e4302f44c3fb5754c0362fa383a57&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_c5bcb7b960535d373a6be3b8d957b387.setContent(html_676e4302f44c3fb5754c0362fa383a57);
#
#
#
#         marker_649329ceb1db22a31f562a058ffa8b94.bindPopup(popup_c5bcb7b960535d373a6be3b8d957b387)
#         ;
#
#
#
#
#             var marker_ac2f402f217b03a9517d86bea207ae5a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_4bf9ebfce38b3fa3d1c2d8cff96f7fed);
#
#
#         var popup_0890f877d4eb74c3878f20654932d39f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a17425145220a7f56279df76b1bcb4e3 = $(`&lt;div id=&quot;html_a17425145220a7f56279df76b1bcb4e3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0890f877d4eb74c3878f20654932d39f.setContent(html_a17425145220a7f56279df76b1bcb4e3);
#
#
#
#         marker_ac2f402f217b03a9517d86bea207ae5a.bindPopup(popup_0890f877d4eb74c3878f20654932d39f)
#         ;
#
#
#
#
#             var marker_19c740f9a68b4ba0b7f3f689a2e7e210 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_4bf9ebfce38b3fa3d1c2d8cff96f7fed);
#
#
#         var popup_3ab3bf2d1611b145c984c9a5f79f2cd7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a94afbd2c8b7cf1d069254a4eeb640b1 = $(`&lt;div id=&quot;html_a94afbd2c8b7cf1d069254a4eeb640b1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3ab3bf2d1611b145c984c9a5f79f2cd7.setContent(html_a94afbd2c8b7cf1d069254a4eeb640b1);
#
#
#
#         marker_19c740f9a68b4ba0b7f3f689a2e7e210.bindPopup(popup_3ab3bf2d1611b145c984c9a5f79f2cd7)
#         ;
#
#
#
#
#             var marker_430ca77f4f7237dcb06c5f3826738508 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_4bf9ebfce38b3fa3d1c2d8cff96f7fed);
#
#
#         var popup_dd83dc0734ee9085fb8db16e981d5647 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_86571e0daf5726394162eb3fc230a65d = $(`&lt;div id=&quot;html_86571e0daf5726394162eb3fc230a65d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_dd83dc0734ee9085fb8db16e981d5647.setContent(html_86571e0daf5726394162eb3fc230a65d);
#
#
#
#         marker_430ca77f4f7237dcb06c5f3826738508.bindPopup(popup_dd83dc0734ee9085fb8db16e981d5647)
#         ;
#
#
#
#
#             var marker_e5f9ff7eadeaf3bbd4bd672df731b5f7 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_4bf9ebfce38b3fa3d1c2d8cff96f7fed);
#
#
#         var popup_04d15a1a58c8b03135a9f27b2709564c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9d8ce1389a7661a7655ae146b4b544db = $(`&lt;div id=&quot;html_9d8ce1389a7661a7655ae146b4b544db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_04d15a1a58c8b03135a9f27b2709564c.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_03e7a3d1c3fd348371ecdd083bd2445a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_03e7a3d1c3fd348371ecdd083bd2445a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_03e7a3d1c3fd348371ecdd083bd2445a = L.map(
#                 &quot;map_03e7a3d1c3fd348371ecdd083bd2445a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bde98f78dcd25865a64c05d5e60e9a73 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bde98f78dcd25865a64c05d5e60e9a73.addTo(map_03e7a3d1c3fd348371ecdd083bd2445a);
#
#
#             var feature_group_557d0294466107c80041273a5dce43f8 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8fc3a4cf49cec472405b80921b6084bd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_557d0294466107c80041273a5dce43f8);
#
#
#         var popup_62cf964e5a5a2d4f0e57c315e71652d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dca1670cf4d700140a08d76121b40b1d = $(`&lt;div id=&quot;html_dca1670cf4d700140a08d76121b40b1d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_62cf964e5a5a2d4f0e57c315e71652d9.setContent(html_dca1670cf4d700140a08d76121b40b1d);
#
#
#
#         marker_8fc3a4cf49cec472405b80921b6084bd.bindPopup(popup_62cf964e5a5a2d4f0e57c315e71652d9)
#         ;
#
#
#
#
#             var marker_16b5f93633d3f45e47cc57a5902b7ca5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_557d0294466107c80041273a5dce43f8);
#
#
#         var popup_f88c7b724c6c2e7bdda60528591bed76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9f4f3dd782b31972dd1f315486de1dac = $(`&lt;div id=&quot;html_9f4f3dd782b31972dd1f315486de1dac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_f88c7b724c6c2e7bdda60528591bed76.setContent(html_9f4f3dd782b31972dd1f315486de1dac);
#
#
#
#         marker_16b5f93633d3f45e47cc57a5902b7ca5.bindPopup(popup_f88c7b724c6c2e7bdda60528591bed76)
#         ;
#
#
#
#
#             var marker_d972fccb4f749a30bfe327bd8d528385 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_557d0294466107c80041273a5dce43f8);
#
#
#         var popup_00bcada5194e129bcf84961fc3d873cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e83413b5d332755b5ce03e00b7261b15 = $(`&lt;div id=&quot;html_e83413b5d332755b5ce03e00b7261b15&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_00bcada5194e129bcf84961fc3d873cb.setContent(html_e83413b5d332755b5ce03e00b7261b15);
#
#
#
#         marker_d972fccb4f749a30bfe327bd8d528385.bindPopup(popup_00bcada5194e129bcf84961fc3d873cb)
#         ;
#
#
#
#
#             var marker_b722d0c8fb88f23f48463c08cf89e4cc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_557d0294466107c80041273a5dce43f8);
#
#
#         var popup_f2e675c6c4679a98a864db3dd2fb771f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3756ddcb2a01dadf92177ef6c3460da5 = $(`&lt;div id=&quot;html_3756ddcb2a01dadf92177ef6c3460da5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_f2e675c6c4679a98a864db3dd2fb771f.setContent(html_3756ddcb2a01dadf92177ef6c3460da5);
#
#
#
#         marker_b722d0c8fb88f23f48463c08cf89e4cc.bindPopup(popup_f2e675c6c4679a98a864db3dd2fb771f)
#         ;
#
#
#
#
#             var marker_600708fbd7536565c8825d62163e1559 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_557d0294466107c80041273a5dce43f8);
#
#
#         var popup_df389f2b6433224be3ec4b0f997c75d7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f19b3072ad8f0fd728d602f654427a61 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f19b3072ad8f0fd728d602f654427a61&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_f19b3072ad8f0fd728d602f654427a61 = L.map(
#                 &quot;map_f19b3072ad8f0fd728d602f654427a61&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_34c918e9bfe3fb66ac6ea6741ff67962 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_34c918e9bfe3fb66ac6ea6741ff67962.addTo(map_f19b3072ad8f0fd728d602f654427a61);
#
#
#             var feature_group_5b44e0a65f2456dd718f7ac1fb30937e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5b44e0a65f2456dd718f7ac1fb30937e.addTo(map_f19b3072ad8f0fd728d602f654427a61);
#
#
#             var feature_group_sub_group_a5c8a7bf2153d77269bfacdd9a485b39 = L.featureGroup.subGroup(
#                 feature_group_5b44e0a65f2456dd718f7ac1fb30937e
#             );
#
#
#             var marker_60a607c53f10768d0c098aafaa3ac13e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_a5c8a7bf2153d77269bfacdd9a485b39);
#
#
#         var popup_c318c097c5e228f35a73375d0c9450d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fdb302369c1c9070e814e32fb651eb32 = $(`&lt;div id=&quot;html_fdb302369c1c9070e814e32fb651eb32&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_c318c097c5e228f35a73375d0c9450d9.setContent(html_fdb302369c1c9070e814e32fb651eb32);
#
#
#
#         marker_60a607c53f10768d0c098aafaa3ac13e.bindPopup(popup_c318c097c5e228f35a73375d0c9450d9)
#         ;
#
#
#
#
#             var marker_f974845dfaaace1a4ff5b70ba4e4ec1d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_a5c8a7bf2153d77269bfacdd9a485b39);
#
#
#         var popup_ce08b10697229074c41cbab4bfba60fc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_094d3f5d8d19d7835bfe12948f41f977 = $(`&lt;div id=&quot;html_094d3f5d8d19d7835bfe12948f41f977&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ce08b10697229074c41cbab4bfba60fc.setContent(html_094d3f5d8d19d7835bfe12948f41f977);
#
#
#
#         marker_f974845dfaaace1a4ff5b70ba4e4ec1d.bindPopup(popup_ce08b10697229074c41cbab4bfba60fc)
#         ;
#
#
#
#
#             var marker_ea751691ad824b87796cd025b3af54a4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_a5c8a7bf2153d77269bfacdd9a485b39);
#
#
#         var popup_531dc1d489ee94217e6b1b2eb6381e41 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2b75678c9e2abf3342c63e2a50d9194 = $(`&lt;div id=&quot;html_f2b75678c9e2abf3342c63e2a50d9194&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_531dc1d489ee94217e6b1b2eb6381e41.setContent(html_f2b75678c9e2abf3342c63e2a50d9194);
#
#
#
#         marker_ea751691ad824b87796cd025b3af54a4.bindPopup(popup_531dc1d489ee94217e6b1b2eb6381e41)
#         ;
#
#
#
#
#             var marker_829fb173a0f333689bc30bd470089581 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_a5c8a7bf2153d77269bfacdd9a485b39);
#
#
#         var popup_fabfe0d19d618540ccd97f391219ca9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dd6b6bc55858b5e8eba00d723e2493d6 = $(`&lt;div id=&quot;html_dd6b6bc55858b5e8eba00d723e2493d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_fabfe0d19d618540ccd97f391219ca9a.setContent(html_dd6b6bc55858b5e8eba00d723e2493d6);
#
#
#
#         marker_
