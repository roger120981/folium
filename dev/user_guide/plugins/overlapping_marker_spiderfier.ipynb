# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_872bc31d6ca028884bb390fd9a59bb75 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_872bc31d6ca028884bb390fd9a59bb75&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_872bc31d6ca028884bb390fd9a59bb75 = L.map(
#                 &quot;map_872bc31d6ca028884bb390fd9a59bb75&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4642190356e56d68aeee31a3c83932fd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4642190356e56d68aeee31a3c83932fd.addTo(map_872bc31d6ca028884bb390fd9a59bb75);
#
#
#             var marker_42c4e159642e03193220953c444ea2b1 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_872bc31d6ca028884bb390fd9a59bb75);
#
#
#         var popup_60cf29f450e8a32f55c21c727e0e56be = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b715439e84a3e725cad0e927765983f6 = $(`&lt;div id=&quot;html_b715439e84a3e725cad0e927765983f6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_60cf29f450e8a32f55c21c727e0e56be.setContent(html_b715439e84a3e725cad0e927765983f6);
#
#
#
#         marker_42c4e159642e03193220953c444ea2b1.bindPopup(popup_60cf29f450e8a32f55c21c727e0e56be)
#         ;
#
#
#
#
#             var marker_53443cfd35fc3eafea4689f0d96ec741 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_872bc31d6ca028884bb390fd9a59bb75);
#
#
#         var popup_22a100719e7b8ff7b5861c71c3f85f96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b2491545ea1c4f26ac57af663d2f42dd = $(`&lt;div id=&quot;html_b2491545ea1c4f26ac57af663d2f42dd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_22a100719e7b8ff7b5861c71c3f85f96.setContent(html_b2491545ea1c4f26ac57af663d2f42dd);
#
#
#
#         marker_53443cfd35fc3eafea4689f0d96ec741.bindPopup(popup_22a100719e7b8ff7b5861c71c3f85f96)
#         ;
#
#
#
#
#             var marker_65dedad3e814ce9d2a8533bd1f06df64 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_872bc31d6ca028884bb390fd9a59bb75);
#
#
#         var popup_45af6250544f7319c87e62a24c79094e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e8c39dc1445798c3a3281ad7fc439ede = $(`&lt;div id=&quot;html_e8c39dc1445798c3a3281ad7fc439ede&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_45af6250544f7319c87e62a24c79094e.setContent(html_e8c39dc1445798c3a3281ad7fc439ede);
#
#
#
#         marker_65dedad3e814ce9d2a8533bd1f06df64.bindPopup(popup_45af6250544f7319c87e62a24c79094e)
#         ;
#
#
#
#
#             var marker_c4d40cb7d8fec440e79e26e28a59ecf8 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_872bc31d6ca028884bb390fd9a59bb75);
#
#
#         var popup_c2b5b6e01f10d80399f9b2085b5bd7aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7acbb585d7b62dd149a8519adfceec86 = $(`&lt;div id=&quot;html_7acbb585d7b62dd149a8519adfceec86&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c2b5b6e01f10d80399f9b2085b5bd7aa.setContent(html_7acbb585d7b62dd149a8519adfceec86);
#
#
#
#         marker_c4d40cb7d8fec440e79e26e28a59ecf8.bindPopup(popup_c2b5b6e01f10d80399f9b2085b5bd7aa)
#         ;
#
#
#
#
#             var marker_89060c9b928168372da65a368a032d7d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_872bc31d6ca028884bb390fd9a59bb75);
#
#
#         var popup_4ef214ad5337dda0cdacdf1616452eb4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9fa6bd166057784ec5ef8aab844da49c = $(`&lt;div id=&quot;html_9fa6bd166057784ec5ef8aab844da49c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_4ef214ad5337dda0cdacdf1616452eb4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c411e320cd582dab815b2bba743c9fac {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c411e320cd582dab815b2bba743c9fac&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c411e320cd582dab815b2bba743c9fac = L.map(
#                 &quot;map_c411e320cd582dab815b2bba743c9fac&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dfabce1c95363e7466cfc19599dd795e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dfabce1c95363e7466cfc19599dd795e.addTo(map_c411e320cd582dab815b2bba743c9fac);
#
#
#             var feature_group_f72338d5de2b06cd684d1f8142f1a360 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_8f444734c382395fd286d3a36cc4e2ba = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_f72338d5de2b06cd684d1f8142f1a360);
#
#
#         var popup_7e03b22a2922275b28aea79cf7e31b56 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a75ec8866ed14a40690b4c980556d873 = $(`&lt;div id=&quot;html_a75ec8866ed14a40690b4c980556d873&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_7e03b22a2922275b28aea79cf7e31b56.setContent(html_a75ec8866ed14a40690b4c980556d873);
#
#
#
#         marker_8f444734c382395fd286d3a36cc4e2ba.bindPopup(popup_7e03b22a2922275b28aea79cf7e31b56)
#         ;
#
#
#
#
#             var marker_8de950c9a72646ef9307d3bd9dea3fee = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_f72338d5de2b06cd684d1f8142f1a360);
#
#
#         var popup_ce13d97ac44db9f86897fee40ca02296 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_54a2c9cfb706701226631d908f566601 = $(`&lt;div id=&quot;html_54a2c9cfb706701226631d908f566601&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ce13d97ac44db9f86897fee40ca02296.setContent(html_54a2c9cfb706701226631d908f566601);
#
#
#
#         marker_8de950c9a72646ef9307d3bd9dea3fee.bindPopup(popup_ce13d97ac44db9f86897fee40ca02296)
#         ;
#
#
#
#
#             var marker_083a794da7006aacd6c1dff5b6c8d0ba = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_f72338d5de2b06cd684d1f8142f1a360);
#
#
#         var popup_c74c8c7b961ee9f8447b8a3940ffd239 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3e5a0f55b30d0725bb03e588528d56c = $(`&lt;div id=&quot;html_f3e5a0f55b30d0725bb03e588528d56c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c74c8c7b961ee9f8447b8a3940ffd239.setContent(html_f3e5a0f55b30d0725bb03e588528d56c);
#
#
#
#         marker_083a794da7006aacd6c1dff5b6c8d0ba.bindPopup(popup_c74c8c7b961ee9f8447b8a3940ffd239)
#         ;
#
#
#
#
#             var marker_57c223073cf5b85bd00367ca5f6776a9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_f72338d5de2b06cd684d1f8142f1a360);
#
#
#         var popup_838c93ee19d2f912960cd441641fe769 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ff638e21343f6dc30581614b1ad67f2f = $(`&lt;div id=&quot;html_ff638e21343f6dc30581614b1ad67f2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_838c93ee19d2f912960cd441641fe769.setContent(html_ff638e21343f6dc30581614b1ad67f2f);
#
#
#
#         marker_57c223073cf5b85bd00367ca5f6776a9.bindPopup(popup_838c93ee19d2f912960cd441641fe769)
#         ;
#
#
#
#
#             var marker_18847466dea04454d526561c5732104e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_f72338d5de2b06cd684d1f8142f1a360);
#
#
#         var popup_37e38fac43fb72a0afb9aa0647bdb6f5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9a0fc0ded2c284e6b686e60bc07dce9f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9a0fc0ded2c284e6b686e60bc07dce9f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9a0fc0ded2c284e6b686e60bc07dce9f = L.map(
#                 &quot;map_9a0fc0ded2c284e6b686e60bc07dce9f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_534d03da445d94217098439d6e404a8d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_534d03da445d94217098439d6e404a8d.addTo(map_9a0fc0ded2c284e6b686e60bc07dce9f);
#
#
#             var feature_group_38955d70cb6ca4cf5e1d440b4b159e69 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_38955d70cb6ca4cf5e1d440b4b159e69.addTo(map_9a0fc0ded2c284e6b686e60bc07dce9f);
#
#
#             var feature_group_sub_group_87688b765b91b0648ccdd9b58801f499 = L.featureGroup.subGroup(
#                 feature_group_38955d70cb6ca4cf5e1d440b4b159e69
#             );
#
#
#             var marker_6f865bfa8fd9c704b0f7be5f118405d0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_87688b765b91b0648ccdd9b58801f499);
#
#
#         var popup_839d6a0620bfbcc036f52074ad027ce7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d7c58c8df07b062df5c63b7dabbd34b2 = $(`&lt;div id=&quot;html_d7c58c8df07b062df5c63b7dabbd34b2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_839d6a0620bfbcc036f52074ad027ce7.setContent(html_d7c58c8df07b062df5c63b7dabbd34b2);
#
#
#
#         marker_6f865bfa8fd9c704b0f7be5f118405d0.bindPopup(popup_839d6a0620bfbcc036f52074ad027ce7)
#         ;
#
#
#
#
#             var marker_12b9167c2bd50296e365c68fcd7e6812 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_87688b765b91b0648ccdd9b58801f499);
#
#
#         var popup_e368cac962fe75b0941f5b0fc8496ad0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_69a9368647e39d1c6019ff0fbbd0326e = $(`&lt;div id=&quot;html_69a9368647e39d1c6019ff0fbbd0326e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_e368cac962fe75b0941f5b0fc8496ad0.setContent(html_69a9368647e39d1c6019ff0fbbd0326e);
#
#
#
#         marker_12b9167c2bd50296e365c68fcd7e6812.bindPopup(popup_e368cac962fe75b0941f5b0fc8496ad0)
#         ;
#
#
#
#
#             var marker_1e953d48624b51da08bbf3fcc1ba40c0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_87688b765b91b0648ccdd9b58801f499);
#
#
#         var popup_346c02d1c8642b305aea12d721580556 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ba6317e990ac971a79e65c4a83f2bbd1 = $(`&lt;div id=&quot;html_ba6317e990ac971a79e65c4a83f2bbd1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_346c02d1c8642b305aea12d721580556.setContent(html_ba6317e990ac971a79e65c4a83f2bbd1);
#
#
#
#         marker_1e953d48624b51da08bbf3fcc1ba40c0.bindPopup(popup_346c02d1c8642b305aea12d721580556)
#         ;
#
#
#
#
#             var marker_b9ff3f94f0f48076ade00a1d591a96f9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_87688b765b91b0648ccdd9b58801f499);
#
#
#         var popup_e5907412decacd00260ed738a165f67c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ceedca6e00ca9a796ff5c7ff557d21db = $(`&lt;div id=&quot;html_ceedca6e00ca9a796ff5c7ff557d21db&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e5907412decacd00260ed738a165f67c.setContent(html_ceedca6e00ca9a796ff5c7ff557d21db);
#
#
#
#         marker_
