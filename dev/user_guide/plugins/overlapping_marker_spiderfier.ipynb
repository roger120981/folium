# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8cf275d41e501cc504773a4300682c3e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8cf275d41e501cc504773a4300682c3e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8cf275d41e501cc504773a4300682c3e = L.map(
#                 &quot;map_8cf275d41e501cc504773a4300682c3e&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8bad0abb7e726a889408468bf2027967 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8bad0abb7e726a889408468bf2027967.addTo(map_8cf275d41e501cc504773a4300682c3e);
#
#
#             var marker_338ce7811998ee935b52943d2e0f66a0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8cf275d41e501cc504773a4300682c3e);
#
#
#         var popup_06badc724dce0d11afc6dde4475561ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_adb5c531a160c1b9954e5de87e7d7d66 = $(`&lt;div id=&quot;html_adb5c531a160c1b9954e5de87e7d7d66&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_06badc724dce0d11afc6dde4475561ff.setContent(html_adb5c531a160c1b9954e5de87e7d7d66);
#
#
#
#         marker_338ce7811998ee935b52943d2e0f66a0.bindPopup(popup_06badc724dce0d11afc6dde4475561ff)
#         ;
#
#
#
#
#             var marker_2d9dd3e18425a94e5d5b6e3511410ac0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8cf275d41e501cc504773a4300682c3e);
#
#
#         var popup_278a41ea77a5be4e7fe1417c4c891fb9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_066ba780c79c2279106b95f8e5caa952 = $(`&lt;div id=&quot;html_066ba780c79c2279106b95f8e5caa952&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_278a41ea77a5be4e7fe1417c4c891fb9.setContent(html_066ba780c79c2279106b95f8e5caa952);
#
#
#
#         marker_2d9dd3e18425a94e5d5b6e3511410ac0.bindPopup(popup_278a41ea77a5be4e7fe1417c4c891fb9)
#         ;
#
#
#
#
#             var marker_92f30873de98be451f62aac07e5236e5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8cf275d41e501cc504773a4300682c3e);
#
#
#         var popup_4a89a85ef0c749fad4dbbbe68ce222fa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12eabd179aeb6b50e37612ab181cd1c9 = $(`&lt;div id=&quot;html_12eabd179aeb6b50e37612ab181cd1c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_4a89a85ef0c749fad4dbbbe68ce222fa.setContent(html_12eabd179aeb6b50e37612ab181cd1c9);
#
#
#
#         marker_92f30873de98be451f62aac07e5236e5.bindPopup(popup_4a89a85ef0c749fad4dbbbe68ce222fa)
#         ;
#
#
#
#
#             var marker_e4923ba7b81d15a723f20edc9bb9f56c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8cf275d41e501cc504773a4300682c3e);
#
#
#         var popup_a79f09809cb0185439b8fa56700fa6d5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7cde5eae3547e134b1ba126c2e098d12 = $(`&lt;div id=&quot;html_7cde5eae3547e134b1ba126c2e098d12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_a79f09809cb0185439b8fa56700fa6d5.setContent(html_7cde5eae3547e134b1ba126c2e098d12);
#
#
#
#         marker_e4923ba7b81d15a723f20edc9bb9f56c.bindPopup(popup_a79f09809cb0185439b8fa56700fa6d5)
#         ;
#
#
#
#
#             var marker_dc8c1072e13582971c87d336c442714c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8cf275d41e501cc504773a4300682c3e);
#
#
#         var popup_f1969e1dda2c3d11acb870a34c785419 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3a91869e1bdc446eb616b9829cb1e14 = $(`&lt;div id=&quot;html_e3a91869e1bdc446eb616b9829cb1e14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_f1969e1dda2c3d11acb870a34c785419.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_93f93e6899ec13cfe482e4dea682fcc9 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_93f93e6899ec13cfe482e4dea682fcc9&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_93f93e6899ec13cfe482e4dea682fcc9 = L.map(
#                 &quot;map_93f93e6899ec13cfe482e4dea682fcc9&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_569fabb7aa1e48002254a65e9683309f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_569fabb7aa1e48002254a65e9683309f.addTo(map_93f93e6899ec13cfe482e4dea682fcc9);
#
#
#             var feature_group_2bf1fa51d38f09d58f5ea334371be303 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_5981bddf2d00362d4039a6d41b576059 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2bf1fa51d38f09d58f5ea334371be303);
#
#
#         var popup_dd55dd31e34d5641e061dfac3707ee12 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62f7d160eb87c75bbc350c959d7c9ce1 = $(`&lt;div id=&quot;html_62f7d160eb87c75bbc350c959d7c9ce1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_dd55dd31e34d5641e061dfac3707ee12.setContent(html_62f7d160eb87c75bbc350c959d7c9ce1);
#
#
#
#         marker_5981bddf2d00362d4039a6d41b576059.bindPopup(popup_dd55dd31e34d5641e061dfac3707ee12)
#         ;
#
#
#
#
#             var marker_d64f9391c872ab86422c4b41a17945c9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2bf1fa51d38f09d58f5ea334371be303);
#
#
#         var popup_ff49760ff61cc24e0a0d4439d9c99f8c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e2cacd4b672d459ce2d8bc57d81fc80 = $(`&lt;div id=&quot;html_7e2cacd4b672d459ce2d8bc57d81fc80&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_ff49760ff61cc24e0a0d4439d9c99f8c.setContent(html_7e2cacd4b672d459ce2d8bc57d81fc80);
#
#
#
#         marker_d64f9391c872ab86422c4b41a17945c9.bindPopup(popup_ff49760ff61cc24e0a0d4439d9c99f8c)
#         ;
#
#
#
#
#             var marker_9d94687c0f64b3b865470e1643ae2e1e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2bf1fa51d38f09d58f5ea334371be303);
#
#
#         var popup_bd1c0cd7d72b40fa9ddcb17d97866742 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a07fbd12eadcc71b0ed6822efb9b7ace = $(`&lt;div id=&quot;html_a07fbd12eadcc71b0ed6822efb9b7ace&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_bd1c0cd7d72b40fa9ddcb17d97866742.setContent(html_a07fbd12eadcc71b0ed6822efb9b7ace);
#
#
#
#         marker_9d94687c0f64b3b865470e1643ae2e1e.bindPopup(popup_bd1c0cd7d72b40fa9ddcb17d97866742)
#         ;
#
#
#
#
#             var marker_ee15c03fd778d99006b8ba2e7af2cca5 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2bf1fa51d38f09d58f5ea334371be303);
#
#
#         var popup_58626d3f457dd292a414bf0749c6e8f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f62e0755ccd8eb661fefb3e64fe23829 = $(`&lt;div id=&quot;html_f62e0755ccd8eb661fefb3e64fe23829&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_58626d3f457dd292a414bf0749c6e8f1.setContent(html_f62e0755ccd8eb661fefb3e64fe23829);
#
#
#
#         marker_ee15c03fd778d99006b8ba2e7af2cca5.bindPopup(popup_58626d3f457dd292a414bf0749c6e8f1)
#         ;
#
#
#
#
#             var marker_c52f8d35b5b47199a9414eea2f67fcde = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2bf1fa51d38f09d58f5ea334371be303);
#
#
#         var popup_1adbbeaa5ed3af867057717fa283b788 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_96d164ad878b064a0c425020ab8d2d91 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_96d164ad878b064a0c425020ab8d2d91&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_96d164ad878b064a0c425020ab8d2d91 = L.map(
#                 &quot;map_96d164ad878b064a0c425020ab8d2d91&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b0677146b0f5749b7aef17552ecc2c15 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_b0677146b0f5749b7aef17552ecc2c15.addTo(map_96d164ad878b064a0c425020ab8d2d91);
#
#
#             var feature_group_cd2aec47b54cc66f86524a627a8a9d8e = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_cd2aec47b54cc66f86524a627a8a9d8e.addTo(map_96d164ad878b064a0c425020ab8d2d91);
#
#
#             var feature_group_sub_group_56bb5a508a6d21cc0bc2e6416dfdcfdd = L.featureGroup.subGroup(
#                 feature_group_cd2aec47b54cc66f86524a627a8a9d8e
#             );
#
#
#             var marker_9e63da434c1defa4d83e29440e828c8e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_56bb5a508a6d21cc0bc2e6416dfdcfdd);
#
#
#         var popup_8415e065ca541646c82d0cdfbebe0f58 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4e206a6727cb8f53b91b009a27d4851d = $(`&lt;div id=&quot;html_4e206a6727cb8f53b91b009a27d4851d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8415e065ca541646c82d0cdfbebe0f58.setContent(html_4e206a6727cb8f53b91b009a27d4851d);
#
#
#
#         marker_9e63da434c1defa4d83e29440e828c8e.bindPopup(popup_8415e065ca541646c82d0cdfbebe0f58)
#         ;
#
#
#
#
#             var marker_deee221da2e0eef464c6afc8c863cdd1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_56bb5a508a6d21cc0bc2e6416dfdcfdd);
#
#
#         var popup_2252ec230ff0f2bf93e65816c84c5196 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_965e64f1e4c25885d27e2581f986a495 = $(`&lt;div id=&quot;html_965e64f1e4c25885d27e2581f986a495&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2252ec230ff0f2bf93e65816c84c5196.setContent(html_965e64f1e4c25885d27e2581f986a495);
#
#
#
#         marker_deee221da2e0eef464c6afc8c863cdd1.bindPopup(popup_2252ec230ff0f2bf93e65816c84c5196)
#         ;
#
#
#
#
#             var marker_66461367bc802f3bf0261169b7c7cc78 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_56bb5a508a6d21cc0bc2e6416dfdcfdd);
#
#
#         var popup_ce072eb4874c1eefcd40c9cdd6edd43e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2b28a62fbc584fb377e0fa97821e962e = $(`&lt;div id=&quot;html_2b28a62fbc584fb377e0fa97821e962e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_ce072eb4874c1eefcd40c9cdd6edd43e.setContent(html_2b28a62fbc584fb377e0fa97821e962e);
#
#
#
#         marker_66461367bc802f3bf0261169b7c7cc78.bindPopup(popup_ce072eb4874c1eefcd40c9cdd6edd43e)
#         ;
#
#
#
#
#             var marker_3fe0cacc1848d65c35b4b49fd4f319b2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_56bb5a508a6d21cc0bc2e6416dfdcfdd);
#
#
#         var popup_e67c1e9adfffeabaabac67f624b782bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dcd80b6006102eb99cda7100fc067b76 = $(`&lt;div id=&quot;html_dcd80b6006102eb99cda7100fc067b76&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e67c1e9adfffeabaabac67f624b782bb.setContent(html_dcd80b6006102eb99cda7100fc067b76);
#
#
#
#         marker_
