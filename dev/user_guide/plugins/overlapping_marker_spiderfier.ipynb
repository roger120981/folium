# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_87114fefd6ab71c097e1ab3ad79f6ba2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_87114fefd6ab71c097e1ab3ad79f6ba2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_87114fefd6ab71c097e1ab3ad79f6ba2 = L.map(
#                 &quot;map_87114fefd6ab71c097e1ab3ad79f6ba2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6fe8e7bb2b0e2563c64b715e1c22654e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6fe8e7bb2b0e2563c64b715e1c22654e.addTo(map_87114fefd6ab71c097e1ab3ad79f6ba2);
#
#
#             var marker_72e3febd1efea50bcc4c990f3fa5d6b5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_87114fefd6ab71c097e1ab3ad79f6ba2);
#
#
#         var popup_289f1c51da7b9a49d3bd858f8123302c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09b80df37e1f23cbdba942bfb76396df = $(`&lt;div id=&quot;html_09b80df37e1f23cbdba942bfb76396df&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_289f1c51da7b9a49d3bd858f8123302c.setContent(html_09b80df37e1f23cbdba942bfb76396df);
#
#
#
#         marker_72e3febd1efea50bcc4c990f3fa5d6b5.bindPopup(popup_289f1c51da7b9a49d3bd858f8123302c)
#         ;
#
#
#
#
#             var marker_2b3877bf72c71e860ef5b61d0dbf4cff = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_87114fefd6ab71c097e1ab3ad79f6ba2);
#
#
#         var popup_6cbe2318e9f7635a3a0e4ee3847fafda = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6c4468ad4edb6dd445afa6a21f98948c = $(`&lt;div id=&quot;html_6c4468ad4edb6dd445afa6a21f98948c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_6cbe2318e9f7635a3a0e4ee3847fafda.setContent(html_6c4468ad4edb6dd445afa6a21f98948c);
#
#
#
#         marker_2b3877bf72c71e860ef5b61d0dbf4cff.bindPopup(popup_6cbe2318e9f7635a3a0e4ee3847fafda)
#         ;
#
#
#
#
#             var marker_20c4399bb3dcbaa24e6f25291a69661a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_87114fefd6ab71c097e1ab3ad79f6ba2);
#
#
#         var popup_252f5ee21ba766179bbec56ff3058787 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f2ce796385d292cdcaaea846fdf3abde = $(`&lt;div id=&quot;html_f2ce796385d292cdcaaea846fdf3abde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_252f5ee21ba766179bbec56ff3058787.setContent(html_f2ce796385d292cdcaaea846fdf3abde);
#
#
#
#         marker_20c4399bb3dcbaa24e6f25291a69661a.bindPopup(popup_252f5ee21ba766179bbec56ff3058787)
#         ;
#
#
#
#
#             var marker_289834d47f34c965ffd7e92a697bb748 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_87114fefd6ab71c097e1ab3ad79f6ba2);
#
#
#         var popup_fa075ae75da19e304b0d2f99645e229e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a490d74c33d0923185697cf214c001b = $(`&lt;div id=&quot;html_5a490d74c33d0923185697cf214c001b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fa075ae75da19e304b0d2f99645e229e.setContent(html_5a490d74c33d0923185697cf214c001b);
#
#
#
#         marker_289834d47f34c965ffd7e92a697bb748.bindPopup(popup_fa075ae75da19e304b0d2f99645e229e)
#         ;
#
#
#
#
#             var marker_f146fd2433fe83304d5bc5f43af59dd3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_87114fefd6ab71c097e1ab3ad79f6ba2);
#
#
#         var popup_76ffe45dea20b0be2ed7171a5b035b16 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3d874dcd9875f04426fac1cbf6eaeef = $(`&lt;div id=&quot;html_d3d874dcd9875f04426fac1cbf6eaeef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_76ffe45dea20b0be2ed7171a5b035b16.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_290b11a78071eea028476aaa22bdfbdf {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_290b11a78071eea028476aaa22bdfbdf&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_290b11a78071eea028476aaa22bdfbdf = L.map(
#                 &quot;map_290b11a78071eea028476aaa22bdfbdf&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f68d6e4aec5c6b316e626e62fb40729d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f68d6e4aec5c6b316e626e62fb40729d.addTo(map_290b11a78071eea028476aaa22bdfbdf);
#
#
#             var feature_group_ec96044941444d8caf7fd13d4d463ef0 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d620e4f29590c580ddcafe63dce342c9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_ec96044941444d8caf7fd13d4d463ef0);
#
#
#         var popup_5951ff211d37c81345dba48dcfd70f4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f3f0c4f936a2501a29c89d0197ffd900 = $(`&lt;div id=&quot;html_f3f0c4f936a2501a29c89d0197ffd900&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_5951ff211d37c81345dba48dcfd70f4b.setContent(html_f3f0c4f936a2501a29c89d0197ffd900);
#
#
#
#         marker_d620e4f29590c580ddcafe63dce342c9.bindPopup(popup_5951ff211d37c81345dba48dcfd70f4b)
#         ;
#
#
#
#
#             var marker_e2a5e0392b3f1bdadd1b4ab832dfb5d3 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_ec96044941444d8caf7fd13d4d463ef0);
#
#
#         var popup_fa9bd96eae57a137a35ff2a27c6d9f74 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a156b8dd651bb57b8526a4b79349dc16 = $(`&lt;div id=&quot;html_a156b8dd651bb57b8526a4b79349dc16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_fa9bd96eae57a137a35ff2a27c6d9f74.setContent(html_a156b8dd651bb57b8526a4b79349dc16);
#
#
#
#         marker_e2a5e0392b3f1bdadd1b4ab832dfb5d3.bindPopup(popup_fa9bd96eae57a137a35ff2a27c6d9f74)
#         ;
#
#
#
#
#             var marker_fac38c4905856e91872a1e441ca453e2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_ec96044941444d8caf7fd13d4d463ef0);
#
#
#         var popup_3be4cafc5bd639975de9af0750060dde = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4b5b07297be584b757d52c240e50614a = $(`&lt;div id=&quot;html_4b5b07297be584b757d52c240e50614a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3be4cafc5bd639975de9af0750060dde.setContent(html_4b5b07297be584b757d52c240e50614a);
#
#
#
#         marker_fac38c4905856e91872a1e441ca453e2.bindPopup(popup_3be4cafc5bd639975de9af0750060dde)
#         ;
#
#
#
#
#             var marker_cc5d14f34c2d0f47f6df2f46f061345b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_ec96044941444d8caf7fd13d4d463ef0);
#
#
#         var popup_2c70c371f1f92ab564be2847f4e44e7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d527a40b13073938330b6f96bf056c4 = $(`&lt;div id=&quot;html_2d527a40b13073938330b6f96bf056c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2c70c371f1f92ab564be2847f4e44e7b.setContent(html_2d527a40b13073938330b6f96bf056c4);
#
#
#
#         marker_cc5d14f34c2d0f47f6df2f46f061345b.bindPopup(popup_2c70c371f1f92ab564be2847f4e44e7b)
#         ;
#
#
#
#
#             var marker_29fe1590180a76fb12b3ab8025679300 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_ec96044941444d8caf7fd13d4d463ef0);
#
#
#         var popup_a3d533fc853b7b706842664292268b9a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_02e3a0109c6901a62d77cc0559da405d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_02e3a0109c6901a62d77cc0559da405d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_02e3a0109c6901a62d77cc0559da405d = L.map(
#                 &quot;map_02e3a0109c6901a62d77cc0559da405d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c003502c9987fc4cd2992bdfd6e882cd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c003502c9987fc4cd2992bdfd6e882cd.addTo(map_02e3a0109c6901a62d77cc0559da405d);
#
#
#             var feature_group_4dfb9779efc43d2637bfa34ead7769d6 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_4dfb9779efc43d2637bfa34ead7769d6.addTo(map_02e3a0109c6901a62d77cc0559da405d);
#
#
#             var feature_group_sub_group_27493e5fdea33cf0a8b9e27b86e0d50b = L.featureGroup.subGroup(
#                 feature_group_4dfb9779efc43d2637bfa34ead7769d6
#             );
#
#
#             var marker_09d8f4abf3281b4b77da1a16e6e284e0 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_27493e5fdea33cf0a8b9e27b86e0d50b);
#
#
#         var popup_397399e6e56935499ce8bc113e266743 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4f1ab4923019ee945d372f3a2b8d0948 = $(`&lt;div id=&quot;html_4f1ab4923019ee945d372f3a2b8d0948&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_397399e6e56935499ce8bc113e266743.setContent(html_4f1ab4923019ee945d372f3a2b8d0948);
#
#
#
#         marker_09d8f4abf3281b4b77da1a16e6e284e0.bindPopup(popup_397399e6e56935499ce8bc113e266743)
#         ;
#
#
#
#
#             var marker_13b3f41c030503232f3d370d2fbb812d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_27493e5fdea33cf0a8b9e27b86e0d50b);
#
#
#         var popup_bb27c6fdf7c4662ee2adc745cac2a90c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c5725cd5c0f39392c045a7be34ffff2e = $(`&lt;div id=&quot;html_c5725cd5c0f39392c045a7be34ffff2e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_bb27c6fdf7c4662ee2adc745cac2a90c.setContent(html_c5725cd5c0f39392c045a7be34ffff2e);
#
#
#
#         marker_13b3f41c030503232f3d370d2fbb812d.bindPopup(popup_bb27c6fdf7c4662ee2adc745cac2a90c)
#         ;
#
#
#
#
#             var marker_8e6a2ec9a4a31b169a840223ed4d4310 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_27493e5fdea33cf0a8b9e27b86e0d50b);
#
#
#         var popup_0eb1626919eabbb9e2a76e897752af0a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a92e73732eca3f7eb5394c7dd25fb9b8 = $(`&lt;div id=&quot;html_a92e73732eca3f7eb5394c7dd25fb9b8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_0eb1626919eabbb9e2a76e897752af0a.setContent(html_a92e73732eca3f7eb5394c7dd25fb9b8);
#
#
#
#         marker_8e6a2ec9a4a31b169a840223ed4d4310.bindPopup(popup_0eb1626919eabbb9e2a76e897752af0a)
#         ;
#
#
#
#
#             var marker_b131b5f9ca01aa93abf052876a7d419e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_27493e5fdea33cf0a8b9e27b86e0d50b);
#
#
#         var popup_fd35511fb4528881205b6b1b1c6145a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bfc26dc19b000f7281898989e0717dc3 = $(`&lt;div id=&quot;html_bfc26dc19b000f7281898989e0717dc3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_fd35511fb4528881205b6b1b1c6145a8.setContent(html_bfc26dc19b000f7281898989e0717dc3);
#
#
#
#         marker_
