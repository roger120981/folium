# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e0157390ea482c00cf73c7dc91e7d68a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e0157390ea482c00cf73c7dc91e7d68a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e0157390ea482c00cf73c7dc91e7d68a = L.map(
#                 &quot;map_e0157390ea482c00cf73c7dc91e7d68a&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_fa7cf542996f5950ffaf1e329dd3d8c1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_fa7cf542996f5950ffaf1e329dd3d8c1.addTo(map_e0157390ea482c00cf73c7dc91e7d68a);
#
#
#             var marker_d31ea83918883a9f7cc86e54e39e7040 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_e0157390ea482c00cf73c7dc91e7d68a);
#
#
#         var popup_2e1216f86a1991d6986c71b9e4b73671 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b0c29a0f59082759b6f318cff97f7cc5 = $(`&lt;div id=&quot;html_b0c29a0f59082759b6f318cff97f7cc5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_2e1216f86a1991d6986c71b9e4b73671.setContent(html_b0c29a0f59082759b6f318cff97f7cc5);
#
#
#
#         marker_d31ea83918883a9f7cc86e54e39e7040.bindPopup(popup_2e1216f86a1991d6986c71b9e4b73671)
#         ;
#
#
#
#
#             var marker_04f144e2089ec405c2c46173910ff031 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_e0157390ea482c00cf73c7dc91e7d68a);
#
#
#         var popup_0272365b192695b31f855bea633008bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_325071f2243a20a78623980ec17a13e0 = $(`&lt;div id=&quot;html_325071f2243a20a78623980ec17a13e0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_0272365b192695b31f855bea633008bb.setContent(html_325071f2243a20a78623980ec17a13e0);
#
#
#
#         marker_04f144e2089ec405c2c46173910ff031.bindPopup(popup_0272365b192695b31f855bea633008bb)
#         ;
#
#
#
#
#             var marker_965bd7539ce9f273cff62c3573bc476c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_e0157390ea482c00cf73c7dc91e7d68a);
#
#
#         var popup_bf6305d389960a7bc0478ac2b51694f9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4d0bd56776847e91c4c56aca67fe3bc = $(`&lt;div id=&quot;html_e4d0bd56776847e91c4c56aca67fe3bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_bf6305d389960a7bc0478ac2b51694f9.setContent(html_e4d0bd56776847e91c4c56aca67fe3bc);
#
#
#
#         marker_965bd7539ce9f273cff62c3573bc476c.bindPopup(popup_bf6305d389960a7bc0478ac2b51694f9)
#         ;
#
#
#
#
#             var marker_94f40b0304412829b4fed76621ac2a10 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_e0157390ea482c00cf73c7dc91e7d68a);
#
#
#         var popup_dd3adc9aa3ac3ceb7eb39e60d58a0c50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cbed830aa3f9f77c13e546b46b6b4248 = $(`&lt;div id=&quot;html_cbed830aa3f9f77c13e546b46b6b4248&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_dd3adc9aa3ac3ceb7eb39e60d58a0c50.setContent(html_cbed830aa3f9f77c13e546b46b6b4248);
#
#
#
#         marker_94f40b0304412829b4fed76621ac2a10.bindPopup(popup_dd3adc9aa3ac3ceb7eb39e60d58a0c50)
#         ;
#
#
#
#
#             var marker_754ccf6be8def27cdd10917b94763a5b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_e0157390ea482c00cf73c7dc91e7d68a);
#
#
#         var popup_5c99c458ef2757cd01cb1567a4aeed86 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a87a9e94300e7acf1b86612359a0d3a2 = $(`&lt;div id=&quot;html_a87a9e94300e7acf1b86612359a0d3a2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_5c99c458ef2757cd01cb1567a4aeed86.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9813ebf8b228bbef3a2dc1abfe25cb53 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9813ebf8b228bbef3a2dc1abfe25cb53&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9813ebf8b228bbef3a2dc1abfe25cb53 = L.map(
#                 &quot;map_9813ebf8b228bbef3a2dc1abfe25cb53&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ab3e179f9e0cba0b25f7566bd15bae70 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ab3e179f9e0cba0b25f7566bd15bae70.addTo(map_9813ebf8b228bbef3a2dc1abfe25cb53);
#
#
#             var feature_group_2fea5cb62cb41e8b1e0ad20a782ff1f7 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_2c700c0b2dc4e5c7f6ca4d5b743b11df = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2fea5cb62cb41e8b1e0ad20a782ff1f7);
#
#
#         var popup_52120ffe8eab554ca61838eaf22b6678 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33cbed122d6e4a03feaf5d1d1e462926 = $(`&lt;div id=&quot;html_33cbed122d6e4a03feaf5d1d1e462926&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_52120ffe8eab554ca61838eaf22b6678.setContent(html_33cbed122d6e4a03feaf5d1d1e462926);
#
#
#
#         marker_2c700c0b2dc4e5c7f6ca4d5b743b11df.bindPopup(popup_52120ffe8eab554ca61838eaf22b6678)
#         ;
#
#
#
#
#             var marker_206a183ae9dbcc77196d697d82272d9a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2fea5cb62cb41e8b1e0ad20a782ff1f7);
#
#
#         var popup_67b1cfa80b19078b91d77994795266a1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_79f246f06db1b718e64e5810ee604229 = $(`&lt;div id=&quot;html_79f246f06db1b718e64e5810ee604229&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_67b1cfa80b19078b91d77994795266a1.setContent(html_79f246f06db1b718e64e5810ee604229);
#
#
#
#         marker_206a183ae9dbcc77196d697d82272d9a.bindPopup(popup_67b1cfa80b19078b91d77994795266a1)
#         ;
#
#
#
#
#             var marker_8b8193cfbdbe9f4e0f3578b433085d16 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2fea5cb62cb41e8b1e0ad20a782ff1f7);
#
#
#         var popup_b14e92c18c08c9dcddb2964662cdb4b4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6fa7f4b6c61c1d97bb32261d1ad7cc27 = $(`&lt;div id=&quot;html_6fa7f4b6c61c1d97bb32261d1ad7cc27&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_b14e92c18c08c9dcddb2964662cdb4b4.setContent(html_6fa7f4b6c61c1d97bb32261d1ad7cc27);
#
#
#
#         marker_8b8193cfbdbe9f4e0f3578b433085d16.bindPopup(popup_b14e92c18c08c9dcddb2964662cdb4b4)
#         ;
#
#
#
#
#             var marker_778771a45342d53c9418e357bc0612ac = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2fea5cb62cb41e8b1e0ad20a782ff1f7);
#
#
#         var popup_8f4a9f0f99174885f05e0ffc4641be20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_29fb7320848824a03946e4417839287a = $(`&lt;div id=&quot;html_29fb7320848824a03946e4417839287a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_8f4a9f0f99174885f05e0ffc4641be20.setContent(html_29fb7320848824a03946e4417839287a);
#
#
#
#         marker_778771a45342d53c9418e357bc0612ac.bindPopup(popup_8f4a9f0f99174885f05e0ffc4641be20)
#         ;
#
#
#
#
#             var marker_442615ea52ad8eb7d30e1c20c92edcb9 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2fea5cb62cb41e8b1e0ad20a782ff1f7);
#
#
#         var popup_9057de50716fb2810b102b7d0e359b51 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8549dd4aa3f5cfaf4d0f6d6417014fc0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8549dd4aa3f5cfaf4d0f6d6417014fc0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8549dd4aa3f5cfaf4d0f6d6417014fc0 = L.map(
#                 &quot;map_8549dd4aa3f5cfaf4d0f6d6417014fc0&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e8a33239e8df5cae700596f848fcf7ab = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e8a33239e8df5cae700596f848fcf7ab.addTo(map_8549dd4aa3f5cfaf4d0f6d6417014fc0);
#
#
#             var feature_group_5c596490e1bf5d5ca21e3f9166c85d85 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_5c596490e1bf5d5ca21e3f9166c85d85.addTo(map_8549dd4aa3f5cfaf4d0f6d6417014fc0);
#
#
#             var feature_group_sub_group_5965ec41bb9d44f21633eee6f513327c = L.featureGroup.subGroup(
#                 feature_group_5c596490e1bf5d5ca21e3f9166c85d85
#             );
#
#
#             var marker_bb26124a506f9192ffa0ec5c96775bb6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_5965ec41bb9d44f21633eee6f513327c);
#
#
#         var popup_352f39578335838e8eb909c786ac88e8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3e13572e38a6fbcc15b6b60c30117ea = $(`&lt;div id=&quot;html_e3e13572e38a6fbcc15b6b60c30117ea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_352f39578335838e8eb909c786ac88e8.setContent(html_e3e13572e38a6fbcc15b6b60c30117ea);
#
#
#
#         marker_bb26124a506f9192ffa0ec5c96775bb6.bindPopup(popup_352f39578335838e8eb909c786ac88e8)
#         ;
#
#
#
#
#             var marker_0758ffabab031cdf5bd66c06613367bf = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_5965ec41bb9d44f21633eee6f513327c);
#
#
#         var popup_19fc711ab9280e31e30e0c6415b0ef55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_dae5dd439850c5cc7f0983414caa2883 = $(`&lt;div id=&quot;html_dae5dd439850c5cc7f0983414caa2883&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_19fc711ab9280e31e30e0c6415b0ef55.setContent(html_dae5dd439850c5cc7f0983414caa2883);
#
#
#
#         marker_0758ffabab031cdf5bd66c06613367bf.bindPopup(popup_19fc711ab9280e31e30e0c6415b0ef55)
#         ;
#
#
#
#
#             var marker_047a8948a55340b9bdca2929d046e34d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_5965ec41bb9d44f21633eee6f513327c);
#
#
#         var popup_c6e2561b1f26081dcab9d7df5861a473 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_347b902af51eb7e68a7b88d534caf28d = $(`&lt;div id=&quot;html_347b902af51eb7e68a7b88d534caf28d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_c6e2561b1f26081dcab9d7df5861a473.setContent(html_347b902af51eb7e68a7b88d534caf28d);
#
#
#
#         marker_047a8948a55340b9bdca2929d046e34d.bindPopup(popup_c6e2561b1f26081dcab9d7df5861a473)
#         ;
#
#
#
#
#             var marker_583a7fbc924e0c3659099de3cbe01598 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_5965ec41bb9d44f21633eee6f513327c);
#
#
#         var popup_1204083743b6d3da5f6b10379c370e1c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_40eeaaf0d8ef7ee0c9c70d9df824eb9c = $(`&lt;div id=&quot;html_40eeaaf0d8ef7ee0c9c70d9df824eb9c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_1204083743b6d3da5f6b10379c370e1c.setContent(html_40eeaaf0d8ef7ee0c9c70d9df824eb9c);
#
#
#
#         marker_
