# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d85b6dac84a3417eaecaf3a8941f1f58 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d85b6dac84a3417eaecaf3a8941f1f58&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d85b6dac84a3417eaecaf3a8941f1f58 = L.map(
#                 &quot;map_d85b6dac84a3417eaecaf3a8941f1f58&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ad26165e0b25baf2975868c4066a30ac = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ad26165e0b25baf2975868c4066a30ac.addTo(map_d85b6dac84a3417eaecaf3a8941f1f58);
#
#
#             var marker_0e03a54ff5a6ee519598fc60235147fd = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d85b6dac84a3417eaecaf3a8941f1f58);
#
#
#         var popup_f8de0d71816c0f36c9300b5313134b72 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_154e48245d6aee6e45ea04cf7bdaa5b6 = $(`&lt;div id=&quot;html_154e48245d6aee6e45ea04cf7bdaa5b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f8de0d71816c0f36c9300b5313134b72.setContent(html_154e48245d6aee6e45ea04cf7bdaa5b6);
#
#
#
#         marker_0e03a54ff5a6ee519598fc60235147fd.bindPopup(popup_f8de0d71816c0f36c9300b5313134b72)
#         ;
#
#
#
#
#             var marker_ff4e69da66fb13bb9259f87f488a0157 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d85b6dac84a3417eaecaf3a8941f1f58);
#
#
#         var popup_5b79e3103c777e5c80a4ca9b7b284902 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e823d42ae746ae060d5e61b465aec9a = $(`&lt;div id=&quot;html_7e823d42ae746ae060d5e61b465aec9a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_5b79e3103c777e5c80a4ca9b7b284902.setContent(html_7e823d42ae746ae060d5e61b465aec9a);
#
#
#
#         marker_ff4e69da66fb13bb9259f87f488a0157.bindPopup(popup_5b79e3103c777e5c80a4ca9b7b284902)
#         ;
#
#
#
#
#             var marker_a9ca06a9aaa2125959cb5a3765129684 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d85b6dac84a3417eaecaf3a8941f1f58);
#
#
#         var popup_d0caee60cf13375f90b3b11a392d7d2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c98117fa4ea110edbbc114824e3b2524 = $(`&lt;div id=&quot;html_c98117fa4ea110edbbc114824e3b2524&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_d0caee60cf13375f90b3b11a392d7d2e.setContent(html_c98117fa4ea110edbbc114824e3b2524);
#
#
#
#         marker_a9ca06a9aaa2125959cb5a3765129684.bindPopup(popup_d0caee60cf13375f90b3b11a392d7d2e)
#         ;
#
#
#
#
#             var marker_c25eb5c21f9304588c7b47e6b1641f43 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d85b6dac84a3417eaecaf3a8941f1f58);
#
#
#         var popup_fc1c3064ae0d61f9654a906158c3ec5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0d6dd8b1bfcadaa07f82f3edc132b1e9 = $(`&lt;div id=&quot;html_0d6dd8b1bfcadaa07f82f3edc132b1e9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_fc1c3064ae0d61f9654a906158c3ec5d.setContent(html_0d6dd8b1bfcadaa07f82f3edc132b1e9);
#
#
#
#         marker_c25eb5c21f9304588c7b47e6b1641f43.bindPopup(popup_fc1c3064ae0d61f9654a906158c3ec5d)
#         ;
#
#
#
#
#             var marker_d49179016bc511fa727d4bf5e96a06e5 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d85b6dac84a3417eaecaf3a8941f1f58);
#
#
#         var popup_31d86a85b1dc795a41056550dd6b488d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_be3d725fa5e5d0f1f620b953410e0bb4 = $(`&lt;div id=&quot;html_be3d725fa5e5d0f1f620b953410e0bb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_31d86a85b1dc795a41056550dd6b488d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4db7d72f8de5f1019fc137dc8ad432c4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4db7d72f8de5f1019fc137dc8ad432c4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4db7d72f8de5f1019fc137dc8ad432c4 = L.map(
#                 &quot;map_4db7d72f8de5f1019fc137dc8ad432c4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e994ac1963f9cff985110cc32e3a0c0d = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e994ac1963f9cff985110cc32e3a0c0d.addTo(map_4db7d72f8de5f1019fc137dc8ad432c4);
#
#
#             var feature_group_98201b16e8fe70bc43d93b0155cf069b = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_ca6505210397de540ea4fb599555497f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_98201b16e8fe70bc43d93b0155cf069b);
#
#
#         var popup_d2faa21fe2719fb37853c55bd15c835b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_376ff375e3810f683a3b29ea6124bad7 = $(`&lt;div id=&quot;html_376ff375e3810f683a3b29ea6124bad7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_d2faa21fe2719fb37853c55bd15c835b.setContent(html_376ff375e3810f683a3b29ea6124bad7);
#
#
#
#         marker_ca6505210397de540ea4fb599555497f.bindPopup(popup_d2faa21fe2719fb37853c55bd15c835b)
#         ;
#
#
#
#
#             var marker_c2d2c4dc404fe1ae2346ec7a33f458d0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_98201b16e8fe70bc43d93b0155cf069b);
#
#
#         var popup_1c343de66b01e2e3008a7b40861c59ce = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2bcf25d85eb845bfcd47a2901682b77e = $(`&lt;div id=&quot;html_2bcf25d85eb845bfcd47a2901682b77e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1c343de66b01e2e3008a7b40861c59ce.setContent(html_2bcf25d85eb845bfcd47a2901682b77e);
#
#
#
#         marker_c2d2c4dc404fe1ae2346ec7a33f458d0.bindPopup(popup_1c343de66b01e2e3008a7b40861c59ce)
#         ;
#
#
#
#
#             var marker_0b3b6270b1d6f7af6fc0cad33596a33f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_98201b16e8fe70bc43d93b0155cf069b);
#
#
#         var popup_274bc49967ef896c0515e3e9096b9021 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fc8241bc375a8e9cd1d4367344fd2edf = $(`&lt;div id=&quot;html_fc8241bc375a8e9cd1d4367344fd2edf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_274bc49967ef896c0515e3e9096b9021.setContent(html_fc8241bc375a8e9cd1d4367344fd2edf);
#
#
#
#         marker_0b3b6270b1d6f7af6fc0cad33596a33f.bindPopup(popup_274bc49967ef896c0515e3e9096b9021)
#         ;
#
#
#
#
#             var marker_9f0aafd5f95b430c83204e3b8ad372e6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_98201b16e8fe70bc43d93b0155cf069b);
#
#
#         var popup_2d0d3ee4d9db1b4b25a30b6980a8f534 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14330754f45eea2ee4c20321c838b5eb = $(`&lt;div id=&quot;html_14330754f45eea2ee4c20321c838b5eb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_2d0d3ee4d9db1b4b25a30b6980a8f534.setContent(html_14330754f45eea2ee4c20321c838b5eb);
#
#
#
#         marker_9f0aafd5f95b430c83204e3b8ad372e6.bindPopup(popup_2d0d3ee4d9db1b4b25a30b6980a8f534)
#         ;
#
#
#
#
#             var marker_5aceeb6a0293e53354a5d8469eafc3f3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_98201b16e8fe70bc43d93b0155cf069b);
#
#
#         var popup_25f60ea279e31d4ef26c082b5d36f10b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cefb041d4f2a1e663a4d8076cc2f4296 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cefb041d4f2a1e663a4d8076cc2f4296&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cefb041d4f2a1e663a4d8076cc2f4296 = L.map(
#                 &quot;map_cefb041d4f2a1e663a4d8076cc2f4296&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a68d8985ee9839293c30779f77664cc1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_a68d8985ee9839293c30779f77664cc1.addTo(map_cefb041d4f2a1e663a4d8076cc2f4296);
#
#
#             var feature_group_624e6be6310f8cbce6bf318df69c4c74 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_624e6be6310f8cbce6bf318df69c4c74.addTo(map_cefb041d4f2a1e663a4d8076cc2f4296);
#
#
#             var feature_group_sub_group_cf374930971409d22e4593c06084b400 = L.featureGroup.subGroup(
#                 feature_group_624e6be6310f8cbce6bf318df69c4c74
#             );
#
#
#             var marker_9bd3259b4b4ef482ecee5c1b365912c5 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_cf374930971409d22e4593c06084b400);
#
#
#         var popup_e76e2e8a19f07cd87ebf6ea0d034f642 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_685103a70de7f9cb380a82b506600bc8 = $(`&lt;div id=&quot;html_685103a70de7f9cb380a82b506600bc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_e76e2e8a19f07cd87ebf6ea0d034f642.setContent(html_685103a70de7f9cb380a82b506600bc8);
#
#
#
#         marker_9bd3259b4b4ef482ecee5c1b365912c5.bindPopup(popup_e76e2e8a19f07cd87ebf6ea0d034f642)
#         ;
#
#
#
#
#             var marker_18a0a76f2a4a3e35607a2bb8bb361fa9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_cf374930971409d22e4593c06084b400);
#
#
#         var popup_4b2e131248b3669da90bdb1815178d96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d4082c02e391174f20550fd2cb635c2 = $(`&lt;div id=&quot;html_6d4082c02e391174f20550fd2cb635c2&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4b2e131248b3669da90bdb1815178d96.setContent(html_6d4082c02e391174f20550fd2cb635c2);
#
#
#
#         marker_18a0a76f2a4a3e35607a2bb8bb361fa9.bindPopup(popup_4b2e131248b3669da90bdb1815178d96)
#         ;
#
#
#
#
#             var marker_514d84515c85d851d9a9dbc5c67d329c = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_cf374930971409d22e4593c06084b400);
#
#
#         var popup_cc0e479cbfeefd0251bc39649752c495 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cf94012970cd9633c1ad6f77269fdf9b = $(`&lt;div id=&quot;html_cf94012970cd9633c1ad6f77269fdf9b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_cc0e479cbfeefd0251bc39649752c495.setContent(html_cf94012970cd9633c1ad6f77269fdf9b);
#
#
#
#         marker_514d84515c85d851d9a9dbc5c67d329c.bindPopup(popup_cc0e479cbfeefd0251bc39649752c495)
#         ;
#
#
#
#
#             var marker_cc32624e6cdd228717e81bf9f115e8b6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_cf374930971409d22e4593c06084b400);
#
#
#         var popup_0b9d806dfe9f3ad147031815f255aefb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ba624d5e16bc44eba3ac99f1a3d82d7 = $(`&lt;div id=&quot;html_0ba624d5e16bc44eba3ac99f1a3d82d7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_0b9d806dfe9f3ad147031815f255aefb.setContent(html_0ba624d5e16bc44eba3ac99f1a3d82d7);
#
#
#
#         marker_
