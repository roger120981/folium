# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cf871127158ea3109ce80eb3e51839d6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cf871127158ea3109ce80eb3e51839d6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cf871127158ea3109ce80eb3e51839d6 = L.map(
#                 &quot;map_cf871127158ea3109ce80eb3e51839d6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_145bf2e51e5f972bbf636b6df993b929 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_145bf2e51e5f972bbf636b6df993b929.addTo(map_cf871127158ea3109ce80eb3e51839d6);
#
#
#             var marker_63e93d25ba6300e0b82a9961bf944558 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_cf871127158ea3109ce80eb3e51839d6);
#
#
#         var popup_e9a2e383594f92f6ff47a0ff1bdf1637 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6e662ec4400294ebe73ef5f2584e9ac1 = $(`&lt;div id=&quot;html_6e662ec4400294ebe73ef5f2584e9ac1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_e9a2e383594f92f6ff47a0ff1bdf1637.setContent(html_6e662ec4400294ebe73ef5f2584e9ac1);
#
#
#
#         marker_63e93d25ba6300e0b82a9961bf944558.bindPopup(popup_e9a2e383594f92f6ff47a0ff1bdf1637)
#         ;
#
#
#
#
#             var marker_b01524e66c96d7e12daf47d03934aeb5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_cf871127158ea3109ce80eb3e51839d6);
#
#
#         var popup_3761b0009e4b47f94563d12e9ede7af7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f8231447c745500e52dc1312cd82bd52 = $(`&lt;div id=&quot;html_f8231447c745500e52dc1312cd82bd52&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3761b0009e4b47f94563d12e9ede7af7.setContent(html_f8231447c745500e52dc1312cd82bd52);
#
#
#
#         marker_b01524e66c96d7e12daf47d03934aeb5.bindPopup(popup_3761b0009e4b47f94563d12e9ede7af7)
#         ;
#
#
#
#
#             var marker_361df52a8be6cd7e5965497563fb39f7 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_cf871127158ea3109ce80eb3e51839d6);
#
#
#         var popup_872843769aa98d610da1cdae2edb58f3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e86cdd3c0f982a7ca59dd45725701da7 = $(`&lt;div id=&quot;html_e86cdd3c0f982a7ca59dd45725701da7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_872843769aa98d610da1cdae2edb58f3.setContent(html_e86cdd3c0f982a7ca59dd45725701da7);
#
#
#
#         marker_361df52a8be6cd7e5965497563fb39f7.bindPopup(popup_872843769aa98d610da1cdae2edb58f3)
#         ;
#
#
#
#
#             var marker_48418a2fb49bbf3ee099659c70b498ad = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_cf871127158ea3109ce80eb3e51839d6);
#
#
#         var popup_072074b3e9bfeff021b5e5de5fd03406 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df249c158a75bf8924bde8e24701d378 = $(`&lt;div id=&quot;html_df249c158a75bf8924bde8e24701d378&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_072074b3e9bfeff021b5e5de5fd03406.setContent(html_df249c158a75bf8924bde8e24701d378);
#
#
#
#         marker_48418a2fb49bbf3ee099659c70b498ad.bindPopup(popup_072074b3e9bfeff021b5e5de5fd03406)
#         ;
#
#
#
#
#             var marker_ba87a061117a998e4697364c4e275803 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_cf871127158ea3109ce80eb3e51839d6);
#
#
#         var popup_df76a1e580bdf1f148b1c371e4198680 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8b27345ec4a6e79135e165dbf73d1300 = $(`&lt;div id=&quot;html_8b27345ec4a6e79135e165dbf73d1300&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_df76a1e580bdf1f148b1c371e4198680.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5692533affc829dab22dfa2d3fe7e7dc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5692533affc829dab22dfa2d3fe7e7dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5692533affc829dab22dfa2d3fe7e7dc = L.map(
#                 &quot;map_5692533affc829dab22dfa2d3fe7e7dc&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_72adbd33b49e93441f83e0a1794683e0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_72adbd33b49e93441f83e0a1794683e0.addTo(map_5692533affc829dab22dfa2d3fe7e7dc);
#
#
#             var feature_group_6749399891b842bdb7cd91750d0d86f5 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1e45f9317e3c0ff7e1c65bd7e487f785 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_6749399891b842bdb7cd91750d0d86f5);
#
#
#         var popup_c0ebb811bfa3742299e3a7c9cb177da4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fa2bf48f779fa92adae0cebf3abdae84 = $(`&lt;div id=&quot;html_fa2bf48f779fa92adae0cebf3abdae84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_c0ebb811bfa3742299e3a7c9cb177da4.setContent(html_fa2bf48f779fa92adae0cebf3abdae84);
#
#
#
#         marker_1e45f9317e3c0ff7e1c65bd7e487f785.bindPopup(popup_c0ebb811bfa3742299e3a7c9cb177da4)
#         ;
#
#
#
#
#             var marker_e71c633d88d87ce9db9d4a07ae33d8ad = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_6749399891b842bdb7cd91750d0d86f5);
#
#
#         var popup_9baff60b971d17187598e5cb8d1aeee4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0846a037ec5c1ccf93d457b1ed6d0505 = $(`&lt;div id=&quot;html_0846a037ec5c1ccf93d457b1ed6d0505&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_9baff60b971d17187598e5cb8d1aeee4.setContent(html_0846a037ec5c1ccf93d457b1ed6d0505);
#
#
#
#         marker_e71c633d88d87ce9db9d4a07ae33d8ad.bindPopup(popup_9baff60b971d17187598e5cb8d1aeee4)
#         ;
#
#
#
#
#             var marker_5b427c35a9ad53a78173851b3d8580cf = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_6749399891b842bdb7cd91750d0d86f5);
#
#
#         var popup_baf3054eb9c723abc3ce116a05b00440 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_593a5a6e4d512d71910300dd5c2062f4 = $(`&lt;div id=&quot;html_593a5a6e4d512d71910300dd5c2062f4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_baf3054eb9c723abc3ce116a05b00440.setContent(html_593a5a6e4d512d71910300dd5c2062f4);
#
#
#
#         marker_5b427c35a9ad53a78173851b3d8580cf.bindPopup(popup_baf3054eb9c723abc3ce116a05b00440)
#         ;
#
#
#
#
#             var marker_fcf92daee6e71ab3c4e883ea24a41d66 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_6749399891b842bdb7cd91750d0d86f5);
#
#
#         var popup_7f30e420f429337c120b14df1068de48 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_62944ad41a5043d051e039e64f93063c = $(`&lt;div id=&quot;html_62944ad41a5043d051e039e64f93063c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7f30e420f429337c120b14df1068de48.setContent(html_62944ad41a5043d051e039e64f93063c);
#
#
#
#         marker_fcf92daee6e71ab3c4e883ea24a41d66.bindPopup(popup_7f30e420f429337c120b14df1068de48)
#         ;
#
#
#
#
#             var marker_250ca5fec857f6180544f837c41cf4f1 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_6749399891b842bdb7cd91750d0d86f5);
#
#
#         var popup_f481eeb746f228e9ee2d73f96c84a065 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7e93e4095b59b5693604ddae4a71fed5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7e93e4095b59b5693604ddae4a71fed5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_7e93e4095b59b5693604ddae4a71fed5 = L.map(
#                 &quot;map_7e93e4095b59b5693604ddae4a71fed5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_157fe8529900cf3d143126dc34d151c8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_157fe8529900cf3d143126dc34d151c8.addTo(map_7e93e4095b59b5693604ddae4a71fed5);
#
#
#             var feature_group_be6eefb2201d9d4701657f3627ba0f05 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_be6eefb2201d9d4701657f3627ba0f05.addTo(map_7e93e4095b59b5693604ddae4a71fed5);
#
#
#             var feature_group_sub_group_ace69c3d790c855f83996d94ed53c4f6 = L.featureGroup.subGroup(
#                 feature_group_be6eefb2201d9d4701657f3627ba0f05
#             );
#
#
#             var marker_a324c87fafb2cbb7edeabac94dca63d4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ace69c3d790c855f83996d94ed53c4f6);
#
#
#         var popup_f189cd8fd3462e9b6ada9259ab331909 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_39fc0ab09c8540e87ceb83df0edabf43 = $(`&lt;div id=&quot;html_39fc0ab09c8540e87ceb83df0edabf43&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_f189cd8fd3462e9b6ada9259ab331909.setContent(html_39fc0ab09c8540e87ceb83df0edabf43);
#
#
#
#         marker_a324c87fafb2cbb7edeabac94dca63d4.bindPopup(popup_f189cd8fd3462e9b6ada9259ab331909)
#         ;
#
#
#
#
#             var marker_72150446783d72f225a3a85d799f87b9 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ace69c3d790c855f83996d94ed53c4f6);
#
#
#         var popup_c3f20b7d200685ec7212dead4954ed2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_95c627ab335069ca37e1c377debad22a = $(`&lt;div id=&quot;html_95c627ab335069ca37e1c377debad22a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_c3f20b7d200685ec7212dead4954ed2e.setContent(html_95c627ab335069ca37e1c377debad22a);
#
#
#
#         marker_72150446783d72f225a3a85d799f87b9.bindPopup(popup_c3f20b7d200685ec7212dead4954ed2e)
#         ;
#
#
#
#
#             var marker_a577a8f282489e44fd90b15a7ab4a838 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ace69c3d790c855f83996d94ed53c4f6);
#
#
#         var popup_8b020b57e6be814efff72d1a7bcae288 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_52db0be49c4489aaa3145955f074272e = $(`&lt;div id=&quot;html_52db0be49c4489aaa3145955f074272e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_8b020b57e6be814efff72d1a7bcae288.setContent(html_52db0be49c4489aaa3145955f074272e);
#
#
#
#         marker_a577a8f282489e44fd90b15a7ab4a838.bindPopup(popup_8b020b57e6be814efff72d1a7bcae288)
#         ;
#
#
#
#
#             var marker_a2954fb0c5ab0ab021e264583ee0f8f9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ace69c3d790c855f83996d94ed53c4f6);
#
#
#         var popup_3adb7b1f37c889be588047490e1dd1cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_02c5c4b83dbf04ebd4c2160d19ce60c3 = $(`&lt;div id=&quot;html_02c5c4b83dbf04ebd4c2160d19ce60c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_3adb7b1f37c889be588047490e1dd1cf.setContent(html_02c5c4b83dbf04ebd4c2160d19ce60c3);
#
#
#
#         marker_
