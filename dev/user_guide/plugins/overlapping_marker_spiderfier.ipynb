# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_fd825b0009e68f88a52390da19b2993b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_fd825b0009e68f88a52390da19b2993b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_fd825b0009e68f88a52390da19b2993b = L.map(
#                 &quot;map_fd825b0009e68f88a52390da19b2993b&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_31e72d4eeb2ba1795534a79d8ae79482 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_31e72d4eeb2ba1795534a79d8ae79482.addTo(map_fd825b0009e68f88a52390da19b2993b);
#
#
#             var marker_9297ce69d2d56a630f197525d1218625 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_fd825b0009e68f88a52390da19b2993b);
#
#
#         var popup_03c7c8d70d39beec1798b9501240acba = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_46dda25b038963eee85be76f7b8607be = $(`&lt;div id=&quot;html_46dda25b038963eee85be76f7b8607be&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_03c7c8d70d39beec1798b9501240acba.setContent(html_46dda25b038963eee85be76f7b8607be);
#
#
#
#         marker_9297ce69d2d56a630f197525d1218625.bindPopup(popup_03c7c8d70d39beec1798b9501240acba)
#         ;
#
#
#
#
#             var marker_4a99051ad426fed58cc0a70d953ab7f8 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_fd825b0009e68f88a52390da19b2993b);
#
#
#         var popup_3ba510ff2d4e067e6b82486729384719 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_936f93abe71cc95153334295ebfaab28 = $(`&lt;div id=&quot;html_936f93abe71cc95153334295ebfaab28&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_3ba510ff2d4e067e6b82486729384719.setContent(html_936f93abe71cc95153334295ebfaab28);
#
#
#
#         marker_4a99051ad426fed58cc0a70d953ab7f8.bindPopup(popup_3ba510ff2d4e067e6b82486729384719)
#         ;
#
#
#
#
#             var marker_b8f8c5b8a7451de549e18533ba53a8bb = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_fd825b0009e68f88a52390da19b2993b);
#
#
#         var popup_858aa5926d6f485067c21fde837039c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_67779ecee209a626eecbb97b90c5dc71 = $(`&lt;div id=&quot;html_67779ecee209a626eecbb97b90c5dc71&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_858aa5926d6f485067c21fde837039c0.setContent(html_67779ecee209a626eecbb97b90c5dc71);
#
#
#
#         marker_b8f8c5b8a7451de549e18533ba53a8bb.bindPopup(popup_858aa5926d6f485067c21fde837039c0)
#         ;
#
#
#
#
#             var marker_d3d5e4ca821e26d26db29b8f40de46c9 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_fd825b0009e68f88a52390da19b2993b);
#
#
#         var popup_03ebf11b2d70c9d7a05ad7159ee738ff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6b09de365c0ee9389743c250d3f51d89 = $(`&lt;div id=&quot;html_6b09de365c0ee9389743c250d3f51d89&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_03ebf11b2d70c9d7a05ad7159ee738ff.setContent(html_6b09de365c0ee9389743c250d3f51d89);
#
#
#
#         marker_d3d5e4ca821e26d26db29b8f40de46c9.bindPopup(popup_03ebf11b2d70c9d7a05ad7159ee738ff)
#         ;
#
#
#
#
#             var marker_759ee5432248fcfd93c2c3340f9a7621 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_fd825b0009e68f88a52390da19b2993b);
#
#
#         var popup_91fd58e9b11e01cb6ef2177f6bae7da4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_64a64a91a2d0c971c23b3e0817ad8537 = $(`&lt;div id=&quot;html_64a64a91a2d0c971c23b3e0817ad8537&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_91fd58e9b11e01cb6ef2177f6bae7da4.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea38c327ce930e47b15cb1b6f35c6ba4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea38c327ce930e47b15cb1b6f35c6ba4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea38c327ce930e47b15cb1b6f35c6ba4 = L.map(
#                 &quot;map_ea38c327ce930e47b15cb1b6f35c6ba4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ac73062dc85b0cd09164c8c5393161eb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ac73062dc85b0cd09164c8c5393161eb.addTo(map_ea38c327ce930e47b15cb1b6f35c6ba4);
#
#
#             var feature_group_48db14f39f5aec31da61b254cfdcf3c1 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_d5d8b368605ab1e5bf6d286c867d4203 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_48db14f39f5aec31da61b254cfdcf3c1);
#
#
#         var popup_f66f86f82d079bacb0b1e614619e627c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9713eb97e9cdf72f2603c2059e432a2f = $(`&lt;div id=&quot;html_9713eb97e9cdf72f2603c2059e432a2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_f66f86f82d079bacb0b1e614619e627c.setContent(html_9713eb97e9cdf72f2603c2059e432a2f);
#
#
#
#         marker_d5d8b368605ab1e5bf6d286c867d4203.bindPopup(popup_f66f86f82d079bacb0b1e614619e627c)
#         ;
#
#
#
#
#             var marker_5d16987832da3e8f3b8ee9ef68bae619 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_48db14f39f5aec31da61b254cfdcf3c1);
#
#
#         var popup_df5a612eda3ab4fc8f140e762ca30366 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3a6015f0177d0be2c6736cadd5889cb = $(`&lt;div id=&quot;html_d3a6015f0177d0be2c6736cadd5889cb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_df5a612eda3ab4fc8f140e762ca30366.setContent(html_d3a6015f0177d0be2c6736cadd5889cb);
#
#
#
#         marker_5d16987832da3e8f3b8ee9ef68bae619.bindPopup(popup_df5a612eda3ab4fc8f140e762ca30366)
#         ;
#
#
#
#
#             var marker_a5c79bb67daeba50c3478e5eac567a41 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_48db14f39f5aec31da61b254cfdcf3c1);
#
#
#         var popup_3a7ac9b8bbce9eb9c52603f11a2e9c8c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_df64e606efcaf04e5f674761397b96a1 = $(`&lt;div id=&quot;html_df64e606efcaf04e5f674761397b96a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_3a7ac9b8bbce9eb9c52603f11a2e9c8c.setContent(html_df64e606efcaf04e5f674761397b96a1);
#
#
#
#         marker_a5c79bb67daeba50c3478e5eac567a41.bindPopup(popup_3a7ac9b8bbce9eb9c52603f11a2e9c8c)
#         ;
#
#
#
#
#             var marker_f887627e921c3a1fe3be537282b826dc = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_48db14f39f5aec31da61b254cfdcf3c1);
#
#
#         var popup_6138542c304736161788bb8ff2b022cb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78c695b8546821e1017592a47d893ad4 = $(`&lt;div id=&quot;html_78c695b8546821e1017592a47d893ad4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_6138542c304736161788bb8ff2b022cb.setContent(html_78c695b8546821e1017592a47d893ad4);
#
#
#
#         marker_f887627e921c3a1fe3be537282b826dc.bindPopup(popup_6138542c304736161788bb8ff2b022cb)
#         ;
#
#
#
#
#             var marker_0620d8a028ac07d65786cb7b09c56f59 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_48db14f39f5aec31da61b254cfdcf3c1);
#
#
#         var popup_eacc5eb99ee85888aa5bf15c498f601d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8602062fb6da3d20947bbfe769b70f9f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8602062fb6da3d20947bbfe769b70f9f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8602062fb6da3d20947bbfe769b70f9f = L.map(
#                 &quot;map_8602062fb6da3d20947bbfe769b70f9f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6de0413b335f9bc7eb8b5bc02f7adee9 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6de0413b335f9bc7eb8b5bc02f7adee9.addTo(map_8602062fb6da3d20947bbfe769b70f9f);
#
#
#             var feature_group_cab92e5d27e888e5406cdf5cbc523eca = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_cab92e5d27e888e5406cdf5cbc523eca.addTo(map_8602062fb6da3d20947bbfe769b70f9f);
#
#
#             var feature_group_sub_group_aa941254db22a4e5f3cd0acdbeaa62ec = L.featureGroup.subGroup(
#                 feature_group_cab92e5d27e888e5406cdf5cbc523eca
#             );
#
#
#             var marker_54ece1f43254bda06ba622346b371a96 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_aa941254db22a4e5f3cd0acdbeaa62ec);
#
#
#         var popup_8c5d7e62267431fb8bc7cdc5d5bdfb2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c85a75b4ec8c29beff11fe8662f1b852 = $(`&lt;div id=&quot;html_c85a75b4ec8c29beff11fe8662f1b852&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_8c5d7e62267431fb8bc7cdc5d5bdfb2e.setContent(html_c85a75b4ec8c29beff11fe8662f1b852);
#
#
#
#         marker_54ece1f43254bda06ba622346b371a96.bindPopup(popup_8c5d7e62267431fb8bc7cdc5d5bdfb2e)
#         ;
#
#
#
#
#             var marker_76d74ce36d8325e721226137f9764a1c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_aa941254db22a4e5f3cd0acdbeaa62ec);
#
#
#         var popup_4eee0c255191dc759f5db56a330ed2f7 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89ff7c140c94e96f45f745352a18e09e = $(`&lt;div id=&quot;html_89ff7c140c94e96f45f745352a18e09e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_4eee0c255191dc759f5db56a330ed2f7.setContent(html_89ff7c140c94e96f45f745352a18e09e);
#
#
#
#         marker_76d74ce36d8325e721226137f9764a1c.bindPopup(popup_4eee0c255191dc759f5db56a330ed2f7)
#         ;
#
#
#
#
#             var marker_ac39d494d1727ff036d04e1580726b0f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_aa941254db22a4e5f3cd0acdbeaa62ec);
#
#
#         var popup_e78ae20cb78d0719a47e9e0c69576259 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce742ce85dd88b09d06c3b3ef9f99c41 = $(`&lt;div id=&quot;html_ce742ce85dd88b09d06c3b3ef9f99c41&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_e78ae20cb78d0719a47e9e0c69576259.setContent(html_ce742ce85dd88b09d06c3b3ef9f99c41);
#
#
#
#         marker_ac39d494d1727ff036d04e1580726b0f.bindPopup(popup_e78ae20cb78d0719a47e9e0c69576259)
#         ;
#
#
#
#
#             var marker_c33c91518c50b12c4e55e14c90fded82 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_aa941254db22a4e5f3cd0acdbeaa62ec);
#
#
#         var popup_b027e513d23bb99c6885d320449fa9d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8637bd506749a43f4cfaccab667c970d = $(`&lt;div id=&quot;html_8637bd506749a43f4cfaccab667c970d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b027e513d23bb99c6885d320449fa9d9.setContent(html_8637bd506749a43f4cfaccab667c970d);
#
#
#
#         marker_
