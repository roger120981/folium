# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5eba914c069d071b456ce2c15a3b7c36 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5eba914c069d071b456ce2c15a3b7c36&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5eba914c069d071b456ce2c15a3b7c36 = L.map(
#                 &quot;map_5eba914c069d071b456ce2c15a3b7c36&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5a0ec9e2fe2d8284d3994971a52ac951 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5a0ec9e2fe2d8284d3994971a52ac951.addTo(map_5eba914c069d071b456ce2c15a3b7c36);
#
#
#             var marker_5ba33914a587e8fe9fab903253b942ff = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_5eba914c069d071b456ce2c15a3b7c36);
#
#
#         var popup_6cd77c0fc4a087a2943f6fa4b324c7c0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4dcb68564e66b312d381584f2b7806c9 = $(`&lt;div id=&quot;html_4dcb68564e66b312d381584f2b7806c9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6cd77c0fc4a087a2943f6fa4b324c7c0.setContent(html_4dcb68564e66b312d381584f2b7806c9);
#
#
#
#         marker_5ba33914a587e8fe9fab903253b942ff.bindPopup(popup_6cd77c0fc4a087a2943f6fa4b324c7c0)
#         ;
#
#
#
#
#             var marker_9a541a3de0c4a9b430ac1428b4f78757 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_5eba914c069d071b456ce2c15a3b7c36);
#
#
#         var popup_fc391d5dc82a0a359ee4622d9a9c1aa6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c978e15519545b05209c1e81e4d8943a = $(`&lt;div id=&quot;html_c978e15519545b05209c1e81e4d8943a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_fc391d5dc82a0a359ee4622d9a9c1aa6.setContent(html_c978e15519545b05209c1e81e4d8943a);
#
#
#
#         marker_9a541a3de0c4a9b430ac1428b4f78757.bindPopup(popup_fc391d5dc82a0a359ee4622d9a9c1aa6)
#         ;
#
#
#
#
#             var marker_4110e4c3e2f2aea6f40d0ee8aa4c45b3 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_5eba914c069d071b456ce2c15a3b7c36);
#
#
#         var popup_911dbb2e3ca18e10b6624ae44ad80c35 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a76eb86d9368518f89de549af543610f = $(`&lt;div id=&quot;html_a76eb86d9368518f89de549af543610f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_911dbb2e3ca18e10b6624ae44ad80c35.setContent(html_a76eb86d9368518f89de549af543610f);
#
#
#
#         marker_4110e4c3e2f2aea6f40d0ee8aa4c45b3.bindPopup(popup_911dbb2e3ca18e10b6624ae44ad80c35)
#         ;
#
#
#
#
#             var marker_e956c29e176795270eaf1ffd67229354 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_5eba914c069d071b456ce2c15a3b7c36);
#
#
#         var popup_69a9c11134c91be6fef291883ab888a0 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89a6973b2eb73af0833c064143b35673 = $(`&lt;div id=&quot;html_89a6973b2eb73af0833c064143b35673&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_69a9c11134c91be6fef291883ab888a0.setContent(html_89a6973b2eb73af0833c064143b35673);
#
#
#
#         marker_e956c29e176795270eaf1ffd67229354.bindPopup(popup_69a9c11134c91be6fef291883ab888a0)
#         ;
#
#
#
#
#             var marker_0c8fb12cc0cb8486c5bb6ab1dd5afe45 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_5eba914c069d071b456ce2c15a3b7c36);
#
#
#         var popup_fb7f0faa7ae9969969316309bb203496 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_406ccf9f0aaca394feafbc6309d51c68 = $(`&lt;div id=&quot;html_406ccf9f0aaca394feafbc6309d51c68&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_fb7f0faa7ae9969969316309bb203496.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ac7dcfcee12335f53f5c57bf578b1189 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ac7dcfcee12335f53f5c57bf578b1189&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ac7dcfcee12335f53f5c57bf578b1189 = L.map(
#                 &quot;map_ac7dcfcee12335f53f5c57bf578b1189&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8bc596253ff4a6f93418dd77504cbc63 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8bc596253ff4a6f93418dd77504cbc63.addTo(map_ac7dcfcee12335f53f5c57bf578b1189);
#
#
#             var feature_group_769ce98612264fe774885a73ade3e998 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_c7d81a684ff0a728538ef0f1a8cf2041 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_769ce98612264fe774885a73ade3e998);
#
#
#         var popup_488fb8df776fec21b504d71ddb3c0494 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0ee887d530897f5045c54b0b4b0ace06 = $(`&lt;div id=&quot;html_0ee887d530897f5045c54b0b4b0ace06&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_488fb8df776fec21b504d71ddb3c0494.setContent(html_0ee887d530897f5045c54b0b4b0ace06);
#
#
#
#         marker_c7d81a684ff0a728538ef0f1a8cf2041.bindPopup(popup_488fb8df776fec21b504d71ddb3c0494)
#         ;
#
#
#
#
#             var marker_af2b2edcd4998ca48f0bd6f6bea6173f = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_769ce98612264fe774885a73ade3e998);
#
#
#         var popup_178b83e2d17ad28ed6f79ce41388eb7b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_90bf544f7eeb2828326ff0bd7df96134 = $(`&lt;div id=&quot;html_90bf544f7eeb2828326ff0bd7df96134&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_178b83e2d17ad28ed6f79ce41388eb7b.setContent(html_90bf544f7eeb2828326ff0bd7df96134);
#
#
#
#         marker_af2b2edcd4998ca48f0bd6f6bea6173f.bindPopup(popup_178b83e2d17ad28ed6f79ce41388eb7b)
#         ;
#
#
#
#
#             var marker_ce467c6ed7f2e02cf5b2619602baa1f2 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_769ce98612264fe774885a73ade3e998);
#
#
#         var popup_04e8e9bc99cb2c8518305d2530ca06bf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bdac88a822751773431661772619bedc = $(`&lt;div id=&quot;html_bdac88a822751773431661772619bedc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_04e8e9bc99cb2c8518305d2530ca06bf.setContent(html_bdac88a822751773431661772619bedc);
#
#
#
#         marker_ce467c6ed7f2e02cf5b2619602baa1f2.bindPopup(popup_04e8e9bc99cb2c8518305d2530ca06bf)
#         ;
#
#
#
#
#             var marker_e66a0887bf0eec64e7a1f9732bf80e2b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_769ce98612264fe774885a73ade3e998);
#
#
#         var popup_4918630106f494ee077083673cf815cf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cfb8f147fea54cd5c4ce4302b214de5a = $(`&lt;div id=&quot;html_cfb8f147fea54cd5c4ce4302b214de5a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_4918630106f494ee077083673cf815cf.setContent(html_cfb8f147fea54cd5c4ce4302b214de5a);
#
#
#
#         marker_e66a0887bf0eec64e7a1f9732bf80e2b.bindPopup(popup_4918630106f494ee077083673cf815cf)
#         ;
#
#
#
#
#             var marker_82c2fc11a3173e811ed3520d6258b63e = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_769ce98612264fe774885a73ade3e998);
#
#
#         var popup_e4832c0e32cf41609e5f152759101466 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e9bfd51a4fb9bd1ee69696f7e92f6197 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e9bfd51a4fb9bd1ee69696f7e92f6197&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e9bfd51a4fb9bd1ee69696f7e92f6197 = L.map(
#                 &quot;map_e9bfd51a4fb9bd1ee69696f7e92f6197&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1499ad57a0be70240703fdac49121f95 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1499ad57a0be70240703fdac49121f95.addTo(map_e9bfd51a4fb9bd1ee69696f7e92f6197);
#
#
#             var feature_group_d9b2d7ece59ab137eaf09461c1f1e041 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_d9b2d7ece59ab137eaf09461c1f1e041.addTo(map_e9bfd51a4fb9bd1ee69696f7e92f6197);
#
#
#             var feature_group_sub_group_264e0325321e691d7b0b1bd4482a3301 = L.featureGroup.subGroup(
#                 feature_group_d9b2d7ece59ab137eaf09461c1f1e041
#             );
#
#
#             var marker_bc83fc3d2e3793765e0d50bf7cacbfad = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_264e0325321e691d7b0b1bd4482a3301);
#
#
#         var popup_a827524defe6e26c6df6a112d7e7b210 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ccc791129fa44cdaf60e0f5e7daa8f19 = $(`&lt;div id=&quot;html_ccc791129fa44cdaf60e0f5e7daa8f19&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_a827524defe6e26c6df6a112d7e7b210.setContent(html_ccc791129fa44cdaf60e0f5e7daa8f19);
#
#
#
#         marker_bc83fc3d2e3793765e0d50bf7cacbfad.bindPopup(popup_a827524defe6e26c6df6a112d7e7b210)
#         ;
#
#
#
#
#             var marker_b328b75e15b4d12ca1c631d2918d3a92 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_264e0325321e691d7b0b1bd4482a3301);
#
#
#         var popup_f1ae0e073c08aa609c0b521dfd0c9fea = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d658c513143527ddc26e94fc5919cc16 = $(`&lt;div id=&quot;html_d658c513143527ddc26e94fc5919cc16&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_f1ae0e073c08aa609c0b521dfd0c9fea.setContent(html_d658c513143527ddc26e94fc5919cc16);
#
#
#
#         marker_b328b75e15b4d12ca1c631d2918d3a92.bindPopup(popup_f1ae0e073c08aa609c0b521dfd0c9fea)
#         ;
#
#
#
#
#             var marker_e6efa5789ed47705ed77f49c2215318b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_264e0325321e691d7b0b1bd4482a3301);
#
#
#         var popup_a7dfdb85b620e32760776c7feafe51d9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3be5d284a66a7b6335f1e16a19f6255c = $(`&lt;div id=&quot;html_3be5d284a66a7b6335f1e16a19f6255c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_a7dfdb85b620e32760776c7feafe51d9.setContent(html_3be5d284a66a7b6335f1e16a19f6255c);
#
#
#
#         marker_e6efa5789ed47705ed77f49c2215318b.bindPopup(popup_a7dfdb85b620e32760776c7feafe51d9)
#         ;
#
#
#
#
#             var marker_082f52e772cb91759127d77b3eb7bd7a = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_264e0325321e691d7b0b1bd4482a3301);
#
#
#         var popup_8cd56bb636146ed208dc3d3fa059af5f = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b941c1fba210ce0b5ab156a6b73d9b84 = $(`&lt;div id=&quot;html_b941c1fba210ce0b5ab156a6b73d9b84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_8cd56bb636146ed208dc3d3fa059af5f.setContent(html_b941c1fba210ce0b5ab156a6b73d9b84);
#
#
#
#         marker_
