# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8fdd278c6971a70542a31a7646a008e6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8fdd278c6971a70542a31a7646a008e6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8fdd278c6971a70542a31a7646a008e6 = L.map(
#                 &quot;map_8fdd278c6971a70542a31a7646a008e6&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8bd037134f6ae06bfff5180856ea6a61 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8bd037134f6ae06bfff5180856ea6a61.addTo(map_8fdd278c6971a70542a31a7646a008e6);
#
#
#             var marker_b51e86b9f24057bc8db1c44933bea450 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_8fdd278c6971a70542a31a7646a008e6);
#
#
#         var popup_42dfcd8711a414e0d4866e98235fe918 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_31e6c258e92e0df525babbccc4e1a1a1 = $(`&lt;div id=&quot;html_31e6c258e92e0df525babbccc4e1a1a1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_42dfcd8711a414e0d4866e98235fe918.setContent(html_31e6c258e92e0df525babbccc4e1a1a1);
#
#
#
#         marker_b51e86b9f24057bc8db1c44933bea450.bindPopup(popup_42dfcd8711a414e0d4866e98235fe918)
#         ;
#
#
#
#
#             var marker_775615668c46d0c6e84e5c31850182aa = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_8fdd278c6971a70542a31a7646a008e6);
#
#
#         var popup_bb77709ddf6205916d5c52cbcf6c2abb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b558fa5161cd474e292f2440511a3c36 = $(`&lt;div id=&quot;html_b558fa5161cd474e292f2440511a3c36&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_bb77709ddf6205916d5c52cbcf6c2abb.setContent(html_b558fa5161cd474e292f2440511a3c36);
#
#
#
#         marker_775615668c46d0c6e84e5c31850182aa.bindPopup(popup_bb77709ddf6205916d5c52cbcf6c2abb)
#         ;
#
#
#
#
#             var marker_76c399ca913b68265937c63fa9cd44f0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_8fdd278c6971a70542a31a7646a008e6);
#
#
#         var popup_c889fee591ca57ae1d9fdf94b5bea054 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b97af383c8be8192674463cef1a35eae = $(`&lt;div id=&quot;html_b97af383c8be8192674463cef1a35eae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c889fee591ca57ae1d9fdf94b5bea054.setContent(html_b97af383c8be8192674463cef1a35eae);
#
#
#
#         marker_76c399ca913b68265937c63fa9cd44f0.bindPopup(popup_c889fee591ca57ae1d9fdf94b5bea054)
#         ;
#
#
#
#
#             var marker_91a7865c734e4573f83983504ccedc89 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_8fdd278c6971a70542a31a7646a008e6);
#
#
#         var popup_c70c0ad0aa5aec14a2fc0ee12a852ebe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5d6ea57ddad1f4d59b485e27a443bd14 = $(`&lt;div id=&quot;html_5d6ea57ddad1f4d59b485e27a443bd14&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_c70c0ad0aa5aec14a2fc0ee12a852ebe.setContent(html_5d6ea57ddad1f4d59b485e27a443bd14);
#
#
#
#         marker_91a7865c734e4573f83983504ccedc89.bindPopup(popup_c70c0ad0aa5aec14a2fc0ee12a852ebe)
#         ;
#
#
#
#
#             var marker_fba6f90f4a69fa36960276b57fd72d5a = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_8fdd278c6971a70542a31a7646a008e6);
#
#
#         var popup_05ef51c41ace67ad56461b1f1cbb7f1d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1c7e1e70d23b51ef95de18061e92c45 = $(`&lt;div id=&quot;html_c1c7e1e70d23b51ef95de18061e92c45&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_05ef51c41ace67ad56461b1f1cbb7f1d.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9cd9321ee96c56d0d9598fdd8b735e5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9cd9321ee96c56d0d9598fdd8b735e5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9cd9321ee96c56d0d9598fdd8b735e5 = L.map(
#                 &quot;map_c9cd9321ee96c56d0d9598fdd8b735e5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c98a0d433294097e503d718945ec25b3 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c98a0d433294097e503d718945ec25b3.addTo(map_c9cd9321ee96c56d0d9598fdd8b735e5);
#
#
#             var feature_group_716e784f03b45b06a831b200fa6b1081 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_f940f9a61bafd12c4badafbc2f137fa9 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_716e784f03b45b06a831b200fa6b1081);
#
#
#         var popup_63c27bd846af815b55546c95e9920090 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_72fadaf7aeb7d354cfccd60fb300da17 = $(`&lt;div id=&quot;html_72fadaf7aeb7d354cfccd60fb300da17&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_63c27bd846af815b55546c95e9920090.setContent(html_72fadaf7aeb7d354cfccd60fb300da17);
#
#
#
#         marker_f940f9a61bafd12c4badafbc2f137fa9.bindPopup(popup_63c27bd846af815b55546c95e9920090)
#         ;
#
#
#
#
#             var marker_282cd2acf3044db0d688cfa138813206 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_716e784f03b45b06a831b200fa6b1081);
#
#
#         var popup_1bf6ac2daaf52f7c619a1ab2b7490512 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8ae4b24f5814c0b60381c9a73de4fc42 = $(`&lt;div id=&quot;html_8ae4b24f5814c0b60381c9a73de4fc42&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1bf6ac2daaf52f7c619a1ab2b7490512.setContent(html_8ae4b24f5814c0b60381c9a73de4fc42);
#
#
#
#         marker_282cd2acf3044db0d688cfa138813206.bindPopup(popup_1bf6ac2daaf52f7c619a1ab2b7490512)
#         ;
#
#
#
#
#             var marker_0ac6b51904131912d75babb2ee1716ac = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_716e784f03b45b06a831b200fa6b1081);
#
#
#         var popup_c02fb2fd7f78ec82c1562a026d9e4591 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f6df93637dfaee6298ae0d7c44cea39e = $(`&lt;div id=&quot;html_f6df93637dfaee6298ae0d7c44cea39e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_c02fb2fd7f78ec82c1562a026d9e4591.setContent(html_f6df93637dfaee6298ae0d7c44cea39e);
#
#
#
#         marker_0ac6b51904131912d75babb2ee1716ac.bindPopup(popup_c02fb2fd7f78ec82c1562a026d9e4591)
#         ;
#
#
#
#
#             var marker_0607acd5705b80750c5020e065583743 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_716e784f03b45b06a831b200fa6b1081);
#
#
#         var popup_76e55abaf4ccc6047618a6f8bc258e08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_70ace1e71d318452c11788829799c897 = $(`&lt;div id=&quot;html_70ace1e71d318452c11788829799c897&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_76e55abaf4ccc6047618a6f8bc258e08.setContent(html_70ace1e71d318452c11788829799c897);
#
#
#
#         marker_0607acd5705b80750c5020e065583743.bindPopup(popup_76e55abaf4ccc6047618a6f8bc258e08)
#         ;
#
#
#
#
#             var marker_c3e030f5538d45941321d4f4164e44a3 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_716e784f03b45b06a831b200fa6b1081);
#
#
#         var popup_3bf9848adad02b9ed1e3caa2858b59d8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_60ac241b7b8590d7e7e1a3b80ab56b16 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_60ac241b7b8590d7e7e1a3b80ab56b16&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_60ac241b7b8590d7e7e1a3b80ab56b16 = L.map(
#                 &quot;map_60ac241b7b8590d7e7e1a3b80ab56b16&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f2e479ac619f5c9727218a803f3e120e = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f2e479ac619f5c9727218a803f3e120e.addTo(map_60ac241b7b8590d7e7e1a3b80ab56b16);
#
#
#             var feature_group_bcc46a2d6dc2df2f2783f497c2e9c72a = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_bcc46a2d6dc2df2f2783f497c2e9c72a.addTo(map_60ac241b7b8590d7e7e1a3b80ab56b16);
#
#
#             var feature_group_sub_group_d4771808f71ef45e134fde034e90e145 = L.featureGroup.subGroup(
#                 feature_group_bcc46a2d6dc2df2f2783f497c2e9c72a
#             );
#
#
#             var marker_7d911a433ae3d48bd31ddd6ae919abe7 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_d4771808f71ef45e134fde034e90e145);
#
#
#         var popup_2e3e7dd046981b9350d053b590eb9c67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e1dab33fdf1a277bcc0db33e785311e8 = $(`&lt;div id=&quot;html_e1dab33fdf1a277bcc0db33e785311e8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_2e3e7dd046981b9350d053b590eb9c67.setContent(html_e1dab33fdf1a277bcc0db33e785311e8);
#
#
#
#         marker_7d911a433ae3d48bd31ddd6ae919abe7.bindPopup(popup_2e3e7dd046981b9350d053b590eb9c67)
#         ;
#
#
#
#
#             var marker_5f74a2834f2e9dcda9587ca51c1d444c = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_d4771808f71ef45e134fde034e90e145);
#
#
#         var popup_fb8fecab5d1639922a11766eebce65ab = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_12d71261d5258cabd5c1325e058e1b54 = $(`&lt;div id=&quot;html_12d71261d5258cabd5c1325e058e1b54&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_fb8fecab5d1639922a11766eebce65ab.setContent(html_12d71261d5258cabd5c1325e058e1b54);
#
#
#
#         marker_5f74a2834f2e9dcda9587ca51c1d444c.bindPopup(popup_fb8fecab5d1639922a11766eebce65ab)
#         ;
#
#
#
#
#             var marker_d5c26eebe390472d3e1a51286eaf5884 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_d4771808f71ef45e134fde034e90e145);
#
#
#         var popup_93688105c8517ac4a5e3588163ca4225 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7d43ff4c93537a0be91c4604f9aa3138 = $(`&lt;div id=&quot;html_7d43ff4c93537a0be91c4604f9aa3138&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_93688105c8517ac4a5e3588163ca4225.setContent(html_7d43ff4c93537a0be91c4604f9aa3138);
#
#
#
#         marker_d5c26eebe390472d3e1a51286eaf5884.bindPopup(popup_93688105c8517ac4a5e3588163ca4225)
#         ;
#
#
#
#
#             var marker_7a71c08df571032a9b84857f31bd5380 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_d4771808f71ef45e134fde034e90e145);
#
#
#         var popup_ea238671244f1fdc2ce11da8334d4a29 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7fe5f157d0ea66bcf4e0a0b41ffdb491 = $(`&lt;div id=&quot;html_7fe5f157d0ea66bcf4e0a0b41ffdb491&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_ea238671244f1fdc2ce11da8334d4a29.setContent(html_7fe5f157d0ea66bcf4e0a0b41ffdb491);
#
#
#
#         marker_
