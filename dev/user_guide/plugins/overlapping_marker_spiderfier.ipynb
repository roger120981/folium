# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1488719fdcbc89ef8e898ded02a03ce2 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1488719fdcbc89ef8e898ded02a03ce2&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1488719fdcbc89ef8e898ded02a03ce2 = L.map(
#                 &quot;map_1488719fdcbc89ef8e898ded02a03ce2&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_3dc8b9434e5b9f733d038e2ff3a87fe1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_3dc8b9434e5b9f733d038e2ff3a87fe1.addTo(map_1488719fdcbc89ef8e898ded02a03ce2);
#
#
#             var marker_63cd6519e61767190cd964f7c59af1ff = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_1488719fdcbc89ef8e898ded02a03ce2);
#
#
#         var popup_6793d69a0b2bac54bb339af56adb0f20 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a05c2c739275b375367fd588fecbefa9 = $(`&lt;div id=&quot;html_a05c2c739275b375367fd588fecbefa9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_6793d69a0b2bac54bb339af56adb0f20.setContent(html_a05c2c739275b375367fd588fecbefa9);
#
#
#
#         marker_63cd6519e61767190cd964f7c59af1ff.bindPopup(popup_6793d69a0b2bac54bb339af56adb0f20)
#         ;
#
#
#
#
#             var marker_f989333bd486d2b9d500b9731df53c1d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_1488719fdcbc89ef8e898ded02a03ce2);
#
#
#         var popup_27ff747063bd43f174b3f874755318b3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e2d671390872b56493677c8a9771e5bd = $(`&lt;div id=&quot;html_e2d671390872b56493677c8a9771e5bd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_27ff747063bd43f174b3f874755318b3.setContent(html_e2d671390872b56493677c8a9771e5bd);
#
#
#
#         marker_f989333bd486d2b9d500b9731df53c1d.bindPopup(popup_27ff747063bd43f174b3f874755318b3)
#         ;
#
#
#
#
#             var marker_112046c4317960873af62d823faf9f61 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_1488719fdcbc89ef8e898ded02a03ce2);
#
#
#         var popup_74f3d4417acc122bff3891396dec37e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ee64bc9ec4ed31c68eac2135c7bb3316 = $(`&lt;div id=&quot;html_ee64bc9ec4ed31c68eac2135c7bb3316&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_74f3d4417acc122bff3891396dec37e9.setContent(html_ee64bc9ec4ed31c68eac2135c7bb3316);
#
#
#
#         marker_112046c4317960873af62d823faf9f61.bindPopup(popup_74f3d4417acc122bff3891396dec37e9)
#         ;
#
#
#
#
#             var marker_f8eff46fe7d8a855c53861809dcff793 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_1488719fdcbc89ef8e898ded02a03ce2);
#
#
#         var popup_3ddb1ba2d5edfdc08f6594f5f7b60150 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1f8c598e75397cc681f28070f0c2add9 = $(`&lt;div id=&quot;html_1f8c598e75397cc681f28070f0c2add9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_3ddb1ba2d5edfdc08f6594f5f7b60150.setContent(html_1f8c598e75397cc681f28070f0c2add9);
#
#
#
#         marker_f8eff46fe7d8a855c53861809dcff793.bindPopup(popup_3ddb1ba2d5edfdc08f6594f5f7b60150)
#         ;
#
#
#
#
#             var marker_f5c377f0503a701f59f4958b16ac26cc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_1488719fdcbc89ef8e898ded02a03ce2);
#
#
#         var popup_c811c48bd47fc48dd207c2a1ed9a3939 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9fc855cf0bf89cc8fc113986a981a00f = $(`&lt;div id=&quot;html_9fc855cf0bf89cc8fc113986a981a00f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_c811c48bd47fc48dd207c2a1ed9a3939.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5611e977fe195952bf2d87fdef4e8f15 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5611e977fe195952bf2d87fdef4e8f15&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5611e977fe195952bf2d87fdef4e8f15 = L.map(
#                 &quot;map_5611e977fe195952bf2d87fdef4e8f15&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_23841c5f3bc3e1db922031a955be9291 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_23841c5f3bc3e1db922031a955be9291.addTo(map_5611e977fe195952bf2d87fdef4e8f15);
#
#
#             var feature_group_3d4ff40df3e2500cb8ba4e1c74858d9f = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_20f0f03c1497d6c255fa84af23f71152 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_3d4ff40df3e2500cb8ba4e1c74858d9f);
#
#
#         var popup_6e7483ba1a557a9533288297b4e6e4cc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4d84dbdbe5c1db8c71036e02869b7bbc = $(`&lt;div id=&quot;html_4d84dbdbe5c1db8c71036e02869b7bbc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6e7483ba1a557a9533288297b4e6e4cc.setContent(html_4d84dbdbe5c1db8c71036e02869b7bbc);
#
#
#
#         marker_20f0f03c1497d6c255fa84af23f71152.bindPopup(popup_6e7483ba1a557a9533288297b4e6e4cc)
#         ;
#
#
#
#
#             var marker_00bfda912a0d23587b2116967e161891 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_3d4ff40df3e2500cb8ba4e1c74858d9f);
#
#
#         var popup_680628abccc8059124e6630406164e5d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fe2b386f9213f4801e2fd11a443c77bc = $(`&lt;div id=&quot;html_fe2b386f9213f4801e2fd11a443c77bc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_680628abccc8059124e6630406164e5d.setContent(html_fe2b386f9213f4801e2fd11a443c77bc);
#
#
#
#         marker_00bfda912a0d23587b2116967e161891.bindPopup(popup_680628abccc8059124e6630406164e5d)
#         ;
#
#
#
#
#             var marker_e88f5461e3638c6c412eba4c48c1c119 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_3d4ff40df3e2500cb8ba4e1c74858d9f);
#
#
#         var popup_933c0c14602614aed2293cf0d60ca593 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c54d3ba42cd57187d51ee4bfb85b33ef = $(`&lt;div id=&quot;html_c54d3ba42cd57187d51ee4bfb85b33ef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_933c0c14602614aed2293cf0d60ca593.setContent(html_c54d3ba42cd57187d51ee4bfb85b33ef);
#
#
#
#         marker_e88f5461e3638c6c412eba4c48c1c119.bindPopup(popup_933c0c14602614aed2293cf0d60ca593)
#         ;
#
#
#
#
#             var marker_402577d4de8dc33a304cfc3949df6734 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_3d4ff40df3e2500cb8ba4e1c74858d9f);
#
#
#         var popup_7cc90bbf645d701b9ab27adfaab1415b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f43924989714f2eb216c64fd09c8a5c5 = $(`&lt;div id=&quot;html_f43924989714f2eb216c64fd09c8a5c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7cc90bbf645d701b9ab27adfaab1415b.setContent(html_f43924989714f2eb216c64fd09c8a5c5);
#
#
#
#         marker_402577d4de8dc33a304cfc3949df6734.bindPopup(popup_7cc90bbf645d701b9ab27adfaab1415b)
#         ;
#
#
#
#
#             var marker_417e3b76638da72e375a99f99b56ea1f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_3d4ff40df3e2500cb8ba4e1c74858d9f);
#
#
#         var popup_8fab40ae7fb0b8d9b3fddfa87e955148 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_077dd7d0a68815f569329d2da6058a2f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_077dd7d0a68815f569329d2da6058a2f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_077dd7d0a68815f569329d2da6058a2f = L.map(
#                 &quot;map_077dd7d0a68815f569329d2da6058a2f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_dda985900255f892b37a974d2c1f7159 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_dda985900255f892b37a974d2c1f7159.addTo(map_077dd7d0a68815f569329d2da6058a2f);
#
#
#             var feature_group_7ad3bcc212e110f0cf10bd5a4c2c6c60 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_7ad3bcc212e110f0cf10bd5a4c2c6c60.addTo(map_077dd7d0a68815f569329d2da6058a2f);
#
#
#             var feature_group_sub_group_3cd431f4a2188ef5313366c50aeb423b = L.featureGroup.subGroup(
#                 feature_group_7ad3bcc212e110f0cf10bd5a4c2c6c60
#             );
#
#
#             var marker_f9fe2335c7ab644abe95eb1060ce1f6e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3cd431f4a2188ef5313366c50aeb423b);
#
#
#         var popup_b1dbdd21f3c9a1758fbd24e20fe895aa = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7084c1d48c1a4da33b74048571e4961b = $(`&lt;div id=&quot;html_7084c1d48c1a4da33b74048571e4961b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_b1dbdd21f3c9a1758fbd24e20fe895aa.setContent(html_7084c1d48c1a4da33b74048571e4961b);
#
#
#
#         marker_f9fe2335c7ab644abe95eb1060ce1f6e.bindPopup(popup_b1dbdd21f3c9a1758fbd24e20fe895aa)
#         ;
#
#
#
#
#             var marker_8f0b950694ef7e313d46eb2f36eeab21 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3cd431f4a2188ef5313366c50aeb423b);
#
#
#         var popup_2ca290cb022e1ac69108d11223e00458 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0946d6ba4c034c85a280c8f30e3772a8 = $(`&lt;div id=&quot;html_0946d6ba4c034c85a280c8f30e3772a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_2ca290cb022e1ac69108d11223e00458.setContent(html_0946d6ba4c034c85a280c8f30e3772a8);
#
#
#
#         marker_8f0b950694ef7e313d46eb2f36eeab21.bindPopup(popup_2ca290cb022e1ac69108d11223e00458)
#         ;
#
#
#
#
#             var marker_f542f9bf9dac882e63513fb6849d5584 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3cd431f4a2188ef5313366c50aeb423b);
#
#
#         var popup_5dfe17901284f4dd2453df50a68e407c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2652c0d74bbd4fd4f9ab832df512a4d0 = $(`&lt;div id=&quot;html_2652c0d74bbd4fd4f9ab832df512a4d0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5dfe17901284f4dd2453df50a68e407c.setContent(html_2652c0d74bbd4fd4f9ab832df512a4d0);
#
#
#
#         marker_f542f9bf9dac882e63513fb6849d5584.bindPopup(popup_5dfe17901284f4dd2453df50a68e407c)
#         ;
#
#
#
#
#             var marker_64d9f9e1b097ea746d2521b04bb14c52 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3cd431f4a2188ef5313366c50aeb423b);
#
#
#         var popup_5cc61a55d9b39628c8337e53f4cb2970 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6840030b25ff811677795de93970a85a = $(`&lt;div id=&quot;html_6840030b25ff811677795de93970a85a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_5cc61a55d9b39628c8337e53f4cb2970.setContent(html_6840030b25ff811677795de93970a85a);
#
#
#
#         marker_
