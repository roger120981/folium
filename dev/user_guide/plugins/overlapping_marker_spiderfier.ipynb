# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_92312d06cf6286ffd0fcab7565ea9e78 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_92312d06cf6286ffd0fcab7565ea9e78&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_92312d06cf6286ffd0fcab7565ea9e78 = L.map(
#                 &quot;map_92312d06cf6286ffd0fcab7565ea9e78&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_104fbca89ab45955bd012eaccd8d1fd5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_104fbca89ab45955bd012eaccd8d1fd5.addTo(map_92312d06cf6286ffd0fcab7565ea9e78);
#
#
#             var marker_5280856edaaf9ab39d7defcf3a77a022 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_92312d06cf6286ffd0fcab7565ea9e78);
#
#
#         var popup_447af35043c8e20616c4e8f1484dfc28 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_73c57fa8a8c3a4c8b1c665805df8fd79 = $(`&lt;div id=&quot;html_73c57fa8a8c3a4c8b1c665805df8fd79&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_447af35043c8e20616c4e8f1484dfc28.setContent(html_73c57fa8a8c3a4c8b1c665805df8fd79);
#
#
#
#         marker_5280856edaaf9ab39d7defcf3a77a022.bindPopup(popup_447af35043c8e20616c4e8f1484dfc28)
#         ;
#
#
#
#
#             var marker_b0c2000dab1cf423bddcf331d8316e00 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_92312d06cf6286ffd0fcab7565ea9e78);
#
#
#         var popup_fdd7523d25eda9dfffa4bd08ac2684c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d3456f25c64e46c362f559ac6cb9d646 = $(`&lt;div id=&quot;html_d3456f25c64e46c362f559ac6cb9d646&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_fdd7523d25eda9dfffa4bd08ac2684c8.setContent(html_d3456f25c64e46c362f559ac6cb9d646);
#
#
#
#         marker_b0c2000dab1cf423bddcf331d8316e00.bindPopup(popup_fdd7523d25eda9dfffa4bd08ac2684c8)
#         ;
#
#
#
#
#             var marker_ea6878d0f737561bbc6a75be781f74be = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_92312d06cf6286ffd0fcab7565ea9e78);
#
#
#         var popup_ae4633fdce61161e7ee11709ebb9e943 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b5197e5a63d655905fc70857ee6453a8 = $(`&lt;div id=&quot;html_b5197e5a63d655905fc70857ee6453a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_ae4633fdce61161e7ee11709ebb9e943.setContent(html_b5197e5a63d655905fc70857ee6453a8);
#
#
#
#         marker_ea6878d0f737561bbc6a75be781f74be.bindPopup(popup_ae4633fdce61161e7ee11709ebb9e943)
#         ;
#
#
#
#
#             var marker_896473e5b9a61b14b025a0e2bea8715c = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_92312d06cf6286ffd0fcab7565ea9e78);
#
#
#         var popup_e468a93beab618111e240febefd10853 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c6be154df961129b72881845688eaa84 = $(`&lt;div id=&quot;html_c6be154df961129b72881845688eaa84&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e468a93beab618111e240febefd10853.setContent(html_c6be154df961129b72881845688eaa84);
#
#
#
#         marker_896473e5b9a61b14b025a0e2bea8715c.bindPopup(popup_e468a93beab618111e240febefd10853)
#         ;
#
#
#
#
#             var marker_7574b473f574aff7c2bba2221ff6c86b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_92312d06cf6286ffd0fcab7565ea9e78);
#
#
#         var popup_58d28ce549fc055579dae157cb60a3e1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_598533deeee5125f4f7ac78250f10b72 = $(`&lt;div id=&quot;html_598533deeee5125f4f7ac78250f10b72&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_58d28ce549fc055579dae157cb60a3e1.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80b4a7a1f6cc2a337137e92ae7dce54d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80b4a7a1f6cc2a337137e92ae7dce54d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_80b4a7a1f6cc2a337137e92ae7dce54d = L.map(
#                 &quot;map_80b4a7a1f6cc2a337137e92ae7dce54d&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5d5e590bcf812fea053148f5027bf5e5 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5d5e590bcf812fea053148f5027bf5e5.addTo(map_80b4a7a1f6cc2a337137e92ae7dce54d);
#
#
#             var feature_group_2fdd852a452a20acbb80aa97af270705 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b5e850ca446d76d255dcae670d0c83d6 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2fdd852a452a20acbb80aa97af270705);
#
#
#         var popup_4523f58c2abb4c16b7d75f6365daacff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ac18bc331ced1a6cb3ad4156db0770e1 = $(`&lt;div id=&quot;html_ac18bc331ced1a6cb3ad4156db0770e1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_4523f58c2abb4c16b7d75f6365daacff.setContent(html_ac18bc331ced1a6cb3ad4156db0770e1);
#
#
#
#         marker_b5e850ca446d76d255dcae670d0c83d6.bindPopup(popup_4523f58c2abb4c16b7d75f6365daacff)
#         ;
#
#
#
#
#             var marker_fcf575d50e442236e72b6433bdc2c624 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2fdd852a452a20acbb80aa97af270705);
#
#
#         var popup_1c4ee2a5d1e90ef0779a628a5d1345e5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da29e56a33c5edde4c866520e6dcd48b = $(`&lt;div id=&quot;html_da29e56a33c5edde4c866520e6dcd48b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_1c4ee2a5d1e90ef0779a628a5d1345e5.setContent(html_da29e56a33c5edde4c866520e6dcd48b);
#
#
#
#         marker_fcf575d50e442236e72b6433bdc2c624.bindPopup(popup_1c4ee2a5d1e90ef0779a628a5d1345e5)
#         ;
#
#
#
#
#             var marker_edc06fbeee07300f560d3f036d6eaff0 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2fdd852a452a20acbb80aa97af270705);
#
#
#         var popup_badf5d6c62021717e124ecafb65fa824 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_faf300b74e1f767d4feb553873321a05 = $(`&lt;div id=&quot;html_faf300b74e1f767d4feb553873321a05&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_badf5d6c62021717e124ecafb65fa824.setContent(html_faf300b74e1f767d4feb553873321a05);
#
#
#
#         marker_edc06fbeee07300f560d3f036d6eaff0.bindPopup(popup_badf5d6c62021717e124ecafb65fa824)
#         ;
#
#
#
#
#             var marker_bb639201fbabca57c7f0bd870041c09b = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2fdd852a452a20acbb80aa97af270705);
#
#
#         var popup_a7d4a6a41cb66b2b20e44895d2e2f6c3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2541f3e1818f0b1ca67de1da6ef58eef = $(`&lt;div id=&quot;html_2541f3e1818f0b1ca67de1da6ef58eef&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_a7d4a6a41cb66b2b20e44895d2e2f6c3.setContent(html_2541f3e1818f0b1ca67de1da6ef58eef);
#
#
#
#         marker_bb639201fbabca57c7f0bd870041c09b.bindPopup(popup_a7d4a6a41cb66b2b20e44895d2e2f6c3)
#         ;
#
#
#
#
#             var marker_1f1c1eea239ef531a7fa35b1ce6b559f = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2fdd852a452a20acbb80aa97af270705);
#
#
#         var popup_b1650ba6e7877ec04ee4b9f7af1fe416 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6ba46f468ef6318c1d596fd335dcfa19 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6ba46f468ef6318c1d596fd335dcfa19&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6ba46f468ef6318c1d596fd335dcfa19 = L.map(
#                 &quot;map_6ba46f468ef6318c1d596fd335dcfa19&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6dea650b2a0ac1ffcc3d69ef12435b4a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_6dea650b2a0ac1ffcc3d69ef12435b4a.addTo(map_6ba46f468ef6318c1d596fd335dcfa19);
#
#
#             var feature_group_450b68c9a82064b705ea2d14879b40ea = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_450b68c9a82064b705ea2d14879b40ea.addTo(map_6ba46f468ef6318c1d596fd335dcfa19);
#
#
#             var feature_group_sub_group_3c97dfcc51b6b3d027bc024e33bf39a2 = L.featureGroup.subGroup(
#                 feature_group_450b68c9a82064b705ea2d14879b40ea
#             );
#
#
#             var marker_2a9d86a178426b841edda46afc90406e = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_3c97dfcc51b6b3d027bc024e33bf39a2);
#
#
#         var popup_d2ea69f433fc0b86945a6731a0dc419c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e9ef7a5154eafd732756396d009e28ac = $(`&lt;div id=&quot;html_e9ef7a5154eafd732756396d009e28ac&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_d2ea69f433fc0b86945a6731a0dc419c.setContent(html_e9ef7a5154eafd732756396d009e28ac);
#
#
#
#         marker_2a9d86a178426b841edda46afc90406e.bindPopup(popup_d2ea69f433fc0b86945a6731a0dc419c)
#         ;
#
#
#
#
#             var marker_db61d416f2662b92cee1466986e07819 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_3c97dfcc51b6b3d027bc024e33bf39a2);
#
#
#         var popup_212000482509c70c95cb3368ee538248 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_605f67502a235a24f44eac88e2472dc8 = $(`&lt;div id=&quot;html_605f67502a235a24f44eac88e2472dc8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_212000482509c70c95cb3368ee538248.setContent(html_605f67502a235a24f44eac88e2472dc8);
#
#
#
#         marker_db61d416f2662b92cee1466986e07819.bindPopup(popup_212000482509c70c95cb3368ee538248)
#         ;
#
#
#
#
#             var marker_b237c8b7a5bad852f95b6100f164995d = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_3c97dfcc51b6b3d027bc024e33bf39a2);
#
#
#         var popup_fb4cbb2db5e97914720867a5d5cf4e62 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_18e0b001bfa761663546a7a01f384012 = $(`&lt;div id=&quot;html_18e0b001bfa761663546a7a01f384012&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_fb4cbb2db5e97914720867a5d5cf4e62.setContent(html_18e0b001bfa761663546a7a01f384012);
#
#
#
#         marker_b237c8b7a5bad852f95b6100f164995d.bindPopup(popup_fb4cbb2db5e97914720867a5d5cf4e62)
#         ;
#
#
#
#
#             var marker_1e0c865fd543541b362d4e65ebffcf5e = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_3c97dfcc51b6b3d027bc024e33bf39a2);
#
#
#         var popup_41d28a92dc07f82f3f9c33e893a73061 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9e9af1cf317a97f7a2266db95c08cb7f = $(`&lt;div id=&quot;html_9e9af1cf317a97f7a2266db95c08cb7f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_41d28a92dc07f82f3f9c33e893a73061.setContent(html_9e9af1cf317a97f7a2266db95c08cb7f);
#
#
#
#         marker_
