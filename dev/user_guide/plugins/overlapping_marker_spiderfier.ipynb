# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_2e0c42795f37ba429e184a76bb433e56 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_2e0c42795f37ba429e184a76bb433e56&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_2e0c42795f37ba429e184a76bb433e56 = L.map(
#                 &quot;map_2e0c42795f37ba429e184a76bb433e56&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7463b045147028b481f5d0debf8cde90 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7463b045147028b481f5d0debf8cde90.addTo(map_2e0c42795f37ba429e184a76bb433e56);
#
#
#             var marker_3f6661f6505e64207f821df66ef6c118 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_2e0c42795f37ba429e184a76bb433e56);
#
#
#         var popup_210b4a2e030507758f9b97c4d81a3ead = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_00e6b5c43a7c963dbda8b716a0ddaaa4 = $(`&lt;div id=&quot;html_00e6b5c43a7c963dbda8b716a0ddaaa4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_210b4a2e030507758f9b97c4d81a3ead.setContent(html_00e6b5c43a7c963dbda8b716a0ddaaa4);
#
#
#
#         marker_3f6661f6505e64207f821df66ef6c118.bindPopup(popup_210b4a2e030507758f9b97c4d81a3ead)
#         ;
#
#
#
#
#             var marker_1bce2437788c2a3b51770c2878456483 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_2e0c42795f37ba429e184a76bb433e56);
#
#
#         var popup_a8650cb3d01f8f84bf7e1d9bbb60b3db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_caf63e6a6dcbd3a65a421184d22f29d6 = $(`&lt;div id=&quot;html_caf63e6a6dcbd3a65a421184d22f29d6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_a8650cb3d01f8f84bf7e1d9bbb60b3db.setContent(html_caf63e6a6dcbd3a65a421184d22f29d6);
#
#
#
#         marker_1bce2437788c2a3b51770c2878456483.bindPopup(popup_a8650cb3d01f8f84bf7e1d9bbb60b3db)
#         ;
#
#
#
#
#             var marker_f964556919a044f8bcb6daa9cd04531f = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_2e0c42795f37ba429e184a76bb433e56);
#
#
#         var popup_3b8c215e60a4d04caf39bb1b128ceead = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_784f05e40fd6c763b1c3345575b3d748 = $(`&lt;div id=&quot;html_784f05e40fd6c763b1c3345575b3d748&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_3b8c215e60a4d04caf39bb1b128ceead.setContent(html_784f05e40fd6c763b1c3345575b3d748);
#
#
#
#         marker_f964556919a044f8bcb6daa9cd04531f.bindPopup(popup_3b8c215e60a4d04caf39bb1b128ceead)
#         ;
#
#
#
#
#             var marker_acbc12d239572e5ef9b78400d61016b6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_2e0c42795f37ba429e184a76bb433e56);
#
#
#         var popup_e1320c76dc6f627e73edff0d0823d598 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f81847ad4488e0a8fdfa20aadd86eafc = $(`&lt;div id=&quot;html_f81847ad4488e0a8fdfa20aadd86eafc&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_e1320c76dc6f627e73edff0d0823d598.setContent(html_f81847ad4488e0a8fdfa20aadd86eafc);
#
#
#
#         marker_acbc12d239572e5ef9b78400d61016b6.bindPopup(popup_e1320c76dc6f627e73edff0d0823d598)
#         ;
#
#
#
#
#             var marker_689f6a82366dcad2b977273d5041668b = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_2e0c42795f37ba429e184a76bb433e56);
#
#
#         var popup_e43d95d5fd7b1e7eed7690ac16ecda4b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3cb65ebc4d27ea16fe882f4923bc2680 = $(`&lt;div id=&quot;html_3cb65ebc4d27ea16fe882f4923bc2680&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_e43d95d5fd7b1e7eed7690ac16ecda4b.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_51bc631a83df8ca187007d503c92b3d8 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_51bc631a83df8ca187007d503c92b3d8&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_51bc631a83df8ca187007d503c92b3d8 = L.map(
#                 &quot;map_51bc631a83df8ca187007d503c92b3d8&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_99b2bbe784ec6f82b8651322d08b0a56 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_99b2bbe784ec6f82b8651322d08b0a56.addTo(map_51bc631a83df8ca187007d503c92b3d8);
#
#
#             var feature_group_2cba8a592fc140b13e9216622ffafe34 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_343125ec81005434566096409d05b1b4 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_2cba8a592fc140b13e9216622ffafe34);
#
#
#         var popup_a49bfcae893ac79338bb7d7a8b7acfc1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e4cf5f2abdaf2924e69a2fc03b0d56a5 = $(`&lt;div id=&quot;html_e4cf5f2abdaf2924e69a2fc03b0d56a5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a49bfcae893ac79338bb7d7a8b7acfc1.setContent(html_e4cf5f2abdaf2924e69a2fc03b0d56a5);
#
#
#
#         marker_343125ec81005434566096409d05b1b4.bindPopup(popup_a49bfcae893ac79338bb7d7a8b7acfc1)
#         ;
#
#
#
#
#             var marker_42b00c4ef4c407e54af0eb490c230d13 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_2cba8a592fc140b13e9216622ffafe34);
#
#
#         var popup_bd4efec59d40d914a05bdcd99fa01cd4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b670f18473bbceafb59050a9c9c85689 = $(`&lt;div id=&quot;html_b670f18473bbceafb59050a9c9c85689&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_bd4efec59d40d914a05bdcd99fa01cd4.setContent(html_b670f18473bbceafb59050a9c9c85689);
#
#
#
#         marker_42b00c4ef4c407e54af0eb490c230d13.bindPopup(popup_bd4efec59d40d914a05bdcd99fa01cd4)
#         ;
#
#
#
#
#             var marker_6ceed69c4b803390ea167a11e6a5145b = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_2cba8a592fc140b13e9216622ffafe34);
#
#
#         var popup_44e7dc0e226cb7a8c155d23a44539d3b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6cf525d42e54584855421aa0e121551e = $(`&lt;div id=&quot;html_6cf525d42e54584855421aa0e121551e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_44e7dc0e226cb7a8c155d23a44539d3b.setContent(html_6cf525d42e54584855421aa0e121551e);
#
#
#
#         marker_6ceed69c4b803390ea167a11e6a5145b.bindPopup(popup_44e7dc0e226cb7a8c155d23a44539d3b)
#         ;
#
#
#
#
#             var marker_388084126a638df1ff5c270b31581574 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_2cba8a592fc140b13e9216622ffafe34);
#
#
#         var popup_ac5c5fdc16094781af0c510aadee6c76 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_856bd08fecea7f95bef1cacf5bb1f259 = $(`&lt;div id=&quot;html_856bd08fecea7f95bef1cacf5bb1f259&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_ac5c5fdc16094781af0c510aadee6c76.setContent(html_856bd08fecea7f95bef1cacf5bb1f259);
#
#
#
#         marker_388084126a638df1ff5c270b31581574.bindPopup(popup_ac5c5fdc16094781af0c510aadee6c76)
#         ;
#
#
#
#
#             var marker_f6693d5939c94cf6d7d070306fa105dd = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_2cba8a592fc140b13e9216622ffafe34);
#
#
#         var popup_ce29b393f410cf701d93d4b113b8b411 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b9d80f9a6a61d8a9865acbcbae8083a4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b9d80f9a6a61d8a9865acbcbae8083a4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b9d80f9a6a61d8a9865acbcbae8083a4 = L.map(
#                 &quot;map_b9d80f9a6a61d8a9865acbcbae8083a4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_5c2d0b1534519fa32225864e39a601f1 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_5c2d0b1534519fa32225864e39a601f1.addTo(map_b9d80f9a6a61d8a9865acbcbae8083a4);
#
#
#             var feature_group_f416b55cca4c86d255f27362775d9b06 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_f416b55cca4c86d255f27362775d9b06.addTo(map_b9d80f9a6a61d8a9865acbcbae8083a4);
#
#
#             var feature_group_sub_group_2375b20d3f40fe322d337f75311bcc79 = L.featureGroup.subGroup(
#                 feature_group_f416b55cca4c86d255f27362775d9b06
#             );
#
#
#             var marker_8451b8cd7bd9146c365a6c7947bb6d8b = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_2375b20d3f40fe322d337f75311bcc79);
#
#
#         var popup_859bf9b72903bbc594c1b71a7e693912 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a6f22095338072578b3cc838ae2c8b3e = $(`&lt;div id=&quot;html_a6f22095338072578b3cc838ae2c8b3e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_859bf9b72903bbc594c1b71a7e693912.setContent(html_a6f22095338072578b3cc838ae2c8b3e);
#
#
#
#         marker_8451b8cd7bd9146c365a6c7947bb6d8b.bindPopup(popup_859bf9b72903bbc594c1b71a7e693912)
#         ;
#
#
#
#
#             var marker_06253fdc3938b17caf8125af78443e93 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_2375b20d3f40fe322d337f75311bcc79);
#
#
#         var popup_ab3b65bc5b4165c45538c907ef9b8609 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_89dee1518996c0fcd74c62fded534a59 = $(`&lt;div id=&quot;html_89dee1518996c0fcd74c62fded534a59&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_ab3b65bc5b4165c45538c907ef9b8609.setContent(html_89dee1518996c0fcd74c62fded534a59);
#
#
#
#         marker_06253fdc3938b17caf8125af78443e93.bindPopup(popup_ab3b65bc5b4165c45538c907ef9b8609)
#         ;
#
#
#
#
#             var marker_01524293cf4b39e0b454debce377364e = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_2375b20d3f40fe322d337f75311bcc79);
#
#
#         var popup_72e64da726bc6f89679d268b98a15d42 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5b700f7e7a38c135ae129cf9e0a3cad5 = $(`&lt;div id=&quot;html_5b700f7e7a38c135ae129cf9e0a3cad5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_72e64da726bc6f89679d268b98a15d42.setContent(html_5b700f7e7a38c135ae129cf9e0a3cad5);
#
#
#
#         marker_01524293cf4b39e0b454debce377364e.bindPopup(popup_72e64da726bc6f89679d268b98a15d42)
#         ;
#
#
#
#
#             var marker_d9fcd5e1ecb329adc13d5cfc81f5d03f = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_2375b20d3f40fe322d337f75311bcc79);
#
#
#         var popup_7f25ae204e007cf65d230b801ad56fae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a914978aff242ecb04d735fe9c142233 = $(`&lt;div id=&quot;html_a914978aff242ecb04d735fe9c142233&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_7f25ae204e007cf65d230b801ad56fae.setContent(html_a914978aff242ecb04d735fe9c142233);
#
#
#
#         marker_
