# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d3fc408bb311a295169c9277adb7de1f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d3fc408bb311a295169c9277adb7de1f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d3fc408bb311a295169c9277adb7de1f = L.map(
#                 &quot;map_d3fc408bb311a295169c9277adb7de1f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d60f81202af1d884adf6313db9cd4533 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d60f81202af1d884adf6313db9cd4533.addTo(map_d3fc408bb311a295169c9277adb7de1f);
#
#
#             var marker_32faa0e5db4ef7806b5a53ef88cf98f2 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_d3fc408bb311a295169c9277adb7de1f);
#
#
#         var popup_f0496f50812317df2a9b5a64d7874e08 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9c01786cab658f69968e27b84942c690 = $(`&lt;div id=&quot;html_9c01786cab658f69968e27b84942c690&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_f0496f50812317df2a9b5a64d7874e08.setContent(html_9c01786cab658f69968e27b84942c690);
#
#
#
#         marker_32faa0e5db4ef7806b5a53ef88cf98f2.bindPopup(popup_f0496f50812317df2a9b5a64d7874e08)
#         ;
#
#
#
#
#             var marker_06698f43a7abc67a054f7df9f642cca5 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_d3fc408bb311a295169c9277adb7de1f);
#
#
#         var popup_482b20ea58201dc3099e7bec7c255f8b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_13b5a1e6b94b3b4a8ce09bc18c26edfa = $(`&lt;div id=&quot;html_13b5a1e6b94b3b4a8ce09bc18c26edfa&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_482b20ea58201dc3099e7bec7c255f8b.setContent(html_13b5a1e6b94b3b4a8ce09bc18c26edfa);
#
#
#
#         marker_06698f43a7abc67a054f7df9f642cca5.bindPopup(popup_482b20ea58201dc3099e7bec7c255f8b)
#         ;
#
#
#
#
#             var marker_e0feedaa9fe0c6d80d1709b0fbb39ebd = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_d3fc408bb311a295169c9277adb7de1f);
#
#
#         var popup_100b5dfa99f6af9cd9579040e2dc9edc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_24e1bcff97f01a2ebaa41ad120ef3c5b = $(`&lt;div id=&quot;html_24e1bcff97f01a2ebaa41ad120ef3c5b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_100b5dfa99f6af9cd9579040e2dc9edc.setContent(html_24e1bcff97f01a2ebaa41ad120ef3c5b);
#
#
#
#         marker_e0feedaa9fe0c6d80d1709b0fbb39ebd.bindPopup(popup_100b5dfa99f6af9cd9579040e2dc9edc)
#         ;
#
#
#
#
#             var marker_5d32209e651135b47e2df2c943af4d87 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_d3fc408bb311a295169c9277adb7de1f);
#
#
#         var popup_42ff169a16db9c6821bf15f52375a6f1 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_82b34d5a659002ff1d68bd42fe47bdad = $(`&lt;div id=&quot;html_82b34d5a659002ff1d68bd42fe47bdad&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_42ff169a16db9c6821bf15f52375a6f1.setContent(html_82b34d5a659002ff1d68bd42fe47bdad);
#
#
#
#         marker_5d32209e651135b47e2df2c943af4d87.bindPopup(popup_42ff169a16db9c6821bf15f52375a6f1)
#         ;
#
#
#
#
#             var marker_d65604cd65ac48a55d590b5332c58bdc = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_d3fc408bb311a295169c9277adb7de1f);
#
#
#         var popup_1c134b826fbb3107a76dd64a6d6e5ddf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_315013710fdccfb332b772bab6392c95 = $(`&lt;div id=&quot;html_315013710fdccfb332b772bab6392c95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1c134b826fbb3107a76dd64a6d6e5ddf.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_4d0676d876bd816757f79006eb59a1b4 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_4d0676d876bd816757f79006eb59a1b4&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_4d0676d876bd816757f79006eb59a1b4 = L.map(
#                 &quot;map_4d0676d876bd816757f79006eb59a1b4&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_e9ab844e690ed5d9e3e4dbf2013822ea = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e9ab844e690ed5d9e3e4dbf2013822ea.addTo(map_4d0676d876bd816757f79006eb59a1b4);
#
#
#             var feature_group_b7a4d63dfdb9be813f6b8cd53fee8926 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_3e2de47017a90fe8f5ca4b9d21a9d330 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_b7a4d63dfdb9be813f6b8cd53fee8926);
#
#
#         var popup_6aa428be85e9912ff742bda579cde997 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_20aa6b4d07fd70c96c64e140b4971c90 = $(`&lt;div id=&quot;html_20aa6b4d07fd70c96c64e140b4971c90&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_6aa428be85e9912ff742bda579cde997.setContent(html_20aa6b4d07fd70c96c64e140b4971c90);
#
#
#
#         marker_3e2de47017a90fe8f5ca4b9d21a9d330.bindPopup(popup_6aa428be85e9912ff742bda579cde997)
#         ;
#
#
#
#
#             var marker_66a977e096de947880a2780c75f7802d = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_b7a4d63dfdb9be813f6b8cd53fee8926);
#
#
#         var popup_beb0235f9f62b8920e5e5c82a6658053 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0a3da62f302f144cd36818056a14666c = $(`&lt;div id=&quot;html_0a3da62f302f144cd36818056a14666c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_beb0235f9f62b8920e5e5c82a6658053.setContent(html_0a3da62f302f144cd36818056a14666c);
#
#
#
#         marker_66a977e096de947880a2780c75f7802d.bindPopup(popup_beb0235f9f62b8920e5e5c82a6658053)
#         ;
#
#
#
#
#             var marker_49c782d92a90ddf82fdd45ecb0b40603 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_b7a4d63dfdb9be813f6b8cd53fee8926);
#
#
#         var popup_e7d2bb0f5edeff7647fc6d2d7c06cb3e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7e3bbbd636da9913156dd3c184f4edc9 = $(`&lt;div id=&quot;html_7e3bbbd636da9913156dd3c184f4edc9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_e7d2bb0f5edeff7647fc6d2d7c06cb3e.setContent(html_7e3bbbd636da9913156dd3c184f4edc9);
#
#
#
#         marker_49c782d92a90ddf82fdd45ecb0b40603.bindPopup(popup_e7d2bb0f5edeff7647fc6d2d7c06cb3e)
#         ;
#
#
#
#
#             var marker_f5930044239a3d4d3c1edd89e42159d6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_b7a4d63dfdb9be813f6b8cd53fee8926);
#
#
#         var popup_cb01d48c15b36dcdee26777cac1f23fe = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21dd8a1f47d423742dd27f4a8d4e38ba = $(`&lt;div id=&quot;html_21dd8a1f47d423742dd27f4a8d4e38ba&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_cb01d48c15b36dcdee26777cac1f23fe.setContent(html_21dd8a1f47d423742dd27f4a8d4e38ba);
#
#
#
#         marker_f5930044239a3d4d3c1edd89e42159d6.bindPopup(popup_cb01d48c15b36dcdee26777cac1f23fe)
#         ;
#
#
#
#
#             var marker_4c6a66807867e9492c8b4fd6b446fd9d = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_b7a4d63dfdb9be813f6b8cd53fee8926);
#
#
#         var popup_653a33a02aa5d17d62a809bd3c389821 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a3616f331d8c8e8c5ef592c67b54391f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a3616f331d8c8e8c5ef592c67b54391f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a3616f331d8c8e8c5ef592c67b54391f = L.map(
#                 &quot;map_a3616f331d8c8e8c5ef592c67b54391f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4a2fa5cf56efbbadda0ebe37cb5dddc8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_4a2fa5cf56efbbadda0ebe37cb5dddc8.addTo(map_a3616f331d8c8e8c5ef592c67b54391f);
#
#
#             var feature_group_ed4c227d66b1751dc51d8ec92e33d915 = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_ed4c227d66b1751dc51d8ec92e33d915.addTo(map_a3616f331d8c8e8c5ef592c67b54391f);
#
#
#             var feature_group_sub_group_8b6d589eb4f47c03c27fc25c583e06ef = L.featureGroup.subGroup(
#                 feature_group_ed4c227d66b1751dc51d8ec92e33d915
#             );
#
#
#             var marker_00093e1031104734ec87d7cea5c84716 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_8b6d589eb4f47c03c27fc25c583e06ef);
#
#
#         var popup_0c5c905039f2a6830d8421e67c2bb9e9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6bcd96f7ad9e2f8eaa34880c6e381cde = $(`&lt;div id=&quot;html_6bcd96f7ad9e2f8eaa34880c6e381cde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0c5c905039f2a6830d8421e67c2bb9e9.setContent(html_6bcd96f7ad9e2f8eaa34880c6e381cde);
#
#
#
#         marker_00093e1031104734ec87d7cea5c84716.bindPopup(popup_0c5c905039f2a6830d8421e67c2bb9e9)
#         ;
#
#
#
#
#             var marker_7a7b398bb56f95ad20b59ed378fa23a0 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_8b6d589eb4f47c03c27fc25c583e06ef);
#
#
#         var popup_d988a649418e1d14f7651465d676af38 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5a095b7a3b5f965eafeb34ab9cdc711e = $(`&lt;div id=&quot;html_5a095b7a3b5f965eafeb34ab9cdc711e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_d988a649418e1d14f7651465d676af38.setContent(html_5a095b7a3b5f965eafeb34ab9cdc711e);
#
#
#
#         marker_7a7b398bb56f95ad20b59ed378fa23a0.bindPopup(popup_d988a649418e1d14f7651465d676af38)
#         ;
#
#
#
#
#             var marker_943214b01cc04df67196069d39aa132a = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_8b6d589eb4f47c03c27fc25c583e06ef);
#
#
#         var popup_5d89374d09cb769ee6406a992d50db88 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_41b176655c40b8ac4ca4629621fbd4a8 = $(`&lt;div id=&quot;html_41b176655c40b8ac4ca4629621fbd4a8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_5d89374d09cb769ee6406a992d50db88.setContent(html_41b176655c40b8ac4ca4629621fbd4a8);
#
#
#
#         marker_943214b01cc04df67196069d39aa132a.bindPopup(popup_5d89374d09cb769ee6406a992d50db88)
#         ;
#
#
#
#
#             var marker_11e8b43d973f84c25b49426ec1e16016 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_8b6d589eb4f47c03c27fc25c583e06ef);
#
#
#         var popup_b891ae85e084313089906b5a12445b55 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a826e1f594262307522867e6fed2f613 = $(`&lt;div id=&quot;html_a826e1f594262307522867e6fed2f613&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_b891ae85e084313089906b5a12445b55.setContent(html_a826e1f594262307522867e6fed2f613);
#
#
#
#         marker_
