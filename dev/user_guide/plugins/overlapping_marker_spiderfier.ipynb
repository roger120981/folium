# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_cc49a4a654940302a88c4459c1b060b5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_cc49a4a654940302a88c4459c1b060b5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_cc49a4a654940302a88c4459c1b060b5 = L.map(
#                 &quot;map_cc49a4a654940302a88c4459c1b060b5&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_67b193cc872a834f7e8ccf76731f17b0 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_67b193cc872a834f7e8ccf76731f17b0.addTo(map_cc49a4a654940302a88c4459c1b060b5);
#
#
#             var marker_899ee66a604e28c0957bcba0f4f3f60d = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_cc49a4a654940302a88c4459c1b060b5);
#
#
#         var popup_19c6d052192a61cfc5029fa1bc178d50 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9a60c75cef3b899710e70b27942b81bf = $(`&lt;div id=&quot;html_9a60c75cef3b899710e70b27942b81bf&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_19c6d052192a61cfc5029fa1bc178d50.setContent(html_9a60c75cef3b899710e70b27942b81bf);
#
#
#
#         marker_899ee66a604e28c0957bcba0f4f3f60d.bindPopup(popup_19c6d052192a61cfc5029fa1bc178d50)
#         ;
#
#
#
#
#             var marker_62f2eb80769ce4cd7d999255d16486f1 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_cc49a4a654940302a88c4459c1b060b5);
#
#
#         var popup_d40f2a0dc1ae79c7eb1c682205e7a1da = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8fa693bd72f2881b44a9bb9b86cd3d2f = $(`&lt;div id=&quot;html_8fa693bd72f2881b44a9bb9b86cd3d2f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_d40f2a0dc1ae79c7eb1c682205e7a1da.setContent(html_8fa693bd72f2881b44a9bb9b86cd3d2f);
#
#
#
#         marker_62f2eb80769ce4cd7d999255d16486f1.bindPopup(popup_d40f2a0dc1ae79c7eb1c682205e7a1da)
#         ;
#
#
#
#
#             var marker_fb9459a13da55a75ab841dcc504a90ee = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_cc49a4a654940302a88c4459c1b060b5);
#
#
#         var popup_c3df2936346a7e8f597e606ea47f3f67 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a28614c44d6d473f4bd59fc8e691beeb = $(`&lt;div id=&quot;html_a28614c44d6d473f4bd59fc8e691beeb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_c3df2936346a7e8f597e606ea47f3f67.setContent(html_a28614c44d6d473f4bd59fc8e691beeb);
#
#
#
#         marker_fb9459a13da55a75ab841dcc504a90ee.bindPopup(popup_c3df2936346a7e8f597e606ea47f3f67)
#         ;
#
#
#
#
#             var marker_b7e2f418a0785726764c7b80c40180f4 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_cc49a4a654940302a88c4459c1b060b5);
#
#
#         var popup_1b2c3ac7f1a0ec852cc1220a346f8201 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21a2ffdf4d5a0a7809fbf625f3f6e42c = $(`&lt;div id=&quot;html_21a2ffdf4d5a0a7809fbf625f3f6e42c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_1b2c3ac7f1a0ec852cc1220a346f8201.setContent(html_21a2ffdf4d5a0a7809fbf625f3f6e42c);
#
#
#
#         marker_b7e2f418a0785726764c7b80c40180f4.bindPopup(popup_1b2c3ac7f1a0ec852cc1220a346f8201)
#         ;
#
#
#
#
#             var marker_c2217c882c1ac9200e3b7c657127b0a6 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_cc49a4a654940302a88c4459c1b060b5);
#
#
#         var popup_1a3c9b7f91ecc1e818d05c1180807dd6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_da5c71a90fbeab68843851d286ef37b0 = $(`&lt;div id=&quot;html_da5c71a90fbeab68843851d286ef37b0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_1a3c9b7f91ecc1e818d05c1180807dd6.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b4a7163a6e7a4a5e47cbff3d18a8de69 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b4a7163a6e7a4a5e47cbff3d18a8de69&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_b4a7163a6e7a4a5e47cbff3d18a8de69 = L.map(
#                 &quot;map_b4a7163a6e7a4a5e47cbff3d18a8de69&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_49d97cf60648322af3279dd80f9190b8 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_49d97cf60648322af3279dd80f9190b8.addTo(map_b4a7163a6e7a4a5e47cbff3d18a8de69);
#
#
#             var feature_group_01688b2ca31aeb031c6eb4e77321f9ea = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_1f98067ed15fa0d69f902511a9c85e16 = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_01688b2ca31aeb031c6eb4e77321f9ea);
#
#
#         var popup_a54c6c5c0109e496e754dff31f134ddf = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2a08e500af9d4baecf0dae12d075471f = $(`&lt;div id=&quot;html_2a08e500af9d4baecf0dae12d075471f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_a54c6c5c0109e496e754dff31f134ddf.setContent(html_2a08e500af9d4baecf0dae12d075471f);
#
#
#
#         marker_1f98067ed15fa0d69f902511a9c85e16.bindPopup(popup_a54c6c5c0109e496e754dff31f134ddf)
#         ;
#
#
#
#
#             var marker_158cb707c08c6c17705008683bef5a59 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_01688b2ca31aeb031c6eb4e77321f9ea);
#
#
#         var popup_28955a22e4d21ce9bb67460b87291743 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c2b13df7adf00d603996af7dd3382080 = $(`&lt;div id=&quot;html_c2b13df7adf00d603996af7dd3382080&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_28955a22e4d21ce9bb67460b87291743.setContent(html_c2b13df7adf00d603996af7dd3382080);
#
#
#
#         marker_158cb707c08c6c17705008683bef5a59.bindPopup(popup_28955a22e4d21ce9bb67460b87291743)
#         ;
#
#
#
#
#             var marker_90fe1c74ff0ecd256a21ebed82ca7848 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_01688b2ca31aeb031c6eb4e77321f9ea);
#
#
#         var popup_5c553947e5f58f2124815ef0b0e7dbb5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f9a8fa9cac46f1c827bf399ea3cb8ae1 = $(`&lt;div id=&quot;html_f9a8fa9cac46f1c827bf399ea3cb8ae1&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_5c553947e5f58f2124815ef0b0e7dbb5.setContent(html_f9a8fa9cac46f1c827bf399ea3cb8ae1);
#
#
#
#         marker_90fe1c74ff0ecd256a21ebed82ca7848.bindPopup(popup_5c553947e5f58f2124815ef0b0e7dbb5)
#         ;
#
#
#
#
#             var marker_cc768f5ebb7694655d12a352025e8aa6 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_01688b2ca31aeb031c6eb4e77321f9ea);
#
#
#         var popup_7f6b0dd6eab77d5b50b2e45668d5a070 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_efedadc33e074fb20821868290d72d6a = $(`&lt;div id=&quot;html_efedadc33e074fb20821868290d72d6a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_7f6b0dd6eab77d5b50b2e45668d5a070.setContent(html_efedadc33e074fb20821868290d72d6a);
#
#
#
#         marker_cc768f5ebb7694655d12a352025e8aa6.bindPopup(popup_7f6b0dd6eab77d5b50b2e45668d5a070)
#         ;
#
#
#
#
#             var marker_85673296a111c2c6389d975cd8936c10 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_01688b2ca31aeb031c6eb4e77321f9ea);
#
#
#         var popup_26a52ae426e4052aeea621579120dc02 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d5ffb2b79955dff753682afc895914be {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d5ffb2b79955dff753682afc895914be&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d5ffb2b79955dff753682afc895914be = L.map(
#                 &quot;map_d5ffb2b79955dff753682afc895914be&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_57025c573bbfbc9fa7591dbee5c88a8b = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_57025c573bbfbc9fa7591dbee5c88a8b.addTo(map_d5ffb2b79955dff753682afc895914be);
#
#
#             var feature_group_069bca4a92e5e7037f9c36f338e406ec = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_069bca4a92e5e7037f9c36f338e406ec.addTo(map_d5ffb2b79955dff753682afc895914be);
#
#
#             var feature_group_sub_group_4690e261974c024825ed0576fd97a265 = L.featureGroup.subGroup(
#                 feature_group_069bca4a92e5e7037f9c36f338e406ec
#             );
#
#
#             var marker_7fdfb6fe3dd87b8521b6897b3c07f49f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_4690e261974c024825ed0576fd97a265);
#
#
#         var popup_fa6089c843aecc5f614be312725baf2e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98f26e9c76f3cec69ce40ff38951dc2b = $(`&lt;div id=&quot;html_98f26e9c76f3cec69ce40ff38951dc2b&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_fa6089c843aecc5f614be312725baf2e.setContent(html_98f26e9c76f3cec69ce40ff38951dc2b);
#
#
#
#         marker_7fdfb6fe3dd87b8521b6897b3c07f49f.bindPopup(popup_fa6089c843aecc5f614be312725baf2e)
#         ;
#
#
#
#
#             var marker_15ca55e82006edf6ddda441ef0d85f77 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_4690e261974c024825ed0576fd97a265);
#
#
#         var popup_1658ec5d6e2aac10c7fc6b71404ad8a8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_95376a9fb56d339d8d825e596a2a63b5 = $(`&lt;div id=&quot;html_95376a9fb56d339d8d825e596a2a63b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_1658ec5d6e2aac10c7fc6b71404ad8a8.setContent(html_95376a9fb56d339d8d825e596a2a63b5);
#
#
#
#         marker_15ca55e82006edf6ddda441ef0d85f77.bindPopup(popup_1658ec5d6e2aac10c7fc6b71404ad8a8)
#         ;
#
#
#
#
#             var marker_82adfb6c24ea2735b50afc4fe66a6ca5 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_4690e261974c024825ed0576fd97a265);
#
#
#         var popup_754438f8287f3bff81275b6397fd7142 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_500e2dd5ff2190061b82eded817c85e4 = $(`&lt;div id=&quot;html_500e2dd5ff2190061b82eded817c85e4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_754438f8287f3bff81275b6397fd7142.setContent(html_500e2dd5ff2190061b82eded817c85e4);
#
#
#
#         marker_82adfb6c24ea2735b50afc4fe66a6ca5.bindPopup(popup_754438f8287f3bff81275b6397fd7142)
#         ;
#
#
#
#
#             var marker_e295ce929841368238103274df05f374 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_4690e261974c024825ed0576fd97a265);
#
#
#         var popup_e579d9717687cf350fcad8dd43647d53 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ce037f3edbd8a411e60927f228783242 = $(`&lt;div id=&quot;html_ce037f3edbd8a411e60927f228783242&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_e579d9717687cf350fcad8dd43647d53.setContent(html_ce037f3edbd8a411e60927f228783242);
#
#
#
#         marker_
