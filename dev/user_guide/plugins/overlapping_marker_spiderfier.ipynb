# %% [markdown]
# # OverlappingMarkerSpiderfier
#
# The `OverlappingMarkerSpiderfier` is a plugin for Folium that helps manage overlapping markers by "spiderfying" them when clicked, making it easier to select individual markers.
#
# ## Using with Markers

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Add markers to the map
for i in range(20):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Marker {i}"
    ).add_to(m)

# Add the OverlappingMarkerSpiderfier plugin
oms = OverlappingMarkerSpiderfier(
    keep_spiderfied=True,  # Markers remain spiderfied after clicking
    nearby_distance=20,  # Distance for clustering markers in pixel
    circle_spiral_switchover=10,  # Threshold for switching between circle and spiral
    leg_weight=2.0  # Line thickness for spider legs
    )
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a5a33b2cbe7764bc6c0c30c0e05c7954 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a5a33b2cbe7764bc6c0c30c0e05c7954&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a5a33b2cbe7764bc6c0c30c0e05c7954 = L.map(
#                 &quot;map_a5a33b2cbe7764bc6c0c30c0e05c7954&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f45c5204e3fc988cce5cf6964c26ac99 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f45c5204e3fc988cce5cf6964c26ac99.addTo(map_a5a33b2cbe7764bc6c0c30c0e05c7954);
#
#
#             var marker_ba9c3f93a1649bec1ddba30eac6d60eb = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(map_a5a33b2cbe7764bc6c0c30c0e05c7954);
#
#
#         var popup_0457e2de6a45b2fbd535d5245bc5a1a6 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_07b976bfe8d129b7d540db5e2ae7748a = $(`&lt;div id=&quot;html_07b976bfe8d129b7d540db5e2ae7748a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 0&lt;/div&gt;`)[0];
#                 popup_0457e2de6a45b2fbd535d5245bc5a1a6.setContent(html_07b976bfe8d129b7d540db5e2ae7748a);
#
#
#
#         marker_ba9c3f93a1649bec1ddba30eac6d60eb.bindPopup(popup_0457e2de6a45b2fbd535d5245bc5a1a6)
#         ;
#
#
#
#
#             var marker_774c3b35b99c995f47c656bfba5a344e = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(map_a5a33b2cbe7764bc6c0c30c0e05c7954);
#
#
#         var popup_f052b24fbafafa179dcdec5ab2550cec = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_01f14677f57197daa27718cee9abb94c = $(`&lt;div id=&quot;html_01f14677f57197daa27718cee9abb94c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 1&lt;/div&gt;`)[0];
#                 popup_f052b24fbafafa179dcdec5ab2550cec.setContent(html_01f14677f57197daa27718cee9abb94c);
#
#
#
#         marker_774c3b35b99c995f47c656bfba5a344e.bindPopup(popup_f052b24fbafafa179dcdec5ab2550cec)
#         ;
#
#
#
#
#             var marker_7a79f030b768754ee0f08d68621483f4 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(map_a5a33b2cbe7764bc6c0c30c0e05c7954);
#
#
#         var popup_160007d13721203d5e85f3dcbc34a496 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d68b45515746398944004e9b306353c6 = $(`&lt;div id=&quot;html_d68b45515746398944004e9b306353c6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 2&lt;/div&gt;`)[0];
#                 popup_160007d13721203d5e85f3dcbc34a496.setContent(html_d68b45515746398944004e9b306353c6);
#
#
#
#         marker_7a79f030b768754ee0f08d68621483f4.bindPopup(popup_160007d13721203d5e85f3dcbc34a496)
#         ;
#
#
#
#
#             var marker_db90e6e2a2d8f658278469b502d90381 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(map_a5a33b2cbe7764bc6c0c30c0e05c7954);
#
#
#         var popup_04a34c26014b02c4e128157b00c88aff = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_753d2ffdb17d01d34a7e17aed84e4db3 = $(`&lt;div id=&quot;html_753d2ffdb17d01d34a7e17aed84e4db3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 3&lt;/div&gt;`)[0];
#                 popup_04a34c26014b02c4e128157b00c88aff.setContent(html_753d2ffdb17d01d34a7e17aed84e4db3);
#
#
#
#         marker_db90e6e2a2d8f658278469b502d90381.bindPopup(popup_04a34c26014b02c4e128157b00c88aff)
#         ;
#
#
#
#
#             var marker_fdf903b6a55a6f649654ba458288d03c = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(map_a5a33b2cbe7764bc6c0c30c0e05c7954);
#
#
#         var popup_7083e92cd331a938b72c6ec5603411a9 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_4a353c82a3c8d11e333cc66d948c2f6e = $(`&lt;div id=&quot;html_4a353c82a3c8d11e333cc66d948c2f6e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Marker 4&lt;/div&gt;`)[0];
#                 popup_7083e92cd331a938b72c6ec5603411a9.

# %% [markdown]
# ## Using with FeatureGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a FeatureGroup
feature_group = folium.FeatureGroup(name='Feature Group')

# Add markers to the FeatureGroup
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Feature Group Marker {i}"
    ).add_to(feature_group)

# Add the FeatureGroup to the map
feature_group.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_954282a487a2b0cc343777e3b9150765 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_954282a487a2b0cc343777e3b9150765&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_954282a487a2b0cc343777e3b9150765 = L.map(
#                 &quot;map_954282a487a2b0cc343777e3b9150765&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ce5529328b3bd2244eed6ba47fbcaad7 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ce5529328b3bd2244eed6ba47fbcaad7.addTo(map_954282a487a2b0cc343777e3b9150765);
#
#
#             var feature_group_62dbdb9be4e0e5a0b438d12488e30043 = L.featureGroup(
#                 {
# }
#             );
#
#
#             var marker_b472ae3cacfee316b32be37f0bad2a7f = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_62dbdb9be4e0e5a0b438d12488e30043);
#
#
#         var popup_e324cfe6eb2949367a50b8b49c2786bb = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_e3ad1ca7c600a587d91108b9a89a5ffb = $(`&lt;div id=&quot;html_e3ad1ca7c600a587d91108b9a89a5ffb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 0&lt;/div&gt;`)[0];
#                 popup_e324cfe6eb2949367a50b8b49c2786bb.setContent(html_e3ad1ca7c600a587d91108b9a89a5ffb);
#
#
#
#         marker_b472ae3cacfee316b32be37f0bad2a7f.bindPopup(popup_e324cfe6eb2949367a50b8b49c2786bb)
#         ;
#
#
#
#
#             var marker_22cea0afeff6ba5e684c2ca07934a32a = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_62dbdb9be4e0e5a0b438d12488e30043);
#
#
#         var popup_c6a88460b788ed0128182eb17e850008 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_eff1fba140fd3f47096d233f8c197fde = $(`&lt;div id=&quot;html_eff1fba140fd3f47096d233f8c197fde&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 1&lt;/div&gt;`)[0];
#                 popup_c6a88460b788ed0128182eb17e850008.setContent(html_eff1fba140fd3f47096d233f8c197fde);
#
#
#
#         marker_22cea0afeff6ba5e684c2ca07934a32a.bindPopup(popup_c6a88460b788ed0128182eb17e850008)
#         ;
#
#
#
#
#             var marker_8ab77e1916fc9e667fff1acb4df9e451 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_62dbdb9be4e0e5a0b438d12488e30043);
#
#
#         var popup_2b916a67c48d4934f7ccd024d86956b8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0f3427f31c36a561de5bcb5aa8a8eee8 = $(`&lt;div id=&quot;html_0f3427f31c36a561de5bcb5aa8a8eee8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 2&lt;/div&gt;`)[0];
#                 popup_2b916a67c48d4934f7ccd024d86956b8.setContent(html_0f3427f31c36a561de5bcb5aa8a8eee8);
#
#
#
#         marker_8ab77e1916fc9e667fff1acb4df9e451.bindPopup(popup_2b916a67c48d4934f7ccd024d86956b8)
#         ;
#
#
#
#
#             var marker_941e5606b71b990c5e0721a22b5d1469 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_62dbdb9be4e0e5a0b438d12488e30043);
#
#
#         var popup_23b823757949bc8f32f9f6fc6dd45495 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_982a3ee1ac6a4429364bc76a29534289 = $(`&lt;div id=&quot;html_982a3ee1ac6a4429364bc76a29534289&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Feature Group Marker 3&lt;/div&gt;`)[0];
#                 popup_23b823757949bc8f32f9f6fc6dd45495.setContent(html_982a3ee1ac6a4429364bc76a29534289);
#
#
#
#         marker_941e5606b71b990c5e0721a22b5d1469.bindPopup(popup_23b823757949bc8f32f9f6fc6dd45495)
#         ;
#
#
#
#
#             var marker_3229465cf54dca23489c958ba5ddfe76 = L.marker(
#                 [45.050399999999996, 3.0504],
#                 {
# }
#             ).addTo(feature_group_62dbdb9be4e0e5a0b438d12488e30043);
#
#
#         var popup_96fdd88e92417d5a4d5fd1f9f063dabd = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var ht

# %% [markdown]
# ## Using with FeatureGroupSubGroups

# %%
import folium
from folium.plugins import OverlappingMarkerSpiderfier, FeatureGroupSubGroup

# Create a map
m = folium.Map(location=[45.05, 3.05], zoom_start=13)

# Create a main FeatureGroup
main_group = folium.FeatureGroup(name='Main Group')

# Create sub-groups
sub_group1 = FeatureGroupSubGroup(main_group, name='Sub Group 1')
sub_group2 = FeatureGroupSubGroup(main_group, name='Sub Group 2')

# Add markers to the first sub-group
for i in range(10):
    folium.Marker(
        location=[45.05 + i * 0.0001, 3.05 + i * 0.0001],
        popup=f"Sub Group 1 Marker {i}"
    ).add_to(sub_group1)

# Add markers to the second sub-group
for i in range(10, 20):
    folium.Marker(
        location=[45.06 + (i - 10) * 0.0001, 3.06 + (i - 10) * 0.0001],
        popup=f"Sub Group 2 Marker {i}"
    ).add_to(sub_group2)

# Add the main group to the map
main_group.add_to(m)

# Add sub-groups to the map
sub_group1.add_to(m)
sub_group2.add_to(m)

# Initialize OverlappingMarkerSpiderfier
oms = OverlappingMarkerSpiderfier()
oms.add_to(m)

# Add the LayerControl plugin
folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_059c658b428662db19f4e0654d9dba3f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://unpkg.com/leaflet.featuregroup.subgroup@1.0.2/dist/leaflet.featuregroup.subgroup.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/OverlappingMarkerSpiderfier-Leaflet/0.2.6/oms.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_059c658b428662db19f4e0654d9dba3f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_059c658b428662db19f4e0654d9dba3f = L.map(
#                 &quot;map_059c658b428662db19f4e0654d9dba3f&quot;,
#                 {
#                     center: [45.05, 3.05],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 13,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_35023a722c0fff486f6cfdb592e6307a = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_35023a722c0fff486f6cfdb592e6307a.addTo(map_059c658b428662db19f4e0654d9dba3f);
#
#
#             var feature_group_fd9e0b92af2c55af3ce2f4b0717662cc = L.featureGroup(
#                 {
# }
#             );
#
#
#             feature_group_fd9e0b92af2c55af3ce2f4b0717662cc.addTo(map_059c658b428662db19f4e0654d9dba3f);
#
#
#             var feature_group_sub_group_ed663f3edb51358dfe0683e05805ebce = L.featureGroup.subGroup(
#                 feature_group_fd9e0b92af2c55af3ce2f4b0717662cc
#             );
#
#
#             var marker_6a7d5091ca7bfe0d985ee458dd14dcff = L.marker(
#                 [45.05, 3.05],
#                 {
# }
#             ).addTo(feature_group_sub_group_ed663f3edb51358dfe0683e05805ebce);
#
#
#         var popup_0a9d1394d77cbb9384d04e09c84fa3db = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_43247ea7e8d830e49ebba728b106d3b6 = $(`&lt;div id=&quot;html_43247ea7e8d830e49ebba728b106d3b6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 0&lt;/div&gt;`)[0];
#                 popup_0a9d1394d77cbb9384d04e09c84fa3db.setContent(html_43247ea7e8d830e49ebba728b106d3b6);
#
#
#
#         marker_6a7d5091ca7bfe0d985ee458dd14dcff.bindPopup(popup_0a9d1394d77cbb9384d04e09c84fa3db)
#         ;
#
#
#
#
#             var marker_41dd1f7b58f12fad61ad776f3deac6c7 = L.marker(
#                 [45.0501, 3.0501],
#                 {
# }
#             ).addTo(feature_group_sub_group_ed663f3edb51358dfe0683e05805ebce);
#
#
#         var popup_3deeb04b12d9be6f6aae674474683009 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0fe5ecccf55158647906c431cb9d41c5 = $(`&lt;div id=&quot;html_0fe5ecccf55158647906c431cb9d41c5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 1&lt;/div&gt;`)[0];
#                 popup_3deeb04b12d9be6f6aae674474683009.setContent(html_0fe5ecccf55158647906c431cb9d41c5);
#
#
#
#         marker_41dd1f7b58f12fad61ad776f3deac6c7.bindPopup(popup_3deeb04b12d9be6f6aae674474683009)
#         ;
#
#
#
#
#             var marker_522008fa0ee9004a91d831a7cf260d89 = L.marker(
#                 [45.0502, 3.0502],
#                 {
# }
#             ).addTo(feature_group_sub_group_ed663f3edb51358dfe0683e05805ebce);
#
#
#         var popup_1a0868901b15df1fb2b5e2c5ab4a2275 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_5e0a3eaf139a2748663876604535a54e = $(`&lt;div id=&quot;html_5e0a3eaf139a2748663876604535a54e&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 2&lt;/div&gt;`)[0];
#                 popup_1a0868901b15df1fb2b5e2c5ab4a2275.setContent(html_5e0a3eaf139a2748663876604535a54e);
#
#
#
#         marker_522008fa0ee9004a91d831a7cf260d89.bindPopup(popup_1a0868901b15df1fb2b5e2c5ab4a2275)
#         ;
#
#
#
#
#             var marker_fe22c28d9079facc712f84a79b1cbcc2 = L.marker(
#                 [45.0503, 3.0503],
#                 {
# }
#             ).addTo(feature_group_sub_group_ed663f3edb51358dfe0683e05805ebce);
#
#
#         var popup_672419fc2107843f729f8f57c49d819e = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_14b4871c219a18b990f7896be1a3ba4d = $(`&lt;div id=&quot;html_14b4871c219a18b990f7896be1a3ba4d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Sub Group 1 Marker 3&lt;/div&gt;`)[0];
#                 popup_672419fc2107843f729f8f57c49d819e.setContent(html_14b4871c219a18b990f7896be1a3ba4d);
#
#
#
#         marker_
