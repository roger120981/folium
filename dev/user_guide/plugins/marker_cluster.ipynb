# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e60cb42e921518497ab40b10c0cb18ed {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e60cb42e921518497ab40b10c0cb18ed&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e60cb42e921518497ab40b10c0cb18ed = L.map(
#                 &quot;map_e60cb42e921518497ab40b10c0cb18ed&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_433f3c2743145bcadfd66d49e31b1c63 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_433f3c2743145bcadfd66d49e31b1c63.addTo(map_e60cb42e921518497ab40b10c0cb18ed);
#
#
#             var marker_cluster_48c2e747e90bda0213df6c66fdf16bb3 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_9a22cbc343e85f8b0bac2bdea74fbb5d = L.marker(
#                 [40.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_48c2e747e90bda0213df6c66fdf16bb3);
#
#
#             var icon_dc01c47de38e4c44c350ad40a29649e0 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;ok-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_57027377df2551da0f2bb0fbb1724e23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2461755122e7731485c6ad9dcfc05b1a = $(`&lt;div id=&quot;html_2461755122e7731485c6ad9dcfc05b1a&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_57027377df2551da0f2bb0fbb1724e23.setContent(html_2461755122e7731485c6ad9dcfc05b1a);
#
#
#
#         marker_9a22cbc343e85f8b0bac2bdea74fbb5d.bindPopup(popup_57027377df2551da0f2bb0fbb1724e23)
#         ;
#
#
#
#
#                 marker_9a22cbc343e85f8b0bac2bdea74fbb5d.setIcon(icon_dc01c47de38e4c44c350ad40a29649e0);
#
#
#             var marker_3741845aeae16171cff3f7e7fd2bfde3 = L.marker(
#                 [44.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_48c2e747e90bda0213df6c66fdf16bb3);
#
#
#             var icon_0fcb08089fb60f3e124caad2137aefb6 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_2b62f390fbccc793fe7ac6a16c2a11b5 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_bc1bf03b3048dcb1c45eca4dbcfb7b50 = $(`&lt;div id=&quot;html_bc1bf03b3048dcb1c45eca4dbcfb7b50&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_2b62f390fbccc793fe7ac6a16c2a11b5.setContent(html_bc1bf03b3048dcb1c45eca4dbcfb7b50);
#
#
#
#         marker_3741845aeae16171cff3f7e7fd2bfde3.bindPopup(popup_2b62f390fbccc793fe7ac6a16c2a11b5)
#         ;
#
#
#
#
#                 marker_3741845aeae16171cff3f7e7fd2bfde3.setIcon(icon_0fcb08089fb60f3e124caad2137aefb6);
#
#
#             var marker_b741807e899a5eb71bd292f11ca3ccfa = L.marker(
#                 [44.67, -71.94],
#                 {
# }
#             ).addTo(marker_cluster_48c2e747e90bda0213df6c66fdf16bb3);
#
#
#         var popup_ad80aae936b4215ca17d2c5b72cc2724 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_2d489c61c422b9c9b44f5ba2f74801c4 = $(`&lt;div id=&quot;html_2d489c61c422b9c9b44f5ba2f74801c4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_ad80aae936b4215ca17d2c5b72cc2724.setContent(html_2d489c61c422b9c9b44f5ba2f74801c4);
#
#
#
#         marker_b741807e899a5eb71bd292f11ca3ccfa.

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8160efdb1c42abdb0d1c343074a4d668 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8160efdb1c42abdb0d1c343074a4d668&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8160efdb1c42abdb0d1c343074a4d668 = L.map(
#                 &quot;map_8160efdb1c42abdb0d1c343074a4d668&quot;,
#                 {
#                     center: [-3.44, -0.85],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_62f485e4ecc911da82a7c98bc2d07c42 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_62f485e4ecc911da82a7c98bc2d07c42.addTo(map_8160efdb1c42abdb0d1c343074a4d668);
#
#
#             var marker_cluster_3bd8cd84181165eda9c97ab118c2ee52 = L.markerClusterGroup(
#                 {
# }
#             );
#             marker_cluster_3bd8cd84181165eda9c97ab118c2ee52.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_c35d16b9a3cd59f0dd8f6733325f565a = L.marker(
#                 [72.0, 152.0],
#                 {
# }
#             ).addTo(marker_cluster_3bd8cd84181165eda9c97ab118c2ee52);
#
#
#         var popup_d8bba9cd0348cbd6e24645c396498ecc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ec05e78beac0c13d97a749fb53370c0c = $(`&lt;div id=&quot;html_ec05e78beac0c13d97a749fb53370c0c&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:152&lt;br&gt;lat:72&lt;/div&gt;`)[0];
#                 popup_d8bba9cd0348cbd6e24645c396498ecc.setContent(html_ec05e78beac0c13d97a749fb53370c0c);
#
#
#
#         marker_c35d16b9a3cd59f0dd8f6733325f565a.bindPopup(popup_d8bba9cd0348cbd6e24645c396498ecc)
#         ;
#
#
#
#
#             var marker_8d5ae9e8abc19972e18c379696d2db13 = L.marker(
#                 [42.0, 140.0],
#                 {
# }
#             ).addTo(marker_cluster_3bd8cd84181165eda9c97ab118c2ee52);
#
#
#         var popup_5a72ffbba3aa1d5904f19f4917afe0e2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_96cd2a4d408c063577cad4358d058beb = $(`&lt;div id=&quot;html_96cd2a4d408c063577cad4358d058beb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:140&lt;br&gt;lat:42&lt;/div&gt;`)[0];
#                 popup_5a72ffbba3aa1d5904f19f4917afe0e2.setContent(html_96cd2a4d408c063577cad4358d058beb);
#
#
#
#         marker_8d5ae9e8abc19972e18c379696d2db13.bindPopup(popup_5a72ffbba3aa1d5904f19f4917afe0e2)
#         ;
#
#
#
#
#             var marker_3b8f994e9b792bf5dfda32af8a38f5ea = L.marker(
#                 [74.0, 175.0],
#                 {
# }
#             ).addTo(marker_cluster_3bd8cd84181165eda9c97ab118c2ee52);
#
#
#         var popup_3245c84685b29d0ee58e32380954f426 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_cb9f31acdc55881edfc6835b549f8444 = $(`&lt;div id=&quot;html_cb9f31acdc55881edfc6835b549f8444&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:175&lt;br&gt;lat:74&lt;/div&gt;`)[0];
#                 popup_3245c84685b29d0ee58e32380954f426.setContent(html_cb9f31acdc55881edfc6835b549f8444);
#
#
#
#         marker_3b8f994e9b792bf5dfda32af8a38f5ea.bindPopup(popup_3245c84685b29d0ee58e32380954f426)
#         ;
#
#
#
#
#             var marker_67822a5a68863cc49ee6e17efafb9d8f = L.marker(
#                 [21.0, -79.0],
#                 {
# }
#             ).addTo(marker_cluster_3bd8cd84181165eda9c97ab118c2ee52);
#
#
#         var popup_ab9387ed32cfd469f40c63cf44718930 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_78de2847c798fc768eaea116ef7cd6ec = $(`&lt;div id=&quot;html_78d

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6fd8b40531e3f24d328e2f92b7cebc05 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6fd8b40531e3f24d328e2f92b7cebc05&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_6fd8b40531e3f24d328e2f92b7cebc05 = L.map(
#                 &quot;map_6fd8b40531e3f24d328e2f92b7cebc05&quot;,
#                 {
#                     center: [-3.44, -0.85],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_63b43c67ccd26959eb0afc2e842630ed = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_63b43c67ccd26959eb0afc2e842630ed.addTo(map_6fd8b40531e3f24d328e2f92b7cebc05);
#
#
#             var marker_cluster_3c4bedf9ccd244cf22ea2b21e9a8efee = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_db894e1d4bc68a0e940285e8099e879f = L.marker(
#                 [72.0, 152.0],
#                 {
# }
#             ).addTo(marker_cluster_3c4bedf9ccd244cf22ea2b21e9a8efee);
#
#
#         var popup_a79c5c5a044d3b3a880ab967de9e5534 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_c1ed3bf972dd603e6e2a3363c1224d00 = $(`&lt;div id=&quot;html_c1ed3bf972dd603e6e2a3363c1224d00&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:152&lt;br&gt;lat:72&lt;/div&gt;`)[0];
#                 popup_a79c5c5a044d3b3a880ab967de9e5534.setContent(html_c1ed3bf972dd603e6e2a3363c1224d00);
#
#
#
#         marker_db894e1d4bc68a0e940285e8099e879f.bindPopup(popup_a79c5c5a044d3b3a880ab967de9e5534)
#         ;
#
#
#
#
#             var marker_737c72138d4b8b42b2485c67ea72c346 = L.marker(
#                 [42.0, 140.0],
#                 {
# }
#             ).addTo(marker_cluster_3c4bedf9ccd244cf22ea2b21e9a8efee);
#
#
#         var popup_16da0d00e16dc9c7d58d9f853c6f367b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7b9c7aa5b718506688dc681620c09827 = $(`&lt;div id=&quot;html_7b9c7aa5b718506688dc681620c09827&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:140&lt;br&gt;lat:42&lt;/div&gt;`)[0];
#                 popup_16da0d00e16dc9c7d58d9f853c6f367b.setContent(html_7b9c7aa5b718506688dc681620c09827);
#
#
#
#         marker_737c72138d4b8b42b2485c67ea72c346.bindPopup(popup_16da0d00e16dc9c7d58d9f853c6f367b)
#         ;
#
#
#
#
#             var marker_30111f962ae70fe1c0835267dc798e82 = L.marker(
#                 [74.0, 175.0],
#                 {
# }
#             ).addTo(marker_cluster_3c4bedf9ccd244cf22ea2b21e9a8efee);
#
#
#         var popup_8462653fc951f89215f44b661933d45b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_279a49b720786f0c93d0c3a759aab430 = $(`&lt;div id=&quot;html_279a49b720786f0c93d0c3a759aab430&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:175&lt;br&gt;lat:74&lt;/div&gt;`)[0];
#                 popup_8462653fc951f89215f44b661933d45b.setContent(html_279a49b720786f0c93d0c3a759aab430);
#
#
#
#         marker_30111f962ae70fe1c0835267dc798e82.bindPopup(popup_8462653fc951f89215f44b661933d45b)
#         ;
#
#
#
#
#             var marker_119a1ad403e793a7647f348e2d021b7b = L.marker(
#                 [21.0, -79.0],
#                 {
# }
#             ).addTo(marker_cluster_3c4bedf9ccd244cf22ea2b21e9a8efee);
#
#
#         var popup_57e713fa787bfea61697dbc8a4266d23 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_8cfa9724b64afd91537d811d5c1fee34 = $(`&lt;div id=&quot;html_8cfa9724b64afd91537d811d5c1fee34&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-79&lt;br&gt;lat:21&lt;/div&gt;`)[0];
#                 popup_57e713fa787bfea61697dbc8a4266d23.setContent(html_8cfa9724b64afd91537d811d5c1fee34);
#
#
#
#         marker_119a1ad403e793a7647f348e2d021b7b.bindPopup(popup_57e713fa787bfea616

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_66a10188c9c9b9327aba255caa9c956a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_66a10188c9c9b9327aba255caa9c956a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_66a10188c9c9b9327aba255caa9c956a = L.map(
#                 &quot;map_66a10188c9c9b9327aba255caa9c956a&quot;,
#                 {
#                     center: [-3.44, -0.85],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_ed5a4e212598cfed26ac0386f59fe4c3 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_ed5a4e212598cfed26ac0386f59fe4c3.addTo(map_66a10188c9c9b9327aba255caa9c956a);
#
#
#             var fast_marker_cluster_10c2faf1331c69d147462ac4e3f3b1df = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[72.0, 152.0], [42.0, 140.0], [74.0, 175.0], [21.0, -79.0], [-66.0, 165.0], [-44.0, -13.0], [-35.0, 150.0], [58.0, -63.0], [-38.0, 2.0], [-44.0, -23.0], [-68.0, -50.0], [-76.0, 161.0], [-65.0, 23.0], [-55.0, -67.0], [41.0, -4.0], [68.0, -1.0], [-28.0, -91.0], [-87.0, -160.0], [12.0, -31.0], [88.0, 112.0], [0.0, -7.0], [41.0, -81.0], [27.0, -71.0], [58.0, 110.0], [73.0, -2.0], [-65.0, 52.0], [-85.0, -120.0], [-26.0, 90.0], [-59.0, -86.0], [-21.0, 55.0], [-17.0, -116.0], [-32.0, -80.0], [57.0, 164.0], [-17.0, -118.0], [-36.0, 45.0], [-33.0, -90.0], [-26.0, 97.0], [-9.0, -90.0], [27.0, 138.0], [-68.0, 83.0], [-85.0, -128.0], [-24.0, 151.0], [-81.0, 158.0], [-66.0, -165.0], [-86.0, -101.0], [48.0, -36.0], [7.0, 5.0], [46.0, 112.0], [-18.0, -92.0], [-39.0, -150.0], [41.0, -169.0], [-25.0, -70.0], [30.0, -92.0], [-13.0, -13.0], [-12.0, 116.0], [-10.0, 96.0], [-13.0, -116.0], [23.0, -105.0], [56.0, 158.0], [-30.0, -166.0], [13.0, -149.0], [-30.0, -22.0], [77.0, -141.0], [81.0, -53.0], [40.0, 149.0], [53.0, -144.0], [-70.0, -125.0], [-33.0, -178.0], [51.0, -133.0], [-35.0, 1.0], [86.0, 23.0], [-87.0, -106.0], [2.0, 175.0], [31.0, 126.0], [-53.0, 170.0], [28.0, 165.0], [-74.0, -94.0], [-66.0, -130.0], [54.0, -2.0], [-17.0, -179.0], [-76.0, 90.0], [61.0, -76.0], [7.0, 76.0], [22.0, 178.0], [-20.0, -75.0], [30.0, 139.0], [6.0, -34.0], [21.0, 20.0], [72.0, 168.0], [-5.0, -143.0], [25.0, 44.0], [-41.0, 88.0], [54.0, -18.0], [23.0, -114.0], [-81.0, -5.0], [13.0, 42.0], [26.0, 151.0], [-32.0, -15.0], [5.0, 110.0], [87.0, 72.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_66a10188c9c9b9327aba255caa9c956a);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_10c2faf1331c69d147462ac4e3f3b1df.addTo(map_66a10188c9c9b9327aba255caa9c956a);
#
#
#             var layer_control_faa806244268446bdff55f14c46316b1_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_ed5a4e212598cfed26ac0386f59fe4c3,
#                 },
#                 overlays :  {
#                     &quot;macro_element_10c2faf1331c69d147462ac4e3f3b1df&quot; : fast_marker_cluster_10c2faf1331c69d147462ac4e3f3b1df,
#                 },
#             };
#             let layer_control_faa806244268446bdff55f14c46316b1 = L.control.layers(
#                 layer_control_faa806244268446bdff55f14c46316b1_layers.base_layers,
#                 layer_control_faa806244268446bdff55f14c46316b1_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_66a10188c9c9b9327aba255caa9c956a);
#
#
# &l

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_094bdaa31b774deadb748055da0ff15d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_094bdaa31b774deadb748055da0ff15d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_094bdaa31b774deadb748055da0ff15d = L.map(
#                 &quot;map_094bdaa31b774deadb748055da0ff15d&quot;,
#                 {
#                     center: [-3.44, -0.85],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_318dc2aee62e152e770611b08df31f8e = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_318dc2aee62e152e770611b08df31f8e.addTo(map_094bdaa31b774deadb748055da0ff15d);
#
#
#             var fast_marker_cluster_69672101709e763a7a8e0c61685f7cb4 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[72.0, 152.0], [42.0, 140.0], [74.0, 175.0], [21.0, -79.0], [-66.0, 165.0], [-44.0, -13.0], [-35.0, 150.0], [58.0, -63.0], [-38.0, 2.0], [-44.0, -23.0], [-68.0, -50.0], [-76.0, 161.0], [-65.0, 23.0], [-55.0, -67.0], [41.0, -4.0], [68.0, -1.0], [-28.0, -91.0], [-87.0, -160.0], [12.0, -31.0], [88.0, 112.0], [0.0, -7.0], [41.0, -81.0], [27.0, -71.0], [58.0, 110.0], [73.0, -2.0], [-65.0, 52.0], [-85.0, -120.0], [-26.0, 90.0], [-59.0, -86.0], [-21.0, 55.0], [-17.0, -116.0], [-32.0, -80.0], [57.0, 164.0], [-17.0, -118.0], [-36.0, 45.0], [-33.0, -90.0], [-26.0, 97.0], [-9.0, -90.0], [27.0, 138.0], [-68.0, 83.0], [-85.0, -128.0], [-24.0, 151.0], [-81.0, 158.0], [-66.0, -165.0], [-86.0, -101.0], [48.0, -36.0], [7.0, 5.0], [46.0, 112.0], [-18.0, -92.0], [-39.0, -150.0], [41.0, -169.0], [-25.0, -70.0], [30.0, -92.0], [-13.0, -13.0], [-12.0, 116.0], [-10.0, 96.0], [-13.0, -116.0], [23.0, -105.0], [56.0, 158.0], [-30.0, -166.0], [13.0, -149.0], [-30.0, -22.0], [77.0, -141.0], [81.0, -53.0], [40.0, 149.0], [53.0, -144.0], [-70.0, -125.0], [-33.0, -178.0], [51.0, -133.0], [-35.0, 1.0], [86.0, 23.0], [-87.0, -106.0], [2.0, 175.0], [31.0, 126.0], [-53.0, 170.0], [28.0, 165.0], [-74.0, -94.0], [-66.0, -130.0], [54.0, -2.0], [-17.0, -179.0], [-76.0, 90.0], [61.0, -76.0], [7.0, 76.0], [22.0, 178.0], [-20.0, -75.0], [30.0, 139.0], [6.0, -34.0], [21.0, 20.0], [72.0, 168.0], [-5.0, -143.0], [25.0, 44.0], [-41.0, 88.0], [54.0, -18.0], [23.0, -114.0], [-81.0, -5.0], [13.0, 42.0], [26.0, 151.0], [-32.0, -15.0], [5.0, 110.0], [87.0, 72.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_094bdaa31b774deadb748055da0ff15d);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_69672101709e763a7a8e0c61685f7cb4.addTo(map_094bdaa31b774deadb748055da0ff15d);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
