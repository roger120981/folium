# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9ea7909e025c4c5e14344b68dd3f2230 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9ea7909e025c4c5e14344b68dd3f2230&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9ea7909e025c4c5e14344b68dd3f2230 = L.map(
#                 &quot;map_9ea7909e025c4c5e14344b68dd3f2230&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_908a9436114701b5058188298032c003 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_908a9436114701b5058188298032c003.addTo(map_9ea7909e025c4c5e14344b68dd3f2230);
#
#
#             var marker_cluster_d65e093ca8a1943b63c7e95dbec55c4a = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_f867afd87cda3dbcb8cb18b169ba8181 = L.marker(
#                 [40.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_d65e093ca8a1943b63c7e95dbec55c4a);
#
#
#             var icon_7e316403a722d4b710f72a9c80ba10a3 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;ok-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7fbe215e88083a1a4c2f64eee0d6f843 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_fbe65aad0a3074ad160c541faf813fa5 = $(`&lt;div id=&quot;html_fbe65aad0a3074ad160c541faf813fa5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_7fbe215e88083a1a4c2f64eee0d6f843.setContent(html_fbe65aad0a3074ad160c541faf813fa5);
#
#
#
#         marker_f867afd87cda3dbcb8cb18b169ba8181.bindPopup(popup_7fbe215e88083a1a4c2f64eee0d6f843)
#         ;
#
#
#
#
#                 marker_f867afd87cda3dbcb8cb18b169ba8181.setIcon(icon_7e316403a722d4b710f72a9c80ba10a3);
#
#
#             var marker_09da565f250e7f94ee902f692ded0ff7 = L.marker(
#                 [44.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_d65e093ca8a1943b63c7e95dbec55c4a);
#
#
#             var icon_bd2186cac2b80279ee5ec13f8a9e6ffd = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_7ccd90ceaa404898637a5230e25b1a8d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_76c703a1ba0d42a20503c555ddb14148 = $(`&lt;div id=&quot;html_76c703a1ba0d42a20503c555ddb14148&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_7ccd90ceaa404898637a5230e25b1a8d.setContent(html_76c703a1ba0d42a20503c555ddb14148);
#
#
#
#         marker_09da565f250e7f94ee902f692ded0ff7.bindPopup(popup_7ccd90ceaa404898637a5230e25b1a8d)
#         ;
#
#
#
#
#                 marker_09da565f250e7f94ee902f692ded0ff7.setIcon(icon_bd2186cac2b80279ee5ec13f8a9e6ffd);
#
#
#             var marker_02948757d489491c87aa5f6343f79016 = L.marker(
#                 [44.67, -71.94],
#                 {
# }
#             ).addTo(marker_cluster_d65e093ca8a1943b63c7e95dbec55c4a);
#
#
#         var popup_e871ddada4d321ddb00a0b77a579874b = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_b36d18f91afdc4aab3f88ec724b271b4 = $(`&lt;div id=&quot;html_b36d18f91afdc4aab3f88ec724b271b4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_e871ddada4d321ddb00a0b77a579874b.setContent(html_b36d18f91afdc4aab3f88ec724b271b4);
#
#
#
#         marker_02948757d489491c87aa5f6343f79016.

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_1f9e7d3efd4e855edaad425a583bdaf0 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_1f9e7d3efd4e855edaad425a583bdaf0&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_1f9e7d3efd4e855edaad425a583bdaf0 = L.map(
#                 &quot;map_1f9e7d3efd4e855edaad425a583bdaf0&quot;,
#                 {
#                     center: [0.96, 2.02],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c6e0f05b240fa43a399e09fc714e245a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c6e0f05b240fa43a399e09fc714e245a.addTo(map_1f9e7d3efd4e855edaad425a583bdaf0);
#
#
#             var marker_cluster_862c3644d8b54f717993c70a277711cd = L.markerClusterGroup(
#                 {
# }
#             );
#             marker_cluster_862c3644d8b54f717993c70a277711cd.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_252cb93d7179b66bdebf42861c307ade = L.marker(
#                 [-81.0, -140.0],
#                 {
# }
#             ).addTo(marker_cluster_862c3644d8b54f717993c70a277711cd);
#
#
#         var popup_77598846da7b3049654184ae2faaabdc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_620f038c59dbdb22fe045b9c46ad7642 = $(`&lt;div id=&quot;html_620f038c59dbdb22fe045b9c46ad7642&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-140&lt;br&gt;lat:-81&lt;/div&gt;`)[0];
#                 popup_77598846da7b3049654184ae2faaabdc.setContent(html_620f038c59dbdb22fe045b9c46ad7642);
#
#
#
#         marker_252cb93d7179b66bdebf42861c307ade.bindPopup(popup_77598846da7b3049654184ae2faaabdc)
#         ;
#
#
#
#
#             var marker_86870482f007d6effd676d06069f9b59 = L.marker(
#                 [-8.0, -160.0],
#                 {
# }
#             ).addTo(marker_cluster_862c3644d8b54f717993c70a277711cd);
#
#
#         var popup_be4077e3709f58330bf27674990d0b69 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a41dbe04e151cf1e9103cba4419ef3d9 = $(`&lt;div id=&quot;html_a41dbe04e151cf1e9103cba4419ef3d9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-160&lt;br&gt;lat:-8&lt;/div&gt;`)[0];
#                 popup_be4077e3709f58330bf27674990d0b69.setContent(html_a41dbe04e151cf1e9103cba4419ef3d9);
#
#
#
#         marker_86870482f007d6effd676d06069f9b59.bindPopup(popup_be4077e3709f58330bf27674990d0b69)
#         ;
#
#
#
#
#             var marker_d28134e0074890abed2f7d673071b8a6 = L.marker(
#                 [-20.0, 49.0],
#                 {
# }
#             ).addTo(marker_cluster_862c3644d8b54f717993c70a277711cd);
#
#
#         var popup_b25989206838f84030917dcce36daf52 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a5977f087baae504c11e2cafb5a62ae8 = $(`&lt;div id=&quot;html_a5977f087baae504c11e2cafb5a62ae8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:49&lt;br&gt;lat:-20&lt;/div&gt;`)[0];
#                 popup_b25989206838f84030917dcce36daf52.setContent(html_a5977f087baae504c11e2cafb5a62ae8);
#
#
#
#         marker_d28134e0074890abed2f7d673071b8a6.bindPopup(popup_b25989206838f84030917dcce36daf52)
#         ;
#
#
#
#
#             var marker_577681e0b7654e59834599043616ffe6 = L.marker(
#                 [-46.0, 127.0],
#                 {
# }
#             ).addTo(marker_cluster_862c3644d8b54f717993c70a277711cd);
#
#
#         var popup_eca4a1a20dc5a0e9a6fe80bcb5f88a96 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_f39d9b3b60dece0b5bccd3a65fabbc8d = $(`&lt;div id=&quot;htm

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_ea43fef28e01f566f92bac78cdd9f835 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_ea43fef28e01f566f92bac78cdd9f835&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_ea43fef28e01f566f92bac78cdd9f835 = L.map(
#                 &quot;map_ea43fef28e01f566f92bac78cdd9f835&quot;,
#                 {
#                     center: [0.96, 2.02],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c0ab395df8323ec23ba40eec3a348655 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_c0ab395df8323ec23ba40eec3a348655.addTo(map_ea43fef28e01f566f92bac78cdd9f835);
#
#
#             var marker_cluster_6ff0f8e2199c4c9edc5aece0706e1fac = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_7d98ad74285fa0f912d0190dcd1effc6 = L.marker(
#                 [-81.0, -140.0],
#                 {
# }
#             ).addTo(marker_cluster_6ff0f8e2199c4c9edc5aece0706e1fac);
#
#
#         var popup_8c8e21aab59cd51aedcc973b2393e10d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_0b527ddca0bf3dc84cb332d8d01883d8 = $(`&lt;div id=&quot;html_0b527ddca0bf3dc84cb332d8d01883d8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-140&lt;br&gt;lat:-81&lt;/div&gt;`)[0];
#                 popup_8c8e21aab59cd51aedcc973b2393e10d.setContent(html_0b527ddca0bf3dc84cb332d8d01883d8);
#
#
#
#         marker_7d98ad74285fa0f912d0190dcd1effc6.bindPopup(popup_8c8e21aab59cd51aedcc973b2393e10d)
#         ;
#
#
#
#
#             var marker_4bb1299e7369d16ab15dca1e78903cf1 = L.marker(
#                 [-8.0, -160.0],
#                 {
# }
#             ).addTo(marker_cluster_6ff0f8e2199c4c9edc5aece0706e1fac);
#
#
#         var popup_a9516e769263fc4d85a787d38cdf2865 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6902632f3ac05b24901d9cdd5928bbae = $(`&lt;div id=&quot;html_6902632f3ac05b24901d9cdd5928bbae&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-160&lt;br&gt;lat:-8&lt;/div&gt;`)[0];
#                 popup_a9516e769263fc4d85a787d38cdf2865.setContent(html_6902632f3ac05b24901d9cdd5928bbae);
#
#
#
#         marker_4bb1299e7369d16ab15dca1e78903cf1.bindPopup(popup_a9516e769263fc4d85a787d38cdf2865)
#         ;
#
#
#
#
#             var marker_5e5ac949fe6c0344c9266045288d83e8 = L.marker(
#                 [-20.0, 49.0],
#                 {
# }
#             ).addTo(marker_cluster_6ff0f8e2199c4c9edc5aece0706e1fac);
#
#
#         var popup_afb322f1f4f6aa2b1881d0ac92f5ed87 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_33ea550a0281c4a13840b61136ebebd0 = $(`&lt;div id=&quot;html_33ea550a0281c4a13840b61136ebebd0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:49&lt;br&gt;lat:-20&lt;/div&gt;`)[0];
#                 popup_afb322f1f4f6aa2b1881d0ac92f5ed87.setContent(html_33ea550a0281c4a13840b61136ebebd0);
#
#
#
#         marker_5e5ac949fe6c0344c9266045288d83e8.bindPopup(popup_afb322f1f4f6aa2b1881d0ac92f5ed87)
#         ;
#
#
#
#
#             var marker_be97261fc8bfb07d6188db33d2662a46 = L.marker(
#                 [-46.0, 127.0],
#                 {
# }
#             ).addTo(marker_cluster_6ff0f8e2199c4c9edc5aece0706e1fac);
#
#
#         var popup_6e403535a821fef0fc26f29f333b6888 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_74cfb1440aa2fe1edbb95c8a42890dd5 = $(`&lt;div id=&quot;html_74cfb1440aa2fe1edbb95c8a42890dd5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:127&lt;br&gt;lat:-46&lt;/div&gt;`)[0];
#                 popup_6e403535a821fef0fc26f29f333b6888.setContent(html_74cfb1440aa2fe1edbb95c8a42890dd5);
#
#
#
#         marker_be97261fc8bfb07d6188db33d2662a46.bindPopup(popup_6e403535a821

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5e019bde21386b1f581a03e6ecf63449 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5e019bde21386b1f581a03e6ecf63449&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5e019bde21386b1f581a03e6ecf63449 = L.map(
#                 &quot;map_5e019bde21386b1f581a03e6ecf63449&quot;,
#                 {
#                     center: [0.96, 2.02],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_1c031feec00989f80d583992af3aa989 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_1c031feec00989f80d583992af3aa989.addTo(map_5e019bde21386b1f581a03e6ecf63449);
#
#
#             var fast_marker_cluster_c8092073062fafaad45d356d552ce92f = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[-81.0, -140.0], [-8.0, -160.0], [-20.0, 49.0], [-46.0, 127.0], [-20.0, -129.0], [-84.0, -161.0], [-13.0, -122.0], [-11.0, 107.0], [-24.0, 118.0], [-49.0, -4.0], [19.0, -81.0], [7.0, 160.0], [38.0, 106.0], [-42.0, 4.0], [62.0, 121.0], [-76.0, -72.0], [66.0, 141.0], [80.0, 99.0], [30.0, 40.0], [-64.0, -154.0], [16.0, -28.0], [-17.0, -125.0], [-4.0, -41.0], [72.0, 46.0], [-63.0, 64.0], [72.0, 118.0], [-14.0, -31.0], [-67.0, 120.0], [19.0, -35.0], [31.0, -89.0], [0.0, -127.0], [-50.0, 62.0], [-90.0, -7.0], [81.0, 12.0], [-67.0, 94.0], [42.0, -140.0], [6.0, -179.0], [-15.0, 149.0], [-47.0, -119.0], [-89.0, 149.0], [34.0, -128.0], [76.0, -157.0], [14.0, 101.0], [72.0, 161.0], [23.0, -51.0], [31.0, 56.0], [25.0, -174.0], [-50.0, 96.0], [-82.0, 114.0], [-26.0, -82.0], [81.0, -51.0], [-3.0, 131.0], [-33.0, 62.0], [-30.0, 150.0], [-86.0, 26.0], [66.0, 88.0], [-39.0, 92.0], [44.0, -84.0], [10.0, -178.0], [36.0, 176.0], [41.0, 101.0], [-34.0, -9.0], [26.0, 140.0], [49.0, -117.0], [24.0, -5.0], [75.0, -37.0], [-16.0, -144.0], [-29.0, 22.0], [73.0, 1.0], [-64.0, -10.0], [15.0, -36.0], [-70.0, 177.0], [15.0, 52.0], [-75.0, 98.0], [78.0, -146.0], [28.0, -158.0], [49.0, 151.0], [55.0, 48.0], [50.0, -74.0], [-6.0, 149.0], [12.0, 113.0], [68.0, -144.0], [-65.0, 117.0], [12.0, 42.0], [62.0, 92.0], [78.0, 29.0], [-10.0, -36.0], [-16.0, -105.0], [11.0, -58.0], [-35.0, 140.0], [-62.0, -157.0], [-47.0, -139.0], [-69.0, 72.0], [45.0, -165.0], [-7.0, 152.0], [80.0, -15.0], [74.0, 12.0], [-24.0, 24.0], [16.0, -98.0], [-54.0, -167.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_5e019bde21386b1f581a03e6ecf63449);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_c8092073062fafaad45d356d552ce92f.addTo(map_5e019bde21386b1f581a03e6ecf63449);
#
#
#             var layer_control_ff66709e589fd1a4d7fbf0adf3f9b962_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_1c031feec00989f80d583992af3aa989,
#                 },
#                 overlays :  {
#                     &quot;macro_element_c8092073062fafaad45d356d552ce92f&quot; : fast_marker_cluster_c8092073062fafaad45d356d552ce92f,
#                 },
#             };
#             let layer_control_ff66709e589fd1a4d7fbf0adf3f9b962 = L.control.layers(
#                 layer_control_ff66709e589fd1a4d7fbf0adf3f9b962_layers.base_layers,
#                 layer_control_ff66709e589fd1a4d7fbf0adf3f9b962_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_5e019bde21386b1f581a03e6ecf63449);
#
#
# &lt;/scri

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e34e6fa14be3b81583a8010eb4812e0f {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e34e6fa14be3b81583a8010eb4812e0f&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e34e6fa14be3b81583a8010eb4812e0f = L.map(
#                 &quot;map_e34e6fa14be3b81583a8010eb4812e0f&quot;,
#                 {
#                     center: [0.96, 2.02],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0eb21156cc4f8af28acd9207be07f1e1 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0eb21156cc4f8af28acd9207be07f1e1.addTo(map_e34e6fa14be3b81583a8010eb4812e0f);
#
#
#             var fast_marker_cluster_0ba389061705b231c45033b6c55ef070 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[-81.0, -140.0], [-8.0, -160.0], [-20.0, 49.0], [-46.0, 127.0], [-20.0, -129.0], [-84.0, -161.0], [-13.0, -122.0], [-11.0, 107.0], [-24.0, 118.0], [-49.0, -4.0], [19.0, -81.0], [7.0, 160.0], [38.0, 106.0], [-42.0, 4.0], [62.0, 121.0], [-76.0, -72.0], [66.0, 141.0], [80.0, 99.0], [30.0, 40.0], [-64.0, -154.0], [16.0, -28.0], [-17.0, -125.0], [-4.0, -41.0], [72.0, 46.0], [-63.0, 64.0], [72.0, 118.0], [-14.0, -31.0], [-67.0, 120.0], [19.0, -35.0], [31.0, -89.0], [0.0, -127.0], [-50.0, 62.0], [-90.0, -7.0], [81.0, 12.0], [-67.0, 94.0], [42.0, -140.0], [6.0, -179.0], [-15.0, 149.0], [-47.0, -119.0], [-89.0, 149.0], [34.0, -128.0], [76.0, -157.0], [14.0, 101.0], [72.0, 161.0], [23.0, -51.0], [31.0, 56.0], [25.0, -174.0], [-50.0, 96.0], [-82.0, 114.0], [-26.0, -82.0], [81.0, -51.0], [-3.0, 131.0], [-33.0, 62.0], [-30.0, 150.0], [-86.0, 26.0], [66.0, 88.0], [-39.0, 92.0], [44.0, -84.0], [10.0, -178.0], [36.0, 176.0], [41.0, 101.0], [-34.0, -9.0], [26.0, 140.0], [49.0, -117.0], [24.0, -5.0], [75.0, -37.0], [-16.0, -144.0], [-29.0, 22.0], [73.0, 1.0], [-64.0, -10.0], [15.0, -36.0], [-70.0, 177.0], [15.0, 52.0], [-75.0, 98.0], [78.0, -146.0], [28.0, -158.0], [49.0, 151.0], [55.0, 48.0], [50.0, -74.0], [-6.0, 149.0], [12.0, 113.0], [68.0, -144.0], [-65.0, 117.0], [12.0, 42.0], [62.0, 92.0], [78.0, 29.0], [-10.0, -36.0], [-16.0, -105.0], [11.0, -58.0], [-35.0, 140.0], [-62.0, -157.0], [-47.0, -139.0], [-69.0, 72.0], [45.0, -165.0], [-7.0, 152.0], [80.0, -15.0], [74.0, 12.0], [-24.0, 24.0], [16.0, -98.0], [-54.0, -167.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_e34e6fa14be3b81583a8010eb4812e0f);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_0ba389061705b231c45033b6c55ef070.addTo(map_e34e6fa14be3b81583a8010eb4812e0f);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
