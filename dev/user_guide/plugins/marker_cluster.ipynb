# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_8057288f73ab3b826670afcb88df36f6 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_8057288f73ab3b826670afcb88df36f6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_8057288f73ab3b826670afcb88df36f6 = L.map(
#                 &quot;map_8057288f73ab3b826670afcb88df36f6&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8abe0d9215d6f7ecd61c4d2ebc3f1abe = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_8abe0d9215d6f7ecd61c4d2ebc3f1abe.addTo(map_8057288f73ab3b826670afcb88df36f6);
#
#
#             var marker_cluster_7b5c02a681eb6310dbbf3ae0928ea6a4 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_ac19b13cf76273fe1f05caf60cbe539a = L.marker(
#                 [40.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_7b5c02a681eb6310dbbf3ae0928ea6a4);
#
#
#             var icon_63c50b05da8d39ac55afd92c113e422d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;ok-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_5d8f18e7f9a08886278ae52dcd0513ae = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6d0d0b55783b0328be9e72c96867a626 = $(`&lt;div id=&quot;html_6d0d0b55783b0328be9e72c96867a626&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_5d8f18e7f9a08886278ae52dcd0513ae.setContent(html_6d0d0b55783b0328be9e72c96867a626);
#
#
#
#         marker_ac19b13cf76273fe1f05caf60cbe539a.bindPopup(popup_5d8f18e7f9a08886278ae52dcd0513ae)
#         ;
#
#
#
#
#                 marker_ac19b13cf76273fe1f05caf60cbe539a.setIcon(icon_63c50b05da8d39ac55afd92c113e422d);
#
#
#             var marker_2540db5ff96a13fc3c80ed15afc1d23a = L.marker(
#                 [44.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_7b5c02a681eb6310dbbf3ae0928ea6a4);
#
#
#             var icon_e7c61c676eeee8efbe8ada135009d56a = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_fe284ef827dcb43942a29daec790e07d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d5f7605dba9b9ca9cd9f0d4791c75dfb = $(`&lt;div id=&quot;html_d5f7605dba9b9ca9cd9f0d4791c75dfb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_fe284ef827dcb43942a29daec790e07d.setContent(html_d5f7605dba9b9ca9cd9f0d4791c75dfb);
#
#
#
#         marker_2540db5ff96a13fc3c80ed15afc1d23a.bindPopup(popup_fe284ef827dcb43942a29daec790e07d)
#         ;
#
#
#
#
#                 marker_2540db5ff96a13fc3c80ed15afc1d23a.setIcon(icon_e7c61c676eeee8efbe8ada135009d56a);
#
#
#             var marker_e5f38edd03d41b93483aad341462fb27 = L.marker(
#                 [44.67, -71.94],
#                 {
# }
#             ).addTo(marker_cluster_7b5c02a681eb6310dbbf3ae0928ea6a4);
#
#
#         var popup_5eea1c1299664c55dc5460051e5fe352 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21e3281fa242c0c2a380796ead11f2f7 = $(`&lt;div id=&quot;html_21e3281fa242c0c2a380796ead11f2f7&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_5eea1c1299664c55dc5460051e5fe352.setContent(html_21e3281fa242c0c2a380796ead11f2f7);
#
#
#
#         marker_e5f38edd03d41b93483aad341462fb27.

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a861c91397bb3fc9031ecbca1664760a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a861c91397bb3fc9031ecbca1664760a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_a861c91397bb3fc9031ecbca1664760a = L.map(
#                 &quot;map_a861c91397bb3fc9031ecbca1664760a&quot;,
#                 {
#                     center: [1.53, -3.31],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0fd173a0467697a03948acbefb3bf959 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0fd173a0467697a03948acbefb3bf959.addTo(map_a861c91397bb3fc9031ecbca1664760a);
#
#
#             var marker_cluster_9c8396f8b702442833db59f241707439 = L.markerClusterGroup(
#                 {
# }
#             );
#             marker_cluster_9c8396f8b702442833db59f241707439.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_f1df84805c7204420a03011567925d07 = L.marker(
#                 [-65.0, -73.0],
#                 {
# }
#             ).addTo(marker_cluster_9c8396f8b702442833db59f241707439);
#
#
#         var popup_102dc8247e9dccb59a5c53cf2de0fdfc = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_ece04858fac74208e2841cadc381d5c3 = $(`&lt;div id=&quot;html_ece04858fac74208e2841cadc381d5c3&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-73&lt;br&gt;lat:-65&lt;/div&gt;`)[0];
#                 popup_102dc8247e9dccb59a5c53cf2de0fdfc.setContent(html_ece04858fac74208e2841cadc381d5c3);
#
#
#
#         marker_f1df84805c7204420a03011567925d07.bindPopup(popup_102dc8247e9dccb59a5c53cf2de0fdfc)
#         ;
#
#
#
#
#             var marker_de70a5a4d80c7eafd5267a18fd747562 = L.marker(
#                 [68.0, -143.0],
#                 {
# }
#             ).addTo(marker_cluster_9c8396f8b702442833db59f241707439);
#
#
#         var popup_1bd0c78f6a93595ba37308feca1d841a = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_7724832f56b7e1d0a2ed251fefa33bb4 = $(`&lt;div id=&quot;html_7724832f56b7e1d0a2ed251fefa33bb4&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-143&lt;br&gt;lat:68&lt;/div&gt;`)[0];
#                 popup_1bd0c78f6a93595ba37308feca1d841a.setContent(html_7724832f56b7e1d0a2ed251fefa33bb4);
#
#
#
#         marker_de70a5a4d80c7eafd5267a18fd747562.bindPopup(popup_1bd0c78f6a93595ba37308feca1d841a)
#         ;
#
#
#
#
#             var marker_045cee8ca5778d56afaa10da095b581e = L.marker(
#                 [66.0, -173.0],
#                 {
# }
#             ).addTo(marker_cluster_9c8396f8b702442833db59f241707439);
#
#
#         var popup_0ac4d187afa53b54b1ae8afec71ff378 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_21cd7f34d6abb5aa7f94de7c5ef695fe = $(`&lt;div id=&quot;html_21cd7f34d6abb5aa7f94de7c5ef695fe&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-173&lt;br&gt;lat:66&lt;/div&gt;`)[0];
#                 popup_0ac4d187afa53b54b1ae8afec71ff378.setContent(html_21cd7f34d6abb5aa7f94de7c5ef695fe);
#
#
#
#         marker_045cee8ca5778d56afaa10da095b581e.bindPopup(popup_0ac4d187afa53b54b1ae8afec71ff378)
#         ;
#
#
#
#
#             var marker_597e085abbf1b9f33fe7433b3810240a = L.marker(
#                 [59.0, -147.0],
#                 {
# }
#             ).addTo(marker_cluster_9c8396f8b702442833db59f241707439);
#
#
#         var popup_d5b4cf2a74a3c042ad0c87b48830f2c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_240d4cb905a8cb682ca251b655ba3e31 = $(`&lt;div id=&quot;ht

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_35a3bd3b90a0feea5d8308b72cd91ff5 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_35a3bd3b90a0feea5d8308b72cd91ff5&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_35a3bd3b90a0feea5d8308b72cd91ff5 = L.map(
#                 &quot;map_35a3bd3b90a0feea5d8308b72cd91ff5&quot;,
#                 {
#                     center: [1.53, -3.31],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_bcd0834e7bb1a99d18b7171c8b39bc37 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_bcd0834e7bb1a99d18b7171c8b39bc37.addTo(map_35a3bd3b90a0feea5d8308b72cd91ff5);
#
#
#             var marker_cluster_88a8f41729b8bc5cd2c7aa3e07dfffab = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_7ae44b6d6c0580f4aa5f86fd6f37dabb = L.marker(
#                 [-65.0, -73.0],
#                 {
# }
#             ).addTo(marker_cluster_88a8f41729b8bc5cd2c7aa3e07dfffab);
#
#
#         var popup_b94e8e42eced7988734ac91cbd9c49c8 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_09da894c69f9c258869c3e9502d23dcd = $(`&lt;div id=&quot;html_09da894c69f9c258869c3e9502d23dcd&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-73&lt;br&gt;lat:-65&lt;/div&gt;`)[0];
#                 popup_b94e8e42eced7988734ac91cbd9c49c8.setContent(html_09da894c69f9c258869c3e9502d23dcd);
#
#
#
#         marker_7ae44b6d6c0580f4aa5f86fd6f37dabb.bindPopup(popup_b94e8e42eced7988734ac91cbd9c49c8)
#         ;
#
#
#
#
#             var marker_5acb216b6c6281c78b654224259349cb = L.marker(
#                 [68.0, -143.0],
#                 {
# }
#             ).addTo(marker_cluster_88a8f41729b8bc5cd2c7aa3e07dfffab);
#
#
#         var popup_607fe63e48da821f319b77696b92b011 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_293946eece084817a1e0387ef27f31ed = $(`&lt;div id=&quot;html_293946eece084817a1e0387ef27f31ed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-143&lt;br&gt;lat:68&lt;/div&gt;`)[0];
#                 popup_607fe63e48da821f319b77696b92b011.setContent(html_293946eece084817a1e0387ef27f31ed);
#
#
#
#         marker_5acb216b6c6281c78b654224259349cb.bindPopup(popup_607fe63e48da821f319b77696b92b011)
#         ;
#
#
#
#
#             var marker_16b04e538a64d94b38ea8ad20f4e2380 = L.marker(
#                 [66.0, -173.0],
#                 {
# }
#             ).addTo(marker_cluster_88a8f41729b8bc5cd2c7aa3e07dfffab);
#
#
#         var popup_9176c874d416263b783c566241ed470c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a9bc719f9ed8fcdf38c4336e92d93bf0 = $(`&lt;div id=&quot;html_a9bc719f9ed8fcdf38c4336e92d93bf0&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-173&lt;br&gt;lat:66&lt;/div&gt;`)[0];
#                 popup_9176c874d416263b783c566241ed470c.setContent(html_a9bc719f9ed8fcdf38c4336e92d93bf0);
#
#
#
#         marker_16b04e538a64d94b38ea8ad20f4e2380.bindPopup(popup_9176c874d416263b783c566241ed470c)
#         ;
#
#
#
#
#             var marker_d9b91cc372681497b7f5c242db80a63a = L.marker(
#                 [59.0, -147.0],
#                 {
# }
#             ).addTo(marker_cluster_88a8f41729b8bc5cd2c7aa3e07dfffab);
#
#
#         var popup_7d79c95d452739c331c7ac9fcbb51a2c = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_6f809b8a78452b50a1f2b5bfb406dad9 = $(`&lt;div id=&quot;html_6f809b8a78452b50a1f2b5bfb406dad9&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-147&lt;br&gt;lat:59&lt;/div&gt;`)[0];
#                 popup_7d79c95d452739c331c7ac9fcbb51a2c.setContent(html_6f809b8a78452b50a1f2b5bfb406dad9);
#
#
#
#         marker_d9b91cc372681497b7f5c242db80a63a.bindPopup(popup_7d79c95d452

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_690fc6e00ad33b295a676cf7dd5f4ccd {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_690fc6e00ad33b295a676cf7dd5f4ccd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_690fc6e00ad33b295a676cf7dd5f4ccd = L.map(
#                 &quot;map_690fc6e00ad33b295a676cf7dd5f4ccd&quot;,
#                 {
#                     center: [1.53, -3.31],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7c71708557a089dbbf7a8da583b17c22 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7c71708557a089dbbf7a8da583b17c22.addTo(map_690fc6e00ad33b295a676cf7dd5f4ccd);
#
#
#             var fast_marker_cluster_695bf0e1e3571b3ca58caf86e713dcd1 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[-65.0, -73.0], [68.0, -143.0], [66.0, -173.0], [59.0, -147.0], [-6.0, -70.0], [47.0, -93.0], [19.0, -138.0], [76.0, -110.0], [-57.0, 109.0], [7.0, 41.0], [28.0, -177.0], [66.0, -146.0], [-72.0, 56.0], [12.0, -133.0], [-72.0, 93.0], [48.0, 121.0], [62.0, 8.0], [79.0, 32.0], [-67.0, 76.0], [49.0, -86.0], [-61.0, 102.0], [-29.0, -67.0], [-12.0, -155.0], [9.0, 6.0], [-12.0, 108.0], [27.0, 17.0], [-89.0, -176.0], [67.0, 126.0], [40.0, 172.0], [-72.0, 131.0], [-29.0, -60.0], [-26.0, -153.0], [-89.0, -2.0], [-86.0, 150.0], [59.0, 101.0], [38.0, 127.0], [80.0, -121.0], [-4.0, -54.0], [48.0, -52.0], [14.0, 141.0], [62.0, -131.0], [-33.0, 100.0], [-16.0, -46.0], [21.0, -68.0], [7.0, 3.0], [13.0, -44.0], [16.0, -35.0], [-55.0, 37.0], [26.0, -114.0], [-11.0, 17.0], [-87.0, -167.0], [-22.0, 131.0], [-14.0, -92.0], [0.0, -31.0], [74.0, 47.0], [3.0, -174.0], [-75.0, 139.0], [72.0, 17.0], [-38.0, 92.0], [-85.0, 120.0], [41.0, 66.0], [-90.0, 177.0], [43.0, 96.0], [76.0, 156.0], [2.0, -141.0], [-28.0, 35.0], [-82.0, 80.0], [-50.0, -85.0], [-89.0, 138.0], [52.0, -83.0], [-75.0, 7.0], [32.0, 93.0], [-13.0, -82.0], [-9.0, 1.0], [-2.0, 150.0], [34.0, 2.0], [47.0, 170.0], [46.0, 83.0], [-32.0, -68.0], [-44.0, -58.0], [16.0, -15.0], [-16.0, 130.0], [-29.0, 107.0], [-76.0, -1.0], [10.0, -95.0], [60.0, -109.0], [39.0, -127.0], [42.0, -72.0], [7.0, -53.0], [-71.0, -23.0], [-75.0, 18.0], [45.0, 145.0], [55.0, 26.0], [9.0, -38.0], [41.0, -180.0], [3.0, -40.0], [69.0, -110.0], [51.0, 135.0], [-32.0, 11.0], [68.0, 34.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_690fc6e00ad33b295a676cf7dd5f4ccd);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_695bf0e1e3571b3ca58caf86e713dcd1.addTo(map_690fc6e00ad33b295a676cf7dd5f4ccd);
#
#
#             var layer_control_d86cb1032289bbc409ab93657f3846d2_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_7c71708557a089dbbf7a8da583b17c22,
#                 },
#                 overlays :  {
#                     &quot;macro_element_695bf0e1e3571b3ca58caf86e713dcd1&quot; : fast_marker_cluster_695bf0e1e3571b3ca58caf86e713dcd1,
#                 },
#             };
#             let layer_control_d86cb1032289bbc409ab93657f3846d2 = L.control.layers(
#                 layer_control_d86cb1032289bbc409ab93657f3846d2_layers.base_layers,
#                 layer_control_d86cb1032289bbc409ab93657f3846d2_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_690fc6e00ad33b295a676cf7dd5f4ccd);
#
#
# &lt;/script&gt;
# &lt;/html

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_90c2350f805a7e2c2fc2b728836bf73b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_90c2350f805a7e2c2fc2b728836bf73b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_90c2350f805a7e2c2fc2b728836bf73b = L.map(
#                 &quot;map_90c2350f805a7e2c2fc2b728836bf73b&quot;,
#                 {
#                     center: [1.53, -3.31],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_615eb61b63ddc5b0d757c0ab4da1a704 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_615eb61b63ddc5b0d757c0ab4da1a704.addTo(map_90c2350f805a7e2c2fc2b728836bf73b);
#
#
#             var fast_marker_cluster_032076a09c8a50f6c7745b9d32dac6c5 = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[-65.0, -73.0], [68.0, -143.0], [66.0, -173.0], [59.0, -147.0], [-6.0, -70.0], [47.0, -93.0], [19.0, -138.0], [76.0, -110.0], [-57.0, 109.0], [7.0, 41.0], [28.0, -177.0], [66.0, -146.0], [-72.0, 56.0], [12.0, -133.0], [-72.0, 93.0], [48.0, 121.0], [62.0, 8.0], [79.0, 32.0], [-67.0, 76.0], [49.0, -86.0], [-61.0, 102.0], [-29.0, -67.0], [-12.0, -155.0], [9.0, 6.0], [-12.0, 108.0], [27.0, 17.0], [-89.0, -176.0], [67.0, 126.0], [40.0, 172.0], [-72.0, 131.0], [-29.0, -60.0], [-26.0, -153.0], [-89.0, -2.0], [-86.0, 150.0], [59.0, 101.0], [38.0, 127.0], [80.0, -121.0], [-4.0, -54.0], [48.0, -52.0], [14.0, 141.0], [62.0, -131.0], [-33.0, 100.0], [-16.0, -46.0], [21.0, -68.0], [7.0, 3.0], [13.0, -44.0], [16.0, -35.0], [-55.0, 37.0], [26.0, -114.0], [-11.0, 17.0], [-87.0, -167.0], [-22.0, 131.0], [-14.0, -92.0], [0.0, -31.0], [74.0, 47.0], [3.0, -174.0], [-75.0, 139.0], [72.0, 17.0], [-38.0, 92.0], [-85.0, 120.0], [41.0, 66.0], [-90.0, 177.0], [43.0, 96.0], [76.0, 156.0], [2.0, -141.0], [-28.0, 35.0], [-82.0, 80.0], [-50.0, -85.0], [-89.0, 138.0], [52.0, -83.0], [-75.0, 7.0], [32.0, 93.0], [-13.0, -82.0], [-9.0, 1.0], [-2.0, 150.0], [34.0, 2.0], [47.0, 170.0], [46.0, 83.0], [-32.0, -68.0], [-44.0, -58.0], [16.0, -15.0], [-16.0, 130.0], [-29.0, 107.0], [-76.0, -1.0], [10.0, -95.0], [60.0, -109.0], [39.0, -127.0], [42.0, -72.0], [7.0, -53.0], [-71.0, -23.0], [-75.0, 18.0], [45.0, 145.0], [55.0, 26.0], [9.0, -38.0], [41.0, -180.0], [3.0, -40.0], [69.0, -110.0], [51.0, 135.0], [-32.0, 11.0], [68.0, 34.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_90c2350f805a7e2c2fc2b728836bf73b);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_032076a09c8a50f6c7745b9d32dac6c5.addTo(map_90c2350f805a7e2c2fc2b728836bf73b);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
