# %% [markdown]
# # MarkerCluster

# %%
import folium
from folium.plugins import MarkerCluster

m = folium.Map(location=[44, -73], zoom_start=5)

marker_cluster = MarkerCluster().add_to(m)

folium.Marker(
    location=[40.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="green", icon="ok-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -73.94],
    popup="Add popup text here.",
    icon=folium.Icon(color="red", icon="remove-sign"),
).add_to(marker_cluster)

folium.Marker(
    location=[44.67, -71.94],
    popup="Add popup text here.",
    icon=None,
).add_to(marker_cluster)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_9127ab50e4d952d4e8441888c94a3782 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_9127ab50e4d952d4e8441888c94a3782&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_9127ab50e4d952d4e8441888c94a3782 = L.map(
#                 &quot;map_9127ab50e4d952d4e8441888c94a3782&quot;,
#                 {
#                     center: [44.0, -73.0],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 5,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_2a52854b4cad41949b5c7eafa7ca3e73 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_2a52854b4cad41949b5c7eafa7ca3e73.addTo(map_9127ab50e4d952d4e8441888c94a3782);
#
#
#             var marker_cluster_f5f6116670a2669c56a891ff3cc36d4f = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_b2265b09c8023db14ae0843b582b6843 = L.marker(
#                 [40.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_f5f6116670a2669c56a891ff3cc36d4f);
#
#
#             var icon_8cfa09e373c8654dbfb5c31ec8715ca8 = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;green&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;ok-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_6b880256b5a1b74c2810749dfa0bbda2 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_23b91aa21df35069aee075ec6da5baea = $(`&lt;div id=&quot;html_23b91aa21df35069aee075ec6da5baea&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_6b880256b5a1b74c2810749dfa0bbda2.setContent(html_23b91aa21df35069aee075ec6da5baea);
#
#
#
#         marker_b2265b09c8023db14ae0843b582b6843.bindPopup(popup_6b880256b5a1b74c2810749dfa0bbda2)
#         ;
#
#
#
#
#                 marker_b2265b09c8023db14ae0843b582b6843.setIcon(icon_8cfa09e373c8654dbfb5c31ec8715ca8);
#
#
#             var marker_d071a52fa71012e20615bb6e3d3dbcef = L.marker(
#                 [44.67, -73.94],
#                 {
# }
#             ).addTo(marker_cluster_f5f6116670a2669c56a891ff3cc36d4f);
#
#
#             var icon_20e0b007e277e54905c6ad01a4b2cf4d = L.AwesomeMarkers.icon(
#                 {
#   &quot;markerColor&quot;: &quot;red&quot;,
#   &quot;iconColor&quot;: &quot;white&quot;,
#   &quot;icon&quot;: &quot;remove-sign&quot;,
#   &quot;prefix&quot;: &quot;glyphicon&quot;,
#   &quot;extraClasses&quot;: &quot;fa-rotate-0&quot;,
# }
#             );
#
#
#         var popup_00356eecbe920e0af63e54878235b119 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_1b430553685deda240eb872f5a43662f = $(`&lt;div id=&quot;html_1b430553685deda240eb872f5a43662f&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_00356eecbe920e0af63e54878235b119.setContent(html_1b430553685deda240eb872f5a43662f);
#
#
#
#         marker_d071a52fa71012e20615bb6e3d3dbcef.bindPopup(popup_00356eecbe920e0af63e54878235b119)
#         ;
#
#
#
#
#                 marker_d071a52fa71012e20615bb6e3d3dbcef.setIcon(icon_20e0b007e277e54905c6ad01a4b2cf4d);
#
#
#             var marker_96bbf402239794085b5f91b86a6becc0 = L.marker(
#                 [44.67, -71.94],
#                 {
# }
#             ).addTo(marker_cluster_f5f6116670a2669c56a891ff3cc36d4f);
#
#
#         var popup_a657311f1f3c212285ebcea61b38a686 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3695b013b94cf7919dfea796cfaff12 = $(`&lt;div id=&quot;html_a3695b013b94cf7919dfea796cfaff12&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Add popup text here.&lt;/div&gt;`)[0];
#                 popup_a657311f1f3c212285ebcea61b38a686.setContent(html_a3695b013b94cf7919dfea796cfaff12);
#
#
#
#         marker_96bbf402239794085b5f91b86a6becc0.

# %%
import numpy as np

size = 100
lons = np.random.randint(-180, 180, size=size)
lats = np.random.randint(-90, 90, size=size)

locations = list(zip(lats, lons))
popups = ["lon:{}<br>lat:{}".format(lon, lat) for (lat, lon) in locations]

# %% [markdown]
# ## Adding all icons in a single call

# %%
icon_create_function = """\
function(cluster) {
    return L.divIcon({
    html: '<b>' + cluster.getChildCount() + '</b>',
    className: 'marker-cluster marker-cluster-large',
    iconSize: new L.Point(20, 20)
    });
}"""

# %%
from folium.plugins import MarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

marker_cluster = MarkerCluster(
    locations=locations,
    popups=popups,
    name="1000 clustered icons",
    overlay=True,
    control=True,
    icon_create_function=icon_create_function,
)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_510e166e0b2a8b3ae6da33a76ea70b2b {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_510e166e0b2a8b3ae6da33a76ea70b2b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_510e166e0b2a8b3ae6da33a76ea70b2b = L.map(
#                 &quot;map_510e166e0b2a8b3ae6da33a76ea70b2b&quot;,
#                 {
#                     center: [6.71, 22.14],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_243a0946904c951e0857c529af66ea53 = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_243a0946904c951e0857c529af66ea53.addTo(map_510e166e0b2a8b3ae6da33a76ea70b2b);
#
#
#             var marker_cluster_ca7816e6d3e0b0ba0a4f76e5665d4084 = L.markerClusterGroup(
#                 {
# }
#             );
#             marker_cluster_ca7816e6d3e0b0ba0a4f76e5665d4084.options.iconCreateFunction =
#                 function(cluster) {
#     return L.divIcon({
#     html: &#x27;&lt;b&gt;&#x27; + cluster.getChildCount() + &#x27;&lt;/b&gt;&#x27;,
#     className: &#x27;marker-cluster marker-cluster-large&#x27;,
#     iconSize: new L.Point(20, 20)
#     });
# };
#
#
#             var marker_f8e55e0780fb82ce2b9d135d9286b73e = L.marker(
#                 [-22.0, 116.0],
#                 {
# }
#             ).addTo(marker_cluster_ca7816e6d3e0b0ba0a4f76e5665d4084);
#
#
#         var popup_690f3cef8b8e0babf26e51a03e1ac70d = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_a3277150928d07bf9cbe4b1b9389ba07 = $(`&lt;div id=&quot;html_a3277150928d07bf9cbe4b1b9389ba07&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:116&lt;br&gt;lat:-22&lt;/div&gt;`)[0];
#                 popup_690f3cef8b8e0babf26e51a03e1ac70d.setContent(html_a3277150928d07bf9cbe4b1b9389ba07);
#
#
#
#         marker_f8e55e0780fb82ce2b9d135d9286b73e.bindPopup(popup_690f3cef8b8e0babf26e51a03e1ac70d)
#         ;
#
#
#
#
#             var marker_f3286dc40d900260874347c0afc86841 = L.marker(
#                 [45.0, -28.0],
#                 {
# }
#             ).addTo(marker_cluster_ca7816e6d3e0b0ba0a4f76e5665d4084);
#
#
#         var popup_8cd0490dddba3d72437d7aa970c88453 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_98091496aa1373340bd25735cd48939d = $(`&lt;div id=&quot;html_98091496aa1373340bd25735cd48939d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-28&lt;br&gt;lat:45&lt;/div&gt;`)[0];
#                 popup_8cd0490dddba3d72437d7aa970c88453.setContent(html_98091496aa1373340bd25735cd48939d);
#
#
#
#         marker_f3286dc40d900260874347c0afc86841.bindPopup(popup_8cd0490dddba3d72437d7aa970c88453)
#         ;
#
#
#
#
#             var marker_084577eb504ab23b08245e5042540ab9 = L.marker(
#                 [-29.0, -99.0],
#                 {
# }
#             ).addTo(marker_cluster_ca7816e6d3e0b0ba0a4f76e5665d4084);
#
#
#         var popup_2aa9edeebca79c148ae5f182cfe46881 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_30750cda91c1580adbc04cf386fa7d3d = $(`&lt;div id=&quot;html_30750cda91c1580adbc04cf386fa7d3d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-99&lt;br&gt;lat:-29&lt;/div&gt;`)[0];
#                 popup_2aa9edeebca79c148ae5f182cfe46881.setContent(html_30750cda91c1580adbc04cf386fa7d3d);
#
#
#
#         marker_084577eb504ab23b08245e5042540ab9.bindPopup(popup_2aa9edeebca79c148ae5f182cfe46881)
#         ;
#
#
#
#
#             var marker_94940f2f5c5fc60f0708839bd41dba86 = L.marker(
#                 [-24.0, -159.0],
#                 {
# }
#             ).addTo(marker_cluster_ca7816e6d3e0b0ba0a4f76e5665d4084);
#
#
#         var popup_2921496c0b7b16b67af59436580d9fb4 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_9351a532bb5780ac8985aeaea74e9ba2 = $(`&lt;div id=&quot;htm

# %% [markdown]
# ## Explicit loop allows for customization in the loop.

# %%
m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

marker_cluster = MarkerCluster(
    name='1000 clustered icons',
    overlay=True,
    control=False,
    icon_create_function=None
)

for k in range(size):
    location = lats[k], lons[k]
    marker = folium.Marker(location=location)
    popup = 'lon:{}<br>lat:{}'.format(location[1], location[0])
    folium.Popup(popup).add_to(marker)
    marker_cluster.add_child(marker)

marker_cluster.add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_67ab094076f1a03ca086405800e843fa {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_67ab094076f1a03ca086405800e843fa&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_67ab094076f1a03ca086405800e843fa = L.map(
#                 &quot;map_67ab094076f1a03ca086405800e843fa&quot;,
#                 {
#                     center: [6.71, 22.14],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_f42e43cdecb80c561503e10c17eedf6a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_f42e43cdecb80c561503e10c17eedf6a.addTo(map_67ab094076f1a03ca086405800e843fa);
#
#
#             var marker_cluster_88c2df809c7ea58db14dec8c5538de16 = L.markerClusterGroup(
#                 {
# }
#             );
#
#
#             var marker_ea34b3955b4e270933e64f36f387a536 = L.marker(
#                 [-22.0, 116.0],
#                 {
# }
#             ).addTo(marker_cluster_88c2df809c7ea58db14dec8c5538de16);
#
#
#         var popup_c3d133f2b7ace47450c9c9b49d205399 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_45616ba3edc8d230a6a5654ef088bc95 = $(`&lt;div id=&quot;html_45616ba3edc8d230a6a5654ef088bc95&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:116&lt;br&gt;lat:-22&lt;/div&gt;`)[0];
#                 popup_c3d133f2b7ace47450c9c9b49d205399.setContent(html_45616ba3edc8d230a6a5654ef088bc95);
#
#
#
#         marker_ea34b3955b4e270933e64f36f387a536.bindPopup(popup_c3d133f2b7ace47450c9c9b49d205399)
#         ;
#
#
#
#
#             var marker_44cc157a4d180a799d47207ab715893d = L.marker(
#                 [45.0, -28.0],
#                 {
# }
#             ).addTo(marker_cluster_88c2df809c7ea58db14dec8c5538de16);
#
#
#         var popup_052d7cd764efb2493cfe7de7de0722af = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_d06b71f5c0a0cad34d45df57b6999891 = $(`&lt;div id=&quot;html_d06b71f5c0a0cad34d45df57b6999891&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-28&lt;br&gt;lat:45&lt;/div&gt;`)[0];
#                 popup_052d7cd764efb2493cfe7de7de0722af.setContent(html_d06b71f5c0a0cad34d45df57b6999891);
#
#
#
#         marker_44cc157a4d180a799d47207ab715893d.bindPopup(popup_052d7cd764efb2493cfe7de7de0722af)
#         ;
#
#
#
#
#             var marker_3f089b9316edc5f6f431b55b00555b33 = L.marker(
#                 [-29.0, -99.0],
#                 {
# }
#             ).addTo(marker_cluster_88c2df809c7ea58db14dec8c5538de16);
#
#
#         var popup_516f6c4be9109552ea1b141908c32994 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_3dec45479de80a8ef65fbd40f83faaec = $(`&lt;div id=&quot;html_3dec45479de80a8ef65fbd40f83faaec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-99&lt;br&gt;lat:-29&lt;/div&gt;`)[0];
#                 popup_516f6c4be9109552ea1b141908c32994.setContent(html_3dec45479de80a8ef65fbd40f83faaec);
#
#
#
#         marker_3f089b9316edc5f6f431b55b00555b33.bindPopup(popup_516f6c4be9109552ea1b141908c32994)
#         ;
#
#
#
#
#             var marker_233da299d328efab5213f4a878eeeab3 = L.marker(
#                 [-24.0, -159.0],
#                 {
# }
#             ).addTo(marker_cluster_88c2df809c7ea58db14dec8c5538de16);
#
#
#         var popup_46b29f6e443f81b132d28a4974f30fe3 = L.popup({
#   &quot;maxWidth&quot;: &quot;100%&quot;,
# });
#
#
#
#                 var html_22820380dd07dff532821e0c17c14743 = $(`&lt;div id=&quot;html_22820380dd07dff532821e0c17c14743&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;lon:-159&lt;br&gt;lat:-24&lt;/div&gt;`)[0];
#                 popup_46b29f6e443f81b132d28a4974f30fe3.setContent(html_22820380dd07dff532821e0c17c14743);
#
#
#
#         marker_233da299d328efab5213f4a878eeeab3.bindPopup(popup_46b29f6e443

# %% [markdown]
# ## FastMarkerCluster
#
# `FastMarkerCluster` is not as flexible as MarkerCluster but, like the name suggests, it is faster.

# %%
from folium.plugins import FastMarkerCluster

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)],
    tiles='Cartodb Positron',
    zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons))).add_to(m)

folium.LayerControl().add_to(m);

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3d8e0bb9098da1f0dc2b7e12658a2d94 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3d8e0bb9098da1f0dc2b7e12658a2d94&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3d8e0bb9098da1f0dc2b7e12658a2d94 = L.map(
#                 &quot;map_3d8e0bb9098da1f0dc2b7e12658a2d94&quot;,
#                 {
#                     center: [6.71, 22.14],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d2d90c338726fae98136c063e10f86ec = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_d2d90c338726fae98136c063e10f86ec.addTo(map_3d8e0bb9098da1f0dc2b7e12658a2d94);
#
#
#             var fast_marker_cluster_98318f2a66fef0aa01a0538af09af884 = (function(){
#
#                 var callback = function (row) {
#                     var icon = L.AwesomeMarkers.icon();
#                     var marker = L.marker(new L.LatLng(row[0], row[1]));
#                     marker.setIcon(icon);
#                     return marker;
#                 };
#
#                 var data = [[-22.0, 116.0], [45.0, -28.0], [-29.0, -99.0], [-24.0, -159.0], [-68.0, 127.0], [-3.0, 103.0], [-46.0, 130.0], [78.0, 118.0], [-21.0, 67.0], [-29.0, -10.0], [-39.0, 60.0], [77.0, 127.0], [58.0, 133.0], [75.0, -155.0], [-69.0, 156.0], [43.0, -41.0], [62.0, -159.0], [-77.0, -112.0], [-25.0, -94.0], [-41.0, -109.0], [70.0, -47.0], [-62.0, 67.0], [-46.0, -55.0], [84.0, -62.0], [9.0, -92.0], [16.0, -5.0], [28.0, 158.0], [-45.0, -76.0], [-88.0, 77.0], [39.0, 103.0], [-5.0, 96.0], [7.0, 4.0], [87.0, -131.0], [16.0, -59.0], [-48.0, -56.0], [3.0, -157.0], [-50.0, 89.0], [39.0, -172.0], [33.0, 135.0], [-2.0, -118.0], [-33.0, -4.0], [33.0, 121.0], [-43.0, 144.0], [26.0, 154.0], [-43.0, 137.0], [19.0, 18.0], [19.0, 106.0], [-4.0, 15.0], [36.0, 132.0], [59.0, 138.0], [-40.0, 9.0], [17.0, -131.0], [8.0, -74.0], [67.0, 167.0], [-61.0, 132.0], [26.0, 166.0], [17.0, -177.0], [29.0, -1.0], [-87.0, 140.0], [40.0, 76.0], [72.0, -163.0], [55.0, 158.0], [67.0, 91.0], [-63.0, -117.0], [-83.0, 119.0], [36.0, 104.0], [-56.0, 165.0], [19.0, 4.0], [1.0, -157.0], [72.0, -90.0], [-49.0, 116.0], [38.0, 15.0], [41.0, 93.0], [50.0, 5.0], [57.0, -37.0], [82.0, 102.0], [24.0, 118.0], [-54.0, 89.0], [-72.0, 106.0], [-61.0, -124.0], [29.0, -48.0], [-66.0, 71.0], [37.0, -12.0], [60.0, -149.0], [-28.0, 131.0], [-10.0, 0.0], [72.0, 157.0], [-36.0, 117.0], [76.0, -164.0], [73.0, 146.0], [48.0, -80.0], [72.0, 142.0], [-45.0, -21.0], [86.0, 21.0], [20.0, 151.0], [-57.0, 28.0], [76.0, -11.0], [28.0, 30.0], [28.0, -42.0], [-83.0, 12.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_3d8e0bb9098da1f0dc2b7e12658a2d94);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_98318f2a66fef0aa01a0538af09af884.addTo(map_3d8e0bb9098da1f0dc2b7e12658a2d94);
#
#
#             var layer_control_a97d51ef8efa7b47bae5543a53bde21b_layers = {
#                 base_layers : {
#                     &quot;cartodbpositron&quot; : tile_layer_d2d90c338726fae98136c063e10f86ec,
#                 },
#                 overlays :  {
#                     &quot;macro_element_98318f2a66fef0aa01a0538af09af884&quot; : fast_marker_cluster_98318f2a66fef0aa01a0538af09af884,
#                 },
#             };
#             let layer_control_a97d51ef8efa7b47bae5543a53bde21b = L.control.layers(
#                 layer_control_a97d51ef8efa7b47bae5543a53bde21b_layers.base_layers,
#                 layer_control_a97d51ef8efa7b47bae5543a53bde21b_layers.overlays,
#                 {
#   &quot;position&quot;: &quot;topright&quot;,
#   &quot;collapsed&quot;: true,
#   &quot;autoZIndex&quot;: true,
# }
#             ).addTo(map_3d8e0bb9098da1f0dc2b7e12658a2d94);
#
#
# &lt;/script&gt;
# &lt;/ht

# %%
callback = """\
function (row) {
    var icon, marker;
    icon = L.AwesomeMarkers.icon({
        icon: "map-marker", markerColor: "red"});
    marker = L.marker(new L.LatLng(row[0], row[1]));
    marker.setIcon(icon);
    return marker;
};
"""

m = folium.Map(
    location=[np.mean(lats), np.mean(lons)], tiles="Cartodb Positron", zoom_start=1
)

FastMarkerCluster(data=list(zip(lats, lons)), callback=callback).add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_80a37aa16ba316701d7044866e240969 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_80a37aa16ba316701d7044866e240969&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_80a37aa16ba316701d7044866e240969 = L.map(
#                 &quot;map_80a37aa16ba316701d7044866e240969&quot;,
#                 {
#                     center: [6.71, 22.14],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 1,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0036947b34681efabe0eb5b3ec35f20a = L.tileLayer(
#                 &quot;https://{s}.basemaps.cartocdn.com/light_all/{z}/{x}/{y}{r}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 20,
#   &quot;maxNativeZoom&quot;: 20,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors \u0026copy; \u003ca href=\&quot;https://carto.com/attributions\&quot;\u003eCARTO\u003c/a\u003e&quot;,
#   &quot;subdomains&quot;: &quot;abcd&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0036947b34681efabe0eb5b3ec35f20a.addTo(map_80a37aa16ba316701d7044866e240969);
#
#
#             var fast_marker_cluster_f9470168ee52db030b988cb579c610fc = (function(){
#                 var callback = function (row) {
#     var icon, marker;
#     icon = L.AwesomeMarkers.icon({
#         icon: &quot;map-marker&quot;, markerColor: &quot;red&quot;});
#     marker = L.marker(new L.LatLng(row[0], row[1]));
#     marker.setIcon(icon);
#     return marker;
# };
# ;
#
#                 var data = [[-22.0, 116.0], [45.0, -28.0], [-29.0, -99.0], [-24.0, -159.0], [-68.0, 127.0], [-3.0, 103.0], [-46.0, 130.0], [78.0, 118.0], [-21.0, 67.0], [-29.0, -10.0], [-39.0, 60.0], [77.0, 127.0], [58.0, 133.0], [75.0, -155.0], [-69.0, 156.0], [43.0, -41.0], [62.0, -159.0], [-77.0, -112.0], [-25.0, -94.0], [-41.0, -109.0], [70.0, -47.0], [-62.0, 67.0], [-46.0, -55.0], [84.0, -62.0], [9.0, -92.0], [16.0, -5.0], [28.0, 158.0], [-45.0, -76.0], [-88.0, 77.0], [39.0, 103.0], [-5.0, 96.0], [7.0, 4.0], [87.0, -131.0], [16.0, -59.0], [-48.0, -56.0], [3.0, -157.0], [-50.0, 89.0], [39.0, -172.0], [33.0, 135.0], [-2.0, -118.0], [-33.0, -4.0], [33.0, 121.0], [-43.0, 144.0], [26.0, 154.0], [-43.0, 137.0], [19.0, 18.0], [19.0, 106.0], [-4.0, 15.0], [36.0, 132.0], [59.0, 138.0], [-40.0, 9.0], [17.0, -131.0], [8.0, -74.0], [67.0, 167.0], [-61.0, 132.0], [26.0, 166.0], [17.0, -177.0], [29.0, -1.0], [-87.0, 140.0], [40.0, 76.0], [72.0, -163.0], [55.0, 158.0], [67.0, 91.0], [-63.0, -117.0], [-83.0, 119.0], [36.0, 104.0], [-56.0, 165.0], [19.0, 4.0], [1.0, -157.0], [72.0, -90.0], [-49.0, 116.0], [38.0, 15.0], [41.0, 93.0], [50.0, 5.0], [57.0, -37.0], [82.0, 102.0], [24.0, 118.0], [-54.0, 89.0], [-72.0, 106.0], [-61.0, -124.0], [29.0, -48.0], [-66.0, 71.0], [37.0, -12.0], [60.0, -149.0], [-28.0, 131.0], [-10.0, 0.0], [72.0, 157.0], [-36.0, 117.0], [76.0, -164.0], [73.0, 146.0], [48.0, -80.0], [72.0, 142.0], [-45.0, -21.0], [86.0, 21.0], [20.0, 151.0], [-57.0, 28.0], [76.0, -11.0], [28.0, 30.0], [28.0, -42.0], [-83.0, 12.0]];
#                 var cluster = L.markerClusterGroup({
# });
#
#                 for (var i = 0; i &lt; data.length; i++) {
#                     var row = data[i];
#                     var marker = callback(row);
#                     marker.addTo(cluster);
#                 }
#
#                 cluster.addTo(map_80a37aa16ba316701d7044866e240969);
#                 return cluster;
#             })();
#
#
#             fast_marker_cluster_f9470168ee52db030b988cb579c610fc.addTo(map_80a37aa16ba316701d7044866e240969);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
